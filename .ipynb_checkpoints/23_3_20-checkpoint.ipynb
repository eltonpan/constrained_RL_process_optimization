# %%
# Authors:
# A. del Rio Chanona - Imperial College

import pylab
import numpy as np
import scipy.integrate as scp
from pylab import *
import matplotlib.pyplot as plt
import csv
import os
import sys
import copy
import numpy.random as rnd
from scipy.spatial.distance import cdist
# !pip install sobol_seq
import sobol_seq
from scipy.optimize import minimize
eps  = np.finfo(float).eps
import random
# Out:
# Requirement already satisfied: sobol_seq in /opt/anaconda3/lib/python3.7/site-packages (0.1.2)
# WARNING: You are using pip version 19.3.1; however, version 20.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %% [markdown]
# ## Dyanmical System
#
# Here we have a dynamic system, where $x$ is biomas, $N$ is nitrogen source, and $F_{N_{in}}$ is an inflow rate.
#
# $$\frac{\text{d}x}{\text{d}t}=\mu~x~\frac{N}{N+K_N}-\mu_d~x$$
#
# $$\frac{\text{d}N}{\text{d}t}=-Y_{Nx}x~\mu~\frac{N}{N+K_N}+F_{N_{in}}$$
#
# We wish to optimize at the final time $t_f$ the cost given by the biomass we can harves, minus a penalization for the nitrogen that was not consumed, the objective function is:
#
# $$f_{obj_1}=100x_{t_f}-N_{t_f}$$
#
# where $x_{t_f}$ and $N_{t_f}$ refer to the final biomass and nitrogen quantity. We can control $F_{N_{in}}\in[0,7]$ with a precision of $0.5$ changing it $10$ times (equidistantly) from time $0$ to time $t_f$
#
# We can aditionally have an objective function that penalizes nitrogen source input:
#
# $$f_{obj_2}=100x_{t_f}-N_{t_f}-\sum_{i=0}^{T}F_{N_{in}}^i$$
#
# where $T$ is the total number of time steps (inputs) and $F_{N_{in}}^i$ corresponds to the nitrate input at time-step $i$.

# %%
class ModelIntegration:
    
    # --- initializing model --- #
    def __init__(self, parameters, controls, tf): # controls is a list of eg. ten numbers, each corresponding to 1 addition at a certain time step
        
        # Object variable definitions
        self.parameters, self.controls = parameters, controls
        self.dt, self.tf               = tf/(controls.shape[1]), tf
        self.u0                        = controls[:,0]
        
    # --- dynamic model definition --- #    
    def model(self, t, state):
        # internal definitions
        params = self.parameters
        ctrl   = self.u0
        
        FCn    = ctrl[0]
        
        # state vector
        Cx  = state[0]
        Cn  = state[1]
        
        # parameters
        u_m  = params['u_m']; K_N  = params['K_N'];
        u_d  = params['u_d']; Y_nx = params['Y_nx'];
        
        # algebraic equations
        
        # variable rate equations
        dev_Cx  = u_m * Cx * Cn/(Cn+K_N) - u_d*Cx**2
        dev_Cn  = - Y_nx * u_m * Cx * Cn/(Cn+K_N) + FCn
        
        return np.array([dev_Cx, dev_Cn],dtype='float64')
    
    # --- simulation --- #
    def simulation(self, x0):
        # internal definitions
        dt, steps   = self.dt, int(self.tf/float(self.dt))
        model, controls = self.model, self.controls
        
        # compile state trajectories
        xt = np.zeros((x0.shape[0],steps+1)) #x0 is init conditions eg. x0 = np.array([0.1,150.0])
        tt = np.zeros((steps+1)) #these two lines initializes a matrix of 2 x (no. of steps + 1)
        
        # initialize simulation
        current_state = x0
        xt[:,0]       = current_state
        tt[0]         = 0.
        
        # simulation
        for s in range(steps):
            self.u0   = controls[:,s]                       # control for this step
            ode       = scp.ode(model)                      # define ode
            ode.set_integrator('lsoda', nsteps=3000)        # define integrator
            ode.set_initial_value(current_state,dt)         # set initial value
            current_state = list(ode.integrate(ode.t + dt)) # integrate system
            xt[:,s+1]     = current_state                   # add current state Note: here we can add randomnes as: + RandomNormal noise
            tt[s+1]       = (s+1)*dt
        
        return xt, tt

# %%
p  = {'u_m' : 0.0923*0.62, 'K_N' : 393.10, 'u_d' : 0.01, 'Y_nx' : 504.49} #don't touch the params!

steps_   = 10
FCn_0    = [np.sin(i/6.5)*2+5. for i in range(steps_)] #just an example solution! #FIND THIS
#FCn_0    = [6. for i in range(steps_)]

u  = np.array([FCn_0])
tf = 16.*24. #16 days of reaction time
x0 = np.array([0.1,150.0])  #don't change initial conditons


m      = ModelIntegration(p, u, tf)
xt, tt = m.simulation(x0) 

# --- plot results --- #

import matplotlib.pyplot as plt
for i in range(xt.shape[0]): #reminder: xt is the matrix of 2 x (no. of steps + 1). where rows 1 and 2 are the conc. of x and N, respectively.
    plt.plot(tt,xt[i,:]/np.max(xt[i,:])) #makes the two *normalized* plots (conc. of x and N) over time
plt.step(tt[:-1],FCn_0/np.max(FCn_0)) #plots the *normalized* control over time
plt.ylabel('state')
plt.xlabel('time')
plt.show()

for i in range(xt.shape[0]): #plot the three graphs separately, and with no normalization.
    plt.plot(tt,xt[i,:])
    plt.ylabel('state')
    plt.xlabel('time')
    plt.show()
plt.step(tt[:-1],FCn_0)
plt.show()

# %% [markdown]
# ## Dynamic Programming solutions
#
# To solve this problem, initially we should think of discretizing states (time is already discretized). This can be done for Biomass in $0.5$ intervals, and for Nitrate in $25$ intervals.

# %% [markdown]
# ## Defining discrete environment

# %%
############ Defining Environment ##############

class Model_env: 
    
    # --- initializing model --- #
    def __init__(self, parameters, tf, modulus):
        
        # Object variable definitions
        self.parameters       = parameters
        self.tf, self.modulus = tf, modulus  # two column array [biomass nitrate]
        
    # --- dynamic model definition --- #    
    # model takes state and action of previous time step and integrates -- definition of ODE system at time, t
    def model(self, t, state):
        # internal definitions
        params = self.parameters
        FCn   = self.u0
                
        # state vector
        Cx  = state[0]
        Cn  = state[1]
        
        # parameters
        u_m  = params['u_m']; K_N  = params['K_N'];
        u_d  = params['u_d']; Y_nx = params['Y_nx'];
        
        # algebraic equations
        
        # variable rate equations
        dev_Cx  = u_m * Cx * Cn/(Cn+K_N) - u_d*Cx**2
        dev_Cn  = - Y_nx * u_m * Cx * Cn/(Cn+K_N) + FCn
        
        return np.array([dev_Cx, dev_Cn],dtype='float64')
    
    def discrete_env(self, state):
        # discretisation of the system, with introduction of stochasticity in terms of modulus
        modulus = self.modulus
        
        # passing to arrays
        modulus = np.array(modulus)    # eg. modulus = np.array([0.2, 20.]) basically what modulus does is it indicates the rounding of the conc of x and conc of nitrate
        state   = np.array(state)  # eg. state = np.array([0.1,150.0]) first number is the conc of x and 2nd number is the conc of nitrate

        resid = state % modulus 
        resid = resid/modulus # remember resid is now an array. resid is normalized with respect to the size of modulus 
        UB = 1 - resid # 1 minus resid because we are talking about normalized inverse length
        draw =  np.random.uniform(0,1,2) # generate an array of 2 random numbers between 0 and 1

        for i in range(state.shape[0]):
            if draw[i] < UB[i]: #introduce stochasticity w.r.t. rounding up or down
                state[i] = state[i] - resid[i] * modulus[i] #rmb now resid is now a NORMALIZED array of 2 numbers so it has to be multiplied back to un-normalize residual #rounds down by substracting away the residual
            else:
                state[i] = state[i] - resid[i] * modulus[i] + modulus[i] #rounds up
        
        # fixes for representation 
        # Nitrate fix
        if state[1] < 0:
            state[1] = 0
        elif state[0] < 0:
            state[0] = 0
        
        # Biomass fix
        f = str(self.modulus[0])
        decimal = f[::-1].find('.')  
        state[0] = np.round(state[0], decimal)
        f1 = str(self.modulus[1])
        decimal1 = f1[::-1].find('.')  
        state[0] = np.round(state[0], decimal1)

        if state[0] == eps:
            state[0] = 0
        if state[1] == eps:
            state[1] = 0
        
        return state

    def simulation(self, x0, controls):
        # internal definitions
        model, tf     = self.model, self.tf
        self.controls = controls
        
        # initialize simulation
        current_state = x0
        
        # simulation #ONLY ONE STEP unlike the previous code shown above
        self.u0   = controls[:]                       # control for this step
        ode       = scp.ode(model)                      # define ode
        ode.set_integrator('lsoda', nsteps=3000)        # define integrator
        ode.set_initial_value(current_state, tf)         # set initial value
        current_state = list(ode.integrate(ode.t + tf)) # integrate system
        xt            = current_state                   # add current state Note: here we can add randomnes as: + RandomNormal noise
        
        return xt

    def MDP_simulation(self, x0, controls): #simulate ONLY ONE STEP
        xt          = self.simulation(x0, controls) #simulate
        xt_discrete = self.discrete_env(xt) # make output state discrete
        return xt_discrete

    def reward(self, state):
        reward = 100*state[-1][0] - state[-1][1]              # objective function 1
        return reward

# %% [markdown]
# ## Simulating one Step of the dynamic system as a MDP

# %%
# Creating the model
p        = {'u_m' : 0.0923*0.62, 'K_N' : 393.10, 'u_d' : 0.01, 'Y_nx' : 504.49} # predetermined parameters by design
tf       = 16.*24./10. # assuming 10 steps, we divide the whole horizon over 10 for one step
x0       = np.array([0.2,700.0]) # initial state
modulus  = [0.2, 20.] # basically what modulus does is it indicates the rounding of the conc of x and conc of nitrate
u0       = np.array([7.]) #this is your CONTROL (rmb here it's only ONE STEP)

MDP_BioEnv = Model_env(p, tf, modulus)
MDP_BioEnv.MDP_simulation(x0, u0)
# Out:
# array([6.0e-01, 6.8e+02])

# %% [markdown]
# ## Simulating multiple steps of the dynamic system as a MDP

# %%
steps_      = 10
FCn_0       = [np.sin(i/6.5)*2+5. for i in range(steps_)]
x0          = np.array([0.1,150.0]) # initial state
tf          = 16.*24./10.
x_list      = np.zeros((2,steps_+1)) #initialize state as 2D array where the 2 rows refer to conc of x and N.
t_list      = np.zeros((1,steps_+1)) #initialize time as 1D array
x_list[:,0] = x0
t_list[0]   = tf

for s in range(len(FCn_0)):
    MDP_BioEnv    = Model_env(p, tf, modulus)
    u0            = np.array([FCn_0[s]])
    x0            = MDP_BioEnv.MDP_simulation(x0, u0) #simulate one step, and update current state 
    tf            = tf + 16.*24./10. #increment time
    x_list[:,s+1] = x0 #update state memory
    t_list[:,s+1] = tf #update time memory

for i in range(x_list.shape[0]):
    plt.plot(t_list[0,:],x_list[i,:])
    plt.ylabel('state')
    plt.xlabel('time')
    plt.show()
plt.step(t_list[0,:-1],FCn_0)
plt.show()

# %%
x_list
# Out:
# array([[1.0e-01, 2.0e-01, 1.0e+00, 1.2e+00, 1.0e+00, 1.2e+00, 1.2e+00,
#         1.2e+00, 1.2e+00, 1.2e+00, 1.2e+00],
#        [1.5e+02, 3.0e+02, 2.2e+02, 8.0e+01, 1.0e+02, 1.0e+02, 1.0e+02,
#         1.0e+02, 1.0e+02, 1.0e+02, 1.0e+02]])

# %%
MDP_BioEnv.reward(x_list) #returns the reward at the final time step (end of episode)
# Out:
# 14700.0

# %% [markdown]
# # Describing the size of system

# %%
modulus = [0.2, 20.] #modulus is the graining of x and N, respectively
Number_of_possible_x = int(2.0/modulus[0]+1) #assumed max x value is 1.6
Number_of_possible_N = int(700/modulus[1]+1) #assumed max N value is 400
Number_of_discrete_states = int(Number_of_possible_x * Number_of_possible_N)
Number_of_possible_actions = int(7.0/0.5 + 1)
Number_of_possible_times = 11

print('Number of discrete_states:', Number_of_discrete_states)
print('Shape of value table:', Number_of_possible_N , 'x', Number_of_possible_x)
print('Number of possible actions:', Number_of_possible_actions)
print('Number of possible times:', Number_of_possible_times)
# Out:
# Number of discrete_states: 396
# Shape of value table: 36 x 11
# Number of possible actions: 15
# Number of possible times: 11

# %% [markdown]
# # Functions

# %%
#dictionary to map action to actual increase in N
action_ID = [x for x in range(15)]
increase_in_N = [x for x in np.arange(0,7.5,0.5)]
action_ID_to_increase_in_N = dict(zip(action_ID,increase_in_N))

action_ID_to_increase_in_N #this dictionary maps action id to actual action itself (increase in N)
# Out:
# {0: 0.0,
#  1: 0.5,
#  2: 1.0,
#  3: 1.5,
#  4: 2.0,
#  5: 2.5,
#  6: 3.0,
#  7: 3.5,
#  8: 4.0,
#  9: 4.5,
#  10: 5.0,
#  11: 5.5,
#  12: 6.0,
#  13: 6.5,
#  14: 7.0}

# %%
def transition(state, action): # state can be described by tuple(x (algae conc), N (nitrate conc), time (in hours)), action can be described by FN ∈[0,7]
    '''arguments
       state: (x, N, t) tuple 
       action: int (0-14)
    
       outputs 
       new state: (x, N, t) tuple
       reward: int 
       '''
    state = np.array(state) 
    action = [action_ID_to_increase_in_N[action]] #assign action according to dictionary defined above
    
    if (abs(state[2] - 16.*24.) < 0.1): #check if terminal state is reached
        reward = 100 * state[0] - state[1]   #give reward when we LEAVE terminal state
        state[2]      += 16.*24./10. #increment time
        state_evolved = MDP_BioEnv.MDP_simulation(state[0:2], action) #evolve the system using ODE
        state_evolved = [round(state_evolved[0],1),round(state_evolved[1],1)]
        new_state = np.append(state_evolved,round(state[2],2)) # append time
        
    elif (state[2] > 16.*24.): #check if time is exceeded
        new_state = state #loop back to itself
        reward = 0 #and given zero reward    
        
#     elif (state[1] >= 700) or (state[0] >= 1.6): #check if unexplored state space is reached
#         new_state = state #loop back to itself
#         reward = 0 #and given zero reward
        
    else: #else evolve the system and assign zero reward
        state[2]      += 16.*24./10. #increment time
        state_evolved = MDP_BioEnv.MDP_simulation(state[0:2], action) #evolve the system using ODE
        state_evolved = [round(state_evolved[0],1),round(state_evolved[1],1)]
        new_state = np.append(state_evolved,round(state[2],2)) # append time
        reward    = 0 # if terminal step not reached, reward = 0

    return tuple(new_state), reward

# %%
# test transition function 
result1 = transition((0.6, 0, 0),0)
result2 = transition(result1[0],0)
result3 = transition(result2[0],0)
result4 = transition(result3[0],0)
result5 = transition(result4[0],0)
# result6 = transition(result5[0],0)
# result7 = transition(result6[0],0)
# result8 = transition(result7[0],0)
# result9 = transition(result8[0],0)
# result10 = transition(result9[0],0)
result5
# Out:
# ((0.2, 0.0, 192.0), 0)

# %%
## initialize value table
# might want to add entries of states as we visit them instead
# but here we use the brute force approach by generate all state and times

def initialise_value_table(num_states = Number_of_discrete_states): #number of discrete states
    '''initializes a random value table (a dictionary)'''
    value_table = {} # start off with empty dict that will be filled up
    for x in range(1, Number_of_possible_x): #remove x = 0.0
        for N in range(Number_of_possible_N):
            for t in np.linspace(0,16*24/10*11,12): #add extra time step
                value_table[(round(x*0.2,1),N*20, round(t,1))] = np.random.rand()
    for key in value_table.keys():
        if 422.4 in key:
            value_table[key] = 0 #assign value of ZERO to terminal states
    return value_table
value_table = initialise_value_table(num_states = Number_of_discrete_states)
print('Number of entries in value table:', len(value_table))
value_table
# Out:
# Number of entries in value table: 4320
# {(0.2, 0, 0.0): 0.4526684637781714,
#  (0.2, 0, 38.4): 0.3004855522152028,
#  (0.2, 0, 76.8): 0.2586864726540701,
#  (0.2, 0, 115.2): 0.7208372107874423,
#  (0.2, 0, 153.6): 0.5442445398339347,
#  (0.2, 0, 192.0): 0.6327861244652622,
#  (0.2, 0, 230.4): 0.17323253410518225,
#  (0.2, 0, 268.8): 0.1853943904479124,
#  (0.2, 0, 307.2): 0.36042944198744764,
#  (0.2, 0, 345.6): 0.2987283866378856,
#  (0.2, 0, 384.0): 0.24571020824675505,
#  (0.2, 0, 422.4): 0,
#  (0.2, 20, 0.0): 0.646190210092929,
#  (0.2, 20, 38.4): 0.8132551576429801,
#  (0.2, 20, 76.8): 0.15280740188924546,
#  (0.2, 20, 115.2): 0.29048109794385246,
#  (0.2, 20, 153.6): 0.6325697259463697,
#  (0.2, 20, 192.0): 0.21279659736482193,
#  (0.2, 20, 230.4): 0.7277306588011203,
#  (0.2, 20, 268.8): 0.5962790588425303,
#  (0.2, 20, 307.2): 0.776156898871139,
#  (0.2, 20, 345.6): 0.0907817329218189,
#  (0.2, 20, 384.0): 0.27860619237770357,
#  (0.2, 20, 422.4): 0,
#  (0.2, 40, 0.0): 0.9766266791305641,
#  (0.2, 40, 38.4): 0.8508232909725995,
#  (0.2, 40, 76.8): 0.9930535515851379,
#  (0.2, 40, 115.2): 0.7076774146038757,
#  (0.2, 40, 153.6): 0.6421791747874609,
#  (0.2, 40, 192.0): 0.19587375509754268,
#  (0.2, 40, 230.4): 0.8090265326336843,
#  (0.2, 40, 268.8): 0.2173625293986,
#  (0.2, 40, 307.2): 0.7753480815185727,
#  (0.2, 40, 345.6): 0.8913084915952498,
#  (0.2, 40, 384.0): 0.050029471785966284,
#  (0.2, 40, 422.4): 0,
#  (0.2, 60, 0.0): 0.6629115581487321,
#  (0.2, 60, 38.4): 0.42051356093348646,
#  (0.2, 60, 76.8): 0.9676770451039477,
#  (0.2, 60, 115.2): 0.4512549161693242,
#  (0.2, 60, 153.6): 0.2603945239057899,
#  (0.2, 60, 192.0): 0.6199413509909928,
#  (0.2, 60, 230.4): 0.9882804637608348,
#  (0.2, 60, 268.8): 0.4907884942104116,
#  (0.2, 60, 307.2): 0.12138861665153966,
#  (0.2, 60, 345.6): 0.7221897072158098,
#  (0.2, 60, 384.0): 0.20215095116344628,
#  (0.2, 60, 422.4): 0,
#  (0.2, 80, 0.0): 0.4158652817726258,
#  (0.2, 80, 38.4): 0.5308721664335366,
#  (0.2, 80, 76.8): 0.056205080158248544,
#  (0.2, 80, 115.2): 0.6764599810960582,
#  (0.2, 80, 153.6): 0.6452190565730747,
#  (0.2, 80, 192.0): 0.9910931849574441,
#  (0.2, 80, 230.4): 0.6239567688738495,
#  (0.2, 80, 268.8): 0.8687772687996743,
#  (0.2, 80, 307.2): 0.7310012713270141,
#  (0.2, 80, 345.6): 0.9478575947436398,
#  (0.2, 80, 384.0): 0.5421935917096573,
#  (0.2, 80, 422.4): 0,
#  (0.2, 100, 0.0): 0.8190031783660493,
#  (0.2, 100, 38.4): 0.01980101211779728,
#  (0.2, 100, 76.8): 0.6475411384524593,
#  (0.2, 100, 115.2): 0.12760334737295465,
#  (0.2, 100, 153.6): 0.32193453204781186,
#  (0.2, 100, 192.0): 0.4289744726663267,
#  (0.2, 100, 230.4): 0.8124736414309243,
#  (0.2, 100, 268.8): 0.4832970535795972,
#  (0.2, 100, 307.2): 0.7363711529072251,
#  (0.2, 100, 345.6): 0.5167710909397403,
#  (0.2, 100, 384.0): 0.2386280743399618,
#  (0.2, 100, 422.4): 0,
#  (0.2, 120, 0.0): 0.35306350287296673,
#  (0.2, 120, 38.4): 0.7254129546346175,
#  (0.2, 120, 76.8): 0.7940088051947938,
#  (0.2, 120, 115.2): 0.13759468971578814,
#  (0.2, 120, 153.6): 0.07955408095007543,
#  (0.2, 120, 192.0): 0.07486645334969955,
#  (0.2, 120, 230.4): 0.788065190712516,
#  (0.2, 120, 268.8): 0.8367760836104083,
#  (0.2, 120, 307.2): 0.14685199609124544,
#  (0.2, 120, 345.6): 0.5700706907180138,
#  (0.2, 120, 384.0): 0.8518069502424943,
#  (0.2, 120, 422.4): 0,
#  (0.2, 140, 0.0): 0.8292590569151587,
#  (0.2, 140, 38.4): 0.06952466705883809,
#  (0.2, 140, 76.8): 0.5786986901031,
#  (0.2, 140, 115.2): 0.036453623623527,
#  (0.2, 140, 153.6): 0.023174025648732943,
#  (0.2, 140, 192.0): 0.8284612089844239,
#  (0.2, 140, 230.4): 0.8365626058902748,
#  (0.2, 140, 268.8): 0.5286736835424068,
#  (0.2, 140, 307.2): 0.5630958974793497,
#  (0.2, 140, 345.6): 0.9392526748461715,
#  (0.2, 140, 384.0): 0.5912404135336004,
#  (0.2, 140, 422.4): 0,
#  (0.2, 160, 0.0): 0.4878420125311579,
#  (0.2, 160, 38.4): 0.5113791657588659,
#  (0.2, 160, 76.8): 0.8257168628198067,
#  (0.2, 160, 115.2): 0.2517082360937134,
#  (0.2, 160, 153.6): 0.9270756174756432,
#  (0.2, 160, 192.0): 0.20836851998663297,
#  (0.2, 160, 230.4): 0.29813341429729245,
#  (0.2, 160, 268.8): 0.5251504643986113,
#  (0.2, 160, 307.2): 0.2383264052960774,
#  (0.2, 160, 345.6): 0.11736416075050515,
#  (0.2, 160, 384.0): 0.46346729810570053,
#  (0.2, 160, 422.4): 0,
#  (0.2, 180, 0.0): 0.33442220680914614,
#  (0.2, 180, 38.4): 0.36490795172680845,
#  (0.2, 180, 76.8): 0.9955136119248541,
#  (0.2, 180, 115.2): 0.41972492832338626,
#  (0.2, 180, 153.6): 0.1537006286116549,
#  (0.2, 180, 192.0): 0.01976011500113184,
#  (0.2, 180, 230.4): 0.05123735438635202,
#  (0.2, 180, 268.8): 0.02057787900969943,
#  (0.2, 180, 307.2): 0.4519266852854298,
#  (0.2, 180, 345.6): 0.8857404091983289,
#  (0.2, 180, 384.0): 0.5705408750749346,
#  (0.2, 180, 422.4): 0,
#  (0.2, 200, 0.0): 0.7183087754286048,
#  (0.2, 200, 38.4): 0.8472093767402522,
#  (0.2, 200, 76.8): 0.02805249366732465,
#  (0.2, 200, 115.2): 0.06067144164039995,
#  (0.2, 200, 153.6): 0.4158787231975798,
#  (0.2, 200, 192.0): 0.5473760794925815,
#  (0.2, 200, 230.4): 0.3737018576467742,
#  (0.2, 200, 268.8): 0.6857872784051546,
#  (0.2, 200, 307.2): 0.32499787977621,
#  (0.2, 200, 345.6): 0.3771774578119583,
#  (0.2, 200, 384.0): 0.5582607308906644,
#  (0.2, 200, 422.4): 0,
#  (0.2, 220, 0.0): 0.7740957128852258,
#  (0.2, 220, 38.4): 0.9731700979931258,
#  (0.2, 220, 76.8): 0.5598772669018101,
#  (0.2, 220, 115.2): 0.6516472195325465,
#  (0.2, 220, 153.6): 0.6127004710181669,
#  (0.2, 220, 192.0): 0.29446163268944003,
#  (0.2, 220, 230.4): 0.6213967719898164,
#  (0.2, 220, 268.8): 0.5488985139840282,
#  (0.2, 220, 307.2): 0.9982872217169968,
#  (0.2, 220, 345.6): 0.03062039719340026,
#  (0.2, 220, 384.0): 0.3911785381051901,
#  (0.2, 220, 422.4): 0,
#  (0.2, 240, 0.0): 0.8412616861388167,
#  (0.2, 240, 38.4): 0.8771006466838487,
#  (0.2, 240, 76.8): 0.0782205168127853,
#  (0.2, 240, 115.2): 0.7614123516795585,
#  (0.2, 240, 153.6): 0.8186149540945924,
#  (0.2, 240, 192.0): 0.38401929094622334,
#  (0.2, 240, 230.4): 0.265530712829361,
#  (0.2, 240, 268.8): 0.1639705746587441,
#  (0.2, 240, 307.2): 0.8142222411992749,
#  (0.2, 240, 345.6): 0.024777777634244602,
#  (0.2, 240, 384.0): 0.8754738205361559,
#  (0.2, 240, 422.4): 0,
#  (0.2, 260, 0.0): 0.10944145296223329,
#  (0.2, 260, 38.4): 0.8494030880751937,
#  (0.2, 260, 76.8): 0.9641446574069505,
#  (0.2, 260, 115.2): 0.9793766864688204,
#  (0.2, 260, 153.6): 0.19293583744858844,
#  (0.2, 260, 192.0): 0.2892196625419762,
#  (0.2, 260, 230.4): 0.8948958647248407,
#  (0.2, 260, 268.8): 0.5005994734260527,
#  (0.2, 260, 307.2): 0.05729937517387207,
#  (0.2, 260, 345.6): 0.28649211563569354,
#  (0.2, 260, 384.0): 0.5273297483051441,
#  (0.2, 260, 422.4): 0,
#  (0.2, 280, 0.0): 0.30147795277685785,
#  (0.2, 280, 38.4): 0.32363062859567115,
#  (0.2, 280, 76.8): 0.2761747591413465,
#  (0.2, 280, 115.2): 0.8181913396899902,
#  (0.2, 280, 153.6): 0.8962150025434935,
#  (0.2, 280, 192.0): 0.6691816629769535,
#  (0.2, 280, 230.4): 0.5754618056473046,
#  (0.2, 280, 268.8): 0.09604776625188005,
#  (0.2, 280, 307.2): 0.6008173634526018,
#  (0.2, 280, 345.6): 0.8885299884140205,
#  (0.2, 280, 384.0): 0.6457978995339906,
#  (0.2, 280, 422.4): 0,
#  (0.2, 300, 0.0): 0.6076906367594392,
#  (0.2, 300, 38.4): 0.0250208051555445,
#  (0.2, 300, 76.8): 0.3955507909323158,
#  (0.2, 300, 115.2): 0.5859201410242346,
#  (0.2, 300, 153.6): 0.9031655182343132,
#  (0.2, 300, 192.0): 0.15317773222247644,
#  (0.2, 300, 230.4): 0.13790697494458126,
#  (0.2, 300, 268.8): 0.7181127968553843,
#  (0.2, 300, 307.2): 0.8964175233934671,
#  (0.2, 300, 345.6): 0.9228478501276114,
#  (0.2, 300, 384.0): 0.2263982828831902,
#  (0.2, 300, 422.4): 0,
#  (0.2, 320, 0.0): 0.9152748110600653,
#  (0.2, 320, 38.4): 0.19308658311312232,
#  (0.2, 320, 76.8): 0.3779094334302481,
#  (0.2, 320, 115.2): 0.03497220153742164,
#  (0.2, 320, 153.6): 0.9334914369196602,
#  (0.2, 320, 192.0): 0.4943423455272601,
#  (0.2, 320, 230.4): 0.42586040772424083,
#  (0.2, 320, 268.8): 0.592037071633296,
#  (0.2, 320, 307.2): 0.19165743334549545,
#  (0.2, 320, 345.6): 0.2771036362606185,
#  (0.2, 320, 384.0): 0.3368188841385473,
#  (0.2, 320, 422.4): 0,
#  (0.2, 340, 0.0): 0.6002669710038653,
#  (0.2, 340, 38.4): 0.9942131196418091,
#  (0.2, 340, 76.8): 0.22209514414053566,
#  (0.2, 340, 115.2): 0.9920246024231827,
#  (0.2, 340, 153.6): 0.016918208455741546,
#  (0.2, 340, 192.0): 0.6365263833500372,
#  (0.2, 340, 230.4): 0.137380261739955,
#  (0.2, 340, 268.8): 0.6160389231533708,
#  (0.2, 340, 307.2): 0.23416153596001021,
#  (0.2, 340, 345.6): 0.4335012761563659,
#  (0.2, 340, 384.0): 0.12547275911874478,
#  (0.2, 340, 422.4): 0,
#  (0.2, 360, 0.0): 0.5975101605681254,
#  (0.2, 360, 38.4): 0.4120287427607988,
#  (0.2, 360, 76.8): 0.935376342472241,
#  (0.2, 360, 115.2): 0.9272713790670315,
#  (0.2, 360, 153.6): 0.9429171711893013,
#  (0.2, 360, 192.0): 0.8271050931269595,
#  (0.2, 360, 230.4): 0.8358116173137601,
#  (0.2, 360, 268.8): 0.16915758997027985,
#  (0.2, 360, 307.2): 0.7648009208427357,
#  (0.2, 360, 345.6): 0.15361802358125287,
#  (0.2, 360, 384.0): 0.7474627208271971,
#  (0.2, 360, 422.4): 0,
#  (0.2, 380, 0.0): 0.619898825660476,
#  (0.2, 380, 38.4): 0.29282823940808633,
#  (0.2, 380, 76.8): 0.8135422096169576,
#  (0.2, 380, 115.2): 0.07888794713646974,
#  (0.2, 380, 153.6): 0.3930141835788291,
#  (0.2, 380, 192.0): 0.991902118424851,
#  (0.2, 380, 230.4): 0.4214625095642571,
#  (0.2, 380, 268.8): 0.15260028858677976,
#  (0.2, 380, 307.2): 0.7756267159417383,
#  (0.2, 380, 345.6): 0.9569575286901366,
#  (0.2, 380, 384.0): 0.2456684909225494,
#  (0.2, 380, 422.4): 0,
#  (0.2, 400, 0.0): 0.20248258976370737,
#  (0.2, 400, 38.4): 0.7998874488015008,
#  (0.2, 400, 76.8): 0.8231773027115696,
#  (0.2, 400, 115.2): 0.6613554868777505,
#  (0.2, 400, 153.6): 0.09550281362194246,
#  (0.2, 400, 192.0): 0.9077822130522246,
#  (0.2, 400, 230.4): 0.6425266684387595,
#  (0.2, 400, 268.8): 0.1444216648246156,
#  (0.2, 400, 307.2): 0.8128521153775632,
#  (0.2, 400, 345.6): 0.668406301842224,
#  (0.2, 400, 384.0): 0.3415081098607321,
#  (0.2, 400, 422.4): 0,
#  (0.2, 420, 0.0): 0.8893002084024179,
#  (0.2, 420, 38.4): 0.813752853095008,
#  (0.2, 420, 76.8): 0.6765573941325742,
#  (0.2, 420, 115.2): 0.1284943703458702,
#  (0.2, 420, 153.6): 0.8122996288294001,
#  (0.2, 420, 192.0): 0.5708374099180165,
#  (0.2, 420, 230.4): 0.4734835984488299,
#  (0.2, 420, 268.8): 0.4835965405012761,
#  (0.2, 420, 307.2): 0.2764474696667133,
#  (0.2, 420, 345.6): 0.3590313734292607,
#  (0.2, 420, 384.0): 0.6941724075729125,
#  (0.2, 420, 422.4): 0,
#  (0.2, 440, 0.0): 0.8179382580829672,
#  (0.2, 440, 38.4): 0.42771286993882096,
#  (0.2, 440, 76.8): 0.37181792089095067,
#  (0.2, 440, 115.2): 0.44499093277423096,
#  (0.2, 440, 153.6): 0.2501343517186875,
#  (0.2, 440, 192.0): 0.08510848653631586,
#  (0.2, 440, 230.4): 0.07834490909279568,
#  (0.2, 440, 268.8): 0.48988378330199345,
#  (0.2, 440, 307.2): 0.6650293678019404,
#  (0.2, 440, 345.6): 0.1589151771932198,
#  (0.2, 440, 384.0): 0.046348960083730684,
#  (0.2, 440, 422.4): 0,
#  (0.2, 460, 0.0): 0.21414559406990286,
#  (0.2, 460, 38.4): 0.2234599103282381,
#  (0.2, 460, 76.8): 0.6303915868250918,
#  (0.2, 460, 115.2): 0.8107186526511837,
#  (0.2, 460, 153.6): 0.4990041492718199,
#  (0.2, 460, 192.0): 0.8171004620779935,
#  (0.2, 460, 230.4): 0.47190132289341646,
#  (0.2, 460, 268.8): 0.14251423745373326,
#  (0.2, 460, 307.2): 0.10832660947650963,
#  (0.2, 460, 345.6): 0.4500786062975717,
#  (0.2, 460, 384.0): 0.1078826574353493,
#  (0.2, 460, 422.4): 0,
#  (0.2, 480, 0.0): 0.28590834525345343,
#  (0.2, 480, 38.4): 0.4523592913925628,
#  (0.2, 480, 76.8): 0.8610605183904201,
#  (0.2, 480, 115.2): 0.9443398303855262,
#  (0.2, 480, 153.6): 0.5641895967400131,
#  (0.2, 480, 192.0): 0.7977631352519666,
#  (0.2, 480, 230.4): 0.4257314176326372,
#  (0.2, 480, 268.8): 0.253341335166146,
#  (0.2, 480, 307.2): 0.3656998333721472,
#  (0.2, 480, 345.6): 0.10422084249422836,
#  (0.2, 480, 384.0): 0.501546349878331,
#  (0.2, 480, 422.4): 0,
#  (0.2, 500, 0.0): 0.4184757500116516,
#  (0.2, 500, 38.4): 0.835021071049627,
#  (0.2, 500, 76.8): 0.5080034015619432,
#  (0.2, 500, 115.2): 0.8579214509285693,
#  (0.2, 500, 153.6): 0.6048727365677404,
#  (0.2, 500, 192.0): 0.34793556386465496,
#  (0.2, 500, 230.4): 0.38758070694335833,
#  (0.2, 500, 268.8): 0.6198852233511638,
#  (0.2, 500, 307.2): 0.0691257639790912,
#  (0.2, 500, 345.6): 0.5748650595037552,
#  (0.2, 500, 384.0): 0.7963351663940614,
#  (0.2, 500, 422.4): 0,
#  (0.2, 520, 0.0): 0.7538865013875455,
#  (0.2, 520, 38.4): 0.09831933142013727,
#  (0.2, 520, 76.8): 0.13080551889728764,
#  (0.2, 520, 115.2): 0.41407418570702215,
#  (0.2, 520, 153.6): 0.6569046060773241,
#  (0.2, 520, 192.0): 0.9085467080397536,
#  (0.2, 520, 230.4): 0.3703549370098854,
#  (0.2, 520, 268.8): 0.5528804291479901,
#  (0.2, 520, 307.2): 0.5102001920788987,
#  (0.2, 520, 345.6): 0.6805006653418626,
#  (0.2, 520, 384.0): 0.7770814961668095,
#  (0.2, 520, 422.4): 0,
#  (0.2, 540, 0.0): 0.6084570117350968,
#  (0.2, 540, 38.4): 0.2550138266944616,
#  (0.2, 540, 76.8): 0.8279189063043466,
#  (0.2, 540, 115.2): 0.5179917942374188,
#  (0.2, 540, 153.6): 0.07625307160088535,
#  (0.2, 540, 192.0): 0.21583238257882542,
#  (0.2, 540, 230.4): 0.2857812378918345,
#  (0.2, 540, 268.8): 0.5852885040052344,
#  (0.2, 540, 307.2): 0.34585766371280624,
#  (0.2, 540, 345.6): 0.6708177998162986,
#  (0.2, 540, 384.0): 0.5380277414612317,
#  (0.2, 540, 422.4): 0,
#  (0.2, 560, 0.0): 0.9510455497300971,
#  (0.2, 560, 38.4): 0.9194566658101907,
#  (0.2, 560, 76.8): 0.8955260987057604,
#  (0.2, 560, 115.2): 0.004834271317322725,
#  (0.2, 560, 153.6): 0.4771780653479305,
#  (0.2, 560, 192.0): 0.32886146588702914,
#  (0.2, 560, 230.4): 0.13013053183576728,
#  (0.2, 560, 268.8): 0.5684677052280054,
#  (0.2, 560, 307.2): 0.2706808706957853,
#  (0.2, 560, 345.6): 0.9186527956292408,
#  (0.2, 560, 384.0): 0.7016416252808748,
#  (0.2, 560, 422.4): 0,
#  (0.2, 580, 0.0): 0.4191127494392054,
#  (0.2, 580, 38.4): 0.161722013026655,
#  (0.2, 580, 76.8): 0.07674523207515405,
#  (0.2, 580, 115.2): 0.6956390672514818,
#  (0.2, 580, 153.6): 0.8237502288431175,
#  (0.2, 580, 192.0): 0.6089160253014014,
#  (0.2, 580, 230.4): 0.4017695960780079,
#  (0.2, 580, 268.8): 0.3041862820466482,
#  (0.2, 580, 307.2): 0.33062496129687247,
#  (0.2, 580, 345.6): 0.757024968265675,
#  (0.2, 580, 384.0): 0.718704705321194,
#  (0.2, 580, 422.4): 0,
#  (0.2, 600, 0.0): 0.4026236054605329,
#  (0.2, 600, 38.4): 0.682187538868362,
#  (0.2, 600, 76.8): 0.5796674609915038,
#  (0.2, 600, 115.2): 0.09240152845123994,
#  (0.2, 600, 153.6): 0.8805152378158312,
#  (0.2, 600, 192.0): 0.7212709428559788,
#  (0.2, 600, 230.4): 0.7197818502809155,
#  (0.2, 600, 268.8): 0.18318734322819796,
#  (0.2, 600, 307.2): 0.3374095139663319,
#  (0.2, 600, 345.6): 0.684237274622784,
#  (0.2, 600, 384.0): 0.13628088861940002,
#  (0.2, 600, 422.4): 0,
#  (0.2, 620, 0.0): 0.00920400660297882,
#  (0.2, 620, 38.4): 0.3187344895875406,
#  (0.2, 620, 76.8): 0.10180761224760815,
#  (0.2, 620, 115.2): 0.2564733834502423,
#  (0.2, 620, 153.6): 0.15005188572745498,
#  (0.2, 620, 192.0): 0.4789631849074989,
#  (0.2, 620, 230.4): 0.5369079336186701,
#  (0.2, 620, 268.8): 0.470965698285443,
#  (0.2, 620, 307.2): 0.6520760454588062,
#  (0.2, 620, 345.6): 0.8677927763424251,
#  (0.2, 620, 384.0): 0.3911794490955721,
#  (0.2, 620, 422.4): 0,
#  (0.2, 640, 0.0): 0.02231560157656798,
#  (0.2, 640, 38.4): 0.1539965374971921,
#  (0.2, 640, 76.8): 0.8240913897675141,
#  (0.2, 640, 115.2): 0.635293138952954,
#  (0.2, 640, 153.6): 0.4909011581362758,
#  (0.2, 640, 192.0): 0.5946227282774916,
#  (0.2, 640, 230.4): 0.29916629332697586,
#  (0.2, 640, 268.8): 0.3542297699198683,
#  (0.2, 640, 307.2): 0.14193997329574926,
#  (0.2, 640, 345.6): 0.5352948537071177,
#  (0.2, 640, 384.0): 0.5645894427724846,
#  (0.2, 640, 422.4): 0,
#  (0.2, 660, 0.0): 0.26582801844083637,
#  (0.2, 660, 38.4): 0.897249271088326,
#  (0.2, 660, 76.8): 0.1535014799099893,
#  (0.2, 660, 115.2): 0.29262541339636605,
#  (0.2, 660, 153.6): 0.15476738781253474,
#  (0.2, 660, 192.0): 0.6741213627716522,
#  (0.2, 660, 230.4): 0.5912925902484996,
#  (0.2, 660, 268.8): 0.5788517525958526,
#  (0.2, 660, 307.2): 0.2454132242734709,
#  (0.2, 660, 345.6): 0.7140935602075295,
#  (0.2, 660, 384.0): 0.7439714515666339,
#  (0.2, 660, 422.4): 0,
#  (0.2, 680, 0.0): 0.4184244765066316,
#  (0.2, 680, 38.4): 0.37482878357839955,
#  (0.2, 680, 76.8): 0.09979945533930856,
#  (0.2, 680, 115.2): 0.922441867466333,
#  (0.2, 680, 153.6): 0.47850244349296045,
#  (0.2, 680, 192.0): 0.6522352823224581,
#  (0.2, 680, 230.4): 0.12591611377759748,
#  (0.2, 680, 268.8): 0.4270723657180935,
#  (0.2, 680, 307.2): 0.9093148104296442,
#  (0.2, 680, 345.6): 0.7171251166435435,
#  (0.2, 680, 384.0): 0.777423884094355,
#  (0.2, 680, 422.4): 0,
#  (0.2, 700, 0.0): 0.4725607634550555,
#  (0.2, 700, 38.4): 0.5310453286288357,
#  (0.2, 700, 76.8): 0.8480322914437394,
#  (0.2, 700, 115.2): 0.6513870300643313,
#  (0.2, 700, 153.6): 0.40049206440076257,
#  (0.2, 700, 192.0): 0.42107386115834233,
#  (0.2, 700, 230.4): 0.3318928715692603,
#  (0.2, 700, 268.8): 0.48026428303666246,
#  (0.2, 700, 307.2): 0.028930923685962395,
#  (0.2, 700, 345.6): 0.37399925698876735,
#  (0.2, 700, 384.0): 0.5256123989633005,
#  (0.2, 700, 422.4): 0,
#  (0.4, 0, 0.0): 0.8577572133697459,
#  (0.4, 0, 38.4): 0.6979039363462894,
#  (0.4, 0, 76.8): 0.30006830134908424,
#  (0.4, 0, 115.2): 0.22343066659934696,
#  (0.4, 0, 153.6): 0.039274895714688784,
#  (0.4, 0, 192.0): 0.1279676887851373,
#  (0.4, 0, 230.4): 0.06137475458824171,
#  (0.4, 0, 268.8): 0.7297596181292029,
#  (0.4, 0, 307.2): 0.8416279792000908,
#  (0.4, 0, 345.6): 0.20178674402244567,
#  (0.4, 0, 384.0): 0.6375421619818694,
#  (0.4, 0, 422.4): 0,
#  (0.4, 20, 0.0): 0.5863736757836773,
#  (0.4, 20, 38.4): 0.870791815073731,
#  (0.4, 20, 76.8): 0.5345339515615568,
#  (0.4, 20, 115.2): 0.7093864690596727,
#  (0.4, 20, 153.6): 0.8149774351627175,
#  (0.4, 20, 192.0): 0.5418952898725762,
#  (0.4, 20, 230.4): 0.20964258454426898,
#  (0.4, 20, 268.8): 0.5725273355565809,
#  (0.4, 20, 307.2): 0.4800941684836397,
#  (0.4, 20, 345.6): 0.06863594911023019,
#  (0.4, 20, 384.0): 0.15211734446662306,
#  (0.4, 20, 422.4): 0,
#  (0.4, 40, 0.0): 0.36413881725108954,
#  (0.4, 40, 38.4): 0.05242007548716199,
#  (0.4, 40, 76.8): 0.008646255592519081,
#  (0.4, 40, 115.2): 0.8517767793313383,
#  (0.4, 40, 153.6): 0.9437781810725886,
#  (0.4, 40, 192.0): 0.7644872727307808,
#  (0.4, 40, 230.4): 0.3380422700821498,
#  (0.4, 40, 268.8): 0.7307810037426368,
#  (0.4, 40, 307.2): 0.8426755424353672,
#  (0.4, 40, 345.6): 0.5990070102530411,
#  (0.4, 40, 384.0): 0.318751892672805,
#  (0.4, 40, 422.4): 0,
#  (0.4, 60, 0.0): 0.16042904522232204,
#  (0.4, 60, 38.4): 0.8154380725308051,
#  (0.4, 60, 76.8): 0.27673404095917875,
#  (0.4, 60, 115.2): 0.35463224346667976,
#  (0.4, 60, 153.6): 0.7903354665394858,
#  (0.4, 60, 192.0): 0.8221608813967952,
#  (0.4, 60, 230.4): 0.6316428922289091,
#  (0.4, 60, 268.8): 0.9541671915470372,
#  (0.4, 60, 307.2): 0.569752405650249,
#  (0.4, 60, 345.6): 0.76174365046291,
#  (0.4, 60, 384.0): 0.5408561933420577,
#  (0.4, 60, 422.4): 0,
#  (0.4, 80, 0.0): 0.5297034681658289,
#  (0.4, 80, 38.4): 0.9575730101253271,
#  (0.4, 80, 76.8): 0.2296533907582956,
#  (0.4, 80, 115.2): 0.7387697650325524,
#  (0.4, 80, 153.6): 0.5711844150122581,
#  (0.4, 80, 192.0): 0.9305216710596644,
#  (0.4, 80, 230.4): 0.9211143767315603,
#  (0.4, 80, 268.8): 0.11302724950909893,
#  (0.4, 80, 307.2): 0.5949106443723884,
#  (0.4, 80, 345.6): 0.6408149479441332,
#  (0.4, 80, 384.0): 0.4427085508268971,
#  (0.4, 80, 422.4): 0,
#  (0.4, 100, 0.0): 0.30023156206686885,
#  (0.4, 100, 38.4): 0.07626253461055699,
#  (0.4, 100, 76.8): 0.1274016040121535,
#  (0.4, 100, 115.2): 0.9679533200037341,
#  (0.4, 100, 153.6): 0.7194905981534616,
#  (0.4, 100, 192.0): 0.12698414423653337,
#  (0.4, 100, 230.4): 0.23606670936208662,
#  (0.4, 100, 268.8): 0.0351880687877546,
#  (0.4, 100, 307.2): 0.4189424281792469,
#  (0.4, 100, 345.6): 0.9566727890088628,
#  (0.4, 100, 384.0): 0.12835537104479888,
#  (0.4, 100, 422.4): 0,
#  (0.4, 120, 0.0): 0.8047542996298039,
#  (0.4, 120, 38.4): 0.9499008012318667,
#  (0.4, 120, 76.8): 0.43043670970269865,
#  (0.4, 120, 115.2): 0.6364049702479284,
#  (0.4, 120, 153.6): 0.3493862960628197,
#  (0.4, 120, 192.0): 0.014797433035318441,
#  (0.4, 120, 230.4): 0.711288411810662,
#  (0.4, 120, 268.8): 0.24862641603988045,
#  (0.4, 120, 307.2): 0.13953866301227869,
#  (0.4, 120, 345.6): 0.39227136373946936,
#  (0.4, 120, 384.0): 0.8268965952446686,
#  (0.4, 120, 422.4): 0,
#  (0.4, 140, 0.0): 0.6495724641252496,
#  (0.4, 140, 38.4): 0.5578693392793461,
#  (0.4, 140, 76.8): 0.2720563986410459,
#  (0.4, 140, 115.2): 0.18731497647911433,
#  (0.4, 140, 153.6): 0.9371697400108013,
#  (0.4, 140, 192.0): 0.8113359826229926,
#  (0.4, 140, 230.4): 0.8876441159761973,
#  (0.4, 140, 268.8): 0.4069055718417133,
#  (0.4, 140, 307.2): 0.6478213988208698,
#  (0.4, 140, 345.6): 0.8096321820679341,
#  (0.4, 140, 384.0): 0.6366102443800579,
#  (0.4, 140, 422.4): 0,
#  (0.4, 160, 0.0): 0.34006538565240507,
#  (0.4, 160, 38.4): 0.034667317255189345,
#  (0.4, 160, 76.8): 0.20964643926207083,
#  (0.4, 160, 115.2): 0.6514323796360983,
#  (0.4, 160, 153.6): 0.8909206499481677,
#  (0.4, 160, 192.0): 0.42834199636512693,
#  (0.4, 160, 230.4): 0.7951492299865627,
#  (0.4, 160, 268.8): 0.5763362862533498,
#  (0.4, 160, 307.2): 0.2658285088624597,
#  (0.4, 160, 345.6): 0.5081599030604936,
#  (0.4, 160, 384.0): 0.13165727396110538,
#  (0.4, 160, 422.4): 0,
#  (0.4, 180, 0.0): 0.195812006501483,
#  (0.4, 180, 38.4): 0.7877266385139277,
#  (0.4, 180, 76.8): 0.13767101661935233,
#  (0.4, 180, 115.2): 0.0330192619909675,
#  (0.4, 180, 153.6): 0.6661382685462962,
#  (0.4, 180, 192.0): 0.7359284420847461,
#  (0.4, 180, 230.4): 0.9353565980242194,
#  (0.4, 180, 268.8): 0.9759021321837408,
#  (0.4, 180, 307.2): 0.17168933654019503,
#  (0.4, 180, 345.6): 0.5220820406418565,
#  (0.4, 180, 384.0): 0.3755053673790024,
#  (0.4, 180, 422.4): 0,
#  (0.4, 200, 0.0): 0.7003331414389031,
#  (0.4, 200, 38.4): 0.6265501028317975,
#  (0.4, 200, 76.8): 0.07147715762477203,
#  (0.4, 200, 115.2): 0.11438923899411768,
#  (0.4, 200, 153.6): 0.5936577646472272,
#  (0.4, 200, 192.0): 0.916570616141663,
#  (0.4, 200, 230.4): 0.24299494755976914,
#  (0.4, 200, 268.8): 0.7642898586416111,
#  (0.4, 200, 307.2): 0.9927941663113267,
#  (0.4, 200, 345.6): 0.4111593214444109,
#  (0.4, 200, 384.0): 0.5266593819154237,
#  (0.4, 200, 422.4): 0,
#  (0.4, 220, 0.0): 0.5174575879994444,
#  (0.4, 220, 38.4): 0.06712596444118801,
#  (0.4, 220, 76.8): 0.7702795460146685,
#  (0.4, 220, 115.2): 0.053369421391267546,
#  (0.4, 220, 153.6): 0.5825202587985642,
#  (0.4, 220, 192.0): 0.44995332297617785,
#  (0.4, 220, 230.4): 0.5501723369140357,
#  (0.4, 220, 268.8): 0.05950929254566917,
#  (0.4, 220, 307.2): 0.45401027602572874,
#  (0.4, 220, 345.6): 0.9913564227204952,
#  (0.4, 220, 384.0): 0.6911248203087079,
#  (0.4, 220, 422.4): 0,
#  (0.4, 240, 0.0): 0.1542594539513299,
#  (0.4, 240, 38.4): 0.4057762553413726,
#  (0.4, 240, 76.8): 0.46819711456609725,
#  (0.4, 240, 115.2): 0.7684000369321132,
#  (0.4, 240, 153.6): 0.19748309614559822,
#  (0.4, 240, 192.0): 0.4596587050784907,
#  (0.4, 240, 230.4): 0.30982248435574156,
#  (0.4, 240, 268.8): 0.8980751189724304,
#  (0.4, 240, 307.2): 0.9406067948726498,
#  (0.4, 240, 345.6): 0.3693465211330723,
#  (0.4, 240, 384.0): 0.6861843593561482,
#  (0.4, 240, 422.4): 0,
#  (0.4, 260, 0.0): 0.332005367052544,
#  (0.4, 260, 38.4): 0.1090594714716594,
#  (0.4, 260, 76.8): 0.7457514163651134,
#  (0.4, 260, 115.2): 0.050879005645880326,
#  (0.4, 260, 153.6): 0.7505743019523301,
#  (0.4, 260, 192.0): 0.9962778531215548,
#  (0.4, 260, 230.4): 0.9170242083174774,
#  (0.4, 260, 268.8): 0.7756135473278015,
#  (0.4, 260, 307.2): 0.248773518713434,
#  (0.4, 260, 345.6): 0.6272712319681842,
#  (0.4, 260, 384.0): 0.10643275919884343,
#  (0.4, 260, 422.4): 0,
#  (0.4, 280, 0.0): 0.17906087494962264,
#  (0.4, 280, 38.4): 0.06916706180307652,
#  (0.4, 280, 76.8): 0.4895779679711697,
#  (0.4, 280, 115.2): 0.6884343719406029,
#  (0.4, 280, 153.6): 0.9156256263885273,
#  (0.4, 280, 192.0): 0.569078055959454,
#  (0.4, 280, 230.4): 0.7805283381712308,
#  (0.4, 280, 268.8): 0.8449360577940247,
#  (0.4, 280, 307.2): 0.7842956124399452,
#  (0.4, 280, 345.6): 0.9034489888146865,
#  (0.4, 280, 384.0): 0.34831879303765434,
#  (0.4, 280, 422.4): 0,
#  (0.4, 300, 0.0): 0.6359009041669581,
#  (0.4, 300, 38.4): 0.6189624717914889,
#  (0.4, 300, 76.8): 0.18545100898796074,
#  (0.4, 300, 115.2): 0.15343208377072604,
#  (0.4, 300, 153.6): 0.7760310479514527,
#  (0.4, 300, 192.0): 0.6035731330525901,
#  (0.4, 300, 230.4): 0.7084364191177477,
#  (0.4, 300, 268.8): 0.0016174624789242475,
#  (0.4, 300, 307.2): 0.3298823962140637,
#  (0.4, 300, 345.6): 0.12303390648134671,
#  (0.4, 300, 384.0): 0.9851311733997952,
#  (0.4, 300, 422.4): 0,
#  (0.4, 320, 0.0): 0.37123384849888796,
#  (0.4, 320, 38.4): 0.7946799176134092,
#  (0.4, 320, 76.8): 0.38579568399828756,
#  (0.4, 320, 115.2): 0.1967452066190597,
#  (0.4, 320, 153.6): 0.7055586962814309,
#  (0.4, 320, 192.0): 0.7938728541870674,
#  (0.4, 320, 230.4): 0.9432484049742694,
#  (0.4, 320, 268.8): 0.6142362214932858,
#  (0.4, 320, 307.2): 0.715501083205379,
#  (0.4, 320, 345.6): 0.8173578991868974,
#  (0.4, 320, 384.0): 0.637375251118686,
#  (0.4, 320, 422.4): 0,
#  (0.4, 340, 0.0): 0.6165158922289676,
#  (0.4, 340, 38.4): 0.7775385147272507,
#  (0.4, 340, 76.8): 0.8270800887802199,
#  (0.4, 340, 115.2): 0.002341446875364417,
#  (0.4, 340, 153.6): 0.19840201263336477,
#  (0.4, 340, 192.0): 0.0005948985713640775,
#  (0.4, 340, 230.4): 0.15536360541222938,
#  (0.4, 340, 268.8): 0.5648429375800391,
#  (0.4, 340, 307.2): 0.644025342962698,
#  (0.4, 340, 345.6): 0.29295135196185784,
#  (0.4, 340, 384.0): 0.21699549802959117,
#  (0.4, 340, 422.4): 0,
#  (0.4, 360, 0.0): 0.4873674623666512,
#  (0.4, 360, 38.4): 0.5843779104549653,
#  (0.4, 360, 76.8): 0.6617741051407049,
#  (0.4, 360, 115.2): 0.582949237652325,
#  (0.4, 360, 153.6): 0.24834597120431368,
#  (0.4, 360, 192.0): 0.07850120813445194,
#  (0.4, 360, 230.4): 0.12588544443705763,
#  (0.4, 360, 268.8): 0.3785569856225732,
#  (0.4, 360, 307.2): 0.586885789850531,
#  (0.4, 360, 345.6): 0.5355490217649236,
#  (0.4, 360, 384.0): 0.8280044223628013,
#  (0.4, 360, 422.4): 0,
#  (0.4, 380, 0.0): 0.4661448609945529,
#  (0.4, 380, 38.4): 0.4727460455878413,
#  (0.4, 380, 76.8): 0.5342515465138871,
#  (0.4, 380, 115.2): 0.44578006769054357,
#  (0.4, 380, 153.6): 0.9537790477628668,
#  (0.4, 380, 192.0): 0.1516528456721561,
#  (0.4, 380, 230.4): 0.7852597641021194,
#  (0.4, 380, 268.8): 0.3759361598910078,
#  (0.4, 380, 307.2): 0.3436635817747823,
#  (0.4, 380, 345.6): 0.001102491702456243,
#  (0.4, 380, 384.0): 0.8849921696511824,
#  (0.4, 380, 422.4): 0,
#  (0.4, 400, 0.0): 0.20644028998739428,
#  (0.4, 400, 38.4): 0.4526374596324422,
#  (0.4, 400, 76.8): 0.02310070850468182,
#  (0.4, 400, 115.2): 0.6386682238796337,
#  (0.4, 400, 153.6): 0.94953139041326,
#  (0.4, 400, 192.0): 0.5298533826577947,
#  (0.4, 400, 230.4): 0.8024091070430689,
#  (0.4, 400, 268.8): 0.30315153210512635,
#  (0.4, 400, 307.2): 0.4871270931904387,
#  (0.4, 400, 345.6): 0.37638070008164004,
#  (0.4, 400, 384.0): 0.9374295198424872,
#  (0.4, 400, 422.4): 0,
#  (0.4, 420, 0.0): 0.9264332240367056,
#  (0.4, 420, 38.4): 0.4842816245173812,
#  (0.4, 420, 76.8): 0.3975686707502609,
#  (0.4, 420, 115.2): 0.5814156349730548,
#  (0.4, 420, 153.6): 0.9865745188812418,
#  (0.4, 420, 192.0): 0.9970402675233926,
#  (0.4, 420, 230.4): 0.8073573470521597,
#  (0.4, 420, 268.8): 0.43437257772772575,
#  (0.4, 420, 307.2): 0.5039262007871382,
#  (0.4, 420, 345.6): 0.5600193251328952,
#  (0.4, 420, 384.0): 0.8572557249393302,
#  (0.4, 420, 422.4): 0,
#  (0.4, 440, 0.0): 0.979705078007258,
#  (0.4, 440, 38.4): 0.5047378483046734,
#  (0.4, 440, 76.8): 0.6421289550645477,
#  (0.4, 440, 115.2): 0.5980039495010828,
#  (0.4, 440, 153.6): 0.9229199988502284,
#  (0.4, 440, 192.0): 0.3264816074372149,
#  (0.4, 440, 230.4): 0.7722089857697262,
#  (0.4, 440, 268.8): 0.15583628527377924,
#  (0.4, 440, 307.2): 0.19651861203606524,
#  (0.4, 440, 345.6): 0.6510211899080367,
#  (0.4, 440, 384.0): 0.0652148742544465,
#  (0.4, 440, 422.4): 0,
#  (0.4, 460, 0.0): 0.07246357588666263,
#  (0.4, 460, 38.4): 0.03870383823361412,
#  (0.4, 460, 76.8): 0.7920613579542689,
#  (0.4, 460, 115.2): 0.8261301100307649,
#  (0.4, 460, 153.6): 0.726839492146942,
#  (0.4, 460, 192.0): 0.16713565910602501,
#  (0.4, 460, 230.4): 0.3609522964442804,
#  (0.4, 460, 268.8): 0.8541759379273576,
#  (0.4, 460, 307.2): 0.20312382525749073,
#  (0.4, 460, 345.6): 0.5343376139847853,
#  (0.4, 460, 384.0): 0.40082530630466706,
#  (0.4, 460, 422.4): 0,
#  (0.4, 480, 0.0): 0.9799680607610445,
#  (0.4, 480, 38.4): 0.5813187754490826,
#  (0.4, 480, 76.8): 0.5835135671159927,
#  (0.4, 480, 115.2): 0.2944390590810311,
#  (0.4, 480, 153.6): 0.8773820638583734,
#  (0.4, 480, 192.0): 0.5297088228461192,
#  (0.4, 480, 230.4): 0.46669874358222907,
#  (0.4, 480, 268.8): 0.9723179822270916,
#  (0.4, 480, 307.2): 0.7362400709233483,
#  (0.4, 480, 345.6): 0.9081249325783767,
#  (0.4, 480, 384.0): 0.36940528095802727,
#  (0.4, 480, 422.4): 0,
#  (0.4, 500, 0.0): 0.06559287120059465,
#  (0.4, 500, 38.4): 0.06126650863605787,
#  (0.4, 500, 76.8): 0.2649201402042569,
#  (0.4, 500, 115.2): 0.11817222506965208,
#  (0.4, 500, 153.6): 0.480787347994464,
#  (0.4, 500, 192.0): 0.28724552011511406,
#  (0.4, 500, 230.4): 0.06283342079302223,
#  (0.4, 500, 268.8): 0.5090204796015219,
#  (0.4, 500, 307.2): 0.8043737360180058,
#  (0.4, 500, 345.6): 0.24947643918657536,
#  (0.4, 500, 384.0): 0.006428324173309963,
#  (0.4, 500, 422.4): 0,
#  (0.4, 520, 0.0): 0.027489347926790253,
#  (0.4, 520, 38.4): 0.9531638797176432,
#  (0.4, 520, 76.8): 0.5264841595680864,
#  (0.4, 520, 115.2): 0.11365016006808637,
#  (0.4, 520, 153.6): 0.23025480344243165,
#  (0.4, 520, 192.0): 0.4777250997959481,
#  (0.4, 520, 230.4): 0.42075043709360094,
#  (0.4, 520, 268.8): 0.763585628551189,
#  (0.4, 520, 307.2): 0.4325193012509946,
#  (0.4, 520, 345.6): 0.9641797429420297,
#  (0.4, 520, 384.0): 0.5823008361794378,
#  (0.4, 520, 422.4): 0,
#  (0.4, 540, 0.0): 0.08046501934812089,
#  (0.4, 540, 38.4): 0.029486539053326655,
#  (0.4, 540, 76.8): 0.4477459814276369,
#  (0.4, 540, 115.2): 0.6159407295953228,
#  (0.4, 540, 153.6): 0.8128906590758543,
#  (0.4, 540, 192.0): 0.6181882593705451,
#  (0.4, 540, 230.4): 0.9070729954942564,
#  (0.4, 540, 268.8): 0.46945488253584067,
#  (0.4, 540, 307.2): 0.000874101379368053,
#  (0.4, 540, 345.6): 0.5185997583667826,
#  (0.4, 540, 384.0): 0.6183505753346081,
#  (0.4, 540, 422.4): 0,
#  (0.4, 560, 0.0): 0.8562297273664429,
#  (0.4, 560, 38.4): 0.6283004306289139,
#  (0.4, 560, 76.8): 0.8247679333255876,
#  (0.4, 560, 115.2): 0.3715834973319754,
#  (0.4, 560, 153.6): 0.589554478406641,
#  (0.4, 560, 192.0): 0.5964608736043182,
#  (0.4, 560, 230.4): 0.6076365224581588,
#  (0.4, 560, 268.8): 0.5220377491490964,
#  (0.4, 560, 307.2): 0.7618420566188088,
#  (0.4, 560, 345.6): 0.4152608350590976,
#  (0.4, 560, 384.0): 0.715985380075321,
#  (0.4, 560, 422.4): 0,
#  (0.4, 580, 0.0): 0.04970877223535752,
#  (0.4, 580, 38.4): 0.48700801426775064,
#  (0.4, 580, 76.8): 0.7788607614391658,
#  (0.4, 580, 115.2): 0.09235526090166135,
#  (0.4, 580, 153.6): 0.3997367763522426,
#  (0.4, 580, 192.0): 0.4427613201063755,
#  (0.4, 580, 230.4): 0.07046442273051823,
#  (0.4, 580, 268.8): 0.9292610274603483,
#  (0.4, 580, 307.2): 0.10708355262197888,
#  (0.4, 580, 345.6): 0.29355370730377306,
#  (0.4, 580, 384.0): 0.7468165325989267,
#  (0.4, 580, 422.4): 0,
#  (0.4, 600, 0.0): 0.47843427427076834,
#  (0.4, 600, 38.4): 0.26014989205510797,
#  (0.4, 600, 76.8): 0.4383642963353397,
#  (0.4, 600, 115.2): 0.8998353946016971,
#  (0.4, 600, 153.6): 0.1566008278780895,
#  (0.4, 600, 192.0): 0.004495631568878666,
#  (0.4, 600, 230.4): 0.7043054550949948,
#  (0.4, 600, 268.8): 0.9717965627770704,
#  (0.4, 600, 307.2): 0.419819815760218,
#  (0.4, 600, 345.6): 0.44376333855627514,
#  (0.4, 600, 384.0): 0.37771255713369,
#  (0.4, 600, 422.4): 0,
#  (0.4, 620, 0.0): 0.9492399951385948,
#  (0.4, 620, 38.4): 0.2831719812750396,
#  (0.4, 620, 76.8): 0.4642613195050298,
#  (0.4, 620, 115.2): 0.8363852048437416,
#  (0.4, 620, 153.6): 0.6813075648442386,
#  (0.4, 620, 192.0): 0.7801175563905678,
#  (0.4, 620, 230.4): 0.4288969733125837,
#  (0.4, 620, 268.8): 0.39055345525470064,
#  (0.4, 620, 307.2): 0.5220014109656934,
#  (0.4, 620, 345.6): 0.052630808552727504,
#  (0.4, 620, 384.0): 0.3911687395947989,
#  (0.4, 620, 422.4): 0,
#  (0.4, 640, 0.0): 0.18858785078347373,
#  (0.4, 640, 38.4): 0.7425523381702677,
#  (0.4, 640, 76.8): 0.6187820409503937,
#  (0.4, 640, 115.2): 0.29949749757405597,
#  (0.4, 640, 153.6): 0.8423121581366074,
#  (0.4, 640, 192.0): 0.6244522817093434,
#  (0.4, 640, 230.4): 0.09455502094881729,
#  (0.4, 640, 268.8): 0.809355306665023,
#  (0.4, 640, 307.2): 0.08341864979487779,
#  (0.4, 640, 345.6): 0.20558612790197162,
#  (0.4, 640, 384.0): 0.03386141291449385,
#  (0.4, 640, 422.4): 0,
#  (0.4, 660, 0.0): 0.7145610807148812,
#  (0.4, 660, 38.4): 0.908371932637584,
#  (0.4, 660, 76.8): 0.1838539512712738,
#  (0.4, 660, 115.2): 0.11818956572900385,
#  (0.4, 660, 153.6): 0.27390124218537615,
#  (0.4, 660, 192.0): 0.2651519809762932,
#  (0.4, 660, 230.4): 0.9262967885378182,
#  (0.4, 660, 268.8): 0.8989870603423037,
#  (0.4, 660, 307.2): 0.24130137051605105,
#  (0.4, 660, 345.6): 0.9822219746382892,
#  (0.4, 660, 384.0): 0.9412743829501354,
#  (0.4, 660, 422.4): 0,
#  (0.4, 680, 0.0): 0.9427064521561909,
#  (0.4, 680, 38.4): 0.25578075385575405,
#  (0.4, 680, 76.8): 0.0611412155714246,
#  (0.4, 680, 115.2): 0.09668426484354498,
#  (0.4, 680, 153.6): 0.11686664709364147,
#  (0.4, 680, 192.0): 0.5160471465304736,
#  (0.4, 680, 230.4): 0.8188402358121402,
#  (0.4, 680, 268.8): 0.8933746581254943,
#  (0.4, 680, 307.2): 0.974672726394735,
#  (0.4, 680, 345.6): 0.2842220878728763,
#  (0.4, 680, 384.0): 0.48299365196552135,
#  (0.4, 680, 422.4): 0,
#  (0.4, 700, 0.0): 0.0894507223321972,
#  (0.4, 700, 38.4): 0.8109311660012652,
#  (0.4, 700, 76.8): 0.5063181937807785,
#  (0.4, 700, 115.2): 0.5107656904778826,
#  (0.4, 700, 153.6): 0.5310326292639868,
#  (0.4, 700, 192.0): 0.407591446422254,
#  (0.4, 700, 230.4): 0.4819756146602109,
#  (0.4, 700, 268.8): 0.9735199969909668,
#  (0.4, 700, 307.2): 0.33984958820948674,
#  (0.4, 700, 345.6): 0.508278895890879,
#  (0.4, 700, 384.0): 0.22683588100798147,
#  (0.4, 700, 422.4): 0,
#  (0.6, 0, 0.0): 0.19341583350995317,
#  (0.6, 0, 38.4): 0.09397645497209184,
#  (0.6, 0, 76.8): 0.1810960034692618,
#  (0.6, 0, 115.2): 0.7574142064777506,
#  (0.6, 0, 153.6): 0.5504588415315745,
#  (0.6, 0, 192.0): 0.5916167494940918,
#  (0.6, 0, 230.4): 0.1590617704811409,
#  (0.6, 0, 268.8): 0.7900778735934166,
#  (0.6, 0, 307.2): 0.46801996669425083,
#  (0.6, 0, 345.6): 0.488063960816982,
#  (0.6, 0, 384.0): 0.7896694712724098,
#  (0.6, 0, 422.4): 0,
#  (0.6, 20, 0.0): 0.8727885496636633,
#  (0.6, 20, 38.4): 0.9001196061214343,
#  (0.6, 20, 76.8): 0.22656017246886517,
#  (0.6, 20, 115.2): 0.9953889880497895,
#  (0.6, 20, 153.6): 0.4210928978747832,
#  (0.6, 20, 192.0): 0.6698605018136288,
#  (0.6, 20, 230.4): 0.34625234694001494,
#  (0.6, 20, 268.8): 0.9582860953344534,
#  (0.6, 20, 307.2): 0.40550024580788624,
#  (0.6, 20, 345.6): 0.300714838279289,
#  (0.6, 20, 384.0): 0.10589859143799596,
#  (0.6, 20, 422.4): 0,
#  (0.6, 40, 0.0): 0.47460712698067964,
#  (0.6, 40, 38.4): 0.9942118151213155,
#  (0.6, 40, 76.8): 0.18156143183141493,
#  (0.6, 40, 115.2): 0.583701187957226,
#  (0.6, 40, 153.6): 0.31160410044616726,
#  (0.6, 40, 192.0): 0.03859290232166601,
#  (0.6, 40, 230.4): 0.10094538961961153,
#  (0.6, 40, 268.8): 0.389745600920374,
#  (0.6, 40, 307.2): 0.5392696811777268,
#  (0.6, 40, 345.6): 0.4198265257818865,
#  (0.6, 40, 384.0): 0.5242612678053094,
#  (0.6, 40, 422.4): 0,
#  (0.6, 60, 0.0): 0.3772578049963241,
#  (0.6, 60, 38.4): 0.6002019252408016,
#  (0.6, 60, 76.8): 0.9932368991475456,
#  (0.6, 60, 115.2): 0.9223065042418905,
#  (0.6, 60, 153.6): 0.11991641585832913,
#  (0.6, 60, 192.0): 0.8818525441059805,
#  (0.6, 60, 230.4): 0.43558373965092845,
#  (0.6, 60, 268.8): 0.5486976799477717,
#  (0.6, 60, 307.2): 0.3198618407344749,
#  (0.6, 60, 345.6): 0.6271348025901595,
#  (0.6, 60, 384.0): 0.8043115626907728,
#  (0.6, 60, 422.4): 0,
#  (0.6, 80, 0.0): 0.2533652599623818,
#  (0.6, 80, 38.4): 0.5850971071114295,
#  (0.6, 80, 76.8): 0.6324490545231258,
#  (0.6, 80, 115.2): 0.9645431815472458,
#  (0.6, 80, 153.6): 0.6476902847877636,
#  (0.6, 80, 192.0): 0.9270446910114069,
#  (0.6, 80, 230.4): 0.2032492674571884,
#  (0.6, 80, 268.8): 0.9445370319212882,
#  (0.6, 80, 307.2): 0.44689277918937,
#  (0.6, 80, 345.6): 0.2617300942823789,
#  (0.6, 80, 384.0): 0.8678539810869025,
#  (0.6, 80, 422.4): 0,
#  (0.6, 100, 0.0): 0.6457866148531654,
#  (0.6, 100, 38.4): 0.5468314292140811,
#  (0.6, 100, 76.8): 0.32578670065796467,
#  (0.6, 100, 115.2): 0.6022492215370503,
#  (0.6, 100, 153.6): 0.21983098627650355,
#  (0.6, 100, 192.0): 0.8840550369429756,
#  (0.6, 100, 230.4): 0.10234585975844701,
#  (0.6, 100, 268.8): 0.6132807250208641,
#  (0.6, 100, 307.2): 0.4803640326830153,
#  (0.6, 100, 345.6): 0.5794334203558886,
#  (0.6, 100, 384.0): 0.6914742697458819,
#  (0.6, 100, 422.4): 0,
#  (0.6, 120, 0.0): 0.34489637952685126,
#  (0.6, 120, 38.4): 0.46536574582085244,
#  (0.6, 120, 76.8): 0.6810858932068043,
#  (0.6, 120, 115.2): 0.023206780020150197,
#  (0.6, 120, 153.6): 0.5767157647387028,
#  (0.6, 120, 192.0): 0.656910767215657,
#  (0.6, 120, 230.4): 0.07421254534898203,
#  (0.6, 120, 268.8): 0.25435485498669785,
#  (0.6, 120, 307.2): 0.9406450251151031,
#  (0.6, 120, 345.6): 0.615279155157263,
#  (0.6, 120, 384.0): 0.7123772331462288,
#  (0.6, 120, 422.4): 0,
#  (0.6, 140, 0.0): 0.10079660143257774,
#  (0.6, 140, 38.4): 0.1756948406208011,
#  (0.6, 140, 76.8): 0.428808117228925,
#  (0.6, 140, 115.2): 0.9017160676296381,
#  (0.6, 140, 153.6): 0.4729460821487358,
#  (0.6, 140, 192.0): 0.9462169796199091,
#  (0.6, 140, 230.4): 0.8087704946419259,
#  (0.6, 140, 268.8): 0.0929736363883622,
#  (0.6, 140, 307.2): 0.36687327609069376,
#  (0.6, 140, 345.6): 0.7110996539807014,
#  (0.6, 140, 384.0): 0.09171878632851194,
#  (0.6, 140, 422.4): 0,
#  (0.6, 160, 0.0): 0.45628375687606293,
#  (0.6, 160, 38.4): 0.5806038968277778,
#  (0.6, 160, 76.8): 0.20551960368264743,
#  (0.6, 160, 115.2): 0.3472782160805593,
#  (0.6, 160, 153.6): 0.8406641981083294,
#  (0.6, 160, 192.0): 0.9470170517720043,
#  (0.6, 160, 230.4): 0.8598594653943105,
#  (0.6, 160, 268.8): 0.06868048174632935,
#  (0.6, 160, 307.2): 0.5086886493028051,
#  (0.6, 160, 345.6): 0.163264669927079,
#  (0.6, 160, 384.0): 2.89963958755024e-05,
#  (0.6, 160, 422.4): 0,
#  (0.6, 180, 0.0): 0.3373389801780037,
#  (0.6, 180, 38.4): 0.23084992397317516,
#  (0.6, 180, 76.8): 0.21461433219612114,
#  (0.6, 180, 115.2): 0.38742690632982746,
#  (0.6, 180, 153.6): 0.8569410667349631,
#  (0.6, 180, 192.0): 0.8687170532431318,
#  (0.6, 180, 230.4): 0.5744821075571277,
#  (0.6, 180, 268.8): 0.44162320325406046,
#  (0.6, 180, 307.2): 0.19030112833216295,
#  (0.6, 180, 345.6): 0.4822365703252369,
#  (0.6, 180, 384.0): 0.056372281104759225,
#  (0.6, 180, 422.4): 0,
#  (0.6, 200, 0.0): 0.30140831280046676,
#  (0.6, 200, 38.4): 0.1714320473605424,
#  (0.6, 200, 76.8): 0.6055214410438058,
#  (0.6, 200, 115.2): 0.5192201481146036,
#  (0.6, 200, 153.6): 0.13245623675037488,
#  (0.6, 200, 192.0): 0.09936392227506674,
#  (0.6, 200, 230.4): 0.5805936554270461,
#  (0.6, 200, 268.8): 0.49270264631131666,
#  (0.6, 200, 307.2): 0.23390359585017306,
#  (0.6, 200, 345.6): 0.5024754801314661,
#  (0.6, 200, 384.0): 0.053792802687767094,
#  (0.6, 200, 422.4): 0,
#  (0.6, 220, 0.0): 0.23682825967858978,
#  (0.6, 220, 38.4): 0.5039997268669916,
#  (0.6, 220, 76.8): 0.30529532757824174,
#  (0.6, 220, 115.2): 0.40779985660288653,
#  ...}

# %%
keys_to_be_iterated = []
for x in range(1, 9): #remove x = 0.0
        for N in range(36):
            for t in np.linspace(0,16*24,11): #add extra time step
                keys_to_be_iterated += [(round(x*0.2,1),N*20, round(t,1))]
keys_to_be_iterated
# Out:
# [(0.2, 0, 0.0),
#  (0.2, 0, 38.4),
#  (0.2, 0, 76.8),
#  (0.2, 0, 115.2),
#  (0.2, 0, 153.6),
#  (0.2, 0, 192.0),
#  (0.2, 0, 230.4),
#  (0.2, 0, 268.8),
#  (0.2, 0, 307.2),
#  (0.2, 0, 345.6),
#  (0.2, 0, 384.0),
#  (0.2, 20, 0.0),
#  (0.2, 20, 38.4),
#  (0.2, 20, 76.8),
#  (0.2, 20, 115.2),
#  (0.2, 20, 153.6),
#  (0.2, 20, 192.0),
#  (0.2, 20, 230.4),
#  (0.2, 20, 268.8),
#  (0.2, 20, 307.2),
#  (0.2, 20, 345.6),
#  (0.2, 20, 384.0),
#  (0.2, 40, 0.0),
#  (0.2, 40, 38.4),
#  (0.2, 40, 76.8),
#  (0.2, 40, 115.2),
#  (0.2, 40, 153.6),
#  (0.2, 40, 192.0),
#  (0.2, 40, 230.4),
#  (0.2, 40, 268.8),
#  (0.2, 40, 307.2),
#  (0.2, 40, 345.6),
#  (0.2, 40, 384.0),
#  (0.2, 60, 0.0),
#  (0.2, 60, 38.4),
#  (0.2, 60, 76.8),
#  (0.2, 60, 115.2),
#  (0.2, 60, 153.6),
#  (0.2, 60, 192.0),
#  (0.2, 60, 230.4),
#  (0.2, 60, 268.8),
#  (0.2, 60, 307.2),
#  (0.2, 60, 345.6),
#  (0.2, 60, 384.0),
#  (0.2, 80, 0.0),
#  (0.2, 80, 38.4),
#  (0.2, 80, 76.8),
#  (0.2, 80, 115.2),
#  (0.2, 80, 153.6),
#  (0.2, 80, 192.0),
#  (0.2, 80, 230.4),
#  (0.2, 80, 268.8),
#  (0.2, 80, 307.2),
#  (0.2, 80, 345.6),
#  (0.2, 80, 384.0),
#  (0.2, 100, 0.0),
#  (0.2, 100, 38.4),
#  (0.2, 100, 76.8),
#  (0.2, 100, 115.2),
#  (0.2, 100, 153.6),
#  (0.2, 100, 192.0),
#  (0.2, 100, 230.4),
#  (0.2, 100, 268.8),
#  (0.2, 100, 307.2),
#  (0.2, 100, 345.6),
#  (0.2, 100, 384.0),
#  (0.2, 120, 0.0),
#  (0.2, 120, 38.4),
#  (0.2, 120, 76.8),
#  (0.2, 120, 115.2),
#  (0.2, 120, 153.6),
#  (0.2, 120, 192.0),
#  (0.2, 120, 230.4),
#  (0.2, 120, 268.8),
#  (0.2, 120, 307.2),
#  (0.2, 120, 345.6),
#  (0.2, 120, 384.0),
#  (0.2, 140, 0.0),
#  (0.2, 140, 38.4),
#  (0.2, 140, 76.8),
#  (0.2, 140, 115.2),
#  (0.2, 140, 153.6),
#  (0.2, 140, 192.0),
#  (0.2, 140, 230.4),
#  (0.2, 140, 268.8),
#  (0.2, 140, 307.2),
#  (0.2, 140, 345.6),
#  (0.2, 140, 384.0),
#  (0.2, 160, 0.0),
#  (0.2, 160, 38.4),
#  (0.2, 160, 76.8),
#  (0.2, 160, 115.2),
#  (0.2, 160, 153.6),
#  (0.2, 160, 192.0),
#  (0.2, 160, 230.4),
#  (0.2, 160, 268.8),
#  (0.2, 160, 307.2),
#  (0.2, 160, 345.6),
#  (0.2, 160, 384.0),
#  (0.2, 180, 0.0),
#  (0.2, 180, 38.4),
#  (0.2, 180, 76.8),
#  (0.2, 180, 115.2),
#  (0.2, 180, 153.6),
#  (0.2, 180, 192.0),
#  (0.2, 180, 230.4),
#  (0.2, 180, 268.8),
#  (0.2, 180, 307.2),
#  (0.2, 180, 345.6),
#  (0.2, 180, 384.0),
#  (0.2, 200, 0.0),
#  (0.2, 200, 38.4),
#  (0.2, 200, 76.8),
#  (0.2, 200, 115.2),
#  (0.2, 200, 153.6),
#  (0.2, 200, 192.0),
#  (0.2, 200, 230.4),
#  (0.2, 200, 268.8),
#  (0.2, 200, 307.2),
#  (0.2, 200, 345.6),
#  (0.2, 200, 384.0),
#  (0.2, 220, 0.0),
#  (0.2, 220, 38.4),
#  (0.2, 220, 76.8),
#  (0.2, 220, 115.2),
#  (0.2, 220, 153.6),
#  (0.2, 220, 192.0),
#  (0.2, 220, 230.4),
#  (0.2, 220, 268.8),
#  (0.2, 220, 307.2),
#  (0.2, 220, 345.6),
#  (0.2, 220, 384.0),
#  (0.2, 240, 0.0),
#  (0.2, 240, 38.4),
#  (0.2, 240, 76.8),
#  (0.2, 240, 115.2),
#  (0.2, 240, 153.6),
#  (0.2, 240, 192.0),
#  (0.2, 240, 230.4),
#  (0.2, 240, 268.8),
#  (0.2, 240, 307.2),
#  (0.2, 240, 345.6),
#  (0.2, 240, 384.0),
#  (0.2, 260, 0.0),
#  (0.2, 260, 38.4),
#  (0.2, 260, 76.8),
#  (0.2, 260, 115.2),
#  (0.2, 260, 153.6),
#  (0.2, 260, 192.0),
#  (0.2, 260, 230.4),
#  (0.2, 260, 268.8),
#  (0.2, 260, 307.2),
#  (0.2, 260, 345.6),
#  (0.2, 260, 384.0),
#  (0.2, 280, 0.0),
#  (0.2, 280, 38.4),
#  (0.2, 280, 76.8),
#  (0.2, 280, 115.2),
#  (0.2, 280, 153.6),
#  (0.2, 280, 192.0),
#  (0.2, 280, 230.4),
#  (0.2, 280, 268.8),
#  (0.2, 280, 307.2),
#  (0.2, 280, 345.6),
#  (0.2, 280, 384.0),
#  (0.2, 300, 0.0),
#  (0.2, 300, 38.4),
#  (0.2, 300, 76.8),
#  (0.2, 300, 115.2),
#  (0.2, 300, 153.6),
#  (0.2, 300, 192.0),
#  (0.2, 300, 230.4),
#  (0.2, 300, 268.8),
#  (0.2, 300, 307.2),
#  (0.2, 300, 345.6),
#  (0.2, 300, 384.0),
#  (0.2, 320, 0.0),
#  (0.2, 320, 38.4),
#  (0.2, 320, 76.8),
#  (0.2, 320, 115.2),
#  (0.2, 320, 153.6),
#  (0.2, 320, 192.0),
#  (0.2, 320, 230.4),
#  (0.2, 320, 268.8),
#  (0.2, 320, 307.2),
#  (0.2, 320, 345.6),
#  (0.2, 320, 384.0),
#  (0.2, 340, 0.0),
#  (0.2, 340, 38.4),
#  (0.2, 340, 76.8),
#  (0.2, 340, 115.2),
#  (0.2, 340, 153.6),
#  (0.2, 340, 192.0),
#  (0.2, 340, 230.4),
#  (0.2, 340, 268.8),
#  (0.2, 340, 307.2),
#  (0.2, 340, 345.6),
#  (0.2, 340, 384.0),
#  (0.2, 360, 0.0),
#  (0.2, 360, 38.4),
#  (0.2, 360, 76.8),
#  (0.2, 360, 115.2),
#  (0.2, 360, 153.6),
#  (0.2, 360, 192.0),
#  (0.2, 360, 230.4),
#  (0.2, 360, 268.8),
#  (0.2, 360, 307.2),
#  (0.2, 360, 345.6),
#  (0.2, 360, 384.0),
#  (0.2, 380, 0.0),
#  (0.2, 380, 38.4),
#  (0.2, 380, 76.8),
#  (0.2, 380, 115.2),
#  (0.2, 380, 153.6),
#  (0.2, 380, 192.0),
#  (0.2, 380, 230.4),
#  (0.2, 380, 268.8),
#  (0.2, 380, 307.2),
#  (0.2, 380, 345.6),
#  (0.2, 380, 384.0),
#  (0.2, 400, 0.0),
#  (0.2, 400, 38.4),
#  (0.2, 400, 76.8),
#  (0.2, 400, 115.2),
#  (0.2, 400, 153.6),
#  (0.2, 400, 192.0),
#  (0.2, 400, 230.4),
#  (0.2, 400, 268.8),
#  (0.2, 400, 307.2),
#  (0.2, 400, 345.6),
#  (0.2, 400, 384.0),
#  (0.2, 420, 0.0),
#  (0.2, 420, 38.4),
#  (0.2, 420, 76.8),
#  (0.2, 420, 115.2),
#  (0.2, 420, 153.6),
#  (0.2, 420, 192.0),
#  (0.2, 420, 230.4),
#  (0.2, 420, 268.8),
#  (0.2, 420, 307.2),
#  (0.2, 420, 345.6),
#  (0.2, 420, 384.0),
#  (0.2, 440, 0.0),
#  (0.2, 440, 38.4),
#  (0.2, 440, 76.8),
#  (0.2, 440, 115.2),
#  (0.2, 440, 153.6),
#  (0.2, 440, 192.0),
#  (0.2, 440, 230.4),
#  (0.2, 440, 268.8),
#  (0.2, 440, 307.2),
#  (0.2, 440, 345.6),
#  (0.2, 440, 384.0),
#  (0.2, 460, 0.0),
#  (0.2, 460, 38.4),
#  (0.2, 460, 76.8),
#  (0.2, 460, 115.2),
#  (0.2, 460, 153.6),
#  (0.2, 460, 192.0),
#  (0.2, 460, 230.4),
#  (0.2, 460, 268.8),
#  (0.2, 460, 307.2),
#  (0.2, 460, 345.6),
#  (0.2, 460, 384.0),
#  (0.2, 480, 0.0),
#  (0.2, 480, 38.4),
#  (0.2, 480, 76.8),
#  (0.2, 480, 115.2),
#  (0.2, 480, 153.6),
#  (0.2, 480, 192.0),
#  (0.2, 480, 230.4),
#  (0.2, 480, 268.8),
#  (0.2, 480, 307.2),
#  (0.2, 480, 345.6),
#  (0.2, 480, 384.0),
#  (0.2, 500, 0.0),
#  (0.2, 500, 38.4),
#  (0.2, 500, 76.8),
#  (0.2, 500, 115.2),
#  (0.2, 500, 153.6),
#  (0.2, 500, 192.0),
#  (0.2, 500, 230.4),
#  (0.2, 500, 268.8),
#  (0.2, 500, 307.2),
#  (0.2, 500, 345.6),
#  (0.2, 500, 384.0),
#  (0.2, 520, 0.0),
#  (0.2, 520, 38.4),
#  (0.2, 520, 76.8),
#  (0.2, 520, 115.2),
#  (0.2, 520, 153.6),
#  (0.2, 520, 192.0),
#  (0.2, 520, 230.4),
#  (0.2, 520, 268.8),
#  (0.2, 520, 307.2),
#  (0.2, 520, 345.6),
#  (0.2, 520, 384.0),
#  (0.2, 540, 0.0),
#  (0.2, 540, 38.4),
#  (0.2, 540, 76.8),
#  (0.2, 540, 115.2),
#  (0.2, 540, 153.6),
#  (0.2, 540, 192.0),
#  (0.2, 540, 230.4),
#  (0.2, 540, 268.8),
#  (0.2, 540, 307.2),
#  (0.2, 540, 345.6),
#  (0.2, 540, 384.0),
#  (0.2, 560, 0.0),
#  (0.2, 560, 38.4),
#  (0.2, 560, 76.8),
#  (0.2, 560, 115.2),
#  (0.2, 560, 153.6),
#  (0.2, 560, 192.0),
#  (0.2, 560, 230.4),
#  (0.2, 560, 268.8),
#  (0.2, 560, 307.2),
#  (0.2, 560, 345.6),
#  (0.2, 560, 384.0),
#  (0.2, 580, 0.0),
#  (0.2, 580, 38.4),
#  (0.2, 580, 76.8),
#  (0.2, 580, 115.2),
#  (0.2, 580, 153.6),
#  (0.2, 580, 192.0),
#  (0.2, 580, 230.4),
#  (0.2, 580, 268.8),
#  (0.2, 580, 307.2),
#  (0.2, 580, 345.6),
#  (0.2, 580, 384.0),
#  (0.2, 600, 0.0),
#  (0.2, 600, 38.4),
#  (0.2, 600, 76.8),
#  (0.2, 600, 115.2),
#  (0.2, 600, 153.6),
#  (0.2, 600, 192.0),
#  (0.2, 600, 230.4),
#  (0.2, 600, 268.8),
#  (0.2, 600, 307.2),
#  (0.2, 600, 345.6),
#  (0.2, 600, 384.0),
#  (0.2, 620, 0.0),
#  (0.2, 620, 38.4),
#  (0.2, 620, 76.8),
#  (0.2, 620, 115.2),
#  (0.2, 620, 153.6),
#  (0.2, 620, 192.0),
#  (0.2, 620, 230.4),
#  (0.2, 620, 268.8),
#  (0.2, 620, 307.2),
#  (0.2, 620, 345.6),
#  (0.2, 620, 384.0),
#  (0.2, 640, 0.0),
#  (0.2, 640, 38.4),
#  (0.2, 640, 76.8),
#  (0.2, 640, 115.2),
#  (0.2, 640, 153.6),
#  (0.2, 640, 192.0),
#  (0.2, 640, 230.4),
#  (0.2, 640, 268.8),
#  (0.2, 640, 307.2),
#  (0.2, 640, 345.6),
#  (0.2, 640, 384.0),
#  (0.2, 660, 0.0),
#  (0.2, 660, 38.4),
#  (0.2, 660, 76.8),
#  (0.2, 660, 115.2),
#  (0.2, 660, 153.6),
#  (0.2, 660, 192.0),
#  (0.2, 660, 230.4),
#  (0.2, 660, 268.8),
#  (0.2, 660, 307.2),
#  (0.2, 660, 345.6),
#  (0.2, 660, 384.0),
#  (0.2, 680, 0.0),
#  (0.2, 680, 38.4),
#  (0.2, 680, 76.8),
#  (0.2, 680, 115.2),
#  (0.2, 680, 153.6),
#  (0.2, 680, 192.0),
#  (0.2, 680, 230.4),
#  (0.2, 680, 268.8),
#  (0.2, 680, 307.2),
#  (0.2, 680, 345.6),
#  (0.2, 680, 384.0),
#  (0.2, 700, 0.0),
#  (0.2, 700, 38.4),
#  (0.2, 700, 76.8),
#  (0.2, 700, 115.2),
#  (0.2, 700, 153.6),
#  (0.2, 700, 192.0),
#  (0.2, 700, 230.4),
#  (0.2, 700, 268.8),
#  (0.2, 700, 307.2),
#  (0.2, 700, 345.6),
#  (0.2, 700, 384.0),
#  (0.4, 0, 0.0),
#  (0.4, 0, 38.4),
#  (0.4, 0, 76.8),
#  (0.4, 0, 115.2),
#  (0.4, 0, 153.6),
#  (0.4, 0, 192.0),
#  (0.4, 0, 230.4),
#  (0.4, 0, 268.8),
#  (0.4, 0, 307.2),
#  (0.4, 0, 345.6),
#  (0.4, 0, 384.0),
#  (0.4, 20, 0.0),
#  (0.4, 20, 38.4),
#  (0.4, 20, 76.8),
#  (0.4, 20, 115.2),
#  (0.4, 20, 153.6),
#  (0.4, 20, 192.0),
#  (0.4, 20, 230.4),
#  (0.4, 20, 268.8),
#  (0.4, 20, 307.2),
#  (0.4, 20, 345.6),
#  (0.4, 20, 384.0),
#  (0.4, 40, 0.0),
#  (0.4, 40, 38.4),
#  (0.4, 40, 76.8),
#  (0.4, 40, 115.2),
#  (0.4, 40, 153.6),
#  (0.4, 40, 192.0),
#  (0.4, 40, 230.4),
#  (0.4, 40, 268.8),
#  (0.4, 40, 307.2),
#  (0.4, 40, 345.6),
#  (0.4, 40, 384.0),
#  (0.4, 60, 0.0),
#  (0.4, 60, 38.4),
#  (0.4, 60, 76.8),
#  (0.4, 60, 115.2),
#  (0.4, 60, 153.6),
#  (0.4, 60, 192.0),
#  (0.4, 60, 230.4),
#  (0.4, 60, 268.8),
#  (0.4, 60, 307.2),
#  (0.4, 60, 345.6),
#  (0.4, 60, 384.0),
#  (0.4, 80, 0.0),
#  (0.4, 80, 38.4),
#  (0.4, 80, 76.8),
#  (0.4, 80, 115.2),
#  (0.4, 80, 153.6),
#  (0.4, 80, 192.0),
#  (0.4, 80, 230.4),
#  (0.4, 80, 268.8),
#  (0.4, 80, 307.2),
#  (0.4, 80, 345.6),
#  (0.4, 80, 384.0),
#  (0.4, 100, 0.0),
#  (0.4, 100, 38.4),
#  (0.4, 100, 76.8),
#  (0.4, 100, 115.2),
#  (0.4, 100, 153.6),
#  (0.4, 100, 192.0),
#  (0.4, 100, 230.4),
#  (0.4, 100, 268.8),
#  (0.4, 100, 307.2),
#  (0.4, 100, 345.6),
#  (0.4, 100, 384.0),
#  (0.4, 120, 0.0),
#  (0.4, 120, 38.4),
#  (0.4, 120, 76.8),
#  (0.4, 120, 115.2),
#  (0.4, 120, 153.6),
#  (0.4, 120, 192.0),
#  (0.4, 120, 230.4),
#  (0.4, 120, 268.8),
#  (0.4, 120, 307.2),
#  (0.4, 120, 345.6),
#  (0.4, 120, 384.0),
#  (0.4, 140, 0.0),
#  (0.4, 140, 38.4),
#  (0.4, 140, 76.8),
#  (0.4, 140, 115.2),
#  (0.4, 140, 153.6),
#  (0.4, 140, 192.0),
#  (0.4, 140, 230.4),
#  (0.4, 140, 268.8),
#  (0.4, 140, 307.2),
#  (0.4, 140, 345.6),
#  (0.4, 140, 384.0),
#  (0.4, 160, 0.0),
#  (0.4, 160, 38.4),
#  (0.4, 160, 76.8),
#  (0.4, 160, 115.2),
#  (0.4, 160, 153.6),
#  (0.4, 160, 192.0),
#  (0.4, 160, 230.4),
#  (0.4, 160, 268.8),
#  (0.4, 160, 307.2),
#  (0.4, 160, 345.6),
#  (0.4, 160, 384.0),
#  (0.4, 180, 0.0),
#  (0.4, 180, 38.4),
#  (0.4, 180, 76.8),
#  (0.4, 180, 115.2),
#  (0.4, 180, 153.6),
#  (0.4, 180, 192.0),
#  (0.4, 180, 230.4),
#  (0.4, 180, 268.8),
#  (0.4, 180, 307.2),
#  (0.4, 180, 345.6),
#  (0.4, 180, 384.0),
#  (0.4, 200, 0.0),
#  (0.4, 200, 38.4),
#  (0.4, 200, 76.8),
#  (0.4, 200, 115.2),
#  (0.4, 200, 153.6),
#  (0.4, 200, 192.0),
#  (0.4, 200, 230.4),
#  (0.4, 200, 268.8),
#  (0.4, 200, 307.2),
#  (0.4, 200, 345.6),
#  (0.4, 200, 384.0),
#  (0.4, 220, 0.0),
#  (0.4, 220, 38.4),
#  (0.4, 220, 76.8),
#  (0.4, 220, 115.2),
#  (0.4, 220, 153.6),
#  (0.4, 220, 192.0),
#  (0.4, 220, 230.4),
#  (0.4, 220, 268.8),
#  (0.4, 220, 307.2),
#  (0.4, 220, 345.6),
#  (0.4, 220, 384.0),
#  (0.4, 240, 0.0),
#  (0.4, 240, 38.4),
#  (0.4, 240, 76.8),
#  (0.4, 240, 115.2),
#  (0.4, 240, 153.6),
#  (0.4, 240, 192.0),
#  (0.4, 240, 230.4),
#  (0.4, 240, 268.8),
#  (0.4, 240, 307.2),
#  (0.4, 240, 345.6),
#  (0.4, 240, 384.0),
#  (0.4, 260, 0.0),
#  (0.4, 260, 38.4),
#  (0.4, 260, 76.8),
#  (0.4, 260, 115.2),
#  (0.4, 260, 153.6),
#  (0.4, 260, 192.0),
#  (0.4, 260, 230.4),
#  (0.4, 260, 268.8),
#  (0.4, 260, 307.2),
#  (0.4, 260, 345.6),
#  (0.4, 260, 384.0),
#  (0.4, 280, 0.0),
#  (0.4, 280, 38.4),
#  (0.4, 280, 76.8),
#  (0.4, 280, 115.2),
#  (0.4, 280, 153.6),
#  (0.4, 280, 192.0),
#  (0.4, 280, 230.4),
#  (0.4, 280, 268.8),
#  (0.4, 280, 307.2),
#  (0.4, 280, 345.6),
#  (0.4, 280, 384.0),
#  (0.4, 300, 0.0),
#  (0.4, 300, 38.4),
#  (0.4, 300, 76.8),
#  (0.4, 300, 115.2),
#  (0.4, 300, 153.6),
#  (0.4, 300, 192.0),
#  (0.4, 300, 230.4),
#  (0.4, 300, 268.8),
#  (0.4, 300, 307.2),
#  (0.4, 300, 345.6),
#  (0.4, 300, 384.0),
#  (0.4, 320, 0.0),
#  (0.4, 320, 38.4),
#  (0.4, 320, 76.8),
#  (0.4, 320, 115.2),
#  (0.4, 320, 153.6),
#  (0.4, 320, 192.0),
#  (0.4, 320, 230.4),
#  (0.4, 320, 268.8),
#  (0.4, 320, 307.2),
#  (0.4, 320, 345.6),
#  (0.4, 320, 384.0),
#  (0.4, 340, 0.0),
#  (0.4, 340, 38.4),
#  (0.4, 340, 76.8),
#  (0.4, 340, 115.2),
#  (0.4, 340, 153.6),
#  (0.4, 340, 192.0),
#  (0.4, 340, 230.4),
#  (0.4, 340, 268.8),
#  (0.4, 340, 307.2),
#  (0.4, 340, 345.6),
#  (0.4, 340, 384.0),
#  (0.4, 360, 0.0),
#  (0.4, 360, 38.4),
#  (0.4, 360, 76.8),
#  (0.4, 360, 115.2),
#  (0.4, 360, 153.6),
#  (0.4, 360, 192.0),
#  (0.4, 360, 230.4),
#  (0.4, 360, 268.8),
#  (0.4, 360, 307.2),
#  (0.4, 360, 345.6),
#  (0.4, 360, 384.0),
#  (0.4, 380, 0.0),
#  (0.4, 380, 38.4),
#  (0.4, 380, 76.8),
#  (0.4, 380, 115.2),
#  (0.4, 380, 153.6),
#  (0.4, 380, 192.0),
#  (0.4, 380, 230.4),
#  (0.4, 380, 268.8),
#  (0.4, 380, 307.2),
#  (0.4, 380, 345.6),
#  (0.4, 380, 384.0),
#  (0.4, 400, 0.0),
#  (0.4, 400, 38.4),
#  (0.4, 400, 76.8),
#  (0.4, 400, 115.2),
#  (0.4, 400, 153.6),
#  (0.4, 400, 192.0),
#  (0.4, 400, 230.4),
#  (0.4, 400, 268.8),
#  (0.4, 400, 307.2),
#  (0.4, 400, 345.6),
#  (0.4, 400, 384.0),
#  (0.4, 420, 0.0),
#  (0.4, 420, 38.4),
#  (0.4, 420, 76.8),
#  (0.4, 420, 115.2),
#  (0.4, 420, 153.6),
#  (0.4, 420, 192.0),
#  (0.4, 420, 230.4),
#  (0.4, 420, 268.8),
#  (0.4, 420, 307.2),
#  (0.4, 420, 345.6),
#  (0.4, 420, 384.0),
#  (0.4, 440, 0.0),
#  (0.4, 440, 38.4),
#  (0.4, 440, 76.8),
#  (0.4, 440, 115.2),
#  (0.4, 440, 153.6),
#  (0.4, 440, 192.0),
#  (0.4, 440, 230.4),
#  (0.4, 440, 268.8),
#  (0.4, 440, 307.2),
#  (0.4, 440, 345.6),
#  (0.4, 440, 384.0),
#  (0.4, 460, 0.0),
#  (0.4, 460, 38.4),
#  (0.4, 460, 76.8),
#  (0.4, 460, 115.2),
#  (0.4, 460, 153.6),
#  (0.4, 460, 192.0),
#  (0.4, 460, 230.4),
#  (0.4, 460, 268.8),
#  (0.4, 460, 307.2),
#  (0.4, 460, 345.6),
#  (0.4, 460, 384.0),
#  (0.4, 480, 0.0),
#  (0.4, 480, 38.4),
#  (0.4, 480, 76.8),
#  (0.4, 480, 115.2),
#  (0.4, 480, 153.6),
#  (0.4, 480, 192.0),
#  (0.4, 480, 230.4),
#  (0.4, 480, 268.8),
#  (0.4, 480, 307.2),
#  (0.4, 480, 345.6),
#  (0.4, 480, 384.0),
#  (0.4, 500, 0.0),
#  (0.4, 500, 38.4),
#  (0.4, 500, 76.8),
#  (0.4, 500, 115.2),
#  (0.4, 500, 153.6),
#  (0.4, 500, 192.0),
#  (0.4, 500, 230.4),
#  (0.4, 500, 268.8),
#  (0.4, 500, 307.2),
#  (0.4, 500, 345.6),
#  (0.4, 500, 384.0),
#  (0.4, 520, 0.0),
#  (0.4, 520, 38.4),
#  (0.4, 520, 76.8),
#  (0.4, 520, 115.2),
#  (0.4, 520, 153.6),
#  (0.4, 520, 192.0),
#  (0.4, 520, 230.4),
#  (0.4, 520, 268.8),
#  (0.4, 520, 307.2),
#  (0.4, 520, 345.6),
#  (0.4, 520, 384.0),
#  (0.4, 540, 0.0),
#  (0.4, 540, 38.4),
#  (0.4, 540, 76.8),
#  (0.4, 540, 115.2),
#  (0.4, 540, 153.6),
#  (0.4, 540, 192.0),
#  (0.4, 540, 230.4),
#  (0.4, 540, 268.8),
#  (0.4, 540, 307.2),
#  (0.4, 540, 345.6),
#  (0.4, 540, 384.0),
#  (0.4, 560, 0.0),
#  (0.4, 560, 38.4),
#  (0.4, 560, 76.8),
#  (0.4, 560, 115.2),
#  (0.4, 560, 153.6),
#  (0.4, 560, 192.0),
#  (0.4, 560, 230.4),
#  (0.4, 560, 268.8),
#  (0.4, 560, 307.2),
#  (0.4, 560, 345.6),
#  (0.4, 560, 384.0),
#  (0.4, 580, 0.0),
#  (0.4, 580, 38.4),
#  (0.4, 580, 76.8),
#  (0.4, 580, 115.2),
#  (0.4, 580, 153.6),
#  (0.4, 580, 192.0),
#  (0.4, 580, 230.4),
#  (0.4, 580, 268.8),
#  (0.4, 580, 307.2),
#  (0.4, 580, 345.6),
#  (0.4, 580, 384.0),
#  (0.4, 600, 0.0),
#  (0.4, 600, 38.4),
#  (0.4, 600, 76.8),
#  (0.4, 600, 115.2),
#  (0.4, 600, 153.6),
#  (0.4, 600, 192.0),
#  (0.4, 600, 230.4),
#  (0.4, 600, 268.8),
#  (0.4, 600, 307.2),
#  (0.4, 600, 345.6),
#  (0.4, 600, 384.0),
#  (0.4, 620, 0.0),
#  (0.4, 620, 38.4),
#  (0.4, 620, 76.8),
#  (0.4, 620, 115.2),
#  (0.4, 620, 153.6),
#  (0.4, 620, 192.0),
#  (0.4, 620, 230.4),
#  (0.4, 620, 268.8),
#  (0.4, 620, 307.2),
#  (0.4, 620, 345.6),
#  (0.4, 620, 384.0),
#  (0.4, 640, 0.0),
#  (0.4, 640, 38.4),
#  (0.4, 640, 76.8),
#  (0.4, 640, 115.2),
#  (0.4, 640, 153.6),
#  (0.4, 640, 192.0),
#  (0.4, 640, 230.4),
#  (0.4, 640, 268.8),
#  (0.4, 640, 307.2),
#  (0.4, 640, 345.6),
#  (0.4, 640, 384.0),
#  (0.4, 660, 0.0),
#  (0.4, 660, 38.4),
#  (0.4, 660, 76.8),
#  (0.4, 660, 115.2),
#  (0.4, 660, 153.6),
#  (0.4, 660, 192.0),
#  (0.4, 660, 230.4),
#  (0.4, 660, 268.8),
#  (0.4, 660, 307.2),
#  (0.4, 660, 345.6),
#  (0.4, 660, 384.0),
#  (0.4, 680, 0.0),
#  (0.4, 680, 38.4),
#  (0.4, 680, 76.8),
#  (0.4, 680, 115.2),
#  (0.4, 680, 153.6),
#  (0.4, 680, 192.0),
#  (0.4, 680, 230.4),
#  (0.4, 680, 268.8),
#  (0.4, 680, 307.2),
#  (0.4, 680, 345.6),
#  (0.4, 680, 384.0),
#  (0.4, 700, 0.0),
#  (0.4, 700, 38.4),
#  (0.4, 700, 76.8),
#  (0.4, 700, 115.2),
#  (0.4, 700, 153.6),
#  (0.4, 700, 192.0),
#  (0.4, 700, 230.4),
#  (0.4, 700, 268.8),
#  (0.4, 700, 307.2),
#  (0.4, 700, 345.6),
#  (0.4, 700, 384.0),
#  (0.6, 0, 0.0),
#  (0.6, 0, 38.4),
#  (0.6, 0, 76.8),
#  (0.6, 0, 115.2),
#  (0.6, 0, 153.6),
#  (0.6, 0, 192.0),
#  (0.6, 0, 230.4),
#  (0.6, 0, 268.8),
#  (0.6, 0, 307.2),
#  (0.6, 0, 345.6),
#  (0.6, 0, 384.0),
#  (0.6, 20, 0.0),
#  (0.6, 20, 38.4),
#  (0.6, 20, 76.8),
#  (0.6, 20, 115.2),
#  (0.6, 20, 153.6),
#  (0.6, 20, 192.0),
#  (0.6, 20, 230.4),
#  (0.6, 20, 268.8),
#  (0.6, 20, 307.2),
#  (0.6, 20, 345.6),
#  (0.6, 20, 384.0),
#  (0.6, 40, 0.0),
#  (0.6, 40, 38.4),
#  (0.6, 40, 76.8),
#  (0.6, 40, 115.2),
#  (0.6, 40, 153.6),
#  (0.6, 40, 192.0),
#  (0.6, 40, 230.4),
#  (0.6, 40, 268.8),
#  (0.6, 40, 307.2),
#  (0.6, 40, 345.6),
#  (0.6, 40, 384.0),
#  (0.6, 60, 0.0),
#  (0.6, 60, 38.4),
#  (0.6, 60, 76.8),
#  (0.6, 60, 115.2),
#  (0.6, 60, 153.6),
#  (0.6, 60, 192.0),
#  (0.6, 60, 230.4),
#  (0.6, 60, 268.8),
#  (0.6, 60, 307.2),
#  (0.6, 60, 345.6),
#  (0.6, 60, 384.0),
#  (0.6, 80, 0.0),
#  (0.6, 80, 38.4),
#  (0.6, 80, 76.8),
#  (0.6, 80, 115.2),
#  (0.6, 80, 153.6),
#  (0.6, 80, 192.0),
#  (0.6, 80, 230.4),
#  (0.6, 80, 268.8),
#  (0.6, 80, 307.2),
#  (0.6, 80, 345.6),
#  (0.6, 80, 384.0),
#  (0.6, 100, 0.0),
#  (0.6, 100, 38.4),
#  (0.6, 100, 76.8),
#  (0.6, 100, 115.2),
#  (0.6, 100, 153.6),
#  (0.6, 100, 192.0),
#  (0.6, 100, 230.4),
#  (0.6, 100, 268.8),
#  (0.6, 100, 307.2),
#  (0.6, 100, 345.6),
#  (0.6, 100, 384.0),
#  (0.6, 120, 0.0),
#  (0.6, 120, 38.4),
#  (0.6, 120, 76.8),
#  (0.6, 120, 115.2),
#  (0.6, 120, 153.6),
#  (0.6, 120, 192.0),
#  (0.6, 120, 230.4),
#  (0.6, 120, 268.8),
#  (0.6, 120, 307.2),
#  (0.6, 120, 345.6),
#  (0.6, 120, 384.0),
#  (0.6, 140, 0.0),
#  (0.6, 140, 38.4),
#  (0.6, 140, 76.8),
#  (0.6, 140, 115.2),
#  (0.6, 140, 153.6),
#  (0.6, 140, 192.0),
#  (0.6, 140, 230.4),
#  (0.6, 140, 268.8),
#  (0.6, 140, 307.2),
#  (0.6, 140, 345.6),
#  (0.6, 140, 384.0),
#  (0.6, 160, 0.0),
#  (0.6, 160, 38.4),
#  (0.6, 160, 76.8),
#  (0.6, 160, 115.2),
#  (0.6, 160, 153.6),
#  (0.6, 160, 192.0),
#  (0.6, 160, 230.4),
#  (0.6, 160, 268.8),
#  (0.6, 160, 307.2),
#  (0.6, 160, 345.6),
#  (0.6, 160, 384.0),
#  (0.6, 180, 0.0),
#  (0.6, 180, 38.4),
#  (0.6, 180, 76.8),
#  (0.6, 180, 115.2),
#  (0.6, 180, 153.6),
#  (0.6, 180, 192.0),
#  (0.6, 180, 230.4),
#  (0.6, 180, 268.8),
#  (0.6, 180, 307.2),
#  (0.6, 180, 345.6),
#  (0.6, 180, 384.0),
#  (0.6, 200, 0.0),
#  (0.6, 200, 38.4),
#  (0.6, 200, 76.8),
#  (0.6, 200, 115.2),
#  (0.6, 200, 153.6),
#  (0.6, 200, 192.0),
#  (0.6, 200, 230.4),
#  (0.6, 200, 268.8),
#  (0.6, 200, 307.2),
#  (0.6, 200, 345.6),
#  (0.6, 200, 384.0),
#  (0.6, 220, 0.0),
#  (0.6, 220, 38.4),
#  (0.6, 220, 76.8),
#  (0.6, 220, 115.2),
#  (0.6, 220, 153.6),
#  (0.6, 220, 192.0),
#  (0.6, 220, 230.4),
#  (0.6, 220, 268.8),
#  (0.6, 220, 307.2),
#  (0.6, 220, 345.6),
#  (0.6, 220, 384.0),
#  (0.6, 240, 0.0),
#  (0.6, 240, 38.4),
#  (0.6, 240, 76.8),
#  (0.6, 240, 115.2),
#  (0.6, 240, 153.6),
#  (0.6, 240, 192.0),
#  (0.6, 240, 230.4),
#  (0.6, 240, 268.8),
#  (0.6, 240, 307.2),
#  (0.6, 240, 345.6),
#  (0.6, 240, 384.0),
#  (0.6, 260, 0.0),
#  (0.6, 260, 38.4),
#  (0.6, 260, 76.8),
#  (0.6, 260, 115.2),
#  (0.6, 260, 153.6),
#  (0.6, 260, 192.0),
#  (0.6, 260, 230.4),
#  (0.6, 260, 268.8),
#  (0.6, 260, 307.2),
#  (0.6, 260, 345.6),
#  (0.6, 260, 384.0),
#  (0.6, 280, 0.0),
#  (0.6, 280, 38.4),
#  (0.6, 280, 76.8),
#  (0.6, 280, 115.2),
#  (0.6, 280, 153.6),
#  (0.6, 280, 192.0),
#  (0.6, 280, 230.4),
#  (0.6, 280, 268.8),
#  (0.6, 280, 307.2),
#  (0.6, 280, 345.6),
#  (0.6, 280, 384.0),
#  (0.6, 300, 0.0),
#  (0.6, 300, 38.4),
#  (0.6, 300, 76.8),
#  (0.6, 300, 115.2),
#  (0.6, 300, 153.6),
#  (0.6, 300, 192.0),
#  (0.6, 300, 230.4),
#  (0.6, 300, 268.8),
#  (0.6, 300, 307.2),
#  (0.6, 300, 345.6),
#  (0.6, 300, 384.0),
#  (0.6, 320, 0.0),
#  (0.6, 320, 38.4),
#  (0.6, 320, 76.8),
#  (0.6, 320, 115.2),
#  (0.6, 320, 153.6),
#  (0.6, 320, 192.0),
#  (0.6, 320, 230.4),
#  (0.6, 320, 268.8),
#  (0.6, 320, 307.2),
#  (0.6, 320, 345.6),
#  (0.6, 320, 384.0),
#  (0.6, 340, 0.0),
#  (0.6, 340, 38.4),
#  (0.6, 340, 76.8),
#  (0.6, 340, 115.2),
#  (0.6, 340, 153.6),
#  (0.6, 340, 192.0),
#  (0.6, 340, 230.4),
#  (0.6, 340, 268.8),
#  (0.6, 340, 307.2),
#  (0.6, 340, 345.6),
#  (0.6, 340, 384.0),
#  (0.6, 360, 0.0),
#  (0.6, 360, 38.4),
#  (0.6, 360, 76.8),
#  (0.6, 360, 115.2),
#  (0.6, 360, 153.6),
#  (0.6, 360, 192.0),
#  (0.6, 360, 230.4),
#  (0.6, 360, 268.8),
#  (0.6, 360, 307.2),
#  (0.6, 360, 345.6),
#  ...]

# %% [markdown]
# # Policy iteration

# %%
def initialise_deterministic_policy(num_states = Number_of_discrete_states, num_actions = Number_of_possible_actions):
    '''Maps state with time to action ID
    returns a policy (dictionary) of this format:
    key (tuple) = (conc of x, conc of N, time). This describes the state and time at which the state is reached
    value (int) = a value from 0 to 14. basically refers to the specific action according to the action_ID_to_increase_in_N dict defined above
    
    For example, '0.2,260, 38.4': 4 means x = 0.2, N = 260 reached at time = 38.4 and take the 5th action which corresponds to increasing N by 2.0 units (according to the action_ID_to_increase_in_N dictionary)
    '''
    policy = {} # start off with empty map
    for x in range(1, Number_of_possible_x): #remove x = 0.0
        for N in range(Number_of_possible_N):
            for t in np.linspace(0,16*24/10*11,12): #add extra time step
                action_probs = np.random.rand((num_actions)) #randomly initialize
                action_probs /= sum(action_probs) #normalize probabilities
                policy[round(x*0.2,1),N*20, round(t,1)] = np.argmax(action_probs) # only line different to above - the function returns the action, rather than the dist over
    
    for state in policy.keys(): # this loop makes sure that when x conc is low, the action is NOT zero
        if (state[0] == 0.2) or (state[0] == 0.4) or (state[0] == 0.6): #check if x is low 
            policy[state] = random.randint(2,14) #reassign action to at least 3 and above to prevent x from falling further
            
    return policy

print('Number of entries in policy =', len(initialise_deterministic_policy(num_states = Number_of_discrete_states, num_actions = Number_of_possible_actions)))
policy = initialise_deterministic_policy(num_states = Number_of_discrete_states, num_actions = Number_of_possible_actions)
policy
# Out:
# Number of entries in policy = 4320
# {(0.2, 0, 0.0): 11,
#  (0.2, 0, 38.4): 8,
#  (0.2, 0, 76.8): 13,
#  (0.2, 0, 115.2): 8,
#  (0.2, 0, 153.6): 3,
#  (0.2, 0, 192.0): 2,
#  (0.2, 0, 230.4): 8,
#  (0.2, 0, 268.8): 8,
#  (0.2, 0, 307.2): 2,
#  (0.2, 0, 345.6): 12,
#  (0.2, 0, 384.0): 14,
#  (0.2, 0, 422.4): 8,
#  (0.2, 20, 0.0): 9,
#  (0.2, 20, 38.4): 13,
#  (0.2, 20, 76.8): 10,
#  (0.2, 20, 115.2): 7,
#  (0.2, 20, 153.6): 14,
#  (0.2, 20, 192.0): 5,
#  (0.2, 20, 230.4): 2,
#  (0.2, 20, 268.8): 8,
#  (0.2, 20, 307.2): 14,
#  (0.2, 20, 345.6): 14,
#  (0.2, 20, 384.0): 14,
#  (0.2, 20, 422.4): 3,
#  (0.2, 40, 0.0): 12,
#  (0.2, 40, 38.4): 12,
#  (0.2, 40, 76.8): 3,
#  (0.2, 40, 115.2): 13,
#  (0.2, 40, 153.6): 14,
#  (0.2, 40, 192.0): 4,
#  (0.2, 40, 230.4): 4,
#  (0.2, 40, 268.8): 6,
#  (0.2, 40, 307.2): 8,
#  (0.2, 40, 345.6): 13,
#  (0.2, 40, 384.0): 11,
#  (0.2, 40, 422.4): 11,
#  (0.2, 60, 0.0): 2,
#  (0.2, 60, 38.4): 12,
#  (0.2, 60, 76.8): 11,
#  (0.2, 60, 115.2): 6,
#  (0.2, 60, 153.6): 9,
#  (0.2, 60, 192.0): 4,
#  (0.2, 60, 230.4): 12,
#  (0.2, 60, 268.8): 3,
#  (0.2, 60, 307.2): 6,
#  (0.2, 60, 345.6): 9,
#  (0.2, 60, 384.0): 4,
#  (0.2, 60, 422.4): 11,
#  (0.2, 80, 0.0): 13,
#  (0.2, 80, 38.4): 12,
#  (0.2, 80, 76.8): 10,
#  (0.2, 80, 115.2): 3,
#  (0.2, 80, 153.6): 4,
#  (0.2, 80, 192.0): 5,
#  (0.2, 80, 230.4): 2,
#  (0.2, 80, 268.8): 12,
#  (0.2, 80, 307.2): 12,
#  (0.2, 80, 345.6): 12,
#  (0.2, 80, 384.0): 13,
#  (0.2, 80, 422.4): 2,
#  (0.2, 100, 0.0): 2,
#  (0.2, 100, 38.4): 13,
#  (0.2, 100, 76.8): 9,
#  (0.2, 100, 115.2): 12,
#  (0.2, 100, 153.6): 7,
#  (0.2, 100, 192.0): 9,
#  (0.2, 100, 230.4): 13,
#  (0.2, 100, 268.8): 3,
#  (0.2, 100, 307.2): 13,
#  (0.2, 100, 345.6): 10,
#  (0.2, 100, 384.0): 4,
#  (0.2, 100, 422.4): 4,
#  (0.2, 120, 0.0): 12,
#  (0.2, 120, 38.4): 14,
#  (0.2, 120, 76.8): 6,
#  (0.2, 120, 115.2): 3,
#  (0.2, 120, 153.6): 6,
#  (0.2, 120, 192.0): 13,
#  (0.2, 120, 230.4): 6,
#  (0.2, 120, 268.8): 14,
#  (0.2, 120, 307.2): 6,
#  (0.2, 120, 345.6): 13,
#  (0.2, 120, 384.0): 9,
#  (0.2, 120, 422.4): 6,
#  (0.2, 140, 0.0): 14,
#  (0.2, 140, 38.4): 12,
#  (0.2, 140, 76.8): 10,
#  (0.2, 140, 115.2): 3,
#  (0.2, 140, 153.6): 14,
#  (0.2, 140, 192.0): 6,
#  (0.2, 140, 230.4): 6,
#  (0.2, 140, 268.8): 10,
#  (0.2, 140, 307.2): 3,
#  (0.2, 140, 345.6): 12,
#  (0.2, 140, 384.0): 6,
#  (0.2, 140, 422.4): 12,
#  (0.2, 160, 0.0): 7,
#  (0.2, 160, 38.4): 4,
#  (0.2, 160, 76.8): 10,
#  (0.2, 160, 115.2): 2,
#  (0.2, 160, 153.6): 12,
#  (0.2, 160, 192.0): 9,
#  (0.2, 160, 230.4): 6,
#  (0.2, 160, 268.8): 4,
#  (0.2, 160, 307.2): 3,
#  (0.2, 160, 345.6): 12,
#  (0.2, 160, 384.0): 11,
#  (0.2, 160, 422.4): 10,
#  (0.2, 180, 0.0): 12,
#  (0.2, 180, 38.4): 5,
#  (0.2, 180, 76.8): 6,
#  (0.2, 180, 115.2): 10,
#  (0.2, 180, 153.6): 5,
#  (0.2, 180, 192.0): 13,
#  (0.2, 180, 230.4): 8,
#  (0.2, 180, 268.8): 6,
#  (0.2, 180, 307.2): 14,
#  (0.2, 180, 345.6): 8,
#  (0.2, 180, 384.0): 5,
#  (0.2, 180, 422.4): 5,
#  (0.2, 200, 0.0): 13,
#  (0.2, 200, 38.4): 9,
#  (0.2, 200, 76.8): 12,
#  (0.2, 200, 115.2): 4,
#  (0.2, 200, 153.6): 14,
#  (0.2, 200, 192.0): 2,
#  (0.2, 200, 230.4): 5,
#  (0.2, 200, 268.8): 13,
#  (0.2, 200, 307.2): 8,
#  (0.2, 200, 345.6): 7,
#  (0.2, 200, 384.0): 4,
#  (0.2, 200, 422.4): 6,
#  (0.2, 220, 0.0): 3,
#  (0.2, 220, 38.4): 9,
#  (0.2, 220, 76.8): 14,
#  (0.2, 220, 115.2): 11,
#  (0.2, 220, 153.6): 14,
#  (0.2, 220, 192.0): 10,
#  (0.2, 220, 230.4): 12,
#  (0.2, 220, 268.8): 10,
#  (0.2, 220, 307.2): 14,
#  (0.2, 220, 345.6): 4,
#  (0.2, 220, 384.0): 9,
#  (0.2, 220, 422.4): 10,
#  (0.2, 240, 0.0): 4,
#  (0.2, 240, 38.4): 3,
#  (0.2, 240, 76.8): 3,
#  (0.2, 240, 115.2): 4,
#  (0.2, 240, 153.6): 3,
#  (0.2, 240, 192.0): 13,
#  (0.2, 240, 230.4): 3,
#  (0.2, 240, 268.8): 5,
#  (0.2, 240, 307.2): 7,
#  (0.2, 240, 345.6): 7,
#  (0.2, 240, 384.0): 8,
#  (0.2, 240, 422.4): 12,
#  (0.2, 260, 0.0): 7,
#  (0.2, 260, 38.4): 9,
#  (0.2, 260, 76.8): 5,
#  (0.2, 260, 115.2): 3,
#  (0.2, 260, 153.6): 3,
#  (0.2, 260, 192.0): 14,
#  (0.2, 260, 230.4): 12,
#  (0.2, 260, 268.8): 9,
#  (0.2, 260, 307.2): 6,
#  (0.2, 260, 345.6): 14,
#  (0.2, 260, 384.0): 12,
#  (0.2, 260, 422.4): 2,
#  (0.2, 280, 0.0): 4,
#  (0.2, 280, 38.4): 11,
#  (0.2, 280, 76.8): 13,
#  (0.2, 280, 115.2): 11,
#  (0.2, 280, 153.6): 14,
#  (0.2, 280, 192.0): 14,
#  (0.2, 280, 230.4): 10,
#  (0.2, 280, 268.8): 14,
#  (0.2, 280, 307.2): 4,
#  (0.2, 280, 345.6): 8,
#  (0.2, 280, 384.0): 4,
#  (0.2, 280, 422.4): 5,
#  (0.2, 300, 0.0): 6,
#  (0.2, 300, 38.4): 9,
#  (0.2, 300, 76.8): 7,
#  (0.2, 300, 115.2): 5,
#  (0.2, 300, 153.6): 12,
#  (0.2, 300, 192.0): 2,
#  (0.2, 300, 230.4): 13,
#  (0.2, 300, 268.8): 4,
#  (0.2, 300, 307.2): 14,
#  (0.2, 300, 345.6): 12,
#  (0.2, 300, 384.0): 5,
#  (0.2, 300, 422.4): 2,
#  (0.2, 320, 0.0): 13,
#  (0.2, 320, 38.4): 12,
#  (0.2, 320, 76.8): 13,
#  (0.2, 320, 115.2): 2,
#  (0.2, 320, 153.6): 7,
#  (0.2, 320, 192.0): 3,
#  (0.2, 320, 230.4): 11,
#  (0.2, 320, 268.8): 2,
#  (0.2, 320, 307.2): 9,
#  (0.2, 320, 345.6): 14,
#  (0.2, 320, 384.0): 9,
#  (0.2, 320, 422.4): 5,
#  (0.2, 340, 0.0): 7,
#  (0.2, 340, 38.4): 9,
#  (0.2, 340, 76.8): 8,
#  (0.2, 340, 115.2): 5,
#  (0.2, 340, 153.6): 6,
#  (0.2, 340, 192.0): 11,
#  (0.2, 340, 230.4): 3,
#  (0.2, 340, 268.8): 9,
#  (0.2, 340, 307.2): 6,
#  (0.2, 340, 345.6): 7,
#  (0.2, 340, 384.0): 13,
#  (0.2, 340, 422.4): 4,
#  (0.2, 360, 0.0): 9,
#  (0.2, 360, 38.4): 10,
#  (0.2, 360, 76.8): 11,
#  (0.2, 360, 115.2): 2,
#  (0.2, 360, 153.6): 4,
#  (0.2, 360, 192.0): 12,
#  (0.2, 360, 230.4): 6,
#  (0.2, 360, 268.8): 13,
#  (0.2, 360, 307.2): 9,
#  (0.2, 360, 345.6): 8,
#  (0.2, 360, 384.0): 14,
#  (0.2, 360, 422.4): 7,
#  (0.2, 380, 0.0): 9,
#  (0.2, 380, 38.4): 4,
#  (0.2, 380, 76.8): 12,
#  (0.2, 380, 115.2): 6,
#  (0.2, 380, 153.6): 13,
#  (0.2, 380, 192.0): 2,
#  (0.2, 380, 230.4): 3,
#  (0.2, 380, 268.8): 12,
#  (0.2, 380, 307.2): 12,
#  (0.2, 380, 345.6): 3,
#  (0.2, 380, 384.0): 10,
#  (0.2, 380, 422.4): 6,
#  (0.2, 400, 0.0): 6,
#  (0.2, 400, 38.4): 14,
#  (0.2, 400, 76.8): 11,
#  (0.2, 400, 115.2): 7,
#  (0.2, 400, 153.6): 7,
#  (0.2, 400, 192.0): 3,
#  (0.2, 400, 230.4): 14,
#  (0.2, 400, 268.8): 14,
#  (0.2, 400, 307.2): 2,
#  (0.2, 400, 345.6): 10,
#  (0.2, 400, 384.0): 5,
#  (0.2, 400, 422.4): 4,
#  (0.2, 420, 0.0): 11,
#  (0.2, 420, 38.4): 4,
#  (0.2, 420, 76.8): 10,
#  (0.2, 420, 115.2): 3,
#  (0.2, 420, 153.6): 4,
#  (0.2, 420, 192.0): 13,
#  (0.2, 420, 230.4): 12,
#  (0.2, 420, 268.8): 2,
#  (0.2, 420, 307.2): 7,
#  (0.2, 420, 345.6): 5,
#  (0.2, 420, 384.0): 13,
#  (0.2, 420, 422.4): 8,
#  (0.2, 440, 0.0): 13,
#  (0.2, 440, 38.4): 14,
#  (0.2, 440, 76.8): 7,
#  (0.2, 440, 115.2): 3,
#  (0.2, 440, 153.6): 3,
#  (0.2, 440, 192.0): 4,
#  (0.2, 440, 230.4): 13,
#  (0.2, 440, 268.8): 8,
#  (0.2, 440, 307.2): 6,
#  (0.2, 440, 345.6): 12,
#  (0.2, 440, 384.0): 6,
#  (0.2, 440, 422.4): 12,
#  (0.2, 460, 0.0): 8,
#  (0.2, 460, 38.4): 8,
#  (0.2, 460, 76.8): 9,
#  (0.2, 460, 115.2): 3,
#  (0.2, 460, 153.6): 12,
#  (0.2, 460, 192.0): 10,
#  (0.2, 460, 230.4): 4,
#  (0.2, 460, 268.8): 14,
#  (0.2, 460, 307.2): 6,
#  (0.2, 460, 345.6): 5,
#  (0.2, 460, 384.0): 4,
#  (0.2, 460, 422.4): 5,
#  (0.2, 480, 0.0): 4,
#  (0.2, 480, 38.4): 6,
#  (0.2, 480, 76.8): 13,
#  (0.2, 480, 115.2): 14,
#  (0.2, 480, 153.6): 2,
#  (0.2, 480, 192.0): 6,
#  (0.2, 480, 230.4): 13,
#  (0.2, 480, 268.8): 5,
#  (0.2, 480, 307.2): 2,
#  (0.2, 480, 345.6): 3,
#  (0.2, 480, 384.0): 6,
#  (0.2, 480, 422.4): 12,
#  (0.2, 500, 0.0): 13,
#  (0.2, 500, 38.4): 4,
#  (0.2, 500, 76.8): 3,
#  (0.2, 500, 115.2): 13,
#  (0.2, 500, 153.6): 9,
#  (0.2, 500, 192.0): 4,
#  (0.2, 500, 230.4): 12,
#  (0.2, 500, 268.8): 14,
#  (0.2, 500, 307.2): 9,
#  (0.2, 500, 345.6): 4,
#  (0.2, 500, 384.0): 9,
#  (0.2, 500, 422.4): 3,
#  (0.2, 520, 0.0): 7,
#  (0.2, 520, 38.4): 9,
#  (0.2, 520, 76.8): 10,
#  (0.2, 520, 115.2): 10,
#  (0.2, 520, 153.6): 6,
#  (0.2, 520, 192.0): 10,
#  (0.2, 520, 230.4): 2,
#  (0.2, 520, 268.8): 6,
#  (0.2, 520, 307.2): 5,
#  (0.2, 520, 345.6): 7,
#  (0.2, 520, 384.0): 11,
#  (0.2, 520, 422.4): 10,
#  (0.2, 540, 0.0): 9,
#  (0.2, 540, 38.4): 14,
#  (0.2, 540, 76.8): 5,
#  (0.2, 540, 115.2): 5,
#  (0.2, 540, 153.6): 5,
#  (0.2, 540, 192.0): 8,
#  (0.2, 540, 230.4): 2,
#  (0.2, 540, 268.8): 12,
#  (0.2, 540, 307.2): 10,
#  (0.2, 540, 345.6): 5,
#  (0.2, 540, 384.0): 4,
#  (0.2, 540, 422.4): 12,
#  (0.2, 560, 0.0): 7,
#  (0.2, 560, 38.4): 7,
#  (0.2, 560, 76.8): 3,
#  (0.2, 560, 115.2): 5,
#  (0.2, 560, 153.6): 11,
#  (0.2, 560, 192.0): 12,
#  (0.2, 560, 230.4): 2,
#  (0.2, 560, 268.8): 4,
#  (0.2, 560, 307.2): 14,
#  (0.2, 560, 345.6): 8,
#  (0.2, 560, 384.0): 6,
#  (0.2, 560, 422.4): 2,
#  (0.2, 580, 0.0): 11,
#  (0.2, 580, 38.4): 8,
#  (0.2, 580, 76.8): 4,
#  (0.2, 580, 115.2): 9,
#  (0.2, 580, 153.6): 7,
#  (0.2, 580, 192.0): 10,
#  (0.2, 580, 230.4): 10,
#  (0.2, 580, 268.8): 12,
#  (0.2, 580, 307.2): 6,
#  (0.2, 580, 345.6): 9,
#  (0.2, 580, 384.0): 3,
#  (0.2, 580, 422.4): 12,
#  (0.2, 600, 0.0): 13,
#  (0.2, 600, 38.4): 3,
#  (0.2, 600, 76.8): 9,
#  (0.2, 600, 115.2): 8,
#  (0.2, 600, 153.6): 6,
#  (0.2, 600, 192.0): 5,
#  (0.2, 600, 230.4): 6,
#  (0.2, 600, 268.8): 12,
#  (0.2, 600, 307.2): 12,
#  (0.2, 600, 345.6): 7,
#  (0.2, 600, 384.0): 6,
#  (0.2, 600, 422.4): 7,
#  (0.2, 620, 0.0): 2,
#  (0.2, 620, 38.4): 12,
#  (0.2, 620, 76.8): 7,
#  (0.2, 620, 115.2): 9,
#  (0.2, 620, 153.6): 7,
#  (0.2, 620, 192.0): 14,
#  (0.2, 620, 230.4): 13,
#  (0.2, 620, 268.8): 12,
#  (0.2, 620, 307.2): 6,
#  (0.2, 620, 345.6): 2,
#  (0.2, 620, 384.0): 2,
#  (0.2, 620, 422.4): 8,
#  (0.2, 640, 0.0): 8,
#  (0.2, 640, 38.4): 6,
#  (0.2, 640, 76.8): 13,
#  (0.2, 640, 115.2): 3,
#  (0.2, 640, 153.6): 4,
#  (0.2, 640, 192.0): 3,
#  (0.2, 640, 230.4): 6,
#  (0.2, 640, 268.8): 13,
#  (0.2, 640, 307.2): 10,
#  (0.2, 640, 345.6): 5,
#  (0.2, 640, 384.0): 10,
#  (0.2, 640, 422.4): 5,
#  (0.2, 660, 0.0): 4,
#  (0.2, 660, 38.4): 2,
#  (0.2, 660, 76.8): 8,
#  (0.2, 660, 115.2): 2,
#  (0.2, 660, 153.6): 7,
#  (0.2, 660, 192.0): 2,
#  (0.2, 660, 230.4): 3,
#  (0.2, 660, 268.8): 13,
#  (0.2, 660, 307.2): 5,
#  (0.2, 660, 345.6): 14,
#  (0.2, 660, 384.0): 3,
#  (0.2, 660, 422.4): 4,
#  (0.2, 680, 0.0): 10,
#  (0.2, 680, 38.4): 14,
#  (0.2, 680, 76.8): 12,
#  (0.2, 680, 115.2): 12,
#  (0.2, 680, 153.6): 6,
#  (0.2, 680, 192.0): 10,
#  (0.2, 680, 230.4): 11,
#  (0.2, 680, 268.8): 13,
#  (0.2, 680, 307.2): 6,
#  (0.2, 680, 345.6): 13,
#  (0.2, 680, 384.0): 6,
#  (0.2, 680, 422.4): 11,
#  (0.2, 700, 0.0): 6,
#  (0.2, 700, 38.4): 5,
#  (0.2, 700, 76.8): 12,
#  (0.2, 700, 115.2): 14,
#  (0.2, 700, 153.6): 3,
#  (0.2, 700, 192.0): 8,
#  (0.2, 700, 230.4): 7,
#  (0.2, 700, 268.8): 5,
#  (0.2, 700, 307.2): 3,
#  (0.2, 700, 345.6): 2,
#  (0.2, 700, 384.0): 8,
#  (0.2, 700, 422.4): 4,
#  (0.4, 0, 0.0): 4,
#  (0.4, 0, 38.4): 9,
#  (0.4, 0, 76.8): 11,
#  (0.4, 0, 115.2): 13,
#  (0.4, 0, 153.6): 5,
#  (0.4, 0, 192.0): 14,
#  (0.4, 0, 230.4): 8,
#  (0.4, 0, 268.8): 12,
#  (0.4, 0, 307.2): 8,
#  (0.4, 0, 345.6): 4,
#  (0.4, 0, 384.0): 12,
#  (0.4, 0, 422.4): 11,
#  (0.4, 20, 0.0): 14,
#  (0.4, 20, 38.4): 2,
#  (0.4, 20, 76.8): 10,
#  (0.4, 20, 115.2): 9,
#  (0.4, 20, 153.6): 8,
#  (0.4, 20, 192.0): 14,
#  (0.4, 20, 230.4): 5,
#  (0.4, 20, 268.8): 11,
#  (0.4, 20, 307.2): 13,
#  (0.4, 20, 345.6): 6,
#  (0.4, 20, 384.0): 10,
#  (0.4, 20, 422.4): 13,
#  (0.4, 40, 0.0): 5,
#  (0.4, 40, 38.4): 12,
#  (0.4, 40, 76.8): 5,
#  (0.4, 40, 115.2): 14,
#  (0.4, 40, 153.6): 5,
#  (0.4, 40, 192.0): 14,
#  (0.4, 40, 230.4): 4,
#  (0.4, 40, 268.8): 11,
#  (0.4, 40, 307.2): 11,
#  (0.4, 40, 345.6): 6,
#  (0.4, 40, 384.0): 10,
#  (0.4, 40, 422.4): 7,
#  (0.4, 60, 0.0): 4,
#  (0.4, 60, 38.4): 5,
#  (0.4, 60, 76.8): 9,
#  (0.4, 60, 115.2): 5,
#  (0.4, 60, 153.6): 13,
#  (0.4, 60, 192.0): 6,
#  (0.4, 60, 230.4): 7,
#  (0.4, 60, 268.8): 3,
#  (0.4, 60, 307.2): 3,
#  (0.4, 60, 345.6): 10,
#  (0.4, 60, 384.0): 4,
#  (0.4, 60, 422.4): 5,
#  (0.4, 80, 0.0): 4,
#  (0.4, 80, 38.4): 13,
#  (0.4, 80, 76.8): 10,
#  (0.4, 80, 115.2): 11,
#  (0.4, 80, 153.6): 8,
#  (0.4, 80, 192.0): 4,
#  (0.4, 80, 230.4): 5,
#  (0.4, 80, 268.8): 6,
#  (0.4, 80, 307.2): 5,
#  (0.4, 80, 345.6): 7,
#  (0.4, 80, 384.0): 2,
#  (0.4, 80, 422.4): 5,
#  (0.4, 100, 0.0): 14,
#  (0.4, 100, 38.4): 14,
#  (0.4, 100, 76.8): 5,
#  (0.4, 100, 115.2): 14,
#  (0.4, 100, 153.6): 10,
#  (0.4, 100, 192.0): 10,
#  (0.4, 100, 230.4): 4,
#  (0.4, 100, 268.8): 8,
#  (0.4, 100, 307.2): 3,
#  (0.4, 100, 345.6): 5,
#  (0.4, 100, 384.0): 8,
#  (0.4, 100, 422.4): 12,
#  (0.4, 120, 0.0): 6,
#  (0.4, 120, 38.4): 11,
#  (0.4, 120, 76.8): 7,
#  (0.4, 120, 115.2): 3,
#  (0.4, 120, 153.6): 2,
#  (0.4, 120, 192.0): 3,
#  (0.4, 120, 230.4): 13,
#  (0.4, 120, 268.8): 12,
#  (0.4, 120, 307.2): 5,
#  (0.4, 120, 345.6): 2,
#  (0.4, 120, 384.0): 10,
#  (0.4, 120, 422.4): 3,
#  (0.4, 140, 0.0): 2,
#  (0.4, 140, 38.4): 2,
#  (0.4, 140, 76.8): 3,
#  (0.4, 140, 115.2): 9,
#  (0.4, 140, 153.6): 3,
#  (0.4, 140, 192.0): 12,
#  (0.4, 140, 230.4): 5,
#  (0.4, 140, 268.8): 4,
#  (0.4, 140, 307.2): 9,
#  (0.4, 140, 345.6): 11,
#  (0.4, 140, 384.0): 3,
#  (0.4, 140, 422.4): 4,
#  (0.4, 160, 0.0): 8,
#  (0.4, 160, 38.4): 10,
#  (0.4, 160, 76.8): 10,
#  (0.4, 160, 115.2): 4,
#  (0.4, 160, 153.6): 9,
#  (0.4, 160, 192.0): 6,
#  (0.4, 160, 230.4): 11,
#  (0.4, 160, 268.8): 13,
#  (0.4, 160, 307.2): 13,
#  (0.4, 160, 345.6): 11,
#  (0.4, 160, 384.0): 13,
#  (0.4, 160, 422.4): 8,
#  (0.4, 180, 0.0): 8,
#  (0.4, 180, 38.4): 4,
#  (0.4, 180, 76.8): 5,
#  (0.4, 180, 115.2): 14,
#  (0.4, 180, 153.6): 7,
#  (0.4, 180, 192.0): 5,
#  (0.4, 180, 230.4): 12,
#  (0.4, 180, 268.8): 11,
#  (0.4, 180, 307.2): 13,
#  (0.4, 180, 345.6): 8,
#  (0.4, 180, 384.0): 8,
#  (0.4, 180, 422.4): 13,
#  (0.4, 200, 0.0): 8,
#  (0.4, 200, 38.4): 14,
#  (0.4, 200, 76.8): 2,
#  (0.4, 200, 115.2): 11,
#  (0.4, 200, 153.6): 5,
#  (0.4, 200, 192.0): 5,
#  (0.4, 200, 230.4): 8,
#  (0.4, 200, 268.8): 3,
#  (0.4, 200, 307.2): 2,
#  (0.4, 200, 345.6): 10,
#  (0.4, 200, 384.0): 13,
#  (0.4, 200, 422.4): 2,
#  (0.4, 220, 0.0): 4,
#  (0.4, 220, 38.4): 7,
#  (0.4, 220, 76.8): 12,
#  (0.4, 220, 115.2): 10,
#  (0.4, 220, 153.6): 11,
#  (0.4, 220, 192.0): 10,
#  (0.4, 220, 230.4): 7,
#  (0.4, 220, 268.8): 7,
#  (0.4, 220, 307.2): 10,
#  (0.4, 220, 345.6): 9,
#  (0.4, 220, 384.0): 6,
#  (0.4, 220, 422.4): 9,
#  (0.4, 240, 0.0): 2,
#  (0.4, 240, 38.4): 5,
#  (0.4, 240, 76.8): 14,
#  (0.4, 240, 115.2): 4,
#  (0.4, 240, 153.6): 12,
#  (0.4, 240, 192.0): 5,
#  (0.4, 240, 230.4): 9,
#  (0.4, 240, 268.8): 4,
#  (0.4, 240, 307.2): 8,
#  (0.4, 240, 345.6): 13,
#  (0.4, 240, 384.0): 11,
#  (0.4, 240, 422.4): 9,
#  (0.4, 260, 0.0): 14,
#  (0.4, 260, 38.4): 9,
#  (0.4, 260, 76.8): 7,
#  (0.4, 260, 115.2): 10,
#  (0.4, 260, 153.6): 3,
#  (0.4, 260, 192.0): 14,
#  (0.4, 260, 230.4): 5,
#  (0.4, 260, 268.8): 13,
#  (0.4, 260, 307.2): 2,
#  (0.4, 260, 345.6): 4,
#  (0.4, 260, 384.0): 9,
#  (0.4, 260, 422.4): 9,
#  (0.4, 280, 0.0): 12,
#  (0.4, 280, 38.4): 6,
#  (0.4, 280, 76.8): 6,
#  (0.4, 280, 115.2): 11,
#  (0.4, 280, 153.6): 9,
#  (0.4, 280, 192.0): 2,
#  (0.4, 280, 230.4): 11,
#  (0.4, 280, 268.8): 9,
#  (0.4, 280, 307.2): 6,
#  (0.4, 280, 345.6): 12,
#  (0.4, 280, 384.0): 4,
#  (0.4, 280, 422.4): 5,
#  (0.4, 300, 0.0): 7,
#  (0.4, 300, 38.4): 9,
#  (0.4, 300, 76.8): 4,
#  (0.4, 300, 115.2): 13,
#  (0.4, 300, 153.6): 14,
#  (0.4, 300, 192.0): 7,
#  (0.4, 300, 230.4): 10,
#  (0.4, 300, 268.8): 8,
#  (0.4, 300, 307.2): 7,
#  (0.4, 300, 345.6): 14,
#  (0.4, 300, 384.0): 7,
#  (0.4, 300, 422.4): 2,
#  (0.4, 320, 0.0): 3,
#  (0.4, 320, 38.4): 3,
#  (0.4, 320, 76.8): 5,
#  (0.4, 320, 115.2): 8,
#  (0.4, 320, 153.6): 9,
#  (0.4, 320, 192.0): 4,
#  (0.4, 320, 230.4): 3,
#  (0.4, 320, 268.8): 3,
#  (0.4, 320, 307.2): 3,
#  (0.4, 320, 345.6): 4,
#  (0.4, 320, 384.0): 7,
#  (0.4, 320, 422.4): 13,
#  (0.4, 340, 0.0): 12,
#  (0.4, 340, 38.4): 9,
#  (0.4, 340, 76.8): 5,
#  (0.4, 340, 115.2): 8,
#  (0.4, 340, 153.6): 11,
#  (0.4, 340, 192.0): 6,
#  (0.4, 340, 230.4): 12,
#  (0.4, 340, 268.8): 2,
#  (0.4, 340, 307.2): 10,
#  (0.4, 340, 345.6): 11,
#  (0.4, 340, 384.0): 3,
#  (0.4, 340, 422.4): 4,
#  (0.4, 360, 0.0): 2,
#  (0.4, 360, 38.4): 5,
#  (0.4, 360, 76.8): 13,
#  (0.4, 360, 115.2): 10,
#  (0.4, 360, 153.6): 11,
#  (0.4, 360, 192.0): 10,
#  (0.4, 360, 230.4): 9,
#  (0.4, 360, 268.8): 11,
#  (0.4, 360, 307.2): 9,
#  (0.4, 360, 345.6): 12,
#  (0.4, 360, 384.0): 12,
#  (0.4, 360, 422.4): 13,
#  (0.4, 380, 0.0): 6,
#  (0.4, 380, 38.4): 10,
#  (0.4, 380, 76.8): 8,
#  (0.4, 380, 115.2): 3,
#  (0.4, 380, 153.6): 13,
#  (0.4, 380, 192.0): 6,
#  (0.4, 380, 230.4): 4,
#  (0.4, 380, 268.8): 12,
#  (0.4, 380, 307.2): 7,
#  (0.4, 380, 345.6): 11,
#  (0.4, 380, 384.0): 7,
#  (0.4, 380, 422.4): 12,
#  (0.4, 400, 0.0): 6,
#  (0.4, 400, 38.4): 9,
#  (0.4, 400, 76.8): 3,
#  (0.4, 400, 115.2): 7,
#  (0.4, 400, 153.6): 9,
#  (0.4, 400, 192.0): 2,
#  (0.4, 400, 230.4): 9,
#  (0.4, 400, 268.8): 7,
#  (0.4, 400, 307.2): 4,
#  (0.4, 400, 345.6): 2,
#  (0.4, 400, 384.0): 3,
#  (0.4, 400, 422.4): 7,
#  (0.4, 420, 0.0): 10,
#  (0.4, 420, 38.4): 4,
#  (0.4, 420, 76.8): 14,
#  (0.4, 420, 115.2): 9,
#  (0.4, 420, 153.6): 12,
#  (0.4, 420, 192.0): 11,
#  (0.4, 420, 230.4): 7,
#  (0.4, 420, 268.8): 2,
#  (0.4, 420, 307.2): 7,
#  (0.4, 420, 345.6): 4,
#  (0.4, 420, 384.0): 11,
#  (0.4, 420, 422.4): 12,
#  (0.4, 440, 0.0): 8,
#  (0.4, 440, 38.4): 10,
#  (0.4, 440, 76.8): 2,
#  (0.4, 440, 115.2): 2,
#  (0.4, 440, 153.6): 4,
#  (0.4, 440, 192.0): 10,
#  (0.4, 440, 230.4): 7,
#  (0.4, 440, 268.8): 2,
#  (0.4, 440, 307.2): 14,
#  (0.4, 440, 345.6): 6,
#  (0.4, 440, 384.0): 11,
#  (0.4, 440, 422.4): 3,
#  (0.4, 460, 0.0): 10,
#  (0.4, 460, 38.4): 14,
#  (0.4, 460, 76.8): 14,
#  (0.4, 460, 115.2): 5,
#  (0.4, 460, 153.6): 7,
#  (0.4, 460, 192.0): 14,
#  (0.4, 460, 230.4): 9,
#  (0.4, 460, 268.8): 13,
#  (0.4, 460, 307.2): 9,
#  (0.4, 460, 345.6): 5,
#  (0.4, 460, 384.0): 13,
#  (0.4, 460, 422.4): 6,
#  (0.4, 480, 0.0): 3,
#  (0.4, 480, 38.4): 12,
#  (0.4, 480, 76.8): 8,
#  (0.4, 480, 115.2): 11,
#  (0.4, 480, 153.6): 4,
#  (0.4, 480, 192.0): 14,
#  (0.4, 480, 230.4): 7,
#  (0.4, 480, 268.8): 3,
#  (0.4, 480, 307.2): 6,
#  (0.4, 480, 345.6): 9,
#  (0.4, 480, 384.0): 9,
#  (0.4, 480, 422.4): 4,
#  (0.4, 500, 0.0): 9,
#  (0.4, 500, 38.4): 11,
#  (0.4, 500, 76.8): 4,
#  (0.4, 500, 115.2): 5,
#  (0.4, 500, 153.6): 10,
#  (0.4, 500, 192.0): 9,
#  (0.4, 500, 230.4): 14,
#  (0.4, 500, 268.8): 3,
#  (0.4, 500, 307.2): 2,
#  (0.4, 500, 345.6): 5,
#  (0.4, 500, 384.0): 3,
#  (0.4, 500, 422.4): 6,
#  (0.4, 520, 0.0): 5,
#  (0.4, 520, 38.4): 8,
#  (0.4, 520, 76.8): 2,
#  (0.4, 520, 115.2): 5,
#  (0.4, 520, 153.6): 13,
#  (0.4, 520, 192.0): 11,
#  (0.4, 520, 230.4): 9,
#  (0.4, 520, 268.8): 3,
#  (0.4, 520, 307.2): 12,
#  (0.4, 520, 345.6): 8,
#  (0.4, 520, 384.0): 12,
#  (0.4, 520, 422.4): 3,
#  (0.4, 540, 0.0): 10,
#  (0.4, 540, 38.4): 7,
#  (0.4, 540, 76.8): 2,
#  (0.4, 540, 115.2): 2,
#  (0.4, 540, 153.6): 3,
#  (0.4, 540, 192.0): 11,
#  (0.4, 540, 230.4): 13,
#  (0.4, 540, 268.8): 14,
#  (0.4, 540, 307.2): 8,
#  (0.4, 540, 345.6): 6,
#  (0.4, 540, 384.0): 3,
#  (0.4, 540, 422.4): 8,
#  (0.4, 560, 0.0): 11,
#  (0.4, 560, 38.4): 11,
#  (0.4, 560, 76.8): 8,
#  (0.4, 560, 115.2): 8,
#  (0.4, 560, 153.6): 6,
#  (0.4, 560, 192.0): 5,
#  (0.4, 560, 230.4): 11,
#  (0.4, 560, 268.8): 2,
#  (0.4, 560, 307.2): 6,
#  (0.4, 560, 345.6): 13,
#  (0.4, 560, 384.0): 7,
#  (0.4, 560, 422.4): 11,
#  (0.4, 580, 0.0): 11,
#  (0.4, 580, 38.4): 2,
#  (0.4, 580, 76.8): 12,
#  (0.4, 580, 115.2): 9,
#  (0.4, 580, 153.6): 7,
#  (0.4, 580, 192.0): 10,
#  (0.4, 580, 230.4): 10,
#  (0.4, 580, 268.8): 5,
#  (0.4, 580, 307.2): 13,
#  (0.4, 580, 345.6): 8,
#  (0.4, 580, 384.0): 3,
#  (0.4, 580, 422.4): 6,
#  (0.4, 600, 0.0): 2,
#  (0.4, 600, 38.4): 10,
#  (0.4, 600, 76.8): 13,
#  (0.4, 600, 115.2): 2,
#  (0.4, 600, 153.6): 14,
#  (0.4, 600, 192.0): 3,
#  (0.4, 600, 230.4): 14,
#  (0.4, 600, 268.8): 6,
#  (0.4, 600, 307.2): 6,
#  (0.4, 600, 345.6): 13,
#  (0.4, 600, 384.0): 8,
#  (0.4, 600, 422.4): 2,
#  (0.4, 620, 0.0): 9,
#  (0.4, 620, 38.4): 13,
#  (0.4, 620, 76.8): 13,
#  (0.4, 620, 115.2): 11,
#  (0.4, 620, 153.6): 12,
#  (0.4, 620, 192.0): 12,
#  (0.4, 620, 230.4): 7,
#  (0.4, 620, 268.8): 3,
#  (0.4, 620, 307.2): 2,
#  (0.4, 620, 345.6): 4,
#  (0.4, 620, 384.0): 5,
#  (0.4, 620, 422.4): 6,
#  (0.4, 640, 0.0): 4,
#  (0.4, 640, 38.4): 2,
#  (0.4, 640, 76.8): 8,
#  (0.4, 640, 115.2): 14,
#  (0.4, 640, 153.6): 10,
#  (0.4, 640, 192.0): 7,
#  (0.4, 640, 230.4): 10,
#  (0.4, 640, 268.8): 2,
#  (0.4, 640, 307.2): 5,
#  (0.4, 640, 345.6): 14,
#  (0.4, 640, 384.0): 14,
#  (0.4, 640, 422.4): 7,
#  (0.4, 660, 0.0): 4,
#  (0.4, 660, 38.4): 12,
#  (0.4, 660, 76.8): 6,
#  (0.4, 660, 115.2): 3,
#  (0.4, 660, 153.6): 7,
#  (0.4, 660, 192.0): 5,
#  (0.4, 660, 230.4): 3,
#  (0.4, 660, 268.8): 11,
#  (0.4, 660, 307.2): 6,
#  (0.4, 660, 345.6): 9,
#  (0.4, 660, 384.0): 10,
#  (0.4, 660, 422.4): 11,
#  (0.4, 680, 0.0): 3,
#  (0.4, 680, 38.4): 10,
#  (0.4, 680, 76.8): 2,
#  (0.4, 680, 115.2): 8,
#  (0.4, 680, 153.6): 3,
#  (0.4, 680, 192.0): 10,
#  (0.4, 680, 230.4): 14,
#  (0.4, 680, 268.8): 3,
#  (0.4, 680, 307.2): 12,
#  (0.4, 680, 345.6): 2,
#  (0.4, 680, 384.0): 12,
#  (0.4, 680, 422.4): 11,
#  (0.4, 700, 0.0): 5,
#  (0.4, 700, 38.4): 3,
#  (0.4, 700, 76.8): 13,
#  (0.4, 700, 115.2): 4,
#  (0.4, 700, 153.6): 10,
#  (0.4, 700, 192.0): 6,
#  (0.4, 700, 230.4): 5,
#  (0.4, 700, 268.8): 11,
#  (0.4, 700, 307.2): 10,
#  (0.4, 700, 345.6): 6,
#  (0.4, 700, 384.0): 13,
#  (0.4, 700, 422.4): 11,
#  (0.6, 0, 0.0): 8,
#  (0.6, 0, 38.4): 14,
#  (0.6, 0, 76.8): 7,
#  (0.6, 0, 115.2): 8,
#  (0.6, 0, 153.6): 14,
#  (0.6, 0, 192.0): 14,
#  (0.6, 0, 230.4): 9,
#  (0.6, 0, 268.8): 6,
#  (0.6, 0, 307.2): 10,
#  (0.6, 0, 345.6): 8,
#  (0.6, 0, 384.0): 3,
#  (0.6, 0, 422.4): 6,
#  (0.6, 20, 0.0): 2,
#  (0.6, 20, 38.4): 13,
#  (0.6, 20, 76.8): 6,
#  (0.6, 20, 115.2): 4,
#  (0.6, 20, 153.6): 8,
#  (0.6, 20, 192.0): 11,
#  (0.6, 20, 230.4): 7,
#  (0.6, 20, 268.8): 5,
#  (0.6, 20, 307.2): 3,
#  (0.6, 20, 345.6): 5,
#  (0.6, 20, 384.0): 12,
#  (0.6, 20, 422.4): 4,
#  (0.6, 40, 0.0): 13,
#  (0.6, 40, 38.4): 10,
#  (0.6, 40, 76.8): 13,
#  (0.6, 40, 115.2): 13,
#  (0.6, 40, 153.6): 4,
#  (0.6, 40, 192.0): 13,
#  (0.6, 40, 230.4): 9,
#  (0.6, 40, 268.8): 12,
#  (0.6, 40, 307.2): 2,
#  (0.6, 40, 345.6): 2,
#  (0.6, 40, 384.0): 9,
#  (0.6, 40, 422.4): 4,
#  (0.6, 60, 0.0): 14,
#  (0.6, 60, 38.4): 11,
#  (0.6, 60, 76.8): 12,
#  (0.6, 60, 115.2): 12,
#  (0.6, 60, 153.6): 4,
#  (0.6, 60, 192.0): 7,
#  (0.6, 60, 230.4): 10,
#  (0.6, 60, 268.8): 5,
#  (0.6, 60, 307.2): 2,
#  (0.6, 60, 345.6): 5,
#  (0.6, 60, 384.0): 10,
#  (0.6, 60, 422.4): 3,
#  (0.6, 80, 0.0): 6,
#  (0.6, 80, 38.4): 2,
#  (0.6, 80, 76.8): 14,
#  (0.6, 80, 115.2): 2,
#  (0.6, 80, 153.6): 14,
#  (0.6, 80, 192.0): 7,
#  (0.6, 80, 230.4): 8,
#  (0.6, 80, 268.8): 4,
#  (0.6, 80, 307.2): 6,
#  (0.6, 80, 345.6): 4,
#  (0.6, 80, 384.0): 5,
#  (0.6, 80, 422.4): 12,
#  (0.6, 100, 0.0): 14,
#  (0.6, 100, 38.4): 10,
#  (0.6, 100, 76.8): 9,
#  (0.6, 100, 115.2): 12,
#  (0.6, 100, 153.6): 5,
#  (0.6, 100, 192.0): 12,
#  (0.6, 100, 230.4): 3,
#  (0.6, 100, 268.8): 13,
#  (0.6, 100, 307.2): 3,
#  (0.6, 100, 345.6): 6,
#  (0.6, 100, 384.0): 11,
#  (0.6, 100, 422.4): 5,
#  (0.6, 120, 0.0): 12,
#  (0.6, 120, 38.4): 2,
#  (0.6, 120, 76.8): 2,
#  (0.6, 120, 115.2): 12,
#  (0.6, 120, 153.6): 7,
#  (0.6, 120, 192.0): 9,
#  (0.6, 120, 230.4): 8,
#  (0.6, 120, 268.8): 4,
#  (0.6, 120, 307.2): 5,
#  (0.6, 120, 345.6): 11,
#  (0.6, 120, 384.0): 5,
#  (0.6, 120, 422.4): 9,
#  (0.6, 140, 0.0): 11,
#  (0.6, 140, 38.4): 8,
#  (0.6, 140, 76.8): 14,
#  (0.6, 140, 115.2): 10,
#  (0.6, 140, 153.6): 14,
#  (0.6, 140, 192.0): 13,
#  (0.6, 140, 230.4): 3,
#  (0.6, 140, 268.8): 5,
#  (0.6, 140, 307.2): 6,
#  (0.6, 140, 345.6): 5,
#  (0.6, 140, 384.0): 6,
#  (0.6, 140, 422.4): 5,
#  (0.6, 160, 0.0): 2,
#  (0.6, 160, 38.4): 13,
#  (0.6, 160, 76.8): 12,
#  (0.6, 160, 115.2): 4,
#  (0.6, 160, 153.6): 9,
#  (0.6, 160, 192.0): 4,
#  (0.6, 160, 230.4): 5,
#  (0.6, 160, 268.8): 12,
#  (0.6, 160, 307.2): 13,
#  (0.6, 160, 345.6): 13,
#  (0.6, 160, 384.0): 9,
#  (0.6, 160, 422.4): 10,
#  (0.6, 180, 0.0): 11,
#  (0.6, 180, 38.4): 14,
#  (0.6, 180, 76.8): 7,
#  (0.6, 180, 115.2): 2,
#  (0.6, 180, 153.6): 5,
#  (0.6, 180, 192.0): 2,
#  (0.6, 180, 230.4): 13,
#  (0.6, 180, 268.8): 3,
#  (0.6, 180, 307.2): 11,
#  (0.6, 180, 345.6): 7,
#  (0.6, 180, 384.0): 3,
#  (0.6, 180, 422.4): 3,
#  (0.6, 200, 0.0): 11,
#  (0.6, 200, 38.4): 3,
#  (0.6, 200, 76.8): 12,
#  (0.6, 200, 115.2): 2,
#  (0.6, 200, 153.6): 2,
#  (0.6, 200, 192.0): 14,
#  (0.6, 200, 230.4): 14,
#  (0.6, 200, 268.8): 9,
#  (0.6, 200, 307.2): 2,
#  (0.6, 200, 345.6): 6,
#  (0.6, 200, 384.0): 3,
#  (0.6, 200, 422.4): 8,
#  (0.6, 220, 0.0): 14,
#  (0.6, 220, 38.4): 9,
#  (0.6, 220, 76.8): 6,
#  (0.6, 220, 115.2): 13,
#  ...}

# %%
keys_to_be_iterated
# Out:
# [(0.2, 0, 0.0),
#  (0.2, 0, 38.4),
#  (0.2, 0, 76.8),
#  (0.2, 0, 115.2),
#  (0.2, 0, 153.6),
#  (0.2, 0, 192.0),
#  (0.2, 0, 230.4),
#  (0.2, 0, 268.8),
#  (0.2, 0, 307.2),
#  (0.2, 0, 345.6),
#  (0.2, 0, 384.0),
#  (0.2, 20, 0.0),
#  (0.2, 20, 38.4),
#  (0.2, 20, 76.8),
#  (0.2, 20, 115.2),
#  (0.2, 20, 153.6),
#  (0.2, 20, 192.0),
#  (0.2, 20, 230.4),
#  (0.2, 20, 268.8),
#  (0.2, 20, 307.2),
#  (0.2, 20, 345.6),
#  (0.2, 20, 384.0),
#  (0.2, 40, 0.0),
#  (0.2, 40, 38.4),
#  (0.2, 40, 76.8),
#  (0.2, 40, 115.2),
#  (0.2, 40, 153.6),
#  (0.2, 40, 192.0),
#  (0.2, 40, 230.4),
#  (0.2, 40, 268.8),
#  (0.2, 40, 307.2),
#  (0.2, 40, 345.6),
#  (0.2, 40, 384.0),
#  (0.2, 60, 0.0),
#  (0.2, 60, 38.4),
#  (0.2, 60, 76.8),
#  (0.2, 60, 115.2),
#  (0.2, 60, 153.6),
#  (0.2, 60, 192.0),
#  (0.2, 60, 230.4),
#  (0.2, 60, 268.8),
#  (0.2, 60, 307.2),
#  (0.2, 60, 345.6),
#  (0.2, 60, 384.0),
#  (0.2, 80, 0.0),
#  (0.2, 80, 38.4),
#  (0.2, 80, 76.8),
#  (0.2, 80, 115.2),
#  (0.2, 80, 153.6),
#  (0.2, 80, 192.0),
#  (0.2, 80, 230.4),
#  (0.2, 80, 268.8),
#  (0.2, 80, 307.2),
#  (0.2, 80, 345.6),
#  (0.2, 80, 384.0),
#  (0.2, 100, 0.0),
#  (0.2, 100, 38.4),
#  (0.2, 100, 76.8),
#  (0.2, 100, 115.2),
#  (0.2, 100, 153.6),
#  (0.2, 100, 192.0),
#  (0.2, 100, 230.4),
#  (0.2, 100, 268.8),
#  (0.2, 100, 307.2),
#  (0.2, 100, 345.6),
#  (0.2, 100, 384.0),
#  (0.2, 120, 0.0),
#  (0.2, 120, 38.4),
#  (0.2, 120, 76.8),
#  (0.2, 120, 115.2),
#  (0.2, 120, 153.6),
#  (0.2, 120, 192.0),
#  (0.2, 120, 230.4),
#  (0.2, 120, 268.8),
#  (0.2, 120, 307.2),
#  (0.2, 120, 345.6),
#  (0.2, 120, 384.0),
#  (0.2, 140, 0.0),
#  (0.2, 140, 38.4),
#  (0.2, 140, 76.8),
#  (0.2, 140, 115.2),
#  (0.2, 140, 153.6),
#  (0.2, 140, 192.0),
#  (0.2, 140, 230.4),
#  (0.2, 140, 268.8),
#  (0.2, 140, 307.2),
#  (0.2, 140, 345.6),
#  (0.2, 140, 384.0),
#  (0.2, 160, 0.0),
#  (0.2, 160, 38.4),
#  (0.2, 160, 76.8),
#  (0.2, 160, 115.2),
#  (0.2, 160, 153.6),
#  (0.2, 160, 192.0),
#  (0.2, 160, 230.4),
#  (0.2, 160, 268.8),
#  (0.2, 160, 307.2),
#  (0.2, 160, 345.6),
#  (0.2, 160, 384.0),
#  (0.2, 180, 0.0),
#  (0.2, 180, 38.4),
#  (0.2, 180, 76.8),
#  (0.2, 180, 115.2),
#  (0.2, 180, 153.6),
#  (0.2, 180, 192.0),
#  (0.2, 180, 230.4),
#  (0.2, 180, 268.8),
#  (0.2, 180, 307.2),
#  (0.2, 180, 345.6),
#  (0.2, 180, 384.0),
#  (0.2, 200, 0.0),
#  (0.2, 200, 38.4),
#  (0.2, 200, 76.8),
#  (0.2, 200, 115.2),
#  (0.2, 200, 153.6),
#  (0.2, 200, 192.0),
#  (0.2, 200, 230.4),
#  (0.2, 200, 268.8),
#  (0.2, 200, 307.2),
#  (0.2, 200, 345.6),
#  (0.2, 200, 384.0),
#  (0.2, 220, 0.0),
#  (0.2, 220, 38.4),
#  (0.2, 220, 76.8),
#  (0.2, 220, 115.2),
#  (0.2, 220, 153.6),
#  (0.2, 220, 192.0),
#  (0.2, 220, 230.4),
#  (0.2, 220, 268.8),
#  (0.2, 220, 307.2),
#  (0.2, 220, 345.6),
#  (0.2, 220, 384.0),
#  (0.2, 240, 0.0),
#  (0.2, 240, 38.4),
#  (0.2, 240, 76.8),
#  (0.2, 240, 115.2),
#  (0.2, 240, 153.6),
#  (0.2, 240, 192.0),
#  (0.2, 240, 230.4),
#  (0.2, 240, 268.8),
#  (0.2, 240, 307.2),
#  (0.2, 240, 345.6),
#  (0.2, 240, 384.0),
#  (0.2, 260, 0.0),
#  (0.2, 260, 38.4),
#  (0.2, 260, 76.8),
#  (0.2, 260, 115.2),
#  (0.2, 260, 153.6),
#  (0.2, 260, 192.0),
#  (0.2, 260, 230.4),
#  (0.2, 260, 268.8),
#  (0.2, 260, 307.2),
#  (0.2, 260, 345.6),
#  (0.2, 260, 384.0),
#  (0.2, 280, 0.0),
#  (0.2, 280, 38.4),
#  (0.2, 280, 76.8),
#  (0.2, 280, 115.2),
#  (0.2, 280, 153.6),
#  (0.2, 280, 192.0),
#  (0.2, 280, 230.4),
#  (0.2, 280, 268.8),
#  (0.2, 280, 307.2),
#  (0.2, 280, 345.6),
#  (0.2, 280, 384.0),
#  (0.2, 300, 0.0),
#  (0.2, 300, 38.4),
#  (0.2, 300, 76.8),
#  (0.2, 300, 115.2),
#  (0.2, 300, 153.6),
#  (0.2, 300, 192.0),
#  (0.2, 300, 230.4),
#  (0.2, 300, 268.8),
#  (0.2, 300, 307.2),
#  (0.2, 300, 345.6),
#  (0.2, 300, 384.0),
#  (0.2, 320, 0.0),
#  (0.2, 320, 38.4),
#  (0.2, 320, 76.8),
#  (0.2, 320, 115.2),
#  (0.2, 320, 153.6),
#  (0.2, 320, 192.0),
#  (0.2, 320, 230.4),
#  (0.2, 320, 268.8),
#  (0.2, 320, 307.2),
#  (0.2, 320, 345.6),
#  (0.2, 320, 384.0),
#  (0.2, 340, 0.0),
#  (0.2, 340, 38.4),
#  (0.2, 340, 76.8),
#  (0.2, 340, 115.2),
#  (0.2, 340, 153.6),
#  (0.2, 340, 192.0),
#  (0.2, 340, 230.4),
#  (0.2, 340, 268.8),
#  (0.2, 340, 307.2),
#  (0.2, 340, 345.6),
#  (0.2, 340, 384.0),
#  (0.2, 360, 0.0),
#  (0.2, 360, 38.4),
#  (0.2, 360, 76.8),
#  (0.2, 360, 115.2),
#  (0.2, 360, 153.6),
#  (0.2, 360, 192.0),
#  (0.2, 360, 230.4),
#  (0.2, 360, 268.8),
#  (0.2, 360, 307.2),
#  (0.2, 360, 345.6),
#  (0.2, 360, 384.0),
#  (0.2, 380, 0.0),
#  (0.2, 380, 38.4),
#  (0.2, 380, 76.8),
#  (0.2, 380, 115.2),
#  (0.2, 380, 153.6),
#  (0.2, 380, 192.0),
#  (0.2, 380, 230.4),
#  (0.2, 380, 268.8),
#  (0.2, 380, 307.2),
#  (0.2, 380, 345.6),
#  (0.2, 380, 384.0),
#  (0.2, 400, 0.0),
#  (0.2, 400, 38.4),
#  (0.2, 400, 76.8),
#  (0.2, 400, 115.2),
#  (0.2, 400, 153.6),
#  (0.2, 400, 192.0),
#  (0.2, 400, 230.4),
#  (0.2, 400, 268.8),
#  (0.2, 400, 307.2),
#  (0.2, 400, 345.6),
#  (0.2, 400, 384.0),
#  (0.2, 420, 0.0),
#  (0.2, 420, 38.4),
#  (0.2, 420, 76.8),
#  (0.2, 420, 115.2),
#  (0.2, 420, 153.6),
#  (0.2, 420, 192.0),
#  (0.2, 420, 230.4),
#  (0.2, 420, 268.8),
#  (0.2, 420, 307.2),
#  (0.2, 420, 345.6),
#  (0.2, 420, 384.0),
#  (0.2, 440, 0.0),
#  (0.2, 440, 38.4),
#  (0.2, 440, 76.8),
#  (0.2, 440, 115.2),
#  (0.2, 440, 153.6),
#  (0.2, 440, 192.0),
#  (0.2, 440, 230.4),
#  (0.2, 440, 268.8),
#  (0.2, 440, 307.2),
#  (0.2, 440, 345.6),
#  (0.2, 440, 384.0),
#  (0.2, 460, 0.0),
#  (0.2, 460, 38.4),
#  (0.2, 460, 76.8),
#  (0.2, 460, 115.2),
#  (0.2, 460, 153.6),
#  (0.2, 460, 192.0),
#  (0.2, 460, 230.4),
#  (0.2, 460, 268.8),
#  (0.2, 460, 307.2),
#  (0.2, 460, 345.6),
#  (0.2, 460, 384.0),
#  (0.2, 480, 0.0),
#  (0.2, 480, 38.4),
#  (0.2, 480, 76.8),
#  (0.2, 480, 115.2),
#  (0.2, 480, 153.6),
#  (0.2, 480, 192.0),
#  (0.2, 480, 230.4),
#  (0.2, 480, 268.8),
#  (0.2, 480, 307.2),
#  (0.2, 480, 345.6),
#  (0.2, 480, 384.0),
#  (0.2, 500, 0.0),
#  (0.2, 500, 38.4),
#  (0.2, 500, 76.8),
#  (0.2, 500, 115.2),
#  (0.2, 500, 153.6),
#  (0.2, 500, 192.0),
#  (0.2, 500, 230.4),
#  (0.2, 500, 268.8),
#  (0.2, 500, 307.2),
#  (0.2, 500, 345.6),
#  (0.2, 500, 384.0),
#  (0.2, 520, 0.0),
#  (0.2, 520, 38.4),
#  (0.2, 520, 76.8),
#  (0.2, 520, 115.2),
#  (0.2, 520, 153.6),
#  (0.2, 520, 192.0),
#  (0.2, 520, 230.4),
#  (0.2, 520, 268.8),
#  (0.2, 520, 307.2),
#  (0.2, 520, 345.6),
#  (0.2, 520, 384.0),
#  (0.2, 540, 0.0),
#  (0.2, 540, 38.4),
#  (0.2, 540, 76.8),
#  (0.2, 540, 115.2),
#  (0.2, 540, 153.6),
#  (0.2, 540, 192.0),
#  (0.2, 540, 230.4),
#  (0.2, 540, 268.8),
#  (0.2, 540, 307.2),
#  (0.2, 540, 345.6),
#  (0.2, 540, 384.0),
#  (0.2, 560, 0.0),
#  (0.2, 560, 38.4),
#  (0.2, 560, 76.8),
#  (0.2, 560, 115.2),
#  (0.2, 560, 153.6),
#  (0.2, 560, 192.0),
#  (0.2, 560, 230.4),
#  (0.2, 560, 268.8),
#  (0.2, 560, 307.2),
#  (0.2, 560, 345.6),
#  (0.2, 560, 384.0),
#  (0.2, 580, 0.0),
#  (0.2, 580, 38.4),
#  (0.2, 580, 76.8),
#  (0.2, 580, 115.2),
#  (0.2, 580, 153.6),
#  (0.2, 580, 192.0),
#  (0.2, 580, 230.4),
#  (0.2, 580, 268.8),
#  (0.2, 580, 307.2),
#  (0.2, 580, 345.6),
#  (0.2, 580, 384.0),
#  (0.2, 600, 0.0),
#  (0.2, 600, 38.4),
#  (0.2, 600, 76.8),
#  (0.2, 600, 115.2),
#  (0.2, 600, 153.6),
#  (0.2, 600, 192.0),
#  (0.2, 600, 230.4),
#  (0.2, 600, 268.8),
#  (0.2, 600, 307.2),
#  (0.2, 600, 345.6),
#  (0.2, 600, 384.0),
#  (0.2, 620, 0.0),
#  (0.2, 620, 38.4),
#  (0.2, 620, 76.8),
#  (0.2, 620, 115.2),
#  (0.2, 620, 153.6),
#  (0.2, 620, 192.0),
#  (0.2, 620, 230.4),
#  (0.2, 620, 268.8),
#  (0.2, 620, 307.2),
#  (0.2, 620, 345.6),
#  (0.2, 620, 384.0),
#  (0.2, 640, 0.0),
#  (0.2, 640, 38.4),
#  (0.2, 640, 76.8),
#  (0.2, 640, 115.2),
#  (0.2, 640, 153.6),
#  (0.2, 640, 192.0),
#  (0.2, 640, 230.4),
#  (0.2, 640, 268.8),
#  (0.2, 640, 307.2),
#  (0.2, 640, 345.6),
#  (0.2, 640, 384.0),
#  (0.2, 660, 0.0),
#  (0.2, 660, 38.4),
#  (0.2, 660, 76.8),
#  (0.2, 660, 115.2),
#  (0.2, 660, 153.6),
#  (0.2, 660, 192.0),
#  (0.2, 660, 230.4),
#  (0.2, 660, 268.8),
#  (0.2, 660, 307.2),
#  (0.2, 660, 345.6),
#  (0.2, 660, 384.0),
#  (0.2, 680, 0.0),
#  (0.2, 680, 38.4),
#  (0.2, 680, 76.8),
#  (0.2, 680, 115.2),
#  (0.2, 680, 153.6),
#  (0.2, 680, 192.0),
#  (0.2, 680, 230.4),
#  (0.2, 680, 268.8),
#  (0.2, 680, 307.2),
#  (0.2, 680, 345.6),
#  (0.2, 680, 384.0),
#  (0.2, 700, 0.0),
#  (0.2, 700, 38.4),
#  (0.2, 700, 76.8),
#  (0.2, 700, 115.2),
#  (0.2, 700, 153.6),
#  (0.2, 700, 192.0),
#  (0.2, 700, 230.4),
#  (0.2, 700, 268.8),
#  (0.2, 700, 307.2),
#  (0.2, 700, 345.6),
#  (0.2, 700, 384.0),
#  (0.4, 0, 0.0),
#  (0.4, 0, 38.4),
#  (0.4, 0, 76.8),
#  (0.4, 0, 115.2),
#  (0.4, 0, 153.6),
#  (0.4, 0, 192.0),
#  (0.4, 0, 230.4),
#  (0.4, 0, 268.8),
#  (0.4, 0, 307.2),
#  (0.4, 0, 345.6),
#  (0.4, 0, 384.0),
#  (0.4, 20, 0.0),
#  (0.4, 20, 38.4),
#  (0.4, 20, 76.8),
#  (0.4, 20, 115.2),
#  (0.4, 20, 153.6),
#  (0.4, 20, 192.0),
#  (0.4, 20, 230.4),
#  (0.4, 20, 268.8),
#  (0.4, 20, 307.2),
#  (0.4, 20, 345.6),
#  (0.4, 20, 384.0),
#  (0.4, 40, 0.0),
#  (0.4, 40, 38.4),
#  (0.4, 40, 76.8),
#  (0.4, 40, 115.2),
#  (0.4, 40, 153.6),
#  (0.4, 40, 192.0),
#  (0.4, 40, 230.4),
#  (0.4, 40, 268.8),
#  (0.4, 40, 307.2),
#  (0.4, 40, 345.6),
#  (0.4, 40, 384.0),
#  (0.4, 60, 0.0),
#  (0.4, 60, 38.4),
#  (0.4, 60, 76.8),
#  (0.4, 60, 115.2),
#  (0.4, 60, 153.6),
#  (0.4, 60, 192.0),
#  (0.4, 60, 230.4),
#  (0.4, 60, 268.8),
#  (0.4, 60, 307.2),
#  (0.4, 60, 345.6),
#  (0.4, 60, 384.0),
#  (0.4, 80, 0.0),
#  (0.4, 80, 38.4),
#  (0.4, 80, 76.8),
#  (0.4, 80, 115.2),
#  (0.4, 80, 153.6),
#  (0.4, 80, 192.0),
#  (0.4, 80, 230.4),
#  (0.4, 80, 268.8),
#  (0.4, 80, 307.2),
#  (0.4, 80, 345.6),
#  (0.4, 80, 384.0),
#  (0.4, 100, 0.0),
#  (0.4, 100, 38.4),
#  (0.4, 100, 76.8),
#  (0.4, 100, 115.2),
#  (0.4, 100, 153.6),
#  (0.4, 100, 192.0),
#  (0.4, 100, 230.4),
#  (0.4, 100, 268.8),
#  (0.4, 100, 307.2),
#  (0.4, 100, 345.6),
#  (0.4, 100, 384.0),
#  (0.4, 120, 0.0),
#  (0.4, 120, 38.4),
#  (0.4, 120, 76.8),
#  (0.4, 120, 115.2),
#  (0.4, 120, 153.6),
#  (0.4, 120, 192.0),
#  (0.4, 120, 230.4),
#  (0.4, 120, 268.8),
#  (0.4, 120, 307.2),
#  (0.4, 120, 345.6),
#  (0.4, 120, 384.0),
#  (0.4, 140, 0.0),
#  (0.4, 140, 38.4),
#  (0.4, 140, 76.8),
#  (0.4, 140, 115.2),
#  (0.4, 140, 153.6),
#  (0.4, 140, 192.0),
#  (0.4, 140, 230.4),
#  (0.4, 140, 268.8),
#  (0.4, 140, 307.2),
#  (0.4, 140, 345.6),
#  (0.4, 140, 384.0),
#  (0.4, 160, 0.0),
#  (0.4, 160, 38.4),
#  (0.4, 160, 76.8),
#  (0.4, 160, 115.2),
#  (0.4, 160, 153.6),
#  (0.4, 160, 192.0),
#  (0.4, 160, 230.4),
#  (0.4, 160, 268.8),
#  (0.4, 160, 307.2),
#  (0.4, 160, 345.6),
#  (0.4, 160, 384.0),
#  (0.4, 180, 0.0),
#  (0.4, 180, 38.4),
#  (0.4, 180, 76.8),
#  (0.4, 180, 115.2),
#  (0.4, 180, 153.6),
#  (0.4, 180, 192.0),
#  (0.4, 180, 230.4),
#  (0.4, 180, 268.8),
#  (0.4, 180, 307.2),
#  (0.4, 180, 345.6),
#  (0.4, 180, 384.0),
#  (0.4, 200, 0.0),
#  (0.4, 200, 38.4),
#  (0.4, 200, 76.8),
#  (0.4, 200, 115.2),
#  (0.4, 200, 153.6),
#  (0.4, 200, 192.0),
#  (0.4, 200, 230.4),
#  (0.4, 200, 268.8),
#  (0.4, 200, 307.2),
#  (0.4, 200, 345.6),
#  (0.4, 200, 384.0),
#  (0.4, 220, 0.0),
#  (0.4, 220, 38.4),
#  (0.4, 220, 76.8),
#  (0.4, 220, 115.2),
#  (0.4, 220, 153.6),
#  (0.4, 220, 192.0),
#  (0.4, 220, 230.4),
#  (0.4, 220, 268.8),
#  (0.4, 220, 307.2),
#  (0.4, 220, 345.6),
#  (0.4, 220, 384.0),
#  (0.4, 240, 0.0),
#  (0.4, 240, 38.4),
#  (0.4, 240, 76.8),
#  (0.4, 240, 115.2),
#  (0.4, 240, 153.6),
#  (0.4, 240, 192.0),
#  (0.4, 240, 230.4),
#  (0.4, 240, 268.8),
#  (0.4, 240, 307.2),
#  (0.4, 240, 345.6),
#  (0.4, 240, 384.0),
#  (0.4, 260, 0.0),
#  (0.4, 260, 38.4),
#  (0.4, 260, 76.8),
#  (0.4, 260, 115.2),
#  (0.4, 260, 153.6),
#  (0.4, 260, 192.0),
#  (0.4, 260, 230.4),
#  (0.4, 260, 268.8),
#  (0.4, 260, 307.2),
#  (0.4, 260, 345.6),
#  (0.4, 260, 384.0),
#  (0.4, 280, 0.0),
#  (0.4, 280, 38.4),
#  (0.4, 280, 76.8),
#  (0.4, 280, 115.2),
#  (0.4, 280, 153.6),
#  (0.4, 280, 192.0),
#  (0.4, 280, 230.4),
#  (0.4, 280, 268.8),
#  (0.4, 280, 307.2),
#  (0.4, 280, 345.6),
#  (0.4, 280, 384.0),
#  (0.4, 300, 0.0),
#  (0.4, 300, 38.4),
#  (0.4, 300, 76.8),
#  (0.4, 300, 115.2),
#  (0.4, 300, 153.6),
#  (0.4, 300, 192.0),
#  (0.4, 300, 230.4),
#  (0.4, 300, 268.8),
#  (0.4, 300, 307.2),
#  (0.4, 300, 345.6),
#  (0.4, 300, 384.0),
#  (0.4, 320, 0.0),
#  (0.4, 320, 38.4),
#  (0.4, 320, 76.8),
#  (0.4, 320, 115.2),
#  (0.4, 320, 153.6),
#  (0.4, 320, 192.0),
#  (0.4, 320, 230.4),
#  (0.4, 320, 268.8),
#  (0.4, 320, 307.2),
#  (0.4, 320, 345.6),
#  (0.4, 320, 384.0),
#  (0.4, 340, 0.0),
#  (0.4, 340, 38.4),
#  (0.4, 340, 76.8),
#  (0.4, 340, 115.2),
#  (0.4, 340, 153.6),
#  (0.4, 340, 192.0),
#  (0.4, 340, 230.4),
#  (0.4, 340, 268.8),
#  (0.4, 340, 307.2),
#  (0.4, 340, 345.6),
#  (0.4, 340, 384.0),
#  (0.4, 360, 0.0),
#  (0.4, 360, 38.4),
#  (0.4, 360, 76.8),
#  (0.4, 360, 115.2),
#  (0.4, 360, 153.6),
#  (0.4, 360, 192.0),
#  (0.4, 360, 230.4),
#  (0.4, 360, 268.8),
#  (0.4, 360, 307.2),
#  (0.4, 360, 345.6),
#  (0.4, 360, 384.0),
#  (0.4, 380, 0.0),
#  (0.4, 380, 38.4),
#  (0.4, 380, 76.8),
#  (0.4, 380, 115.2),
#  (0.4, 380, 153.6),
#  (0.4, 380, 192.0),
#  (0.4, 380, 230.4),
#  (0.4, 380, 268.8),
#  (0.4, 380, 307.2),
#  (0.4, 380, 345.6),
#  (0.4, 380, 384.0),
#  (0.4, 400, 0.0),
#  (0.4, 400, 38.4),
#  (0.4, 400, 76.8),
#  (0.4, 400, 115.2),
#  (0.4, 400, 153.6),
#  (0.4, 400, 192.0),
#  (0.4, 400, 230.4),
#  (0.4, 400, 268.8),
#  (0.4, 400, 307.2),
#  (0.4, 400, 345.6),
#  (0.4, 400, 384.0),
#  (0.4, 420, 0.0),
#  (0.4, 420, 38.4),
#  (0.4, 420, 76.8),
#  (0.4, 420, 115.2),
#  (0.4, 420, 153.6),
#  (0.4, 420, 192.0),
#  (0.4, 420, 230.4),
#  (0.4, 420, 268.8),
#  (0.4, 420, 307.2),
#  (0.4, 420, 345.6),
#  (0.4, 420, 384.0),
#  (0.4, 440, 0.0),
#  (0.4, 440, 38.4),
#  (0.4, 440, 76.8),
#  (0.4, 440, 115.2),
#  (0.4, 440, 153.6),
#  (0.4, 440, 192.0),
#  (0.4, 440, 230.4),
#  (0.4, 440, 268.8),
#  (0.4, 440, 307.2),
#  (0.4, 440, 345.6),
#  (0.4, 440, 384.0),
#  (0.4, 460, 0.0),
#  (0.4, 460, 38.4),
#  (0.4, 460, 76.8),
#  (0.4, 460, 115.2),
#  (0.4, 460, 153.6),
#  (0.4, 460, 192.0),
#  (0.4, 460, 230.4),
#  (0.4, 460, 268.8),
#  (0.4, 460, 307.2),
#  (0.4, 460, 345.6),
#  (0.4, 460, 384.0),
#  (0.4, 480, 0.0),
#  (0.4, 480, 38.4),
#  (0.4, 480, 76.8),
#  (0.4, 480, 115.2),
#  (0.4, 480, 153.6),
#  (0.4, 480, 192.0),
#  (0.4, 480, 230.4),
#  (0.4, 480, 268.8),
#  (0.4, 480, 307.2),
#  (0.4, 480, 345.6),
#  (0.4, 480, 384.0),
#  (0.4, 500, 0.0),
#  (0.4, 500, 38.4),
#  (0.4, 500, 76.8),
#  (0.4, 500, 115.2),
#  (0.4, 500, 153.6),
#  (0.4, 500, 192.0),
#  (0.4, 500, 230.4),
#  (0.4, 500, 268.8),
#  (0.4, 500, 307.2),
#  (0.4, 500, 345.6),
#  (0.4, 500, 384.0),
#  (0.4, 520, 0.0),
#  (0.4, 520, 38.4),
#  (0.4, 520, 76.8),
#  (0.4, 520, 115.2),
#  (0.4, 520, 153.6),
#  (0.4, 520, 192.0),
#  (0.4, 520, 230.4),
#  (0.4, 520, 268.8),
#  (0.4, 520, 307.2),
#  (0.4, 520, 345.6),
#  (0.4, 520, 384.0),
#  (0.4, 540, 0.0),
#  (0.4, 540, 38.4),
#  (0.4, 540, 76.8),
#  (0.4, 540, 115.2),
#  (0.4, 540, 153.6),
#  (0.4, 540, 192.0),
#  (0.4, 540, 230.4),
#  (0.4, 540, 268.8),
#  (0.4, 540, 307.2),
#  (0.4, 540, 345.6),
#  (0.4, 540, 384.0),
#  (0.4, 560, 0.0),
#  (0.4, 560, 38.4),
#  (0.4, 560, 76.8),
#  (0.4, 560, 115.2),
#  (0.4, 560, 153.6),
#  (0.4, 560, 192.0),
#  (0.4, 560, 230.4),
#  (0.4, 560, 268.8),
#  (0.4, 560, 307.2),
#  (0.4, 560, 345.6),
#  (0.4, 560, 384.0),
#  (0.4, 580, 0.0),
#  (0.4, 580, 38.4),
#  (0.4, 580, 76.8),
#  (0.4, 580, 115.2),
#  (0.4, 580, 153.6),
#  (0.4, 580, 192.0),
#  (0.4, 580, 230.4),
#  (0.4, 580, 268.8),
#  (0.4, 580, 307.2),
#  (0.4, 580, 345.6),
#  (0.4, 580, 384.0),
#  (0.4, 600, 0.0),
#  (0.4, 600, 38.4),
#  (0.4, 600, 76.8),
#  (0.4, 600, 115.2),
#  (0.4, 600, 153.6),
#  (0.4, 600, 192.0),
#  (0.4, 600, 230.4),
#  (0.4, 600, 268.8),
#  (0.4, 600, 307.2),
#  (0.4, 600, 345.6),
#  (0.4, 600, 384.0),
#  (0.4, 620, 0.0),
#  (0.4, 620, 38.4),
#  (0.4, 620, 76.8),
#  (0.4, 620, 115.2),
#  (0.4, 620, 153.6),
#  (0.4, 620, 192.0),
#  (0.4, 620, 230.4),
#  (0.4, 620, 268.8),
#  (0.4, 620, 307.2),
#  (0.4, 620, 345.6),
#  (0.4, 620, 384.0),
#  (0.4, 640, 0.0),
#  (0.4, 640, 38.4),
#  (0.4, 640, 76.8),
#  (0.4, 640, 115.2),
#  (0.4, 640, 153.6),
#  (0.4, 640, 192.0),
#  (0.4, 640, 230.4),
#  (0.4, 640, 268.8),
#  (0.4, 640, 307.2),
#  (0.4, 640, 345.6),
#  (0.4, 640, 384.0),
#  (0.4, 660, 0.0),
#  (0.4, 660, 38.4),
#  (0.4, 660, 76.8),
#  (0.4, 660, 115.2),
#  (0.4, 660, 153.6),
#  (0.4, 660, 192.0),
#  (0.4, 660, 230.4),
#  (0.4, 660, 268.8),
#  (0.4, 660, 307.2),
#  (0.4, 660, 345.6),
#  (0.4, 660, 384.0),
#  (0.4, 680, 0.0),
#  (0.4, 680, 38.4),
#  (0.4, 680, 76.8),
#  (0.4, 680, 115.2),
#  (0.4, 680, 153.6),
#  (0.4, 680, 192.0),
#  (0.4, 680, 230.4),
#  (0.4, 680, 268.8),
#  (0.4, 680, 307.2),
#  (0.4, 680, 345.6),
#  (0.4, 680, 384.0),
#  (0.4, 700, 0.0),
#  (0.4, 700, 38.4),
#  (0.4, 700, 76.8),
#  (0.4, 700, 115.2),
#  (0.4, 700, 153.6),
#  (0.4, 700, 192.0),
#  (0.4, 700, 230.4),
#  (0.4, 700, 268.8),
#  (0.4, 700, 307.2),
#  (0.4, 700, 345.6),
#  (0.4, 700, 384.0),
#  (0.6, 0, 0.0),
#  (0.6, 0, 38.4),
#  (0.6, 0, 76.8),
#  (0.6, 0, 115.2),
#  (0.6, 0, 153.6),
#  (0.6, 0, 192.0),
#  (0.6, 0, 230.4),
#  (0.6, 0, 268.8),
#  (0.6, 0, 307.2),
#  (0.6, 0, 345.6),
#  (0.6, 0, 384.0),
#  (0.6, 20, 0.0),
#  (0.6, 20, 38.4),
#  (0.6, 20, 76.8),
#  (0.6, 20, 115.2),
#  (0.6, 20, 153.6),
#  (0.6, 20, 192.0),
#  (0.6, 20, 230.4),
#  (0.6, 20, 268.8),
#  (0.6, 20, 307.2),
#  (0.6, 20, 345.6),
#  (0.6, 20, 384.0),
#  (0.6, 40, 0.0),
#  (0.6, 40, 38.4),
#  (0.6, 40, 76.8),
#  (0.6, 40, 115.2),
#  (0.6, 40, 153.6),
#  (0.6, 40, 192.0),
#  (0.6, 40, 230.4),
#  (0.6, 40, 268.8),
#  (0.6, 40, 307.2),
#  (0.6, 40, 345.6),
#  (0.6, 40, 384.0),
#  (0.6, 60, 0.0),
#  (0.6, 60, 38.4),
#  (0.6, 60, 76.8),
#  (0.6, 60, 115.2),
#  (0.6, 60, 153.6),
#  (0.6, 60, 192.0),
#  (0.6, 60, 230.4),
#  (0.6, 60, 268.8),
#  (0.6, 60, 307.2),
#  (0.6, 60, 345.6),
#  (0.6, 60, 384.0),
#  (0.6, 80, 0.0),
#  (0.6, 80, 38.4),
#  (0.6, 80, 76.8),
#  (0.6, 80, 115.2),
#  (0.6, 80, 153.6),
#  (0.6, 80, 192.0),
#  (0.6, 80, 230.4),
#  (0.6, 80, 268.8),
#  (0.6, 80, 307.2),
#  (0.6, 80, 345.6),
#  (0.6, 80, 384.0),
#  (0.6, 100, 0.0),
#  (0.6, 100, 38.4),
#  (0.6, 100, 76.8),
#  (0.6, 100, 115.2),
#  (0.6, 100, 153.6),
#  (0.6, 100, 192.0),
#  (0.6, 100, 230.4),
#  (0.6, 100, 268.8),
#  (0.6, 100, 307.2),
#  (0.6, 100, 345.6),
#  (0.6, 100, 384.0),
#  (0.6, 120, 0.0),
#  (0.6, 120, 38.4),
#  (0.6, 120, 76.8),
#  (0.6, 120, 115.2),
#  (0.6, 120, 153.6),
#  (0.6, 120, 192.0),
#  (0.6, 120, 230.4),
#  (0.6, 120, 268.8),
#  (0.6, 120, 307.2),
#  (0.6, 120, 345.6),
#  (0.6, 120, 384.0),
#  (0.6, 140, 0.0),
#  (0.6, 140, 38.4),
#  (0.6, 140, 76.8),
#  (0.6, 140, 115.2),
#  (0.6, 140, 153.6),
#  (0.6, 140, 192.0),
#  (0.6, 140, 230.4),
#  (0.6, 140, 268.8),
#  (0.6, 140, 307.2),
#  (0.6, 140, 345.6),
#  (0.6, 140, 384.0),
#  (0.6, 160, 0.0),
#  (0.6, 160, 38.4),
#  (0.6, 160, 76.8),
#  (0.6, 160, 115.2),
#  (0.6, 160, 153.6),
#  (0.6, 160, 192.0),
#  (0.6, 160, 230.4),
#  (0.6, 160, 268.8),
#  (0.6, 160, 307.2),
#  (0.6, 160, 345.6),
#  (0.6, 160, 384.0),
#  (0.6, 180, 0.0),
#  (0.6, 180, 38.4),
#  (0.6, 180, 76.8),
#  (0.6, 180, 115.2),
#  (0.6, 180, 153.6),
#  (0.6, 180, 192.0),
#  (0.6, 180, 230.4),
#  (0.6, 180, 268.8),
#  (0.6, 180, 307.2),
#  (0.6, 180, 345.6),
#  (0.6, 180, 384.0),
#  (0.6, 200, 0.0),
#  (0.6, 200, 38.4),
#  (0.6, 200, 76.8),
#  (0.6, 200, 115.2),
#  (0.6, 200, 153.6),
#  (0.6, 200, 192.0),
#  (0.6, 200, 230.4),
#  (0.6, 200, 268.8),
#  (0.6, 200, 307.2),
#  (0.6, 200, 345.6),
#  (0.6, 200, 384.0),
#  (0.6, 220, 0.0),
#  (0.6, 220, 38.4),
#  (0.6, 220, 76.8),
#  (0.6, 220, 115.2),
#  (0.6, 220, 153.6),
#  (0.6, 220, 192.0),
#  (0.6, 220, 230.4),
#  (0.6, 220, 268.8),
#  (0.6, 220, 307.2),
#  (0.6, 220, 345.6),
#  (0.6, 220, 384.0),
#  (0.6, 240, 0.0),
#  (0.6, 240, 38.4),
#  (0.6, 240, 76.8),
#  (0.6, 240, 115.2),
#  (0.6, 240, 153.6),
#  (0.6, 240, 192.0),
#  (0.6, 240, 230.4),
#  (0.6, 240, 268.8),
#  (0.6, 240, 307.2),
#  (0.6, 240, 345.6),
#  (0.6, 240, 384.0),
#  (0.6, 260, 0.0),
#  (0.6, 260, 38.4),
#  (0.6, 260, 76.8),
#  (0.6, 260, 115.2),
#  (0.6, 260, 153.6),
#  (0.6, 260, 192.0),
#  (0.6, 260, 230.4),
#  (0.6, 260, 268.8),
#  (0.6, 260, 307.2),
#  (0.6, 260, 345.6),
#  (0.6, 260, 384.0),
#  (0.6, 280, 0.0),
#  (0.6, 280, 38.4),
#  (0.6, 280, 76.8),
#  (0.6, 280, 115.2),
#  (0.6, 280, 153.6),
#  (0.6, 280, 192.0),
#  (0.6, 280, 230.4),
#  (0.6, 280, 268.8),
#  (0.6, 280, 307.2),
#  (0.6, 280, 345.6),
#  (0.6, 280, 384.0),
#  (0.6, 300, 0.0),
#  (0.6, 300, 38.4),
#  (0.6, 300, 76.8),
#  (0.6, 300, 115.2),
#  (0.6, 300, 153.6),
#  (0.6, 300, 192.0),
#  (0.6, 300, 230.4),
#  (0.6, 300, 268.8),
#  (0.6, 300, 307.2),
#  (0.6, 300, 345.6),
#  (0.6, 300, 384.0),
#  (0.6, 320, 0.0),
#  (0.6, 320, 38.4),
#  (0.6, 320, 76.8),
#  (0.6, 320, 115.2),
#  (0.6, 320, 153.6),
#  (0.6, 320, 192.0),
#  (0.6, 320, 230.4),
#  (0.6, 320, 268.8),
#  (0.6, 320, 307.2),
#  (0.6, 320, 345.6),
#  (0.6, 320, 384.0),
#  (0.6, 340, 0.0),
#  (0.6, 340, 38.4),
#  (0.6, 340, 76.8),
#  (0.6, 340, 115.2),
#  (0.6, 340, 153.6),
#  (0.6, 340, 192.0),
#  (0.6, 340, 230.4),
#  (0.6, 340, 268.8),
#  (0.6, 340, 307.2),
#  (0.6, 340, 345.6),
#  (0.6, 340, 384.0),
#  (0.6, 360, 0.0),
#  (0.6, 360, 38.4),
#  (0.6, 360, 76.8),
#  (0.6, 360, 115.2),
#  (0.6, 360, 153.6),
#  (0.6, 360, 192.0),
#  (0.6, 360, 230.4),
#  (0.6, 360, 268.8),
#  (0.6, 360, 307.2),
#  (0.6, 360, 345.6),
#  ...]

# %%
# COMPUTING VALUE FUNCTION USING DYNAMIC PROGRAMMING
def policy_evaluation(policy, value_table, discount_factor, error_threshold=0.01, num_states=Number_of_discrete_states):
    print()
    new_value_table = value_table # init new value table to be filled in and returned
    converged = False # initially we have not found a converged value function for this policy
    k = 0 # sweep index
    while not converged: # until the value function converges
        print('sweep ', k)
        k += 1 # increment sweep counter
        worst_delta = 0 # difference between previous values and iterated values
        for state in keys_to_be_iterated: # loop over each state
            action = policy[state] # get the action according to current policy
            new_state, reward = transition(state, action) # use model to simulate next state and reward
         #check for errors if the state entry has not been created in value table
            new_val = reward + discount_factor * value_table[new_state] # compute new value
#             except:
#                 new_value_table[new_state] = 0 #when the above fails, new state is TERMINAL state, hence has value of 0
#                 new_val = reward #if error occurs, the new value will take just reward, with value of unexplored state being zero
#             print(new_val)
#             print(value_table[state])
            new_value_table[state] = new_val # update value table
            delta = abs(new_val - value_table[state]) # find the absolute diff between new val and old val for this state
#             print('delta:', delta)
            if delta > worst_delta: # is this state the one for which our value table is most wrong?
                worst_delta = delta # update worst error for this sweep
                print('worst_delta:', worst_delta)
        if worst_delta < error_threshold: # once the values stop changing
            converged = True # we have found the value function
            print('Converged on value function')
        value_table = new_value_table # update value table (took me ages to realise i was missing this line and debug )
    return value_table # return converged value table evaluated for this policy

# %%
# discount_factor = 0.9
# new_value_table = policy_evaluation(policy, value_table, discount_factor, error_threshold=0.01, num_states=Number_of_discrete_states)
# new_value_table

# %%
def policy_improvement(value_table, discount_factor): # set a greedy policy which will always be better than the previous
    new_policy = {} # initialise empty new policy to be filled and returned
    action_space = range(15) #  
    for state in keys_to_be_iterated: # loop over each state
        best_value = -float('inf') # initialise best value as negative infinity
        best_action = None # no best action found yet
        if (state[0] == 0.2) or (state[0] == 0.4):
            for action in range(2,15): # don't consider small additions of N
                try:
                    new_state, reward = transition(state, action) # use model to simulate next state and reward
                    value = reward + discount_factor * value_table[new_state] # update value of state
                except:
                    value = 0 #assign zero value to new states
                if value > best_value: # checking all actions, which gives this state the best value?
                    best_value = value # update best value
                    best_action = action # update best action found so far
        else:
            for action in action_space: # set the policy as greedy with respect to the value function
                try:
                    new_state, reward = transition(state, action) # use model to simulate next state and reward
                    value = reward + discount_factor * value_table[new_state] # update value of state
                except:
                    value = 0 #assign zero value to new states
                if value > best_value: # checking all actions, which gives this state the best value?
                    best_value = value # update best value
                    best_action = action # update best action found so far
        new_policy[state] = best_action # update new policy to take best action found when it sees this state
    return new_policy

# %%
def check_stable_policy(old_policy, new_policy):
    stable = True
    for state in keys_to_be_iterated:
        old_action = old_policy[state]
        new_action = new_policy[state]
        if new_action != old_action:
            stable = False
    return stable

# %%
# POLICY ITERATION ALGORITHM
def policy_iteration(discount_factor=0.9):
    value_table = initialise_value_table()
#     policy = initialise_policy()
    policy = initialise_deterministic_policy()
    policy_stable = False
    policy_idx = 0
    policy_library = []
    while not policy_stable: # until convergence
        
        # POLICY ITERATION
        print('Evaluating policy ', policy_idx)
        value_table = policy_evaluation(policy, value_table, discount_factor) # converge on value function
        
        # POLICY IMPROVEMENT
        print('Iterating policy ', policy_idx)
        new_policy = policy_improvement(value_table, discount_factor) # get greedy policy using converged value function
        
        # CHECK CONVERGENCE
        if check_stable_policy(policy, new_policy): # compare policies
            policy_stable = True # when they have the same greedy action for each state in the state space
            print('Policy now stable - optimal policy found')
            
        policy = new_policy # update policy
        
        policy_idx += 1
        
        policy_library += [policy]
        
        if policy_idx >= 200:
            break
    print('Optimal policy:', policy)
    return policy, policy_library
        
optimal_policy, policy_library = policy_iteration()
# Out:
# Evaluating policy  0
#
# sweep  0
# Converged on value function
# Iterating policy  0
# Evaluating policy  1
#
# sweep  0
# Converged on value function
# Iterating policy  1
# Evaluating policy  2
#
# sweep  0
# Converged on value function
# Iterating policy  2
# Evaluating policy  3
#
# sweep  0
# Converged on value function
# Iterating policy  3
# Evaluating policy  4
#
# sweep  0
# Converged on value function
# Iterating policy  4
# Evaluating policy  5
#
# sweep  0
# Converged on value function
# Iterating policy  5
# Evaluating policy  6
#
# sweep  0
# Converged on value function
# Iterating policy  6
# Evaluating policy  7
#
# sweep  0
# Converged on value function
# Iterating policy  7
# Evaluating policy  8
#
# sweep  0
# Converged on value function
# Iterating policy  8
# Evaluating policy  9
#
# sweep  0
# Converged on value function
# Iterating policy  9
# Evaluating policy  10
#
# sweep  0
# Converged on value function
# Iterating policy  10
# Evaluating policy  11
#
# sweep  0
# Converged on value function
# Iterating policy  11
# Evaluating policy  12
#
# sweep  0
# Converged on value function
# Iterating policy  12
# Evaluating policy  13
#
# sweep  0
# Converged on value function
# Iterating policy  13
# Evaluating policy  14
#
# sweep  0
# Converged on value function
# Iterating policy  14
# Evaluating policy  15
#
# sweep  0
# Converged on value function
# Iterating policy  15
# Evaluating policy  16
#
# sweep  0
# Converged on value function
# Iterating policy  16
# Evaluating policy  17
#
# sweep  0
# Converged on value function
# Iterating policy  17
# Evaluating policy  18
#
# sweep  0
# Converged on value function
# Iterating policy  18
# Evaluating policy  19
#
# sweep  0
# Converged on value function
# Iterating policy  19
# Evaluating policy  20
#
# sweep  0
# Converged on value function
# Iterating policy  20
# Evaluating policy  21
#
# sweep  0
# Converged on value function
# Iterating policy  21
# Evaluating policy  22
#
# sweep  0
# Converged on value function
# Iterating policy  22
# Evaluating policy  23
#
# sweep  0
# Converged on value function
# Iterating policy  23
# Evaluating policy  24
#
# sweep  0
# Converged on value function
# Iterating policy  24
# Evaluating policy  25
#
# sweep  0
# Converged on value function
# Iterating policy  25
# Evaluating policy  26
#
# sweep  0
# Converged on value function
# Iterating policy  26
# Evaluating policy  27
#
# sweep  0
# Converged on value function
# Iterating policy  27
# Evaluating policy  28
#
# sweep  0
# Converged on value function
# Iterating policy  28
# Evaluating policy  29
#
# sweep  0
# Converged on value function
# Iterating policy  29
# Evaluating policy  30
#
# sweep  0
# Converged on value function
# Iterating policy  30
# Evaluating policy  31
#
# sweep  0
# Converged on value function
# Iterating policy  31
# Evaluating policy  32
#
# sweep  0
# Converged on value function
# Iterating policy  32
# Evaluating policy  33
#
# sweep  0
# Converged on value function
# Iterating policy  33
# Evaluating policy  34
#
# sweep  0
# Converged on value function
# Iterating policy  34
# Evaluating policy  35
#
# sweep  0
# Converged on value function
# Iterating policy  35
# Evaluating policy  36
#
# sweep  0
# Converged on value function
# Iterating policy  36
# Evaluating policy  37
#
# sweep  0
# Converged on value function
# Iterating policy  37
# Evaluating policy  38
#
# sweep  0
# Converged on value function
# Iterating policy  38
# Evaluating policy  39
#
# sweep  0
# Converged on value function
# Iterating policy  39
# Evaluating policy  40
#
# sweep  0
# Converged on value function
# Iterating policy  40
# Evaluating policy  41
#
# sweep  0
# Converged on value function
# Iterating policy  41
# Evaluating policy  42
#
# sweep  0
# Converged on value function
# Iterating policy  42
# Evaluating policy  43
#
# sweep  0
# Converged on value function
# Iterating policy  43
# Evaluating policy  44
#
# sweep  0
# Converged on value function
# Iterating policy  44
# Evaluating policy  45
#
# sweep  0
# Converged on value function
# Iterating policy  45
# Evaluating policy  46
#
# sweep  0
# Converged on value function
# Iterating policy  46
# Evaluating policy  47
#
# sweep  0
# Converged on value function
# Iterating policy  47
# Evaluating policy  48
#
# sweep  0
# Converged on value function
# Iterating policy  48
# Evaluating policy  49
#
# sweep  0
# Converged on value function
# Iterating policy  49
# Evaluating policy  50
#
# sweep  0
# Converged on value function
# Iterating policy  50
# Evaluating policy  51
#
# sweep  0
# Converged on value function
# Iterating policy  51
# Evaluating policy  52
#
# sweep  0
# Converged on value function
# Iterating policy  52
# Evaluating policy  53
#
# sweep  0
# Converged on value function
# Iterating policy  53
# Evaluating policy  54
#
# sweep  0
# Converged on value function
# Iterating policy  54
# Evaluating policy  55
#
# sweep  0
# Converged on value function
# Iterating policy  55
# Evaluating policy  56
#
# sweep  0
# Converged on value function
# Iterating policy  56
# Evaluating policy  57
#
# sweep  0
# Converged on value function
# Iterating policy  57
# Evaluating policy  58
#
# sweep  0
# Converged on value function
# Iterating policy  58
# Evaluating policy  59
#
# sweep  0
# Converged on value function
# Iterating policy  59
# Evaluating policy  60
#
# sweep  0
# Converged on value function
# Iterating policy  60
# Evaluating policy  61
#
# sweep  0
# Converged on value function
# Iterating policy  61
# Evaluating policy  62
#
# sweep  0
# Converged on value function
# Iterating policy  62
# Evaluating policy  63
#
# sweep  0
# Converged on value function
# Iterating policy  63
# Evaluating policy  64
#
# sweep  0
# Converged on value function
# Iterating policy  64
# Evaluating policy  65
#
# sweep  0
# Converged on value function
# Iterating policy  65
# Evaluating policy  66
#
# sweep  0
# Converged on value function
# Iterating policy  66
# Evaluating policy  67
#
# sweep  0
# Converged on value function
# Iterating policy  67
# Evaluating policy  68
#
# sweep  0
# Converged on value function
# Iterating policy  68
# Evaluating policy  69
#
# sweep  0
# Converged on value function
# Iterating policy  69
# Evaluating policy  70
#
# sweep  0
# Converged on value function
# Iterating policy  70
# Evaluating policy  71
#
# sweep  0
# Converged on value function
# Iterating policy  71
# Evaluating policy  72
#
# sweep  0
# Converged on value function
# Iterating policy  72
# Evaluating policy  73
#
# sweep  0
# Converged on value function
# Iterating policy  73
# Evaluating policy  74
#
# sweep  0
# Converged on value function
# Iterating policy  74
# Evaluating policy  75
#
# sweep  0
# Converged on value function
# Iterating policy  75
# Evaluating policy  76
#
# sweep  0
# Converged on value function
# Iterating policy  76
# Evaluating policy  77
#
# sweep  0
# Converged on value function
# Iterating policy  77
# Evaluating policy  78
#
# sweep  0
# Converged on value function
# Iterating policy  78
# Evaluating policy  79
#
# sweep  0
# Converged on value function
# Iterating policy  79
# Evaluating policy  80
#
# sweep  0
# Converged on value function
# Iterating policy  80
# Evaluating policy  81
#
# sweep  0
# Converged on value function
# Iterating policy  81
# Evaluating policy  82
#
# sweep  0
# Converged on value function
# Iterating policy  82
# Evaluating policy  83
#
# sweep  0
# Converged on value function
# Iterating policy  83
# Evaluating policy  84
#
# sweep  0
# Converged on value function
# Iterating policy  84
# Evaluating policy  85
#
# sweep  0
# Converged on value function
# Iterating policy  85
# Evaluating policy  86
#
# sweep  0
# Converged on value function
# Iterating policy  86
# Evaluating policy  87
#
# sweep  0
# Converged on value function
# Iterating policy  87
# Evaluating policy  88
#
# sweep  0
# Converged on value function
# Iterating policy  88
# Evaluating policy  89
#
# sweep  0
# Converged on value function
# Iterating policy  89
# Evaluating policy  90
#
# sweep  0
# Converged on value function
# Iterating policy  90
# Evaluating policy  91
#
# sweep  0
# Converged on value function
# Iterating policy  91
# Evaluating policy  92
#
# sweep  0
# Converged on value function
# Iterating policy  92
# Evaluating policy  93
#
# sweep  0
# Converged on value function
# Iterating policy  93
# Evaluating policy  94
#
# sweep  0
# Converged on value function
# Iterating policy  94
# Evaluating policy  95
#
# sweep  0
# Converged on value function
# Iterating policy  95
# Evaluating policy  96
#
# sweep  0
# Converged on value function
# Iterating policy  96
# Evaluating policy  97
#
# sweep  0
# Converged on value function
# Iterating policy  97
# Evaluating policy  98
#
# sweep  0
# Converged on value function
# Iterating policy  98
# Evaluating policy  99
#
# sweep  0
# Converged on value function
# Iterating policy  99
# Evaluating policy  100
#
# sweep  0
# Converged on value function
# Iterating policy  100
# Evaluating policy  101
#
# sweep  0
# Converged on value function
# Iterating policy  101
# Evaluating policy  102
#
# sweep  0
# Converged on value function
# Iterating policy  102
# Evaluating policy  103
#
# sweep  0
# Converged on value function
# Iterating policy  103
# Evaluating policy  104
#
# sweep  0
# Converged on value function
# Iterating policy  104
# Evaluating policy  105
#
# sweep  0
# Converged on value function
# Iterating policy  105
# Evaluating policy  106
#
# sweep  0
# Converged on value function
# Iterating policy  106
# Evaluating policy  107
#
# sweep  0
# Converged on value function
# Iterating policy  107
# Evaluating policy  108
#
# sweep  0
# Converged on value function
# Iterating policy  108
# Evaluating policy  109
#
# sweep  0
# Converged on value function
# Iterating policy  109
# Evaluating policy  110
#
# sweep  0
# Converged on value function
# Iterating policy  110
# Evaluating policy  111
#
# sweep  0
# Converged on value function
# Iterating policy  111
# Evaluating policy  112
#
# sweep  0
# Converged on value function
# Iterating policy  112
# Evaluating policy  113
#
# sweep  0
# Converged on value function
# Iterating policy  113
# Evaluating policy  114
#
# sweep  0
# Converged on value function
# Iterating policy  114
# Evaluating policy  115
#
# sweep  0
# Converged on value function
# Iterating policy  115
# Evaluating policy  116
#
# sweep  0
# Converged on value function
# Iterating policy  116
# Evaluating policy  117
#
# sweep  0
# Converged on value function
# Iterating policy  117
# Evaluating policy  118
#
# sweep  0
# Converged on value function
# Iterating policy  118
# Evaluating policy  119
#
# sweep  0
# Converged on value function
# Iterating policy  119
# Evaluating policy  120
#
# sweep  0
# Converged on value function
# Iterating policy  120
# Evaluating policy  121
#
# sweep  0
# Converged on value function
# Iterating policy  121
# Evaluating policy  122
#
# sweep  0
# Converged on value function
# Iterating policy  122
# Evaluating policy  123
#
# sweep  0
# Converged on value function
# Iterating policy  123
# Evaluating policy  124
#
# sweep  0
# Converged on value function
# Iterating policy  124
# Evaluating policy  125
#
# sweep  0
# Converged on value function
# Iterating policy  125
# Evaluating policy  126
#
# sweep  0
# Converged on value function
# Iterating policy  126
# Evaluating policy  127
#
# sweep  0
# Converged on value function
# Iterating policy  127
# Evaluating policy  128
#
# sweep  0
# Converged on value function
# Iterating policy  128
# Evaluating policy  129
#
# sweep  0
# Converged on value function
# Iterating policy  129
# Evaluating policy  130
#
# sweep  0
# Converged on value function
# Iterating policy  130
# Evaluating policy  131
#
# sweep  0
# Converged on value function
# Iterating policy  131
# Evaluating policy  132
#
# sweep  0
# Converged on value function
# Iterating policy  132
# Evaluating policy  133
#
# sweep  0
# Converged on value function
# Iterating policy  133
# Evaluating policy  134
#
# sweep  0
# Converged on value function
# Iterating policy  134
# Evaluating policy  135
#
# sweep  0
# Converged on value function
# Iterating policy  135
# Evaluating policy  136
#
# sweep  0
# Converged on value function
# Iterating policy  136
# Evaluating policy  137
#
# sweep  0
# Converged on value function
# Iterating policy  137
# Evaluating policy  138
#
# sweep  0
# Converged on value function
# Iterating policy  138
# Evaluating policy  139
#
# sweep  0
# Converged on value function
# Iterating policy  139
# Evaluating policy  140
#
# sweep  0
# Converged on value function
# Iterating policy  140
# Evaluating policy  141
#
# sweep  0
# Converged on value function
# Iterating policy  141
# Evaluating policy  142
#
# sweep  0
# Converged on value function
# Iterating policy  142
# Evaluating policy  143
#
# sweep  0
# Converged on value function
# Iterating policy  143
# Evaluating policy  144
#
# sweep  0
# Converged on value function
# Iterating policy  144
# Evaluating policy  145
#
# sweep  0
# Converged on value function
# Iterating policy  145
# Evaluating policy  146
#
# sweep  0
# Converged on value function
# Iterating policy  146
# Evaluating policy  147
#
# sweep  0
# Converged on value function
# Iterating policy  147
# Evaluating policy  148
#
# sweep  0
# Converged on value function
# Iterating policy  148
# Evaluating policy  149
#
# sweep  0
# Converged on value function
# Iterating policy  149
# Evaluating policy  150
#
# sweep  0
# Converged on value function
# Iterating policy  150
# Evaluating policy  151
#
# sweep  0
# Converged on value function
# Iterating policy  151
# Evaluating policy  152
#
# sweep  0
# Converged on value function
# Iterating policy  152
# Evaluating policy  153
#
# sweep  0
# Converged on value function
# Iterating policy  153
# Evaluating policy  154
#
# sweep  0
# Converged on value function
# Iterating policy  154
# Evaluating policy  155
#
# sweep  0
# Converged on value function
# Iterating policy  155
# Evaluating policy  156
#
# sweep  0
# Converged on value function
# Iterating policy  156
# Evaluating policy  157
#
# sweep  0
# Converged on value function
# Iterating policy  157
# Evaluating policy  158
#
# sweep  0
# Converged on value function
# Iterating policy  158
# Evaluating policy  159
#
# sweep  0
# Converged on value function
# Iterating policy  159
# Evaluating policy  160
#
# sweep  0
# Converged on value function
# Iterating policy  160
# Evaluating policy  161
#
# sweep  0
# Converged on value function
# Iterating policy  161
# Evaluating policy  162
#
# sweep  0
# Converged on value function
# Iterating policy  162
# Evaluating policy  163
#
# sweep  0
# Converged on value function
# Iterating policy  163
# Evaluating policy  164
#
# sweep  0
# Converged on value function
# Iterating policy  164
# Evaluating policy  165
#
# sweep  0
# Converged on value function
# Iterating policy  165
# Evaluating policy  166
#
# sweep  0
# Converged on value function
# Iterating policy  166
# Evaluating policy  167
#
# sweep  0
# Converged on value function
# Iterating policy  167
# Evaluating policy  168
#
# sweep  0
# Converged on value function
# Iterating policy  168
# Evaluating policy  169
#
# sweep  0
# Converged on value function
# Iterating policy  169
# Evaluating policy  170
#
# sweep  0
# Converged on value function
# Iterating policy  170
# Evaluating policy  171
#
# sweep  0
# Converged on value function
# Iterating policy  171
# Evaluating policy  172
#
# sweep  0
# Converged on value function
# Iterating policy  172
# Evaluating policy  173
#
# sweep  0
# Converged on value function
# Iterating policy  173
# Evaluating policy  174
#
# sweep  0
# Converged on value function
# Iterating policy  174
# Evaluating policy  175
#
# sweep  0
# Converged on value function
# Iterating policy  175
# Evaluating policy  176
#
# sweep  0
# Converged on value function
# Iterating policy  176
# Evaluating policy  177
#
# sweep  0
# Converged on value function
# Iterating policy  177
# Evaluating policy  178
#
# sweep  0
# Converged on value function
# Iterating policy  178
# Evaluating policy  179
#
# sweep  0
# Converged on value function
# Iterating policy  179
# Evaluating policy  180
#
# sweep  0
# Converged on value function
# Iterating policy  180
# Evaluating policy  181
#
# sweep  0
# Converged on value function
# Iterating policy  181
# Evaluating policy  182
#
# sweep  0
# Converged on value function
# Iterating policy  182
# Evaluating policy  183
#
# sweep  0
# Converged on value function
# Iterating policy  183
# Evaluating policy  184
#
# sweep  0
# Converged on value function
# Iterating policy  184
# Evaluating policy  185
#
# sweep  0
# Converged on value function
# Iterating policy  185
# Evaluating policy  186
#
# sweep  0
# Converged on value function
# Iterating policy  186
# Evaluating policy  187
#
# sweep  0
# Converged on value function
# Iterating policy  187
# Evaluating policy  188
#
# sweep  0
# Converged on value function
# Iterating policy  188
# Evaluating policy  189
#
# sweep  0
# Converged on value function
# Iterating policy  189
# Evaluating policy  190
#
# sweep  0
# Converged on value function
# Iterating policy  190
# Evaluating policy  191
#
# sweep  0
# Converged on value function
# Iterating policy  191
# Evaluating policy  192
#
# sweep  0
# Converged on value function
# Iterating policy  192
# Evaluating policy  193
#
# sweep  0
# Converged on value function
# Iterating policy  193
# Evaluating policy  194
#
# sweep  0
# Converged on value function
# Iterating policy  194
# Evaluating policy  195
#
# sweep  0
# Converged on value function
# Iterating policy  195
# Evaluating policy  196
#
# sweep  0
# Converged on value function
# Iterating policy  196
# Evaluating policy  197
#
# sweep  0
# Converged on value function
# Iterating policy  197
# Evaluating policy  198
#
# sweep  0
# Converged on value function
# Iterating policy  198
# Evaluating policy  199
#
# sweep  0
# Converged on value function
# Iterating policy  199
# Optimal policy: {(0.2, 0, 0.0): 2, (0.2, 0, 38.4): 2, (0.2, 0, 76.8): 12, (0.2, 0, 115.2): 4, (0.2, 0, 153.6): 2, (0.2, 0, 192.0): 14, (0.2, 0, 230.4): 2, (0.2, 0, 268.8): 12, (0.2, 0, 307.2): 3, (0.2, 0, 345.6): 2, (0.2, 0, 384.0): 2, (0.2, 20, 0.0): 2, (0.2, 20, 38.4): 5, (0.2, 20, 76.8): 7, (0.2, 20, 115.2): 3, (0.2, 20, 153.6): 2, (0.2, 20, 192.0): 9, (0.2, 20, 230.4): 7, (0.2, 20, 268.8): 14, (0.2, 20, 307.2): 2, (0.2, 20, 345.6): 2, (0.2, 20, 384.0): 2, (0.2, 40, 0.0): 2, (0.2, 40, 38.4): 7, (0.2, 40, 76.8): 6, (0.2, 40, 115.2): 3, (0.2, 40, 153.6): 5, (0.2, 40, 192.0): 8, (0.2, 40, 230.4): 7, (0.2, 40, 268.8): 13, (0.2, 40, 307.2): 2, (0.2, 40, 345.6): 2, (0.2, 40, 384.0): 2, (0.2, 60, 0.0): 2, (0.2, 60, 38.4): 3, (0.2, 60, 76.8): 9, (0.2, 60, 115.2): 2, (0.2, 60, 153.6): 8, (0.2, 60, 192.0): 7, (0.2, 60, 230.4): 6, (0.2, 60, 268.8): 12, (0.2, 60, 307.2): 2, (0.2, 60, 345.6): 2, (0.2, 60, 384.0): 2, (0.2, 80, 0.0): 4, (0.2, 80, 38.4): 3, (0.2, 80, 76.8): 4, (0.2, 80, 115.2): 2, (0.2, 80, 153.6): 4, (0.2, 80, 192.0): 6, (0.2, 80, 230.4): 8, (0.2, 80, 268.8): 8, (0.2, 80, 307.2): 2, (0.2, 80, 345.6): 2, (0.2, 80, 384.0): 2, (0.2, 100, 0.0): 3, (0.2, 100, 38.4): 2, (0.2, 100, 76.8): 2, (0.2, 100, 115.2): 2, (0.2, 100, 153.6): 2, (0.2, 100, 192.0): 6, (0.2, 100, 230.4): 4, (0.2, 100, 268.8): 10, (0.2, 100, 307.2): 5, (0.2, 100, 345.6): 2, (0.2, 100, 384.0): 2, (0.2, 120, 0.0): 2, (0.2, 120, 38.4): 2, (0.2, 120, 76.8): 2, (0.2, 120, 115.2): 3, (0.2, 120, 153.6): 2, (0.2, 120, 192.0): 5, (0.2, 120, 230.4): 6, (0.2, 120, 268.8): 6, (0.2, 120, 307.2): 4, (0.2, 120, 345.6): 2, (0.2, 120, 384.0): 2, (0.2, 140, 0.0): 5, (0.2, 140, 38.4): 3, (0.2, 140, 76.8): 3, (0.2, 140, 115.2): 3, (0.2, 140, 153.6): 2, (0.2, 140, 192.0): 3, (0.2, 140, 230.4): 6, (0.2, 140, 268.8): 10, (0.2, 140, 307.2): 2, (0.2, 140, 345.6): 2, (0.2, 140, 384.0): 2, (0.2, 160, 0.0): 4, (0.2, 160, 38.4): 3, (0.2, 160, 76.8): 4, (0.2, 160, 115.2): 2, (0.2, 160, 153.6): 5, (0.2, 160, 192.0): 3, (0.2, 160, 230.4): 2, (0.2, 160, 268.8): 13, (0.2, 160, 307.2): 2, (0.2, 160, 345.6): 2, (0.2, 160, 384.0): 2, (0.2, 180, 0.0): 4, (0.2, 180, 38.4): 10, (0.2, 180, 76.8): 4, (0.2, 180, 115.2): 2, (0.2, 180, 153.6): 6, (0.2, 180, 192.0): 2, (0.2, 180, 230.4): 4, (0.2, 180, 268.8): 3, (0.2, 180, 307.2): 2, (0.2, 180, 345.6): 2, (0.2, 180, 384.0): 2, (0.2, 200, 0.0): 3, (0.2, 200, 38.4): 7, (0.2, 200, 76.8): 3, (0.2, 200, 115.2): 2, (0.2, 200, 153.6): 3, (0.2, 200, 192.0): 2, (0.2, 200, 230.4): 2, (0.2, 200, 268.8): 3, (0.2, 200, 307.2): 2, (0.2, 200, 345.6): 2, (0.2, 200, 384.0): 2, (0.2, 220, 0.0): 2, (0.2, 220, 38.4): 3, (0.2, 220, 76.8): 2, (0.2, 220, 115.2): 2, (0.2, 220, 153.6): 2, (0.2, 220, 192.0): 2, (0.2, 220, 230.4): 2, (0.2, 220, 268.8): 12, (0.2, 220, 307.2): 14, (0.2, 220, 345.6): 2, (0.2, 220, 384.0): 2, (0.2, 240, 0.0): 2, (0.2, 240, 38.4): 12, (0.2, 240, 76.8): 2, (0.2, 240, 115.2): 2, (0.2, 240, 153.6): 2, (0.2, 240, 192.0): 2, (0.2, 240, 230.4): 2, (0.2, 240, 268.8): 13, (0.2, 240, 307.2): 12, (0.2, 240, 345.6): 2, (0.2, 240, 384.0): 2, (0.2, 260, 0.0): 2, (0.2, 260, 38.4): 4, (0.2, 260, 76.8): 2, (0.2, 260, 115.2): 3, (0.2, 260, 153.6): 4, (0.2, 260, 192.0): 2, (0.2, 260, 230.4): 13, (0.2, 260, 268.8): 12, (0.2, 260, 307.2): 7, (0.2, 260, 345.6): 2, (0.2, 260, 384.0): 2, (0.2, 280, 0.0): 2, (0.2, 280, 38.4): 5, (0.2, 280, 76.8): 2, (0.2, 280, 115.2): 2, (0.2, 280, 153.6): 2, (0.2, 280, 192.0): 2, (0.2, 280, 230.4): 9, (0.2, 280, 268.8): 11, (0.2, 280, 307.2): 8, (0.2, 280, 345.6): 2, (0.2, 280, 384.0): 2, (0.2, 300, 0.0): 2, (0.2, 300, 38.4): 9, (0.2, 300, 76.8): 3, (0.2, 300, 115.2): 2, (0.2, 300, 153.6): 2, (0.2, 300, 192.0): 2, (0.2, 300, 230.4): 12, (0.2, 300, 268.8): 13, (0.2, 300, 307.2): 3, (0.2, 300, 345.6): 2, (0.2, 300, 384.0): 2, (0.2, 320, 0.0): 2, (0.2, 320, 38.4): 3, (0.2, 320, 76.8): 2, (0.2, 320, 115.2): 2, (0.2, 320, 153.6): 2, (0.2, 320, 192.0): 2, (0.2, 320, 230.4): 12, (0.2, 320, 268.8): 10, (0.2, 320, 307.2): 5, (0.2, 320, 345.6): 2, (0. ...

# %%
value_table
# Out:
# {(0.2, 0, 0.0): 0.33738228055571795,
#  (0.2, 0, 38.4): 0.4996232276960296,
#  (0.2, 0, 76.8): 0.8092978048006854,
#  (0.2, 0, 115.2): 0.5583753801111581,
#  (0.2, 0, 153.6): 0.744696035844577,
#  (0.2, 0, 192.0): 0.4812048250845252,
#  (0.2, 0, 230.4): 0.7031419309991923,
#  (0.2, 0, 268.8): 0.040826955356750294,
#  (0.2, 0, 307.2): 0.6329508154762163,
#  (0.2, 0, 345.6): 0.1681745237670934,
#  (0.2, 0, 384.0): 0.6137670635245707,
#  (0.2, 0, 422.4): 0,
#  (0.2, 20, 0.0): 0.010942125930392343,
#  (0.2, 20, 38.4): 0.8252368981514783,
#  (0.2, 20, 76.8): 0.4313375074675715,
#  (0.2, 20, 115.2): 0.19176481189017747,
#  (0.2, 20, 153.6): 0.5803296683254452,
#  (0.2, 20, 192.0): 0.20321329538129862,
#  (0.2, 20, 230.4): 0.7875151060720407,
#  (0.2, 20, 268.8): 0.12739772435367014,
#  (0.2, 20, 307.2): 0.2018966919097248,
#  (0.2, 20, 345.6): 0.07890169941448955,
#  (0.2, 20, 384.0): 0.9284689726569554,
#  (0.2, 20, 422.4): 0,
#  (0.2, 40, 0.0): 0.8848004609835811,
#  (0.2, 40, 38.4): 0.9711801222398828,
#  (0.2, 40, 76.8): 0.36725581047392575,
#  (0.2, 40, 115.2): 0.02752371043214974,
#  (0.2, 40, 153.6): 0.779814094588219,
#  (0.2, 40, 192.0): 0.3907038800748823,
#  (0.2, 40, 230.4): 0.11178174448681799,
#  (0.2, 40, 268.8): 0.6064317226126908,
#  (0.2, 40, 307.2): 0.31733225621358385,
#  (0.2, 40, 345.6): 0.8002701438340719,
#  (0.2, 40, 384.0): 0.38645010161554827,
#  (0.2, 40, 422.4): 0,
#  (0.2, 60, 0.0): 0.07472692609113485,
#  (0.2, 60, 38.4): 0.14546616888439667,
#  (0.2, 60, 76.8): 0.8560702728450135,
#  (0.2, 60, 115.2): 0.009221034123151783,
#  (0.2, 60, 153.6): 0.07498263443187025,
#  (0.2, 60, 192.0): 0.42363057702754037,
#  (0.2, 60, 230.4): 0.11969633333309648,
#  (0.2, 60, 268.8): 0.7055812488517472,
#  (0.2, 60, 307.2): 0.5965083307871434,
#  (0.2, 60, 345.6): 0.9144836143905306,
#  (0.2, 60, 384.0): 0.9399763686485163,
#  (0.2, 60, 422.4): 0,
#  (0.2, 80, 0.0): 0.8602485817312441,
#  (0.2, 80, 38.4): 0.3323828795064081,
#  (0.2, 80, 76.8): 0.3578654512234245,
#  (0.2, 80, 115.2): 0.9497257385003731,
#  (0.2, 80, 153.6): 0.7922193541447535,
#  (0.2, 80, 192.0): 0.3736266073838588,
#  (0.2, 80, 230.4): 0.3727201361331982,
#  (0.2, 80, 268.8): 0.49092782996615436,
#  (0.2, 80, 307.2): 0.3442522331148635,
#  (0.2, 80, 345.6): 0.5365398143115608,
#  (0.2, 80, 384.0): 0.5902501106688778,
#  (0.2, 80, 422.4): 0,
#  (0.2, 100, 0.0): 0.1997736554126469,
#  (0.2, 100, 38.4): 0.1526781197438971,
#  (0.2, 100, 76.8): 0.15406850959947382,
#  (0.2, 100, 115.2): 0.8459125498686424,
#  (0.2, 100, 153.6): 0.05064172213044593,
#  (0.2, 100, 192.0): 0.062161067623603516,
#  (0.2, 100, 230.4): 0.5517301603293484,
#  (0.2, 100, 268.8): 0.03668759884410833,
#  (0.2, 100, 307.2): 0.2927078826519448,
#  (0.2, 100, 345.6): 0.4712735699290813,
#  (0.2, 100, 384.0): 0.8583689206484432,
#  (0.2, 100, 422.4): 0,
#  (0.2, 120, 0.0): 0.7450412811453558,
#  (0.2, 120, 38.4): 0.45476002592678877,
#  (0.2, 120, 76.8): 0.7964239545891736,
#  (0.2, 120, 115.2): 0.6347518686551104,
#  (0.2, 120, 153.6): 0.286499958235641,
#  (0.2, 120, 192.0): 0.8454717159286524,
#  (0.2, 120, 230.4): 0.561096919211312,
#  (0.2, 120, 268.8): 0.000806689094766111,
#  (0.2, 120, 307.2): 0.8619248644122033,
#  (0.2, 120, 345.6): 0.42920116905594663,
#  (0.2, 120, 384.0): 0.5433316622538914,
#  (0.2, 120, 422.4): 0,
#  (0.2, 140, 0.0): 0.44577994850041325,
#  (0.2, 140, 38.4): 0.07140558928686702,
#  (0.2, 140, 76.8): 0.3234131736542716,
#  (0.2, 140, 115.2): 0.07784140696388953,
#  (0.2, 140, 153.6): 0.6816498239292027,
#  (0.2, 140, 192.0): 0.22754287571852627,
#  (0.2, 140, 230.4): 0.0048535885738855145,
#  (0.2, 140, 268.8): 0.19104617477558405,
#  (0.2, 140, 307.2): 0.4811271151981946,
#  (0.2, 140, 345.6): 0.8833295869955226,
#  (0.2, 140, 384.0): 0.25512266154104635,
#  (0.2, 140, 422.4): 0,
#  (0.2, 160, 0.0): 0.7693551730003899,
#  (0.2, 160, 38.4): 0.2143020755900492,
#  (0.2, 160, 76.8): 0.6851382286981011,
#  (0.2, 160, 115.2): 0.644624412696758,
#  (0.2, 160, 153.6): 0.21282274743231344,
#  (0.2, 160, 192.0): 0.8071491543538777,
#  (0.2, 160, 230.4): 0.5261865588835711,
#  (0.2, 160, 268.8): 0.7637991828674122,
#  (0.2, 160, 307.2): 0.9254369407621299,
#  (0.2, 160, 345.6): 0.4002593901025282,
#  (0.2, 160, 384.0): 0.4445798881691516,
#  (0.2, 160, 422.4): 0,
#  (0.2, 180, 0.0): 0.8075819885872548,
#  (0.2, 180, 38.4): 0.6851258535586598,
#  (0.2, 180, 76.8): 0.16221557961993072,
#  (0.2, 180, 115.2): 0.5520767377049169,
#  (0.2, 180, 153.6): 0.9589084981519687,
#  (0.2, 180, 192.0): 0.8473690822511933,
#  (0.2, 180, 230.4): 0.6338460281516297,
#  (0.2, 180, 268.8): 0.8238520618659665,
#  (0.2, 180, 307.2): 0.21314671005743868,
#  (0.2, 180, 345.6): 0.5459157975808877,
#  (0.2, 180, 384.0): 0.0677429745832826,
#  (0.2, 180, 422.4): 0,
#  (0.2, 200, 0.0): 0.6304832251851704,
#  (0.2, 200, 38.4): 0.12810366884427493,
#  (0.2, 200, 76.8): 0.25428978124768964,
#  (0.2, 200, 115.2): 0.3944467830792826,
#  (0.2, 200, 153.6): 0.20030139685260306,
#  (0.2, 200, 192.0): 0.20429552376857385,
#  (0.2, 200, 230.4): 0.6721489225168007,
#  (0.2, 200, 268.8): 0.15874411841063718,
#  (0.2, 200, 307.2): 0.4177896304394464,
#  (0.2, 200, 345.6): 0.4090343526313951,
#  (0.2, 200, 384.0): 0.8601067652268359,
#  (0.2, 200, 422.4): 0,
#  (0.2, 220, 0.0): 0.1178887527113609,
#  (0.2, 220, 38.4): 0.6091422852530934,
#  (0.2, 220, 76.8): 0.9043275607322437,
#  (0.2, 220, 115.2): 0.251079074356485,
#  (0.2, 220, 153.6): 0.7360586574949496,
#  (0.2, 220, 192.0): 0.11723858523917008,
#  (0.2, 220, 230.4): 0.8421514130590352,
#  (0.2, 220, 268.8): 0.34032666068531536,
#  (0.2, 220, 307.2): 0.6749081085634595,
#  (0.2, 220, 345.6): 0.094588258092554,
#  (0.2, 220, 384.0): 0.8839414717185351,
#  (0.2, 220, 422.4): 0,
#  (0.2, 240, 0.0): 0.25160499170569084,
#  (0.2, 240, 38.4): 0.046062549347701265,
#  (0.2, 240, 76.8): 0.03010112549065269,
#  (0.2, 240, 115.2): 0.6860371425913545,
#  (0.2, 240, 153.6): 0.6144077672082258,
#  (0.2, 240, 192.0): 0.6578092935113131,
#  (0.2, 240, 230.4): 0.4725395657744519,
#  (0.2, 240, 268.8): 0.7079313362173918,
#  (0.2, 240, 307.2): 0.5228517515572844,
#  (0.2, 240, 345.6): 0.4464545578600445,
#  (0.2, 240, 384.0): 0.06994760068514272,
#  (0.2, 240, 422.4): 0,
#  (0.2, 260, 0.0): 0.8418245829190186,
#  (0.2, 260, 38.4): 0.06353902801301015,
#  (0.2, 260, 76.8): 0.3181836455668191,
#  (0.2, 260, 115.2): 0.53716234359022,
#  (0.2, 260, 153.6): 0.6147480499072013,
#  (0.2, 260, 192.0): 0.2540742852295391,
#  (0.2, 260, 230.4): 0.9015473904481707,
#  (0.2, 260, 268.8): 0.9611611515181843,
#  (0.2, 260, 307.2): 0.6798966680189182,
#  (0.2, 260, 345.6): 0.10934365584800354,
#  (0.2, 260, 384.0): 0.41858723467156567,
#  (0.2, 260, 422.4): 0,
#  (0.2, 280, 0.0): 0.21859849993478764,
#  (0.2, 280, 38.4): 0.5111340232390217,
#  (0.2, 280, 76.8): 0.11260260035559855,
#  (0.2, 280, 115.2): 0.16958052300011695,
#  (0.2, 280, 153.6): 0.08003920539239484,
#  (0.2, 280, 192.0): 0.3150346485575164,
#  (0.2, 280, 230.4): 0.02710484229939325,
#  (0.2, 280, 268.8): 0.14711623790977935,
#  (0.2, 280, 307.2): 0.030878960293174718,
#  (0.2, 280, 345.6): 0.2841983531754706,
#  (0.2, 280, 384.0): 0.797849854093565,
#  (0.2, 280, 422.4): 0,
#  (0.2, 300, 0.0): 0.8504566472165985,
#  (0.2, 300, 38.4): 0.33230037482872077,
#  (0.2, 300, 76.8): 0.3291767888412014,
#  (0.2, 300, 115.2): 0.48774918228706254,
#  (0.2, 300, 153.6): 0.7567489602556565,
#  (0.2, 300, 192.0): 0.709065216113242,
#  (0.2, 300, 230.4): 0.9993898402396549,
#  (0.2, 300, 268.8): 0.7049143263647261,
#  (0.2, 300, 307.2): 0.2826868396824995,
#  (0.2, 300, 345.6): 0.6100032567513869,
#  (0.2, 300, 384.0): 0.6761851240943065,
#  (0.2, 300, 422.4): 0,
#  (0.2, 320, 0.0): 0.6745921000598272,
#  (0.2, 320, 38.4): 0.9789131897662484,
#  (0.2, 320, 76.8): 0.5975066491498092,
#  (0.2, 320, 115.2): 0.3619605176391608,
#  (0.2, 320, 153.6): 0.11766539797899045,
#  (0.2, 320, 192.0): 0.5294737517113841,
#  (0.2, 320, 230.4): 0.15921385862889448,
#  (0.2, 320, 268.8): 0.08835404362447097,
#  (0.2, 320, 307.2): 0.05840347776373511,
#  (0.2, 320, 345.6): 0.5938088154898072,
#  (0.2, 320, 384.0): 0.7748816312663234,
#  (0.2, 320, 422.4): 0,
#  (0.2, 340, 0.0): 0.2471686115512135,
#  (0.2, 340, 38.4): 0.4330592330332754,
#  (0.2, 340, 76.8): 0.7919151015308461,
#  (0.2, 340, 115.2): 0.3266204561479614,
#  (0.2, 340, 153.6): 0.9197234565743033,
#  (0.2, 340, 192.0): 0.7371757468896957,
#  (0.2, 340, 230.4): 0.6943599974511397,
#  (0.2, 340, 268.8): 0.7321968285487427,
#  (0.2, 340, 307.2): 0.4855699344316916,
#  (0.2, 340, 345.6): 0.3690935800844196,
#  (0.2, 340, 384.0): 0.771822904168152,
#  (0.2, 340, 422.4): 0,
#  (0.2, 360, 0.0): 0.3977786687434087,
#  (0.2, 360, 38.4): 0.006960948733864658,
#  (0.2, 360, 76.8): 0.13015727915226016,
#  (0.2, 360, 115.2): 0.8925827060191845,
#  (0.2, 360, 153.6): 0.6825715764034996,
#  (0.2, 360, 192.0): 0.5093967084895453,
#  (0.2, 360, 230.4): 0.4675880469248016,
#  (0.2, 360, 268.8): 0.5301877274189777,
#  (0.2, 360, 307.2): 0.1366240181176529,
#  (0.2, 360, 345.6): 0.17107224067140014,
#  (0.2, 360, 384.0): 0.668264402784309,
#  (0.2, 360, 422.4): 0,
#  (0.2, 380, 0.0): 0.31799879331223313,
#  (0.2, 380, 38.4): 0.3548966336252807,
#  (0.2, 380, 76.8): 0.28456614515992695,
#  (0.2, 380, 115.2): 0.4296506619255638,
#  (0.2, 380, 153.6): 0.06538349325350756,
#  (0.2, 380, 192.0): 0.05131237212820594,
#  (0.2, 380, 230.4): 0.6786899905675615,
#  (0.2, 380, 268.8): 0.0790254885920818,
#  (0.2, 380, 307.2): 0.4910519487977997,
#  (0.2, 380, 345.6): 0.07290344290310413,
#  (0.2, 380, 384.0): 0.20388013038994812,
#  (0.2, 380, 422.4): 0,
#  (0.2, 400, 0.0): 0.9764266317910328,
#  (0.2, 400, 38.4): 0.5481242300224786,
#  (0.2, 400, 76.8): 0.143498156264236,
#  (0.2, 400, 115.2): 0.30348521689891794,
#  (0.2, 400, 153.6): 0.7471506432700682,
#  (0.2, 400, 192.0): 0.141105902382604,
#  (0.2, 400, 230.4): 0.7933898509835905,
#  (0.2, 400, 268.8): 0.9788161106232626,
#  (0.2, 400, 307.2): 0.12130229697330375,
#  (0.2, 400, 345.6): 0.3774261562472111,
#  (0.2, 400, 384.0): 0.6777519083898612,
#  (0.2, 400, 422.4): 0,
#  (0.2, 420, 0.0): 0.42176641344173504,
#  (0.2, 420, 38.4): 0.7990571843688691,
#  (0.2, 420, 76.8): 0.3705689598389449,
#  (0.2, 420, 115.2): 0.8449093438164916,
#  (0.2, 420, 153.6): 0.5927847571035287,
#  (0.2, 420, 192.0): 0.15484613780194845,
#  (0.2, 420, 230.4): 0.7478975952619911,
#  (0.2, 420, 268.8): 0.337943326139193,
#  (0.2, 420, 307.2): 0.09968732981267026,
#  (0.2, 420, 345.6): 0.9568158415162671,
#  (0.2, 420, 384.0): 0.9418503431646913,
#  (0.2, 420, 422.4): 0,
#  (0.2, 440, 0.0): 0.0993033989598271,
#  (0.2, 440, 38.4): 0.9429326008447521,
#  (0.2, 440, 76.8): 0.307004257378906,
#  (0.2, 440, 115.2): 0.8513901730856214,
#  (0.2, 440, 153.6): 0.9740138871643058,
#  (0.2, 440, 192.0): 0.6080896188210343,
#  (0.2, 440, 230.4): 0.7223099964151234,
#  (0.2, 440, 268.8): 0.12861106828512348,
#  (0.2, 440, 307.2): 0.5438262158727221,
#  (0.2, 440, 345.6): 0.7124794003613859,
#  (0.2, 440, 384.0): 0.07395564121885856,
#  (0.2, 440, 422.4): 0,
#  (0.2, 460, 0.0): 0.18587772231421285,
#  (0.2, 460, 38.4): 0.2029668566772833,
#  (0.2, 460, 76.8): 0.060310393253162675,
#  (0.2, 460, 115.2): 0.8999730435929003,
#  (0.2, 460, 153.6): 0.37366409228573927,
#  (0.2, 460, 192.0): 0.525995815393915,
#  (0.2, 460, 230.4): 0.8876079688436104,
#  (0.2, 460, 268.8): 0.9425205926888088,
#  (0.2, 460, 307.2): 0.5370724844477871,
#  (0.2, 460, 345.6): 0.9308191101516352,
#  (0.2, 460, 384.0): 0.9358920812314784,
#  (0.2, 460, 422.4): 0,
#  (0.2, 480, 0.0): 0.5346902808429487,
#  (0.2, 480, 38.4): 0.017104055578581634,
#  (0.2, 480, 76.8): 0.4191332942674859,
#  (0.2, 480, 115.2): 0.003770807097712603,
#  (0.2, 480, 153.6): 0.041123345190228866,
#  (0.2, 480, 192.0): 0.7543937900920541,
#  (0.2, 480, 230.4): 0.2537241322998258,
#  (0.2, 480, 268.8): 0.6264538296409409,
#  (0.2, 480, 307.2): 0.36180167233808347,
#  (0.2, 480, 345.6): 0.7907043288765984,
#  (0.2, 480, 384.0): 0.7054773172209607,
#  (0.2, 480, 422.4): 0,
#  (0.2, 500, 0.0): 0.6119149307802314,
#  (0.2, 500, 38.4): 0.906868794622758,
#  (0.2, 500, 76.8): 0.15897595581628698,
#  (0.2, 500, 115.2): 0.8503670121984227,
#  (0.2, 500, 153.6): 0.2901584627430819,
#  (0.2, 500, 192.0): 0.9812948955735205,
#  (0.2, 500, 230.4): 0.008646655164997852,
#  (0.2, 500, 268.8): 0.696613835056604,
#  (0.2, 500, 307.2): 0.6505075675707108,
#  (0.2, 500, 345.6): 0.3678183669792435,
#  (0.2, 500, 384.0): 0.2933679285959975,
#  (0.2, 500, 422.4): 0,
#  (0.2, 520, 0.0): 0.5044333044981626,
#  (0.2, 520, 38.4): 0.6814033619168497,
#  (0.2, 520, 76.8): 0.31943097372648255,
#  (0.2, 520, 115.2): 0.1713529489178205,
#  (0.2, 520, 153.6): 0.7057096391168278,
#  (0.2, 520, 192.0): 0.18159822894966549,
#  (0.2, 520, 230.4): 0.039789155470762894,
#  (0.2, 520, 268.8): 0.14263240554766665,
#  (0.2, 520, 307.2): 0.17223005585890094,
#  (0.2, 520, 345.6): 0.5847224016662804,
#  (0.2, 520, 384.0): 0.3649249665453681,
#  (0.2, 520, 422.4): 0,
#  (0.2, 540, 0.0): 0.9761545317731402,
#  (0.2, 540, 38.4): 0.49056949681084017,
#  (0.2, 540, 76.8): 0.3012780387000328,
#  (0.2, 540, 115.2): 0.5371362026158396,
#  (0.2, 540, 153.6): 0.23740297669559063,
#  (0.2, 540, 192.0): 0.05738686299436446,
#  (0.2, 540, 230.4): 0.6906747445052562,
#  (0.2, 540, 268.8): 0.031861351223723466,
#  (0.2, 540, 307.2): 0.30892457097904036,
#  (0.2, 540, 345.6): 0.4630399319965436,
#  (0.2, 540, 384.0): 0.35100620278104944,
#  (0.2, 540, 422.4): 0,
#  (0.2, 560, 0.0): 0.19032748559720403,
#  (0.2, 560, 38.4): 0.2726943520646574,
#  (0.2, 560, 76.8): 0.01179200319228968,
#  (0.2, 560, 115.2): 0.6097487876610862,
#  (0.2, 560, 153.6): 0.7136769370312467,
#  (0.2, 560, 192.0): 0.1626025977927742,
#  (0.2, 560, 230.4): 0.5784662103358748,
#  (0.2, 560, 268.8): 0.9540528308745514,
#  (0.2, 560, 307.2): 0.7379524471005893,
#  (0.2, 560, 345.6): 0.7430473498996162,
#  (0.2, 560, 384.0): 0.8931338702789176,
#  (0.2, 560, 422.4): 0,
#  (0.2, 580, 0.0): 0.44966754747788706,
#  (0.2, 580, 38.4): 0.9640763318939711,
#  (0.2, 580, 76.8): 0.9627795084372439,
#  (0.2, 580, 115.2): 0.9305036749780029,
#  (0.2, 580, 153.6): 0.0964215091740015,
#  (0.2, 580, 192.0): 0.8208817596177048,
#  (0.2, 580, 230.4): 0.038533752717543446,
#  (0.2, 580, 268.8): 0.3881127529413906,
#  (0.2, 580, 307.2): 0.9290965738094054,
#  (0.2, 580, 345.6): 0.1147119772920826,
#  (0.2, 580, 384.0): 0.2355582780482539,
#  (0.2, 580, 422.4): 0,
#  (0.2, 600, 0.0): 0.8156806218760361,
#  (0.2, 600, 38.4): 0.4295350159232644,
#  (0.2, 600, 76.8): 0.9821245372446772,
#  (0.2, 600, 115.2): 0.048217445537173886,
#  (0.2, 600, 153.6): 0.7675495401876568,
#  (0.2, 600, 192.0): 0.9739270819866088,
#  (0.2, 600, 230.4): 0.27936712300638933,
#  (0.2, 600, 268.8): 0.21092273167290498,
#  (0.2, 600, 307.2): 0.4922297611050732,
#  (0.2, 600, 345.6): 0.15832658601471894,
#  (0.2, 600, 384.0): 0.9728424019780432,
#  (0.2, 600, 422.4): 0,
#  (0.2, 620, 0.0): 0.008545489253996008,
#  (0.2, 620, 38.4): 0.18596413955379265,
#  (0.2, 620, 76.8): 0.23662380371792602,
#  (0.2, 620, 115.2): 0.3549055360955906,
#  (0.2, 620, 153.6): 0.08058522829923653,
#  (0.2, 620, 192.0): 0.1274816117574239,
#  (0.2, 620, 230.4): 0.29484425871856335,
#  (0.2, 620, 268.8): 0.45398106700097773,
#  (0.2, 620, 307.2): 0.833827353566586,
#  (0.2, 620, 345.6): 0.21573843165982975,
#  (0.2, 620, 384.0): 0.5345887616752529,
#  (0.2, 620, 422.4): 0,
#  (0.2, 640, 0.0): 0.4088955411301761,
#  (0.2, 640, 38.4): 0.2661692435576749,
#  (0.2, 640, 76.8): 0.3882833306089697,
#  (0.2, 640, 115.2): 0.6463734496833957,
#  (0.2, 640, 153.6): 0.4294930076927148,
#  (0.2, 640, 192.0): 0.5869067564416547,
#  (0.2, 640, 230.4): 0.835102887049546,
#  (0.2, 640, 268.8): 0.7900653387937521,
#  (0.2, 640, 307.2): 0.20929072833600082,
#  (0.2, 640, 345.6): 0.9638103901089157,
#  (0.2, 640, 384.0): 0.3710098650835034,
#  (0.2, 640, 422.4): 0,
#  (0.2, 660, 0.0): 0.8735841834009292,
#  (0.2, 660, 38.4): 0.0020796639804272488,
#  (0.2, 660, 76.8): 0.13880600383159036,
#  (0.2, 660, 115.2): 0.19518561875414786,
#  (0.2, 660, 153.6): 0.506372561941363,
#  (0.2, 660, 192.0): 0.8287414754979915,
#  (0.2, 660, 230.4): 0.579929383147851,
#  (0.2, 660, 268.8): 0.25940339986148087,
#  (0.2, 660, 307.2): 0.3459400749833652,
#  (0.2, 660, 345.6): 0.8545942156983383,
#  (0.2, 660, 384.0): 0.09172404813332058,
#  (0.2, 660, 422.4): 0,
#  (0.2, 680, 0.0): 0.22617977953547808,
#  (0.2, 680, 38.4): 0.26688852834398136,
#  (0.2, 680, 76.8): 0.26710865945304885,
#  (0.2, 680, 115.2): 0.1103485026897092,
#  (0.2, 680, 153.6): 0.696276590351095,
#  (0.2, 680, 192.0): 0.9311633437587931,
#  (0.2, 680, 230.4): 0.6826409141779213,
#  (0.2, 680, 268.8): 0.29751552316998664,
#  (0.2, 680, 307.2): 0.287000081880212,
#  (0.2, 680, 345.6): 0.670537227224155,
#  (0.2, 680, 384.0): 0.16455788381515668,
#  (0.2, 680, 422.4): 0,
#  (0.2, 700, 0.0): 0.13925636442742173,
#  (0.2, 700, 38.4): 0.9137926370466055,
#  (0.2, 700, 76.8): 0.9482569832186516,
#  (0.2, 700, 115.2): 0.6217306151813542,
#  (0.2, 700, 153.6): 0.7639347181544296,
#  (0.2, 700, 192.0): 0.26911139408766704,
#  (0.2, 700, 230.4): 0.5319153120485552,
#  (0.2, 700, 268.8): 0.22260410620515358,
#  (0.2, 700, 307.2): 0.30226571071488073,
#  (0.2, 700, 345.6): 0.1663866194802951,
#  (0.2, 700, 384.0): 0.2848100030248445,
#  (0.2, 700, 422.4): 0,
#  (0.4, 0, 0.0): 0.3165094825404865,
#  (0.4, 0, 38.4): 0.059893244046773875,
#  (0.4, 0, 76.8): 0.02047992931957454,
#  (0.4, 0, 115.2): 0.31388026232784183,
#  (0.4, 0, 153.6): 0.0029799700406795138,
#  (0.4, 0, 192.0): 0.11009827570326647,
#  (0.4, 0, 230.4): 0.06507878730273187,
#  (0.4, 0, 268.8): 0.6418041943923566,
#  (0.4, 0, 307.2): 0.018946421767089938,
#  (0.4, 0, 345.6): 0.6347363924806864,
#  (0.4, 0, 384.0): 0.20530354958535046,
#  (0.4, 0, 422.4): 0,
#  (0.4, 20, 0.0): 0.7755055314836546,
#  (0.4, 20, 38.4): 0.8418459701288332,
#  (0.4, 20, 76.8): 0.24630180602903273,
#  (0.4, 20, 115.2): 0.9062785708807143,
#  (0.4, 20, 153.6): 0.47543946544525295,
#  (0.4, 20, 192.0): 0.5073783147237932,
#  (0.4, 20, 230.4): 0.8726168487086501,
#  (0.4, 20, 268.8): 0.8517295987640595,
#  (0.4, 20, 307.2): 0.7007694728980105,
#  (0.4, 20, 345.6): 0.48076706409674597,
#  (0.4, 20, 384.0): 0.6872148369313049,
#  (0.4, 20, 422.4): 0,
#  (0.4, 40, 0.0): 0.030225889664736494,
#  (0.4, 40, 38.4): 0.7591060051622642,
#  (0.4, 40, 76.8): 0.34630164310868217,
#  (0.4, 40, 115.2): 0.6474038385434164,
#  (0.4, 40, 153.6): 0.05218361090362711,
#  (0.4, 40, 192.0): 0.3000288551893956,
#  (0.4, 40, 230.4): 0.8728892209915879,
#  (0.4, 40, 268.8): 0.7025515317610531,
#  (0.4, 40, 307.2): 0.9635633515992126,
#  (0.4, 40, 345.6): 0.7265617807790713,
#  (0.4, 40, 384.0): 0.7733566946283339,
#  (0.4, 40, 422.4): 0,
#  (0.4, 60, 0.0): 0.9968600850191848,
#  (0.4, 60, 38.4): 0.695935167687354,
#  (0.4, 60, 76.8): 0.7885343092127299,
#  (0.4, 60, 115.2): 0.1170178209878121,
#  (0.4, 60, 153.6): 0.998607919987364,
#  (0.4, 60, 192.0): 0.12995553790818282,
#  (0.4, 60, 230.4): 0.9941829264275617,
#  (0.4, 60, 268.8): 0.5982784929433016,
#  (0.4, 60, 307.2): 0.9529150673735279,
#  (0.4, 60, 345.6): 0.39668315561441725,
#  (0.4, 60, 384.0): 0.886863000419294,
#  (0.4, 60, 422.4): 0,
#  (0.4, 80, 0.0): 0.17853183889299384,
#  (0.4, 80, 38.4): 0.31902420331944414,
#  (0.4, 80, 76.8): 0.9550978474507726,
#  (0.4, 80, 115.2): 0.03294483552595884,
#  (0.4, 80, 153.6): 0.9559157288788291,
#  (0.4, 80, 192.0): 0.12855688073784055,
#  (0.4, 80, 230.4): 0.4025409413791877,
#  (0.4, 80, 268.8): 0.3165552166770109,
#  (0.4, 80, 307.2): 0.47488834131117796,
#  (0.4, 80, 345.6): 0.7561988370657684,
#  (0.4, 80, 384.0): 0.7963561769788947,
#  (0.4, 80, 422.4): 0,
#  (0.4, 100, 0.0): 0.6751993455647791,
#  (0.4, 100, 38.4): 0.6864064639485987,
#  (0.4, 100, 76.8): 0.4477277426869706,
#  (0.4, 100, 115.2): 0.8655031892674088,
#  (0.4, 100, 153.6): 0.6460894097154022,
#  (0.4, 100, 192.0): 0.9980344201371033,
#  (0.4, 100, 230.4): 0.5773209038423007,
#  (0.4, 100, 268.8): 0.7374634585081918,
#  (0.4, 100, 307.2): 0.4260632917707219,
#  (0.4, 100, 345.6): 0.257103135812896,
#  (0.4, 100, 384.0): 0.21278281679433764,
#  (0.4, 100, 422.4): 0,
#  (0.4, 120, 0.0): 0.6659817775989075,
#  (0.4, 120, 38.4): 0.5376347979465433,
#  (0.4, 120, 76.8): 0.02692724118494172,
#  (0.4, 120, 115.2): 0.9409985110877205,
#  (0.4, 120, 153.6): 0.43058823766168086,
#  (0.4, 120, 192.0): 0.018817702195452313,
#  (0.4, 120, 230.4): 0.10524654235664965,
#  (0.4, 120, 268.8): 0.016250686794006763,
#  (0.4, 120, 307.2): 0.48786209882978837,
#  (0.4, 120, 345.6): 0.31747610257983927,
#  (0.4, 120, 384.0): 0.8361181273127215,
#  (0.4, 120, 422.4): 0,
#  (0.4, 140, 0.0): 0.6169158835850005,
#  (0.4, 140, 38.4): 0.2226716063059958,
#  (0.4, 140, 76.8): 0.5165468562007091,
#  (0.4, 140, 115.2): 0.880626809806579,
#  (0.4, 140, 153.6): 0.25131412176760615,
#  (0.4, 140, 192.0): 0.06893216464280794,
#  (0.4, 140, 230.4): 0.4749651717814448,
#  (0.4, 140, 268.8): 0.7519733948034846,
#  (0.4, 140, 307.2): 0.47179372342908943,
#  (0.4, 140, 345.6): 0.16584750976619156,
#  (0.4, 140, 384.0): 0.5064539962260862,
#  (0.4, 140, 422.4): 0,
#  (0.4, 160, 0.0): 0.8545554376432257,
#  (0.4, 160, 38.4): 0.4026117493587049,
#  (0.4, 160, 76.8): 0.41153158437589166,
#  (0.4, 160, 115.2): 0.5349467332970802,
#  (0.4, 160, 153.6): 0.4339229578545585,
#  (0.4, 160, 192.0): 0.09151806704934273,
#  (0.4, 160, 230.4): 0.8393780050904678,
#  (0.4, 160, 268.8): 0.7686622991918866,
#  (0.4, 160, 307.2): 0.8181556675945871,
#  (0.4, 160, 345.6): 0.3534566638103923,
#  (0.4, 160, 384.0): 0.8126710423332019,
#  (0.4, 160, 422.4): 0,
#  (0.4, 180, 0.0): 0.11230686286690106,
#  (0.4, 180, 38.4): 0.5148870542298849,
#  (0.4, 180, 76.8): 0.014895380305188666,
#  (0.4, 180, 115.2): 0.6693463307957642,
#  (0.4, 180, 153.6): 0.06574811240071443,
#  (0.4, 180, 192.0): 0.2101693732994554,
#  (0.4, 180, 230.4): 0.3385788933566778,
#  (0.4, 180, 268.8): 0.6665676553596447,
#  (0.4, 180, 307.2): 0.13644361119478798,
#  (0.4, 180, 345.6): 0.0017619690024380796,
#  (0.4, 180, 384.0): 0.33568593475988395,
#  (0.4, 180, 422.4): 0,
#  (0.4, 200, 0.0): 0.03360119160776831,
#  (0.4, 200, 38.4): 0.3222167020849559,
#  (0.4, 200, 76.8): 0.4924803749871344,
#  (0.4, 200, 115.2): 0.7292603166626638,
#  (0.4, 200, 153.6): 0.5282154950938784,
#  (0.4, 200, 192.0): 0.5968763412017016,
#  (0.4, 200, 230.4): 0.27436040217725555,
#  (0.4, 200, 268.8): 0.48977579657261916,
#  (0.4, 200, 307.2): 0.13604062723919952,
#  (0.4, 200, 345.6): 0.3358117006409176,
#  (0.4, 200, 384.0): 0.2258983492487452,
#  (0.4, 200, 422.4): 0,
#  (0.4, 220, 0.0): 0.7394117765182762,
#  (0.4, 220, 38.4): 0.038120557832316604,
#  (0.4, 220, 76.8): 0.683815958171224,
#  (0.4, 220, 115.2): 0.3929082288133183,
#  (0.4, 220, 153.6): 0.6408423290960794,
#  (0.4, 220, 192.0): 0.13222426005913757,
#  (0.4, 220, 230.4): 0.6705786996150376,
#  (0.4, 220, 268.8): 0.41242479999617454,
#  (0.4, 220, 307.2): 0.7826466299592112,
#  (0.4, 220, 345.6): 0.2262154287233602,
#  (0.4, 220, 384.0): 0.7741218067917801,
#  (0.4, 220, 422.4): 0,
#  (0.4, 240, 0.0): 0.05856690830955347,
#  (0.4, 240, 38.4): 0.5600378055706066,
#  (0.4, 240, 76.8): 0.6780748938507976,
#  (0.4, 240, 115.2): 0.910424939188453,
#  (0.4, 240, 153.6): 0.6009796820120653,
#  (0.4, 240, 192.0): 0.25280765229929736,
#  (0.4, 240, 230.4): 0.4344248022711368,
#  (0.4, 240, 268.8): 0.06710928059341159,
#  (0.4, 240, 307.2): 0.9322721494855558,
#  (0.4, 240, 345.6): 0.599584664138086,
#  (0.4, 240, 384.0): 0.005654013052422524,
#  (0.4, 240, 422.4): 0,
#  (0.4, 260, 0.0): 0.5140400632367164,
#  (0.4, 260, 38.4): 0.549761236305831,
#  (0.4, 260, 76.8): 0.3990550528533028,
#  (0.4, 260, 115.2): 0.06816784810958987,
#  (0.4, 260, 153.6): 0.3539570979277301,
#  (0.4, 260, 192.0): 0.8632178869415149,
#  (0.4, 260, 230.4): 0.8563660882330812,
#  (0.4, 260, 268.8): 0.8583116922165064,
#  (0.4, 260, 307.2): 0.553422202959951,
#  (0.4, 260, 345.6): 0.3394252174358272,
#  (0.4, 260, 384.0): 0.8031136388986378,
#  (0.4, 260, 422.4): 0,
#  (0.4, 280, 0.0): 0.2589053179405233,
#  (0.4, 280, 38.4): 0.1618953929829502,
#  (0.4, 280, 76.8): 0.9760341838342682,
#  (0.4, 280, 115.2): 0.2341275754197485,
#  (0.4, 280, 153.6): 0.33180801189042997,
#  (0.4, 280, 192.0): 0.1291781847630996,
#  (0.4, 280, 230.4): 0.8732189734222825,
#  (0.4, 280, 268.8): 0.8990146490508034,
#  (0.4, 280, 307.2): 0.9398896312887802,
#  (0.4, 280, 345.6): 0.41424523267449753,
#  (0.4, 280, 384.0): 0.6623868638307783,
#  (0.4, 280, 422.4): 0,
#  (0.4, 300, 0.0): 0.48021030842545953,
#  (0.4, 300, 38.4): 0.6061335891244822,
#  (0.4, 300, 76.8): 0.03957779128222516,
#  (0.4, 300, 115.2): 0.057104910523042895,
#  (0.4, 300, 153.6): 0.4314189690366622,
#  (0.4, 300, 192.0): 0.6406436567216885,
#  (0.4, 300, 230.4): 0.36167229017903424,
#  (0.4, 300, 268.8): 0.329567413072429,
#  (0.4, 300, 307.2): 0.28220580869932355,
#  (0.4, 300, 345.6): 0.05053749098538929,
#  (0.4, 300, 384.0): 0.45415238839243466,
#  (0.4, 300, 422.4): 0,
#  (0.4, 320, 0.0): 0.9244453202167152,
#  (0.4, 320, 38.4): 0.8432639709360065,
#  (0.4, 320, 76.8): 0.8521421461894411,
#  (0.4, 320, 115.2): 0.23685131478458477,
#  (0.4, 320, 153.6): 0.4308446456909917,
#  (0.4, 320, 192.0): 0.342032476113721,
#  (0.4, 320, 230.4): 0.24691673443209705,
#  (0.4, 320, 268.8): 0.9358431214740566,
#  (0.4, 320, 307.2): 0.6131345451838808,
#  (0.4, 320, 345.6): 0.13076958815253903,
#  (0.4, 320, 384.0): 0.5373075628577595,
#  (0.4, 320, 422.4): 0,
#  (0.4, 340, 0.0): 0.2242194096219443,
#  (0.4, 340, 38.4): 0.8992085280485157,
#  (0.4, 340, 76.8): 0.4357465672010308,
#  (0.4, 340, 115.2): 0.6841876307552159,
#  (0.4, 340, 153.6): 0.050605752832504014,
#  (0.4, 340, 192.0): 0.687187001442402,
#  (0.4, 340, 230.4): 0.9014603721051775,
#  (0.4, 340, 268.8): 0.8368381221014962,
#  (0.4, 340, 307.2): 0.37824403705642384,
#  (0.4, 340, 345.6): 0.9813502134768758,
#  (0.4, 340, 384.0): 0.8749918812987681,
#  (0.4, 340, 422.4): 0,
#  (0.4, 360, 0.0): 0.15912991788215847,
#  (0.4, 360, 38.4): 0.11272443077497107,
#  (0.4, 360, 76.8): 0.8840608688097719,
#  (0.4, 360, 115.2): 0.2867108511659803,
#  (0.4, 360, 153.6): 0.8881003772491317,
#  (0.4, 360, 192.0): 0.8880307636100475,
#  (0.4, 360, 230.4): 0.9634626243253376,
#  (0.4, 360, 268.8): 0.03339968953081085,
#  (0.4, 360, 307.2): 0.8395005453663238,
#  (0.4, 360, 345.6): 0.34154662801290014,
#  (0.4, 360, 384.0): 0.6182356748569485,
#  (0.4, 360, 422.4): 0,
#  (0.4, 380, 0.0): 0.9811335546955081,
#  (0.4, 380, 38.4): 0.23491110101744328,
#  (0.4, 380, 76.8): 0.1560397610116815,
#  (0.4, 380, 115.2): 0.7021789209602364,
#  (0.4, 380, 153.6): 0.3771399887419328,
#  (0.4, 380, 192.0): 0.3321513432651728,
#  (0.4, 380, 230.4): 0.0470544876807224,
#  (0.4, 380, 268.8): 0.459782802202947,
#  (0.4, 380, 307.2): 0.5375704846761399,
#  (0.4, 380, 345.6): 0.042001395782745976,
#  (0.4, 380, 384.0): 0.0204927893402308,
#  (0.4, 380, 422.4): 0,
#  (0.4, 400, 0.0): 0.3699840344414843,
#  (0.4, 400, 38.4): 0.5547040557300406,
#  (0.4, 400, 76.8): 0.5035074879030514,
#  (0.4, 400, 115.2): 0.3980102941348046,
#  (0.4, 400, 153.6): 0.7067060606259234,
#  (0.4, 400, 192.0): 0.8412878771694193,
#  (0.4, 400, 230.4): 0.22748603048759652,
#  (0.4, 400, 268.8): 0.5462206178500428,
#  (0.4, 400, 307.2): 0.7593819473123722,
#  (0.4, 400, 345.6): 0.3652386966965181,
#  (0.4, 400, 384.0): 0.5055627443116407,
#  (0.4, 400, 422.4): 0,
#  (0.4, 420, 0.0): 0.11062718727118936,
#  (0.4, 420, 38.4): 0.5453007852976829,
#  (0.4, 420, 76.8): 0.9540707483427063,
#  (0.4, 420, 115.2): 0.2555771313638511,
#  (0.4, 420, 153.6): 0.9012290378268379,
#  (0.4, 420, 192.0): 0.43252345194025676,
#  (0.4, 420, 230.4): 0.26652922960067993,
#  (0.4, 420, 268.8): 0.42081612762520504,
#  (0.4, 420, 307.2): 0.3211415543432429,
#  (0.4, 420, 345.6): 0.5192904095828088,
#  (0.4, 420, 384.0): 0.9465703287069019,
#  (0.4, 420, 422.4): 0,
#  (0.4, 440, 0.0): 0.4757790303308822,
#  (0.4, 440, 38.4): 0.24106756389691875,
#  (0.4, 440, 76.8): 0.7805559323188201,
#  (0.4, 440, 115.2): 0.37020741779830124,
#  (0.4, 440, 153.6): 0.6672525852144776,
#  (0.4, 440, 192.0): 0.7088435588241988,
#  (0.4, 440, 230.4): 0.9490881483937876,
#  (0.4, 440, 268.8): 0.8904860386342616,
#  (0.4, 440, 307.2): 0.8953727791466025,
#  (0.4, 440, 345.6): 0.30256560254554576,
#  (0.4, 440, 384.0): 0.5131434061724222,
#  (0.4, 440, 422.4): 0,
#  (0.4, 460, 0.0): 0.8395628375756501,
#  (0.4, 460, 38.4): 0.38429516263391816,
#  (0.4, 460, 76.8): 0.6129748947177031,
#  (0.4, 460, 115.2): 0.3485751022098519,
#  (0.4, 460, 153.6): 0.19667162676557592,
#  (0.4, 460, 192.0): 0.3834189198994692,
#  (0.4, 460, 230.4): 0.32274006853676696,
#  (0.4, 460, 268.8): 0.7881011960926071,
#  (0.4, 460, 307.2): 0.6865023867473056,
#  (0.4, 460, 345.6): 0.5046239087569516,
#  (0.4, 460, 384.0): 0.8013693759768369,
#  (0.4, 460, 422.4): 0,
#  (0.4, 480, 0.0): 0.07938778081552866,
#  (0.4, 480, 38.4): 0.9464986092731297,
#  (0.4, 480, 76.8): 0.5397000386747829,
#  (0.4, 480, 115.2): 0.9975806419245649,
#  (0.4, 480, 153.6): 0.026394181769003766,
#  (0.4, 480, 192.0): 0.10302545867494861,
#  (0.4, 480, 230.4): 0.9262763150351284,
#  (0.4, 480, 268.8): 0.3342890521592443,
#  (0.4, 480, 307.2): 0.1930741472825923,
#  (0.4, 480, 345.6): 0.31903229964630897,
#  (0.4, 480, 384.0): 0.5522252673624937,
#  (0.4, 480, 422.4): 0,
#  (0.4, 500, 0.0): 0.7129049909766164,
#  (0.4, 500, 38.4): 0.558208323087432,
#  (0.4, 500, 76.8): 0.2919134601943014,
#  (0.4, 500, 115.2): 0.352116722288513,
#  (0.4, 500, 153.6): 0.6927261711640185,
#  (0.4, 500, 192.0): 0.8778400875900476,
#  (0.4, 500, 230.4): 0.5889015999040169,
#  (0.4, 500, 268.8): 0.08162663901026723,
#  (0.4, 500, 307.2): 0.28558109982274205,
#  (0.4, 500, 345.6): 0.4836437745913522,
#  (0.4, 500, 384.0): 0.5622589975294587,
#  (0.4, 500, 422.4): 0,
#  (0.4, 520, 0.0): 0.6445692289916946,
#  (0.4, 520, 38.4): 0.007595617111995856,
#  (0.4, 520, 76.8): 0.8756989191958882,
#  (0.4, 520, 115.2): 0.007369220202014026,
#  (0.4, 520, 153.6): 0.32859750878892613,
#  (0.4, 520, 192.0): 0.2985827377732212,
#  (0.4, 520, 230.4): 0.3673885532229191,
#  (0.4, 520, 268.8): 0.2415182968996541,
#  (0.4, 520, 307.2): 0.5208325349047677,
#  (0.4, 520, 345.6): 0.2431434493182959,
#  (0.4, 520, 384.0): 0.987311539880911,
#  (0.4, 520, 422.4): 0,
#  (0.4, 540, 0.0): 0.9942065753119251,
#  (0.4, 540, 38.4): 0.9216196264933608,
#  (0.4, 540, 76.8): 0.11308394730545768,
#  (0.4, 540, 115.2): 0.5504825756376677,
#  (0.4, 540, 153.6): 0.13580637600851164,
#  (0.4, 540, 192.0): 0.09183677391531508,
#  (0.4, 540, 230.4): 0.6388759883353037,
#  (0.4, 540, 268.8): 0.465926573896028,
#  (0.4, 540, 307.2): 0.5545637492978321,
#  (0.4, 540, 345.6): 0.5759903603005784,
#  (0.4, 540, 384.0): 0.1448003785097438,
#  (0.4, 540, 422.4): 0,
#  (0.4, 560, 0.0): 0.6921352642576991,
#  (0.4, 560, 38.4): 0.46226995723370046,
#  (0.4, 560, 76.8): 0.7655187376866377,
#  (0.4, 560, 115.2): 0.7248232808391966,
#  (0.4, 560, 153.6): 0.6420648859529773,
#  (0.4, 560, 192.0): 0.7979465678245788,
#  (0.4, 560, 230.4): 0.03158107287946199,
#  (0.4, 560, 268.8): 0.7037644288173509,
#  (0.4, 560, 307.2): 0.1191231673995724,
#  (0.4, 560, 345.6): 0.5536751750410072,
#  (0.4, 560, 384.0): 0.6923285555754998,
#  (0.4, 560, 422.4): 0,
#  (0.4, 580, 0.0): 0.38556070219978755,
#  (0.4, 580, 38.4): 0.7764707064992992,
#  (0.4, 580, 76.8): 0.22993796658069754,
#  (0.4, 580, 115.2): 0.8186448924039922,
#  (0.4, 580, 153.6): 0.4013074357542975,
#  (0.4, 580, 192.0): 0.3975870309033346,
#  (0.4, 580, 230.4): 0.2977754782700819,
#  (0.4, 580, 268.8): 0.18392799083194455,
#  (0.4, 580, 307.2): 0.8090867187518119,
#  (0.4, 580, 345.6): 0.7432402413114886,
#  (0.4, 580, 384.0): 0.9001649384163429,
#  (0.4, 580, 422.4): 0,
#  (0.4, 600, 0.0): 0.32691860519927607,
#  (0.4, 600, 38.4): 0.3255627558061074,
#  (0.4, 600, 76.8): 0.3302241404689711,
#  (0.4, 600, 115.2): 0.8297601836450773,
#  (0.4, 600, 153.6): 0.7265983032176662,
#  (0.4, 600, 192.0): 0.043700793948600714,
#  (0.4, 600, 230.4): 0.45213147737781545,
#  (0.4, 600, 268.8): 0.5811367415346808,
#  (0.4, 600, 307.2): 0.6503786384635198,
#  (0.4, 600, 345.6): 0.6151690254098744,
#  (0.4, 600, 384.0): 0.5836125782062694,
#  (0.4, 600, 422.4): 0,
#  (0.4, 620, 0.0): 0.33747367057075994,
#  (0.4, 620, 38.4): 0.07004947240058379,
#  (0.4, 620, 76.8): 0.4685209669749827,
#  (0.4, 620, 115.2): 0.0777960039073684,
#  (0.4, 620, 153.6): 0.8385497844037635,
#  (0.4, 620, 192.0): 0.09473712507275933,
#  (0.4, 620, 230.4): 0.7472363042373057,
#  (0.4, 620, 268.8): 0.03622974642046639,
#  (0.4, 620, 307.2): 0.5458471869856086,
#  (0.4, 620, 345.6): 0.8927114038639717,
#  (0.4, 620, 384.0): 0.4775052273769427,
#  (0.4, 620, 422.4): 0,
#  (0.4, 640, 0.0): 0.2817842952548836,
#  (0.4, 640, 38.4): 0.23417188572998415,
#  (0.4, 640, 76.8): 0.10852356937764229,
#  (0.4, 640, 115.2): 0.7715769074151082,
#  (0.4, 640, 153.6): 0.9335736453308602,
#  (0.4, 640, 192.0): 0.7742625588812856,
#  (0.4, 640, 230.4): 0.9906476189849553,
#  (0.4, 640, 268.8): 0.017857099420836242,
#  (0.4, 640, 307.2): 0.8222899600398837,
#  (0.4, 640, 345.6): 0.4095894284110583,
#  (0.4, 640, 384.0): 0.8799823745570572,
#  (0.4, 640, 422.4): 0,
#  (0.4, 660, 0.0): 0.10791945201971387,
#  (0.4, 660, 38.4): 0.7012986158997808,
#  (0.4, 660, 76.8): 0.3388520109704958,
#  (0.4, 660, 115.2): 0.5546037716058055,
#  (0.4, 660, 153.6): 0.5651488270586478,
#  (0.4, 660, 192.0): 0.405887994009152,
#  (0.4, 660, 230.4): 0.8318219374441586,
#  (0.4, 660, 268.8): 0.7947135744183452,
#  (0.4, 660, 307.2): 0.5774136401769882,
#  (0.4, 660, 345.6): 0.846076549189937,
#  (0.4, 660, 384.0): 0.3058526096028804,
#  (0.4, 660, 422.4): 0,
#  (0.4, 680, 0.0): 0.17680729975885245,
#  (0.4, 680, 38.4): 0.04133114105961888,
#  (0.4, 680, 76.8): 0.5066050570443199,
#  (0.4, 680, 115.2): 0.014613266321518714,
#  (0.4, 680, 153.6): 0.901069720933888,
#  (0.4, 680, 192.0): 0.8447613909157669,
#  (0.4, 680, 230.4): 0.9836194868566108,
#  (0.4, 680, 268.8): 0.31340409115231904,
#  (0.4, 680, 307.2): 0.08578997760370466,
#  (0.4, 680, 345.6): 0.4539341362469089,
#  (0.4, 680, 384.0): 0.997488564744206,
#  (0.4, 680, 422.4): 0,
#  (0.4, 700, 0.0): 0.16307324134958578,
#  (0.4, 700, 38.4): 0.1928634768874673,
#  (0.4, 700, 76.8): 0.897104052772837,
#  (0.4, 700, 115.2): 0.3982073939740447,
#  (0.4, 700, 153.6): 0.760317969983957,
#  (0.4, 700, 192.0): 0.45342367044608545,
#  (0.4, 700, 230.4): 0.5161466787731475,
#  (0.4, 700, 268.8): 0.8594257482950859,
#  (0.4, 700, 307.2): 0.2286247604833529,
#  (0.4, 700, 345.6): 0.00598651302755393,
#  (0.4, 700, 384.0): 0.14447552009052567,
#  (0.4, 700, 422.4): 0,
#  (0.6, 0, 0.0): 0.28112897554034566,
#  (0.6, 0, 38.4): 0.7396226360580295,
#  (0.6, 0, 76.8): 0.6893035011329048,
#  (0.6, 0, 115.2): 0.5407199145844142,
#  (0.6, 0, 153.6): 0.39472912905678004,
#  (0.6, 0, 192.0): 0.6140704975282976,
#  (0.6, 0, 230.4): 0.906612206087838,
#  (0.6, 0, 268.8): 0.77527242207451,
#  (0.6, 0, 307.2): 0.9160199340968123,
#  (0.6, 0, 345.6): 0.058171121968637496,
#  (0.6, 0, 384.0): 0.2286823007216705,
#  (0.6, 0, 422.4): 0,
#  (0.6, 20, 0.0): 0.509001920940133,
#  (0.6, 20, 38.4): 0.19918613573556987,
#  (0.6, 20, 76.8): 0.5547505118021928,
#  (0.6, 20, 115.2): 0.31782244386192515,
#  (0.6, 20, 153.6): 0.8877910069596141,
#  (0.6, 20, 192.0): 0.04852023533669103,
#  (0.6, 20, 230.4): 0.062254732383334344,
#  (0.6, 20, 268.8): 0.4711597622095597,
#  (0.6, 20, 307.2): 0.3157300145446894,
#  (0.6, 20, 345.6): 0.7840678893889328,
#  (0.6, 20, 384.0): 0.7503676110685712,
#  (0.6, 20, 422.4): 0,
#  (0.6, 40, 0.0): 0.43237618921016996,
#  (0.6, 40, 38.4): 0.15406912276663698,
#  (0.6, 40, 76.8): 0.9749756325973129,
#  (0.6, 40, 115.2): 0.20403449813043872,
#  (0.6, 40, 153.6): 0.5919966344561182,
#  (0.6, 40, 192.0): 0.712931922560933,
#  (0.6, 40, 230.4): 0.7981803465066989,
#  (0.6, 40, 268.8): 0.4038478771876255,
#  (0.6, 40, 307.2): 0.7691716606757266,
#  (0.6, 40, 345.6): 0.8472371039622796,
#  (0.6, 40, 384.0): 0.4044610765235216,
#  (0.6, 40, 422.4): 0,
#  (0.6, 60, 0.0): 0.0709279670706695,
#  (0.6, 60, 38.4): 0.765650642589636,
#  (0.6, 60, 76.8): 0.009688503038383534,
#  (0.6, 60, 115.2): 0.8794280153701584,
#  (0.6, 60, 153.6): 0.0057256978589455,
#  (0.6, 60, 192.0): 0.0028891163177129364,
#  (0.6, 60, 230.4): 0.15038503648578339,
#  (0.6, 60, 268.8): 0.30904481332126876,
#  (0.6, 60, 307.2): 0.27934704610391203,
#  (0.6, 60, 345.6): 0.887117957361658,
#  (0.6, 60, 384.0): 0.8477942994751357,
#  (0.6, 60, 422.4): 0,
#  (0.6, 80, 0.0): 0.7407100685512678,
#  (0.6, 80, 38.4): 0.42752081438099054,
#  (0.6, 80, 76.8): 0.2780665884687934,
#  (0.6, 80, 115.2): 0.2863173860942414,
#  (0.6, 80, 153.6): 0.9314173977572602,
#  (0.6, 80, 192.0): 0.527128827229589,
#  (0.6, 80, 230.4): 0.8466868295170612,
#  (0.6, 80, 268.8): 0.9336584551233783,
#  (0.6, 80, 307.2): 0.051013015947752316,
#  (0.6, 80, 345.6): 0.21545474699523914,
#  (0.6, 80, 384.0): 0.9825315223258039,
#  (0.6, 80, 422.4): 0,
#  (0.6, 100, 0.0): 0.08397972533854481,
#  (0.6, 100, 38.4): 0.9247425688139391,
#  (0.6, 100, 76.8): 0.2523045305827345,
#  (0.6, 100, 115.2): 0.6103318142393899,
#  (0.6, 100, 153.6): 0.8533906524004955,
#  (0.6, 100, 192.0): 0.3958914482892496,
#  (0.6, 100, 230.4): 0.26976514553860653,
#  (0.6, 100, 268.8): 0.45030865667957176,
#  (0.6, 100, 307.2): 0.7798311208653913,
#  (0.6, 100, 345.6): 0.5425807992921187,
#  (0.6, 100, 384.0): 0.9403616025624529,
#  (0.6, 100, 422.4): 0,
#  (0.6, 120, 0.0): 0.9215716475216895,
#  (0.6, 120, 38.4): 0.5402369116848997,
#  (0.6, 120, 76.8): 0.6462765276505631,
#  (0.6, 120, 115.2): 0.9424270061377272,
#  (0.6, 120, 153.6): 0.698036479113076,
#  (0.6, 120, 192.0): 0.3462282999865173,
#  (0.6, 120, 230.4): 0.22537804447920662,
#  (0.6, 120, 268.8): 0.1264287413251033,
#  (0.6, 120, 307.2): 0.7265558097128779,
#  (0.6, 120, 345.6): 0.11790586015656113,
#  (0.6, 120, 384.0): 0.10126742326687665,
#  (0.6, 120, 422.4): 0,
#  (0.6, 140, 0.0): 0.6211778785831036,
#  (0.6, 140, 38.4): 0.9604178430492547,
#  (0.6, 140, 76.8): 0.2587881672064908,
#  (0.6, 140, 115.2): 0.7945288016640375,
#  (0.6, 140, 153.6): 0.8804656741266409,
#  (0.6, 140, 192.0): 0.7062283632940322,
#  (0.6, 140, 230.4): 0.10797080325574959,
#  (0.6, 140, 268.8): 0.4108918225465489,
#  (0.6, 140, 307.2): 0.653568713476231,
#  (0.6, 140, 345.6): 0.7396131489464152,
#  (0.6, 140, 384.0): 0.09138695424829257,
#  (0.6, 140, 422.4): 0,
#  (0.6, 160, 0.0): 0.910269166799355,
#  (0.6, 160, 38.4): 0.6476641503984892,
#  (0.6, 160, 76.8): 0.7700184720816077,
#  (0.6, 160, 115.2): 0.4749577272102228,
#  (0.6, 160, 153.6): 0.8404942611386905,
#  (0.6, 160, 192.0): 0.05444681363441173,
#  (0.6, 160, 230.4): 0.33284544324298604,
#  (0.6, 160, 268.8): 0.5539245261870349,
#  (0.6, 160, 307.2): 0.949145498326312,
#  (0.6, 160, 345.6): 0.290043847615555,
#  (0.6, 160, 384.0): 0.0022255262110939533,
#  (0.6, 160, 422.4): 0,
#  (0.6, 180, 0.0): 0.6315628149099507,
#  (0.6, 180, 38.4): 0.2399528896255001,
#  (0.6, 180, 76.8): 0.5440230122222791,
#  (0.6, 180, 115.2): 0.24081653369489464,
#  (0.6, 180, 153.6): 0.8478710631680717,
#  (0.6, 180, 192.0): 0.4108753383204765,
#  (0.6, 180, 230.4): 0.8396580418925739,
#  (0.6, 180, 268.8): 0.17322839438212878,
#  (0.6, 180, 307.2): 0.43732617221486436,
#  (0.6, 180, 345.6): 0.5205779817260201,
#  (0.6, 180, 384.0): 0.6598978768714331,
#  (0.6, 180, 422.4): 0,
#  (0.6, 200, 0.0): 0.3505538756069344,
#  (0.6, 200, 38.4): 0.789662535204206,
#  (0.6, 200, 76.8): 0.23150552761942955,
#  (0.6, 200, 115.2): 0.6601152425384867,
#  (0.6, 200, 153.6): 0.28673336750062495,
#  (0.6, 200, 192.0): 0.09893765489797657,
#  (0.6, 200, 230.4): 0.8063934847887063,
#  (0.6, 200, 268.8): 0.8337414893249439,
#  (0.6, 200, 307.2): 0.7259263829904212,
#  (0.6, 200, 345.6): 0.06370750544257542,
#  (0.6, 200, 384.0): 0.6602072636376541,
#  (0.6, 200, 422.4): 0,
#  (0.6, 220, 0.0): 0.36943577903845115,
#  (0.6, 220, 38.4): 0.7589924113197708,
#  (0.6, 220, 76.8): 0.3120950227696906,
#  (0.6, 220, 115.2): 0.5105298615390156,
#  ...}

# %%
len(policy_library)
# Out:
# 200

# %%
#save policy library file
f = open("200iterations_policy_library.txt","w+")
f.write(str(policy_library))
f.close()

# %%
first_entry_in_library = policy_library[0]
for i in range(len(policy_library)):
    number_of_same_action = 0
    for state in keys_to_be_iterated:
        if policy_library[i][state] ==  first_entry_in_library[state]:
            number_of_same_action += 1
    print(i,'th policy','% same as final entry:', number_of_same_action/len(first_entry_in_library))
# Out:
# 0 th policy % same as final entry: 1.0
# 1 th policy % same as final entry: 0.2361111111111111
# 2 th policy % same as final entry: 0.24179292929292928
# 3 th policy % same as final entry: 0.2345328282828283
# 4 th policy % same as final entry: 0.2528409090909091
# 5 th policy % same as final entry: 0.24494949494949494
# 6 th policy % same as final entry: 0.25
# 7 th policy % same as final entry: 0.2730429292929293
# 8 th policy % same as final entry: 0.2471590909090909
# 9 th policy % same as final entry: 0.24210858585858586
# 10 th policy % same as final entry: 0.2380050505050505
# 11 th policy % same as final entry: 0.24526515151515152
# 12 th policy % same as final entry: 0.25315656565656564
# 13 th policy % same as final entry: 0.25063131313131315
# 14 th policy % same as final entry: 0.2563131313131313
# 15 th policy % same as final entry: 0.24431818181818182
# 16 th policy % same as final entry: 0.25978535353535354
# 17 th policy % same as final entry: 0.23958333333333334
# 18 th policy % same as final entry: 0.2465277777777778
# 19 th policy % same as final entry: 0.24337121212121213
# 20 th policy % same as final entry: 0.2730429292929293
# 21 th policy % same as final entry: 0.25757575757575757
# 22 th policy % same as final entry: 0.2588383838383838
# 23 th policy % same as final entry: 0.25946969696969696
# 24 th policy % same as final entry: 0.24936868686868688
# 25 th policy % same as final entry: 0.2503156565656566
# 26 th policy % same as final entry: 0.2534722222222222
# 27 th policy % same as final entry: 0.2455808080808081
# 28 th policy % same as final entry: 0.26073232323232326
# 29 th policy % same as final entry: 0.2316919191919192
# 30 th policy % same as final entry: 0.24842171717171718
# 31 th policy % same as final entry: 0.26704545454545453
# 32 th policy % same as final entry: 0.2601010101010101
# 33 th policy % same as final entry: 0.2515782828282828
# 34 th policy % same as final entry: 0.23011363636363635
# 35 th policy % same as final entry: 0.24368686868686867
# 36 th policy % same as final entry: 0.25946969696969696
# 37 th policy % same as final entry: 0.24431818181818182
# 38 th policy % same as final entry: 0.24589646464646464
# 39 th policy % same as final entry: 0.25978535353535354
# 40 th policy % same as final entry: 0.25
# 41 th policy % same as final entry: 0.24368686868686867
# 42 th policy % same as final entry: 0.25789141414141414
# 43 th policy % same as final entry: 0.24494949494949494
# 44 th policy % same as final entry: 0.2316919191919192
# 45 th policy % same as final entry: 0.24210858585858586
# 46 th policy % same as final entry: 0.2563131313131313
# 47 th policy % same as final entry: 0.26262626262626265
# 48 th policy % same as final entry: 0.2569444444444444
# 49 th policy % same as final entry: 0.23547979797979798
# 50 th policy % same as final entry: 0.2490530303030303
# 51 th policy % same as final entry: 0.25441919191919193
# 52 th policy % same as final entry: 0.25789141414141414
# 53 th policy % same as final entry: 0.24684343434343434
# 54 th policy % same as final entry: 0.2563131313131313
# 55 th policy % same as final entry: 0.257260101010101
# 56 th policy % same as final entry: 0.25410353535353536
# 57 th policy % same as final entry: 0.23106060606060605
# 58 th policy % same as final entry: 0.2537878787878788
# 59 th policy % same as final entry: 0.25126262626262624
# 60 th policy % same as final entry: 0.2623106060606061
# 61 th policy % same as final entry: 0.2518939393939394
# 62 th policy % same as final entry: 0.24526515151515152
# 63 th policy % same as final entry: 0.23863636363636365
# 64 th policy % same as final entry: 0.2689393939393939
# 65 th policy % same as final entry: 0.2481060606060606
# 66 th policy % same as final entry: 0.26136363636363635
# 67 th policy % same as final entry: 0.24873737373737373
# 68 th policy % same as final entry: 0.2528409090909091
# 69 th policy % same as final entry: 0.2591540404040404
# 70 th policy % same as final entry: 0.24621212121212122
# 71 th policy % same as final entry: 0.23327020202020202
# 72 th policy % same as final entry: 0.24526515151515152
# 73 th policy % same as final entry: 0.2465277777777778
# 74 th policy % same as final entry: 0.25252525252525254
# 75 th policy % same as final entry: 0.24368686868686867
# 76 th policy % same as final entry: 0.24053030303030304
# 77 th policy % same as final entry: 0.2503156565656566
# 78 th policy % same as final entry: 0.2588383838383838
# 79 th policy % same as final entry: 0.24779040404040403
# 80 th policy % same as final entry: 0.2528409090909091
# 81 th policy % same as final entry: 0.255050505050505
# 82 th policy % same as final entry: 0.25220959595959597
# 83 th policy % same as final entry: 0.2537878787878788
# 84 th policy % same as final entry: 0.2326388888888889
# 85 th policy % same as final entry: 0.24147727272727273
# 86 th policy % same as final entry: 0.2481060606060606
# 87 th policy % same as final entry: 0.24242424242424243
# 88 th policy % same as final entry: 0.24779040404040403
# 89 th policy % same as final entry: 0.24305555555555555
# 90 th policy % same as final entry: 0.24084595959595959
# 91 th policy % same as final entry: 0.2342171717171717
# 92 th policy % same as final entry: 0.26672979797979796
# 93 th policy % same as final entry: 0.2619949494949495
# 94 th policy % same as final entry: 0.24526515151515152
# 95 th policy % same as final entry: 0.2619949494949495
# 96 th policy % same as final entry: 0.2509469696969697
# 97 th policy % same as final entry: 0.25126262626262624
# 98 th policy % same as final entry: 0.2490530303030303
# 99 th policy % same as final entry: 0.24684343434343434
# 100 th policy % same as final entry: 0.2518939393939394
# 101 th policy % same as final entry: 0.23579545454545456
# 102 th policy % same as final entry: 0.23958333333333334
# 103 th policy % same as final entry: 0.24526515151515152
# 104 th policy % same as final entry: 0.2481060606060606
# 105 th policy % same as final entry: 0.2503156565656566
# 106 th policy % same as final entry: 0.2537878787878788
# 107 th policy % same as final entry: 0.255050505050505
# 108 th policy % same as final entry: 0.22506313131313133
# 109 th policy % same as final entry: 0.23327020202020202
# 110 th policy % same as final entry: 0.25599747474747475
# 111 th policy % same as final entry: 0.24431818181818182
# 112 th policy % same as final entry: 0.2588383838383838
# 113 th policy % same as final entry: 0.26294191919191917
# 114 th policy % same as final entry: 0.2528409090909091
# 115 th policy % same as final entry: 0.2582070707070707
# 116 th policy % same as final entry: 0.2556818181818182
# 117 th policy % same as final entry: 0.25441919191919193
# 118 th policy % same as final entry: 0.2481060606060606
# 119 th policy % same as final entry: 0.21843434343434343
# 120 th policy % same as final entry: 0.25978535353535354
# 121 th policy % same as final entry: 0.24873737373737373
# 122 th policy % same as final entry: 0.257260101010101
# 123 th policy % same as final entry: 0.2569444444444444
# 124 th policy % same as final entry: 0.24526515151515152
# 125 th policy % same as final entry: 0.26325757575757575
# 126 th policy % same as final entry: 0.255050505050505
# 127 th policy % same as final entry: 0.2518939393939394
# 128 th policy % same as final entry: 0.25410353535353536
# 129 th policy % same as final entry: 0.25757575757575757
# 130 th policy % same as final entry: 0.24621212121212122
# 131 th policy % same as final entry: 0.2515782828282828
# 132 th policy % same as final entry: 0.2623106060606061
# 133 th policy % same as final entry: 0.24116161616161616
# 134 th policy % same as final entry: 0.257260101010101
# 135 th policy % same as final entry: 0.2588383838383838
# 136 th policy % same as final entry: 0.2673611111111111
# 137 th policy % same as final entry: 0.2569444444444444
# 138 th policy % same as final entry: 0.23958333333333334
# 139 th policy % same as final entry: 0.2471590909090909
# 140 th policy % same as final entry: 0.24337121212121213
# 141 th policy % same as final entry: 0.25410353535353536
# 142 th policy % same as final entry: 0.22758838383838384
# 143 th policy % same as final entry: 0.2556818181818182
# 144 th policy % same as final entry: 0.23863636363636365
# 145 th policy % same as final entry: 0.24621212121212122
# 146 th policy % same as final entry: 0.24053030303030304
# 147 th policy % same as final entry: 0.25441919191919193
# 148 th policy % same as final entry: 0.24210858585858586
# 149 th policy % same as final entry: 0.255050505050505
# 150 th policy % same as final entry: 0.24242424242424243
# 151 th policy % same as final entry: 0.25
# 152 th policy % same as final entry: 0.2588383838383838
# 153 th policy % same as final entry: 0.2503156565656566
# 154 th policy % same as final entry: 0.2604166666666667
# 155 th policy % same as final entry: 0.2547348484848485
# 156 th policy % same as final entry: 0.25978535353535354
# 157 th policy % same as final entry: 0.24621212121212122
# 158 th policy % same as final entry: 0.24936868686868688
# 159 th policy % same as final entry: 0.24589646464646464
# 160 th policy % same as final entry: 0.2455808080808081
# 161 th policy % same as final entry: 0.24116161616161616
# 162 th policy % same as final entry: 0.24210858585858586
# 163 th policy % same as final entry: 0.26452020202020204
# 164 th policy % same as final entry: 0.24873737373737373
# 165 th policy % same as final entry: 0.24147727272727273
# 166 th policy % same as final entry: 0.2481060606060606
# 167 th policy % same as final entry: 0.2316919191919192
# 168 th policy % same as final entry: 0.25315656565656564
# 169 th policy % same as final entry: 0.2569444444444444
# 170 th policy % same as final entry: 0.24968434343434343
# 171 th policy % same as final entry: 0.26483585858585856
# 172 th policy % same as final entry: 0.2563131313131313
# 173 th policy % same as final entry: 0.26167929292929293
# 174 th policy % same as final entry: 0.24684343434343434
# 175 th policy % same as final entry: 0.2588383838383838
# 176 th policy % same as final entry: 0.2553661616161616
# 177 th policy % same as final entry: 0.26262626262626265
# 178 th policy % same as final entry: 0.2563131313131313
# 179 th policy % same as final entry: 0.25599747474747475
# 180 th policy % same as final entry: 0.24305555555555555
# 181 th policy % same as final entry: 0.24368686868686867
# 182 th policy % same as final entry: 0.25
# 183 th policy % same as final entry: 0.22758838383838384
# 184 th policy % same as final entry: 0.24305555555555555
# 185 th policy % same as final entry: 0.24400252525252525
# 186 th policy % same as final entry: 0.255050505050505
# 187 th policy % same as final entry: 0.26167929292929293
# 188 th policy % same as final entry: 0.2465277777777778
# 189 th policy % same as final entry: 0.24305555555555555
# 190 th policy % same as final entry: 0.24242424242424243
# 191 th policy % same as final entry: 0.24431818181818182
# 192 th policy % same as final entry: 0.2619949494949495
# 193 th policy % same as final entry: 0.2398989898989899
# 194 th policy % same as final entry: 0.24368686868686867
# 195 th policy % same as final entry: 0.2591540404040404
# 196 th policy % same as final entry: 0.24621212121212122
# 197 th policy % same as final entry: 0.2547348484848485
# 198 th policy % same as final entry: 0.27051767676767674
# 199 th policy % same as final entry: 0.26136363636363635

# %%
import numpy as np
policy_library = np.loadtxt('200iterations_policy_library.txt')
policy_library
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-4024e83e4b10> in <module>
#       1 import numpy as np
# ----> 2 policy_library = np.loadtxt('200iterations_policy_library.txt')
#       3 policy_library
#
# /opt/anaconda3/lib/python3.7/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows)
#    1144         # converting the data
#    1145         X = None
# -> 1146         for x in read_data(_loadtxt_chunksize):
#    1147             if X is None:
#    1148                 X = np.array(x, dtype)
#
# /opt/anaconda3/lib/python3.7/site-packages/numpy/lib/npyio.py in read_data(chunk_size)
#    1072
#    1073             # Convert each value according to its column and store
# -> 1074             items = [conv(val) for (conv, val) in zip(converters, vals)]
#    1075
#    1076             # Then pack it according to the dtype's nesting
#
# /opt/anaconda3/lib/python3.7/site-packages/numpy/lib/npyio.py in <listcomp>(.0)
#    1072
#    1073             # Convert each value according to its column and store
# -> 1074             items = [conv(val) for (conv, val) in zip(converters, vals)]
#    1075
#    1076             # Then pack it according to the dtype's nesting
#
# /opt/anaconda3/lib/python3.7/site-packages/numpy/lib/npyio.py in floatconv(x)
#     779         if '0x' in x:
#     780             return float.fromhex(x)
# --> 781         return float(x)
#     782
#     783     typ = dtype.type
#
# ValueError: could not convert string to float: '[{(0.2,'

# %% [markdown]
# # Evaluation

# %%
#Score every policy in the library
scores_of_policy_library = []
ith_iteration = []

for j in range(len(policy_library)):
    policy_entry = policy_library[j]
    my_policy = [action]
    x_data = [state[0]]
    N_data = [state[1]]
    t_data = [state[2]]
    sum_score = 0 #reset counter
    score = 0
    
    for episode in range(1000): #run 1000 episodes and take average score
        state = (0.2,160,0) #set initial state
        
        for step in range(10): #take ten steps in each episode
            action = policy_entry[state] #get action from policy
            state = transition(state, action)[0] #evolve current state and get new state
            my_policy += [action]
            x_data += [state[0]]
            N_data += [state[1]]
            t_data += [state[2]]
            
        score = 100*x_data[-1] - N_data[-1] #calculate score from final state
        sum_score += score #add score to sum
    score = sum_score/1000 #take average
    
    scores_of_policy_library += [score] #store score
    ith_iteration += [j+1] #store jth iteration
    print(j+1,'th policy in library:', score)
# Out:
# 1 th policy in library: 64.86
# 2 th policy in library: 57.04
# 3 th policy in library: 48.9
# 4 th policy in library: 47.18
# 5 th policy in library: 61.02
# 6 th policy in library: 50.04
# 7 th policy in library: 54.4
# 8 th policy in library: 43.14
# 9 th policy in library: 39.32
# 10 th policy in library: 54.92
# 11 th policy in library: 47.94
# 12 th policy in library: 35.12
# 13 th policy in library: 55.26
# 14 th policy in library: 66.82
# 15 th policy in library: 43.6
# 16 th policy in library: 36.78
# 17 th policy in library: 55.96
# 18 th policy in library: 37.28
# 19 th policy in library: 58.1
# 20 th policy in library: 47.88
# 21 th policy in library: 40.36
# 22 th policy in library: 50.72
# 23 th policy in library: 52.44
# 24 th policy in library: 48.86
# 25 th policy in library: 33.44
# 26 th policy in library: 68.36
# 27 th policy in library: 56.52
# 28 th policy in library: 54.68
# 29 th policy in library: 47.24
# 30 th policy in library: 38.78
# 31 th policy in library: 49.34
# 32 th policy in library: 45.38
# 33 th policy in library: 45.74
# 34 th policy in library: 54.08
# 35 th policy in library: 48.7
# 36 th policy in library: 65.4
# 37 th policy in library: 34.52
# 38 th policy in library: 59.66
# 39 th policy in library: 30.24
# 40 th policy in library: 63.34
# 41 th policy in library: 62.36
# 42 th policy in library: 58.22
# 43 th policy in library: 66.72
# 44 th policy in library: 54.02
# 45 th policy in library: 42.58
# 46 th policy in library: 57.34
# 47 th policy in library: 59.16
# 48 th policy in library: 60.06
# 49 th policy in library: 49.96
# 50 th policy in library: 45.48
# 51 th policy in library: 56.24
# 52 th policy in library: 31.42
# 53 th policy in library: 53.6
# 54 th policy in library: 59.46
# 55 th policy in library: 55.46
# 56 th policy in library: 37.82
# 57 th policy in library: 51.1
# 58 th policy in library: 44.92
# 59 th policy in library: 41.76
# 60 th policy in library: 63.42
# 61 th policy in library: 53.92
# 62 th policy in library: 46.02
# 63 th policy in library: 45.0
# 64 th policy in library: 55.84
# 65 th policy in library: 32.9
# 66 th policy in library: 58.02
# 67 th policy in library: 46.34
# 68 th policy in library: 50.92
# 69 th policy in library: 37.38
# 70 th policy in library: 54.08
# 71 th policy in library: 60.84
# 72 th policy in library: 55.38
# 73 th policy in library: 51.48
# 74 th policy in library: 42.46
# 75 th policy in library: 51.88
# 76 th policy in library: 50.22
# 77 th policy in library: 37.38
# 78 th policy in library: 49.04
# 79 th policy in library: 54.92
# 80 th policy in library: 48.22
# 81 th policy in library: 51.66
# 82 th policy in library: 58.48
# 83 th policy in library: 41.88
# 84 th policy in library: 42.94
# 85 th policy in library: 44.24
# 86 th policy in library: 52.02
# 87 th policy in library: 55.34
# 88 th policy in library: 51.96
# 89 th policy in library: 57.6
# 90 th policy in library: 51.06
# 91 th policy in library: 55.8
# 92 th policy in library: 50.6
# 93 th policy in library: 53.48
# 94 th policy in library: 53.84
# 95 th policy in library: 50.78
# 96 th policy in library: 32.84
# 97 th policy in library: 54.84
# 98 th policy in library: 53.12
# 99 th policy in library: 36.48
# 100 th policy in library: 58.0
# 101 th policy in library: 54.12
# 102 th policy in library: 40.26
# 103 th policy in library: 42.2
# 104 th policy in library: 45.84
# 105 th policy in library: 45.82
# 106 th policy in library: 55.72
# 107 th policy in library: 59.84
# 108 th policy in library: 36.26
# 109 th policy in library: 63.92
# 110 th policy in library: 57.36
# 111 th policy in library: 50.22
# 112 th policy in library: 38.38
# 113 th policy in library: 53.3
# 114 th policy in library: 57.84
# 115 th policy in library: 50.22
# 116 th policy in library: 41.68
# 117 th policy in library: 46.86
# 118 th policy in library: 53.12
# 119 th policy in library: 47.58
# 120 th policy in library: 53.88
# 121 th policy in library: 60.42
# 122 th policy in library: 38.92
# 123 th policy in library: 57.32
# 124 th policy in library: 47.62
# 125 th policy in library: 44.52
# 126 th policy in library: 56.32
# 127 th policy in library: 40.42
# 128 th policy in library: 49.56
# 129 th policy in library: 61.78
# 130 th policy in library: 36.02
# 131 th policy in library: 58.0
# 132 th policy in library: 62.28
# 133 th policy in library: 56.32
# 134 th policy in library: 58.7
# 135 th policy in library: 50.1
# 136 th policy in library: 53.98
# 137 th policy in library: 50.16
# 138 th policy in library: 54.86
# 139 th policy in library: 51.1
# 140 th policy in library: 39.34
# 141 th policy in library: 57.5
# 142 th policy in library: 49.2
# 143 th policy in library: 51.06
# 144 th policy in library: 63.1
# 145 th policy in library: 46.0
# 146 th policy in library: 63.1
# 147 th policy in library: 52.28
# 148 th policy in library: 49.44
# 149 th policy in library: 42.3
# 150 th policy in library: 56.24
# 151 th policy in library: 64.8
# 152 th policy in library: 65.34
# 153 th policy in library: 51.72
# 154 th policy in library: 40.28
# 155 th policy in library: 53.24
# 156 th policy in library: 51.26
# 157 th policy in library: 51.42
# 158 th policy in library: 54.1
# 159 th policy in library: 35.5
# 160 th policy in library: 37.14
# 161 th policy in library: 53.34
# 162 th policy in library: 43.34
# 163 th policy in library: 46.46
# 164 th policy in library: 41.0
# 165 th policy in library: 39.72
# 166 th policy in library: 52.7
# 167 th policy in library: 51.6
# 168 th policy in library: 55.28
# 169 th policy in library: 57.9
# 170 th policy in library: 68.98
# 171 th policy in library: 49.8
# 172 th policy in library: 41.82
# 173 th policy in library: 58.3
# 174 th policy in library: 57.44
# 175 th policy in library: 51.42
# 176 th policy in library: 52.56
# 177 th policy in library: 27.58
# 178 th policy in library: 61.22
# 179 th policy in library: 49.88
# 180 th policy in library: 48.72
# 181 th policy in library: 38.1
# 182 th policy in library: 65.52
# 183 th policy in library: 41.14
# 184 th policy in library: 54.9
# 185 th policy in library: 47.74
# 186 th policy in library: 68.18
# 187 th policy in library: 50.88
# 188 th policy in library: 42.12
# 189 th policy in library: 56.96
# 190 th policy in library: 57.98
# 191 th policy in library: 44.96
# 192 th policy in library: 48.56
# 193 th policy in library: 66.74
# 194 th policy in library: 46.02
# 195 th policy in library: 46.86
# 196 th policy in library: 45.82
# 197 th policy in library: 37.8
# 198 th policy in library: 59.62
# 199 th policy in library: 42.8
# 200 th policy in library: 52.08

# %%
#plot score of policy library 
plt.plot(ith_iteration,scores_of_policy_library)
print('Index of best policy in library:', argmax(scores_of_policy_library))
# Out:
# Index of best policy in library: 169

# %%
# evaluate random policy
random_policy = initialise_deterministic_policy()
sum_score = 0
score = 0
for episode in range(1000): #run 1000 episodes and take average score
    state = (0.2,160,0) #set initial state
        
    for step in range(10): #take ten steps in each episode
        action = random_policy[state] #get action from policy
        state = transition(state, action)[0] #evolve current state and get new state
        my_policy += [action]
        x_data += [state[0]]
        N_data += [state[1]]
        t_data += [state[2]]
            
    score = 100*x_data[-1] - N_data[-1] #calculate score from final state
    sum_score += score #add score to sum
score = sum_score/1000 #take average
    
print('Random policy:', score)
# Out:
# Random policy: -0.98

# %%
policy_to_be_plotted = policy_library[169] #choose a particular policy from library
state = (0.2,160,0) #initial state
x_data = [state[0]] #store initial data
N_data = [state[1]]
t_data = [state[2]]
my_policy = []
for i in range(10): #take ten steps
        action = policy_to_be_plotted[state]
        state = transition(state, action)[0]
        my_policy += [action]
        x_data += [state[0]]
        N_data += [state[1]]
        t_data += [state[2]]
print('Current policy:', my_policy)
print('Concentration of x:', x_data)
print('Concentration of N:', N_data)
print('')
score = 100*x_data[-1] - N_data[-1]
print('Score:', score)
def plot(t_data, x_data, N_data):
    plt.figure()
    plt.plot(t_data, x_data, label = 'x')
    plt.legend()
    plt.figure()
    plt.plot(t_data, N_data, label = 'N')
    plt.legend()
    score = 100*x_data[-1] - N_data[-1]
plot(t_data, x_data, N_data)
# Out:
# Current policy: [8, 2, 0, 0, 1, 9, 4, 13, 5, 0]
# Concentration of x: [0.2, 0.4, 0.6, 0.6, 0.6, 0.4, 0.4, 0.4, 0.6, 0.8, 0.8]
# Concentration of N: [160, 220.0, 100.0, 40.0, 20.0, 20.0, 100.0, 100.0, 200.0, 100.0, 0.0]
#
# Score: 80.0
