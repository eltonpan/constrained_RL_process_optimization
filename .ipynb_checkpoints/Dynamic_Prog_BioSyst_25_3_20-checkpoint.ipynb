# %%
# Authors:
# A. del Rio Chanona - Imperial College

import pylab
import numpy as np
import scipy.integrate as scp
from pylab import *
import matplotlib.pyplot as plt
import csv
import os
import sys
import copy
import numpy.random as rnd
from scipy.spatial.distance import cdist
# !pip install sobol_seq
import sobol_seq
from scipy.optimize import minimize
eps  = np.finfo(float).eps
import random
# Out:
# Requirement already satisfied: sobol_seq in /opt/anaconda3/lib/python3.7/site-packages (0.1.2)
# WARNING: You are using pip version 19.3.1; however, version 20.0.2 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %% [markdown]
# ## Dyanmical System
#
# Here we have a dynamic system, where $x$ is biomas, $N$ is nitrogen source, and $F_{N_{in}}$ is an inflow rate.
#
# $$\frac{\text{d}x}{\text{d}t}=\mu~x~\frac{N}{N+K_N}-\mu_d~x$$
#
# $$\frac{\text{d}N}{\text{d}t}=-Y_{Nx}x~\mu~\frac{N}{N+K_N}+F_{N_{in}}$$
#
# We wish to optimize at the final time $t_f$ the cost given by the biomass we can harves, minus a penalization for the nitrogen that was not consumed, the objective function is:
#
# $$f_{obj_1}=100x_{t_f}-N_{t_f}$$
#
# where $x_{t_f}$ and $N_{t_f}$ refer to the final biomass and nitrogen quantity. We can control $F_{N_{in}}\in[0,7]$ with a precision of $0.5$ changing it $10$ times (equidistantly) from time $0$ to time $t_f$
#
# We can aditionally have an objective function that penalizes nitrogen source input:
#
# $$f_{obj_2}=100x_{t_f}-N_{t_f}-\sum_{i=0}^{T}F_{N_{in}}^i$$
#
# where $T$ is the total number of time steps (inputs) and $F_{N_{in}}^i$ corresponds to the nitrate input at time-step $i$.

# %%
class ModelIntegration:
    
    # --- initializing model --- #
    def __init__(self, parameters, controls, tf): # controls is a list of eg. ten numbers, each corresponding to 1 addition at a certain time step
        
        # Object variable definitions
        self.parameters, self.controls = parameters, controls
        self.dt, self.tf               = tf/(controls.shape[1]), tf
        self.u0                        = controls[:,0]
        
    # --- dynamic model definition --- #    
    def model(self, t, state):
        # internal definitions
        params = self.parameters
        ctrl   = self.u0
        
        FCn    = ctrl[0]
        
        # state vector
        Cx  = state[0]
        Cn  = state[1]
        
        # parameters
        u_m  = params['u_m']; K_N  = params['K_N'];
        u_d  = params['u_d']; Y_nx = params['Y_nx'];
        
        # algebraic equations
        
        # variable rate equations
        dev_Cx  = u_m * Cx * Cn/(Cn+K_N) - u_d*Cx**2
        dev_Cn  = - Y_nx * u_m * Cx * Cn/(Cn+K_N) + FCn
        
        return np.array([dev_Cx, dev_Cn],dtype='float64')
    
    # --- simulation --- #
    def simulation(self, x0):
        # internal definitions
        dt, steps   = self.dt, int(self.tf/float(self.dt))
        model, controls = self.model, self.controls
        
        # compile state trajectories
        xt = np.zeros((x0.shape[0],steps+1)) #x0 is init conditions eg. x0 = np.array([0.1,150.0])
        tt = np.zeros((steps+1)) #these two lines initializes a matrix of 2 x (no. of steps + 1)
        
        # initialize simulation
        current_state = x0
        xt[:,0]       = current_state
        tt[0]         = 0.
        
        # simulation
        for s in range(steps):
            self.u0   = controls[:,s]                       # control for this step
            ode       = scp.ode(model)                      # define ode
            ode.set_integrator('lsoda', nsteps=3000)        # define integrator
            ode.set_initial_value(current_state,dt)         # set initial value
            current_state = list(ode.integrate(ode.t + dt)) # integrate system
            xt[:,s+1]     = current_state                   # add current state Note: here we can add randomnes as: + RandomNormal noise
            tt[s+1]       = (s+1)*dt
        
        return xt, tt

# %%
p  = {'u_m' : 0.0923*0.62, 'K_N' : 393.10, 'u_d' : 0.01, 'Y_nx' : 504.49} #don't touch the params!

steps_   = 10
FCn_0    = [np.sin(i/6.5)*2+5. for i in range(steps_)] #just an example solution! #FIND THIS
#FCn_0    = [6. for i in range(steps_)]

u  = np.array([FCn_0])
tf = 16.*24. #16 days of reaction time
x0 = np.array([0.1,150.0])  #don't change initial conditons


m      = ModelIntegration(p, u, tf)
xt, tt = m.simulation(x0) 

# --- plot results --- #

import matplotlib.pyplot as plt
for i in range(xt.shape[0]): #reminder: xt is the matrix of 2 x (no. of steps + 1). where rows 1 and 2 are the conc. of x and N, respectively.
    plt.plot(tt,xt[i,:]/np.max(xt[i,:])) #makes the two *normalized* plots (conc. of x and N) over time
plt.step(tt[:-1],FCn_0/np.max(FCn_0)) #plots the *normalized* control over time
plt.ylabel('state')
plt.xlabel('time')
plt.show()

for i in range(xt.shape[0]): #plot the three graphs separately, and with no normalization.
    plt.plot(tt,xt[i,:])
    plt.ylabel('state')
    plt.xlabel('time')
    plt.show()
plt.step(tt[:-1],FCn_0)
plt.show()

# %% [markdown]
# ## Dynamic Programming solutions
#
# To solve this problem, initially we should think of discretizing states (time is already discretized). This can be done for Biomass in $0.5$ intervals, and for Nitrate in $25$ intervals.

# %% [markdown]
# ## Defining discrete environment

# %%
############ Defining Environment ##############

class Model_env: 
    
    # --- initializing model --- #
    def __init__(self, parameters, tf, modulus):
        
        # Object variable definitions
        self.parameters       = parameters
        self.tf, self.modulus = tf, modulus  # two column array [biomass nitrate]
        
    # --- dynamic model definition --- #    
    # model takes state and action of previous time step and integrates -- definition of ODE system at time, t
    def model(self, t, state):
        # internal definitions
        params = self.parameters
        FCn   = self.u0
                
        # state vector
        Cx  = state[0]
        Cn  = state[1]
        
        # parameters
        u_m  = params['u_m']; K_N  = params['K_N'];
        u_d  = params['u_d']; Y_nx = params['Y_nx'];
        
        # algebraic equations
        
        # variable rate equations
        dev_Cx  = u_m * Cx * Cn/(Cn+K_N) - u_d*Cx**2
        dev_Cn  = - Y_nx * u_m * Cx * Cn/(Cn+K_N) + FCn
        
        return np.array([dev_Cx, dev_Cn],dtype='float64')
    
    def discrete_env(self, state):
        # discretisation of the system, with introduction of stochasticity in terms of modulus
        modulus = self.modulus
        
        # passing to arrays
        modulus = np.array(modulus)    # eg. modulus = np.array([0.2, 20.]) basically what modulus does is it indicates the rounding of the conc of x and conc of nitrate
        state   = np.array(state)  # eg. state = np.array([0.1,150.0]) first number is the conc of x and 2nd number is the conc of nitrate

        resid = state % modulus #find remainder
        resid = resid/modulus # remember resid is now an array. resid is normalized with respect to the size of modulus 
        UB = (1 - resid)**30 #SQUARE of inverse distance to UB # 1 minus resid because we are talking about normalized inverse length from actual value to upper bound
        LB = resid**30 #SQUARE of inverse distance to UB
        draw =  [np.random.uniform(0,UB[0]+LB[0]), np.random.uniform(0,UB[1]+LB[1])] # generate an array of 2 random numbers between 0 and 1

        for i in range(state.shape[0]):
            if draw[i] < UB[i]: #introduce stochasticity w.r.t. rounding up or down
                state[i] = state[i] - resid[i] * modulus[i] #rmb now resid is now a NORMALIZED array of 2 numbers so it has to be multiplied back to un-normalize residual #rounds down by substracting away the residual
            else:
                state[i] = state[i] - resid[i] * modulus[i] + modulus[i] #rounds up
        
        # fixes for representation 
        # Nitrate fix
        if state[1] < 0:
            state[1] = 0
        elif state[0] < 0:
            state[0] = 0
        
        # Biomass fix
        f = str(self.modulus[0])
        decimal = f[::-1].find('.')  
        state[0] = np.round(state[0], decimal)
        f1 = str(self.modulus[1])
        decimal1 = f1[::-1].find('.')  
        state[0] = np.round(state[0], decimal1)

        if state[0] == eps:
            state[0] = 0
        if state[1] == eps:
            state[1] = 0
        
        return state

    def simulation(self, x0, controls):
        # internal definitions
        model, tf     = self.model, self.tf
        self.controls = controls
        
        # initialize simulation
        current_state = x0
        
        # simulation #ONLY ONE STEP unlike the previous code shown above
        self.u0   = controls[:]                       # control for this step
        ode       = scp.ode(model)                      # define ode
        ode.set_integrator('lsoda', nsteps=3000)        # define integrator
        ode.set_initial_value(current_state, tf)         # set initial value
        current_state = list(ode.integrate(ode.t + tf)) # integrate system
        xt            = current_state                   # add current state Note: here we can add randomnes as: + RandomNormal noise
        
        return xt

    def MDP_simulation(self, x0, controls): #simulate ONLY ONE STEP
        xt          = self.simulation(x0, controls) #simulate
        xt_discrete = self.discrete_env(xt) # make output state discrete
        return xt_discrete

    def reward(self, state):
        reward = 100*state[-1][0] - state[-1][1]              # objective function 1
        return reward

# %% [markdown]
# ## Simulating one Step of the dynamic system as a MDP

# %%
# Creating the model
p        = {'u_m' : 0.0923*0.62, 'K_N' : 393.10, 'u_d' : 0.01, 'Y_nx' : 504.49} # predetermined parameters by design
tf       = 16.*24./10. # assuming 10 steps, we divide the whole horizon over 10 for one step
x0       = np.array([0.2,700.0]) # initial state
modulus  = [0.2, 20.] # basically what modulus does is it indicates the rounding of the conc of x and conc of nitrate
u0       = np.array([7.]) #this is your CONTROL (rmb here it's only ONE STEP)

MDP_BioEnv = Model_env(p, tf, modulus)
MDP_BioEnv.MDP_simulation(x0, u0)
# Out:
# array([  0.8, 680. ])

# %% [markdown]
# ## Simulating multiple steps of the dynamic system as a MDP

# %%
steps_      = 10
FCn_0       = [np.sin(i/6.5)*2+5. for i in range(steps_)]
x0          = np.array([0.1,150.0]) # initial state
tf          = 16.*24./10.
x_list      = np.zeros((2,steps_+1)) #initialize state as 2D array where the 2 rows refer to conc of x and N.
t_list      = np.zeros((1,steps_+1)) #initialize time as 1D array
x_list[:,0] = x0
t_list[0]   = tf

for s in range(len(FCn_0)):
    MDP_BioEnv    = Model_env(p, tf, modulus)
    u0            = np.array([FCn_0[s]])
    x0            = MDP_BioEnv.MDP_simulation(x0, u0) #simulate one step, and update current state 
    tf            = tf + 16.*24./10. #increment time
    x_list[:,s+1] = x0 #update state memory
    t_list[:,s+1] = tf #update time memory

for i in range(x_list.shape[0]):
    plt.plot(t_list[0,:],x_list[i,:])
    plt.ylabel('state')
    plt.xlabel('time')
    plt.show()
plt.step(t_list[0,:-1],FCn_0)
plt.show()

# %%
x_list
# Out:
# array([[1.0e-01, 2.0e-01, 1.0e+00, 1.2e+00, 1.0e+00, 1.2e+00, 1.2e+00,
#         1.2e+00, 1.2e+00, 1.2e+00, 1.2e+00],
#        [1.5e+02, 3.0e+02, 2.2e+02, 8.0e+01, 1.0e+02, 1.0e+02, 1.0e+02,
#         1.0e+02, 1.0e+02, 1.0e+02, 1.0e+02]])

# %%
MDP_BioEnv.reward(x_list) #returns the reward at the final time step (end of episode)
# Out:
# 14700.0

# %% [markdown]
# # Describing the size of system

# %%
modulus = [0.2, 20.] #modulus is the graining of x and N, respectively
Number_of_possible_x = int(2.0/modulus[0]+1) #assumed max x value is 1.6
Number_of_possible_N = int(700/modulus[1]+1) #assumed max N value is 400
Number_of_discrete_states = int(Number_of_possible_x * Number_of_possible_N)
Number_of_possible_actions = int(7.0/0.5 + 1)
Number_of_possible_times = 11

print('Number of discrete_states:', Number_of_discrete_states)
print('Shape of value table:', Number_of_possible_N , 'x', Number_of_possible_x)
print('Number of possible actions:', Number_of_possible_actions)
print('Number of possible times:', Number_of_possible_times)
# Out:
# Number of discrete_states: 396
# Shape of value table: 36 x 11
# Number of possible actions: 15
# Number of possible times: 11

# %% [markdown]
# # Functions

# %%
#dictionary to map action to actual increase in N
action_ID = [x for x in range(15)]
increase_in_N = [x for x in np.arange(0,7.5,0.5)]
action_ID_to_increase_in_N = dict(zip(action_ID,increase_in_N))

action_ID_to_increase_in_N #this dictionary maps action id to actual action itself (increase in N)
# Out:
# {0: 0.0,
#  1: 0.5,
#  2: 1.0,
#  3: 1.5,
#  4: 2.0,
#  5: 2.5,
#  6: 3.0,
#  7: 3.5,
#  8: 4.0,
#  9: 4.5,
#  10: 5.0,
#  11: 5.5,
#  12: 6.0,
#  13: 6.5,
#  14: 7.0}

# %%
def transition(state, action): # state can be described by tuple(x (algae conc), N (nitrate conc), time (in hours)), action can be described by FN ∈[0,7]
    '''arguments
       state: (x, N, t) tuple 
       action: int (0-14)
    
       outputs 
       new state: (x, N, t) tuple
       reward: int 
       '''
    state = np.array(state) 
    action = [action_ID_to_increase_in_N[action]] #assign action according to dictionary defined above
    
    if (abs(state[2] - 16.*24.) < 0.1): #check if terminal state is reached
        reward = 100 * state[0] - state[1]   #give reward when we LEAVE terminal state
        state[2]      += 16.*24./10. #increment time
        state_evolved = MDP_BioEnv.MDP_simulation(state[0:2], action) #evolve the system using ODE
        state_evolved = [round(state_evolved[0],1),round(state_evolved[1],1)]
        new_state = np.append(state_evolved,round(state[2],2)) # append time
        
    elif (state[2] > 16.*24.): #check if time is exceeded
        new_state = state #loop back to itself
        reward = 0 #and given zero reward    
        
#     elif (state[1] >= 700) or (state[0] >= 1.6): #check if unexplored state space is reached
#         new_state = state #loop back to itself
#         reward = 0 #and given zero reward
        
    else: #else evolve the system and assign zero reward
        state[2]      += 16.*24./10. #increment time
        state_evolved = MDP_BioEnv.MDP_simulation(state[0:2], action) #evolve the system using ODE
        state_evolved = [round(state_evolved[0],1),round(state_evolved[1],1)]
        new_state = np.append(state_evolved,round(state[2],2)) # append time
        reward    = 0 # if terminal step not reached, reward = 0

    return tuple(new_state), reward

# %%
# test transition function 
result1 = transition((0.6, 0, 0),0)
result2 = transition(result1[0],0)
result3 = transition(result2[0],0)
result4 = transition(result3[0],0)
result5 = transition(result4[0],0)
# result6 = transition(result5[0],0)
# result7 = transition(result6[0],0)
# result8 = transition(result7[0],0)
# result9 = transition(result8[0],0)
# result10 = transition(result9[0],0)
result5
# Out:
# ((0.2, 0.0, 192.0), 0)

# %%
## initialize value table
# might want to add entries of states as we visit them instead
# but here we use the brute force approach by generate all state and times

def initialise_value_table(num_states = Number_of_discrete_states): #number of discrete states
    '''initializes a random value table (a dictionary)'''
    value_table = {} # start off with empty dict that will be filled up
    for x in range(1, Number_of_possible_x): #remove x = 0.0
        for N in range(Number_of_possible_N):
            for t in np.linspace(0,16*24/10*11,12): #add extra time step
                value_table[(round(x*0.2,1),N*20, round(t,1))] = np.random.rand()
    for key in value_table.keys():
        if 422.4 in key:
            value_table[key] = 0 #assign value of ZERO to terminal states
    return value_table
value_table = initialise_value_table(num_states = Number_of_discrete_states)
print('Number of entries in value table:', len(value_table))
value_table
# Out:
# Number of entries in value table: 4320
# {(0.2, 0, 0.0): 0.7910676505873179,
#  (0.2, 0, 38.4): 0.7767267244566668,
#  (0.2, 0, 76.8): 0.8409510964744936,
#  (0.2, 0, 115.2): 0.5422934299510713,
#  (0.2, 0, 153.6): 0.32118409331172404,
#  (0.2, 0, 192.0): 0.5842699733113756,
#  (0.2, 0, 230.4): 0.27510705746343667,
#  (0.2, 0, 268.8): 0.6037230605883249,
#  (0.2, 0, 307.2): 0.9958619346889249,
#  (0.2, 0, 345.6): 0.941043011173788,
#  (0.2, 0, 384.0): 0.20870459285253817,
#  (0.2, 0, 422.4): 0,
#  (0.2, 20, 0.0): 0.968632737254242,
#  (0.2, 20, 38.4): 0.7789078418689285,
#  (0.2, 20, 76.8): 0.04336115462153434,
#  (0.2, 20, 115.2): 0.7444214197531663,
#  (0.2, 20, 153.6): 0.7521416519367781,
#  (0.2, 20, 192.0): 0.5525632999549248,
#  (0.2, 20, 230.4): 0.3604368584358906,
#  (0.2, 20, 268.8): 0.9085971090543179,
#  (0.2, 20, 307.2): 0.3646718520159403,
#  (0.2, 20, 345.6): 0.901059747064921,
#  (0.2, 20, 384.0): 0.8959865836790771,
#  (0.2, 20, 422.4): 0,
#  (0.2, 40, 0.0): 0.12194235700894995,
#  (0.2, 40, 38.4): 0.5634605979587118,
#  (0.2, 40, 76.8): 0.1123432929426117,
#  (0.2, 40, 115.2): 0.6308892983448436,
#  (0.2, 40, 153.6): 0.6020820763035188,
#  (0.2, 40, 192.0): 0.2685021622991961,
#  (0.2, 40, 230.4): 0.9966910330214511,
#  (0.2, 40, 268.8): 0.07873044939378848,
#  (0.2, 40, 307.2): 0.03822859313172433,
#  (0.2, 40, 345.6): 0.5865439328287546,
#  (0.2, 40, 384.0): 0.4784381345301162,
#  (0.2, 40, 422.4): 0,
#  (0.2, 60, 0.0): 0.7997946694014111,
#  (0.2, 60, 38.4): 0.2752072636664299,
#  (0.2, 60, 76.8): 0.7125351527091607,
#  (0.2, 60, 115.2): 0.016298003197118716,
#  (0.2, 60, 153.6): 0.6159542508848886,
#  (0.2, 60, 192.0): 0.6154633300552961,
#  (0.2, 60, 230.4): 0.030419476793973943,
#  (0.2, 60, 268.8): 0.26135186512097586,
#  (0.2, 60, 307.2): 0.18761401690880875,
#  (0.2, 60, 345.6): 0.7885767237023471,
#  (0.2, 60, 384.0): 0.8981714069200867,
#  (0.6, 160, 0.0): 0.382816582292124,
#  (0.6, 160, 38.4): 0.04187029226989192,
#  (0.6, 160, 76.8): 0.6351304625695389,
#  (0.6, 160, 115.2): 0.9425628097172051,
#  (0.6, 160, 153.6): 0.7001923126610913,
#  (0.6, 160, 192.0): 0.8044777879029171,
#  (0.6, 160, 230.4): 0.5888478180390609,
#  (0.6, 160, 268.8): 0.4182127394184283,
#  (0.6, 160, 307.2): 0.24197590865388352,
#  (0.6, 160, 345.6): 0.6115868876882465,
#  (0.6, 160, 384.0): 0.6733277630172996,
#  (0.6, 160, 422.4): 0,
#  (0.6, 180, 0.0): 0.3942759067101437,
#  (0.6, 180, 38.4): 0.7706187868056497,
#  (0.6, 180, 76.8): 0.6803410776966535,
#  (0.6, 180, 115.2): 0.6499397568061536,
#  (0.6, 180, 153.6): 0.0525696425452129,
#  (0.6, 180, 192.0): 0.5251049114217902,
#  (0.6, 180, 230.4): 0.4577870905373863,
#  (0.6, 180, 268.8): 0.010410085582675754,
#  (0.6, 180, 307.2): 0.9034074919141759,
#  (0.6, 180, 345.6): 0.27664964155070526,
#  (0.6, 180, 384.0): 0.7281376463295477,
#  (0.6, 180, 422.4): 0,
#  (0.6, 200, 0.0): 0.6196445948025084,
#  (0.6, 200, 38.4): 0.84194106088257,
#  (0.6, 200, 76.8): 0.6261670373771979,
#  (0.6, 200, 115.2): 0.08362239158051377,
#  (0.6, 200, 153.6): 0.218568452102603,
#  (0.6, 200, 192.0): 0.16974707061251548,
#  (0.6, 200, 230.4): 0.08853018161521986,
#  (0.6, 200, 268.8): 0.7445039386471872,
#  (0.6, 200, 307.2): 0.8776448961166636,
#  (0.6, 200, 345.6): 0.5878972519140733,
#  (0.6, 200, 384.0): 0.14408456923646185,
#  (0.6, 200, 422.4): 0,
#  (0.6, 220, 0.0): 0.8871916598942207,
#  (0.6, 220, 38.4): 0.6827688576057744,
#  (0.6, 220, 76.8): 0.8151849686449527,
#  (0.6, 220, 115.2): 0.5329695961013429,
#  ...}

# %%
keys_to_be_iterated = []
for x in range(1, 9): #remove x = 0.0
        for N in range(36):
            for t in np.linspace(0,16*24,11): #add extra time step
                keys_to_be_iterated += [(round(x*0.2,1),N*20, round(t,1))]
keys_to_be_iterated
# Out:
# [(0.2, 0, 0.0),
#  (0.2, 0, 38.4),
#  (0.2, 0, 76.8),
#  (0.2, 0, 115.2),
#  (0.2, 0, 153.6),
#  (0.2, 0, 192.0),
#  (0.2, 0, 230.4),
#  (0.2, 0, 268.8),
#  (0.2, 0, 307.2),
#  (0.2, 0, 345.6),
#  (0.2, 0, 384.0),
#  (0.2, 20, 0.0),
#  (0.2, 20, 38.4),
#  (0.2, 20, 76.8),
#  (0.2, 20, 115.2),
#  (0.2, 20, 153.6),
#  (0.2, 20, 192.0),
#  (0.2, 20, 230.4),
#  (0.2, 20, 268.8),
#  (0.2, 20, 307.2),
#  (0.2, 20, 345.6),
#  (0.2, 20, 384.0),
#  (0.2, 40, 0.0),
#  (0.2, 40, 38.4),
#  (0.2, 40, 76.8),
#  (0.2, 40, 115.2),
#  (0.2, 40, 153.6),
#  (0.2, 40, 192.0),
#  (0.2, 40, 230.4),
#  (0.2, 40, 268.8),
#  (0.2, 40, 307.2),
#  (0.2, 40, 345.6),
#  (0.2, 40, 384.0),
#  (0.2, 60, 0.0),
#  (0.2, 60, 38.4),
#  (0.2, 60, 76.8),
#  (0.2, 60, 115.2),
#  (0.2, 60, 153.6),
#  (0.2, 60, 192.0),
#  (0.2, 60, 230.4),
#  (0.2, 60, 268.8),
#  (0.2, 60, 307.2),
#  (0.2, 60, 345.6),
#  (0.2, 60, 384.0),
#  (0.2, 80, 0.0),
#  (0.2, 80, 38.4),
#  (0.2, 80, 76.8),
#  (0.2, 80, 115.2),
#  (0.2, 80, 153.6),
#  (0.2, 80, 192.0),
#  (0.2, 80, 230.4),
#  (0.2, 80, 268.8),
#  (0.2, 80, 307.2),
#  (0.2, 80, 345.6),
#  (0.2, 80, 384.0),
#  (0.2, 100, 0.0),
#  (0.2, 100, 38.4),
#  (0.2, 100, 76.8),
#  (0.2, 100, 115.2),
#  (0.2, 100, 153.6),
#  (0.2, 100, 192.0),
#  (0.2, 100, 230.4),
#  (0.2, 100, 268.8),
#  (0.2, 100, 307.2),
#  (0.2, 100, 345.6),
#  (0.2, 100, 384.0),
#  (0.2, 120, 0.0),
#  (0.2, 120, 38.4),
#  (0.2, 120, 76.8),
#  (0.2, 120, 115.2),
#  (0.2, 120, 153.6),
#  (0.2, 120, 192.0),
#  (0.2, 120, 230.4),
#  (0.2, 120, 268.8),
#  (0.2, 120, 307.2),
#  (0.2, 120, 345.6),
#  (0.2, 120, 384.0),
#  (0.2, 140, 0.0),
#  (0.2, 140, 38.4),
#  (0.2, 140, 76.8),
#  (0.2, 140, 115.2),
#  (0.2, 140, 153.6),
#  (0.2, 140, 192.0),
#  (0.2, 140, 230.4),
#  (0.2, 140, 268.8),
#  (0.2, 140, 307.2),
#  (0.2, 140, 345.6),
#  (0.2, 140, 384.0),
#  (0.2, 160, 0.0),
#  (0.2, 160, 38.4),
#  (0.2, 160, 76.8),
#  (0.2, 160, 115.2),
#  (0.2, 160, 153.6),
#  (0.2, 160, 192.0),
#  (0.2, 160, 230.4),
#  (0.2, 160, 268.8),
#  (0.2, 160, 307.2),
#  (0.2, 160, 345.6),
#  (0.2, 160, 384.0),
#  (0.2, 180, 0.0),
#  (0.2, 180, 38.4),
#  (0.2, 180, 76.8),
#  (0.2, 180, 115.2),
#  (0.2, 180, 153.6),
#  (0.2, 180, 192.0),
#  (0.2, 180, 230.4),
#  (0.2, 180, 268.8),
#  (0.2, 180, 307.2),
#  (0.2, 180, 345.6),
#  (0.2, 180, 384.0),
#  (0.2, 200, 0.0),
#  (0.2, 200, 38.4),
#  (0.2, 200, 76.8),
#  (0.2, 200, 115.2),
#  (0.2, 200, 153.6),
#  (0.2, 200, 192.0),
#  (0.2, 200, 230.4),
#  (0.2, 200, 268.8),
#  (0.2, 200, 307.2),
#  (0.2, 200, 345.6),
#  (0.2, 200, 384.0),
#  (0.2, 220, 0.0),
#  (0.2, 220, 38.4),
#  (0.2, 220, 76.8),
#  (0.2, 220, 115.2),
#  (0.2, 220, 153.6),
#  (0.2, 220, 192.0),
#  (0.2, 220, 230.4),
#  (0.2, 220, 268.8),
#  (0.2, 220, 307.2),
#  (0.2, 220, 345.6),
#  (0.2, 220, 384.0),
#  (0.2, 240, 0.0),
#  (0.2, 240, 38.4),
#  (0.2, 240, 76.8),
#  (0.2, 240, 115.2),
#  (0.2, 240, 153.6),
#  (0.2, 240, 192.0),
#  (0.2, 240, 230.4),
#  (0.2, 240, 268.8),
#  (0.2, 240, 307.2),
#  (0.2, 240, 345.6),
#  (0.2, 240, 384.0),
#  (0.2, 260, 0.0),
#  (0.2, 260, 38.4),
#  (0.2, 260, 76.8),
#  (0.2, 260, 115.2),
#  (0.2, 260, 153.6),
#  (0.2, 260, 192.0),
#  (0.2, 260, 230.4),
#  (0.2, 260, 268.8),
#  (0.2, 260, 307.2),
#  (0.2, 260, 345.6),
#  (0.2, 260, 384.0),
#  (0.2, 280, 0.0),
#  (0.2, 280, 38.4),
#  (0.2, 280, 76.8),
#  (0.2, 280, 115.2),
#  (0.2, 280, 153.6),
#  (0.2, 280, 192.0),
#  (0.2, 280, 230.4),
#  (0.2, 280, 268.8),
#  (0.2, 280, 307.2),
#  (0.2, 280, 345.6),
#  (0.2, 280, 384.0),
#  (0.2, 300, 0.0),
#  (0.2, 300, 38.4),
#  (0.2, 300, 76.8),
#  (0.2, 300, 115.2),
#  (0.2, 300, 153.6),
#  (0.2, 300, 192.0),
#  (0.2, 300, 230.4),
#  (0.2, 300, 268.8),
#  (0.2, 300, 307.2),
#  (0.2, 300, 345.6),
#  (0.2, 300, 384.0),
#  (0.2, 320, 0.0),
#  (0.2, 320, 38.4),
#  (0.2, 320, 76.8),
#  (0.2, 320, 115.2),
#  (0.2, 320, 153.6),
#  (0.2, 320, 192.0),
#  (0.2, 320, 230.4),
#  (0.2, 320, 268.8),
#  (0.2, 320, 307.2),
#  (0.2, 320, 345.6),
#  (0.2, 320, 384.0),
#  (0.2, 340, 0.0),
#  (0.2, 340, 38.4),
#  (0.2, 340, 76.8),
#  (0.2, 340, 115.2),
#  (0.2, 340, 153.6),
#  (0.2, 340, 192.0),
#  (0.2, 340, 230.4),
#  (0.2, 340, 268.8),
#  (0.2, 340, 307.2),
#  (0.2, 340, 345.6),
#  (0.2, 340, 384.0),
#  (0.2, 360, 0.0),
#  (0.2, 360, 38.4),
#  (0.2, 360, 76.8),
#  (0.2, 360, 115.2),
#  (0.2, 360, 153.6),
#  (0.2, 360, 192.0),
#  (0.2, 360, 230.4),
#  (0.2, 360, 268.8),
#  (0.2, 360, 307.2),
#  (0.2, 360, 345.6),
#  (0.2, 360, 384.0),
#  (0.2, 380, 0.0),
#  (0.2, 380, 38.4),
#  (0.2, 380, 76.8),
#  (0.2, 380, 115.2),
#  (0.2, 380, 153.6),
#  (0.2, 380, 192.0),
#  (0.2, 380, 230.4),
#  (0.2, 380, 268.8),
#  (0.2, 380, 307.2),
#  (0.2, 380, 345.6),
#  (0.2, 380, 384.0),
#  (0.2, 400, 0.0),
#  (0.2, 400, 38.4),
#  (0.2, 400, 76.8),
#  (0.2, 400, 115.2),
#  (0.2, 400, 153.6),
#  (0.2, 400, 192.0),
#  (0.2, 400, 230.4),
#  (0.2, 400, 268.8),
#  (0.2, 400, 307.2),
#  (0.2, 400, 345.6),
#  (0.2, 400, 384.0),
#  (0.2, 420, 0.0),
#  (0.2, 420, 38.4),
#  (0.2, 420, 76.8),
#  (0.2, 420, 115.2),
#  (0.2, 420, 153.6),
#  (0.2, 420, 192.0),
#  (0.2, 420, 230.4),
#  (0.2, 420, 268.8),
#  (0.2, 420, 307.2),
#  (0.2, 420, 345.6),
#  (0.2, 420, 384.0),
#  (0.2, 440, 0.0),
#  (0.2, 440, 38.4),
#  (0.2, 440, 76.8),
#  (0.2, 440, 115.2),
#  (0.2, 440, 153.6),
#  (0.2, 440, 192.0),
#  (0.2, 440, 230.4),
#  (0.2, 440, 268.8),
#  (0.2, 440, 307.2),
#  (0.2, 440, 345.6),
#  (0.2, 440, 384.0),
#  (0.2, 460, 0.0),
#  (0.2, 460, 38.4),
#  (0.2, 460, 76.8),
#  (0.2, 460, 115.2),
#  (0.2, 460, 153.6),
#  (0.2, 460, 192.0),
#  (0.2, 460, 230.4),
#  (0.2, 460, 268.8),
#  (0.2, 460, 307.2),
#  (0.2, 460, 345.6),
#  (0.2, 460, 384.0),
#  (0.2, 480, 0.0),
#  (0.2, 480, 38.4),
#  (0.2, 480, 76.8),
#  (0.2, 480, 115.2),
#  (0.2, 480, 153.6),
#  (0.2, 480, 192.0),
#  (0.2, 480, 230.4),
#  (0.2, 480, 268.8),
#  (0.2, 480, 307.2),
#  (0.2, 480, 345.6),
#  (0.2, 480, 384.0),
#  (0.2, 500, 0.0),
#  (0.2, 500, 38.4),
#  (0.2, 500, 76.8),
#  (0.2, 500, 115.2),
#  (0.2, 500, 153.6),
#  (0.2, 500, 192.0),
#  (0.2, 500, 230.4),
#  (0.2, 500, 268.8),
#  (0.2, 500, 307.2),
#  (0.2, 500, 345.6),
#  (0.2, 500, 384.0),
#  (0.2, 520, 0.0),
#  (0.2, 520, 38.4),
#  (0.2, 520, 76.8),
#  (0.2, 520, 115.2),
#  (0.2, 520, 153.6),
#  (0.2, 520, 192.0),
#  (0.2, 520, 230.4),
#  (0.2, 520, 268.8),
#  (0.2, 520, 307.2),
#  (0.2, 520, 345.6),
#  (0.2, 520, 384.0),
#  (0.2, 540, 0.0),
#  (0.2, 540, 38.4),
#  (0.2, 540, 76.8),
#  (0.2, 540, 115.2),
#  (0.2, 540, 153.6),
#  (0.2, 540, 192.0),
#  (0.2, 540, 230.4),
#  (0.2, 540, 268.8),
#  (0.2, 540, 307.2),
#  (0.2, 540, 345.6),
#  (0.2, 540, 384.0),
#  (0.2, 560, 0.0),
#  (0.2, 560, 38.4),
#  (0.2, 560, 76.8),
#  (0.2, 560, 115.2),
#  (0.2, 560, 153.6),
#  (0.2, 560, 192.0),
#  (0.2, 560, 230.4),
#  (0.2, 560, 268.8),
#  (0.2, 560, 307.2),
#  (0.2, 560, 345.6),
#  (0.2, 560, 384.0),
#  (0.2, 580, 0.0),
#  (0.2, 580, 38.4),
#  (0.2, 580, 76.8),
#  (0.2, 580, 115.2),
#  (0.2, 580, 153.6),
#  (0.2, 580, 192.0),
#  (0.2, 580, 230.4),
#  (0.2, 580, 268.8),
#  (0.2, 580, 307.2),
#  (0.2, 580, 345.6),
#  (0.2, 580, 384.0),
#  (0.2, 600, 0.0),
#  (0.2, 600, 38.4),
#  (0.2, 600, 76.8),
#  (0.2, 600, 115.2),
#  (0.2, 600, 153.6),
#  (0.2, 600, 192.0),
#  (0.2, 600, 230.4),
#  (0.2, 600, 268.8),
#  (0.2, 600, 307.2),
#  (0.2, 600, 345.6),
#  (0.2, 600, 384.0),
#  (0.2, 620, 0.0),
#  (0.2, 620, 38.4),
#  (0.2, 620, 76.8),
#  (0.2, 620, 115.2),
#  (0.2, 620, 153.6),
#  (0.2, 620, 192.0),
#  (0.2, 620, 230.4),
#  (0.2, 620, 268.8),
#  (0.2, 620, 307.2),
#  (0.2, 620, 345.6),
#  (0.2, 620, 384.0),
#  (0.2, 640, 0.0),
#  (0.2, 640, 38.4),
#  (0.2, 640, 76.8),
#  (0.2, 640, 115.2),
#  (0.2, 640, 153.6),
#  (0.2, 640, 192.0),
#  (0.2, 640, 230.4),
#  (0.2, 640, 268.8),
#  (0.2, 640, 307.2),
#  (0.2, 640, 345.6),
#  (0.2, 640, 384.0),
#  (0.2, 660, 0.0),
#  (0.2, 660, 38.4),
#  (0.2, 660, 76.8),
#  (0.2, 660, 115.2),
#  (0.2, 660, 153.6),
#  (0.2, 660, 192.0),
#  (0.2, 660, 230.4),
#  (0.2, 660, 268.8),
#  (0.2, 660, 307.2),
#  (0.2, 660, 345.6),
#  (0.2, 660, 384.0),
#  (0.2, 680, 0.0),
#  (0.2, 680, 38.4),
#  (0.2, 680, 76.8),
#  (0.2, 680, 115.2),
#  (0.2, 680, 153.6),
#  (0.2, 680, 192.0),
#  (0.2, 680, 230.4),
#  (0.2, 680, 268.8),
#  (0.2, 680, 307.2),
#  (0.2, 680, 345.6),
#  (0.2, 680, 384.0),
#  (0.2, 700, 0.0),
#  (0.2, 700, 38.4),
#  (0.2, 700, 76.8),
#  (0.2, 700, 115.2),
#  (0.2, 700, 153.6),
#  (0.2, 700, 192.0),
#  (0.2, 700, 230.4),
#  (0.2, 700, 268.8),
#  (0.2, 700, 307.2),
#  (0.2, 700, 345.6),
#  (0.2, 700, 384.0),
#  (0.4, 0, 0.0),
#  (0.4, 0, 38.4),
#  (0.4, 0, 76.8),
#  (0.4, 0, 115.2),
#  (0.4, 0, 153.6),
#  (0.4, 0, 192.0),
#  (0.4, 0, 230.4),
#  (0.4, 0, 268.8),
#  (0.4, 0, 307.2),
#  (0.4, 0, 345.6),
#  (0.4, 0, 384.0),
#  (0.4, 20, 0.0),
#  (0.4, 20, 38.4),
#  (0.4, 20, 76.8),
#  (0.4, 20, 115.2),
#  (0.4, 20, 153.6),
#  (0.4, 20, 192.0),
#  (0.4, 20, 230.4),
#  (0.4, 20, 268.8),
#  (0.4, 20, 307.2),
#  (0.4, 20, 345.6),
#  (0.4, 20, 384.0),
#  (0.4, 40, 0.0),
#  (0.4, 40, 38.4),
#  (0.4, 40, 76.8),
#  (0.4, 40, 115.2),
#  (0.4, 40, 153.6),
#  (0.4, 40, 192.0),
#  (0.4, 40, 230.4),
#  (0.4, 40, 268.8),
#  (0.4, 40, 307.2),
#  (0.4, 40, 345.6),
#  (0.4, 40, 384.0),
#  (0.4, 60, 0.0),
#  (0.4, 60, 38.4),
#  (0.4, 60, 76.8),
#  (0.4, 60, 115.2),
#  (0.4, 60, 153.6),
#  (0.4, 60, 192.0),
#  (0.4, 60, 230.4),
#  (0.4, 60, 268.8),
#  (0.4, 60, 307.2),
#  (0.4, 60, 345.6),
#  (0.4, 60, 384.0),
#  (0.4, 80, 0.0),
#  (0.4, 80, 38.4),
#  (0.4, 80, 76.8),
#  (0.4, 80, 115.2),
#  (0.4, 80, 153.6),
#  (0.4, 80, 192.0),
#  (0.4, 80, 230.4),
#  (0.4, 80, 268.8),
#  (0.4, 80, 307.2),
#  (0.4, 80, 345.6),
#  (0.4, 80, 384.0),
#  (0.4, 100, 0.0),
#  (0.4, 100, 38.4),
#  (0.4, 100, 76.8),
#  (0.4, 100, 115.2),
#  (0.4, 100, 153.6),
#  (0.4, 100, 192.0),
#  (0.4, 100, 230.4),
#  (0.4, 100, 268.8),
#  (0.4, 100, 307.2),
#  (0.4, 100, 345.6),
#  (0.4, 100, 384.0),
#  (0.4, 120, 0.0),
#  (0.4, 120, 38.4),
#  (0.4, 120, 76.8),
#  (0.4, 120, 115.2),
#  (0.4, 120, 153.6),
#  (0.4, 120, 192.0),
#  (0.4, 120, 230.4),
#  (0.4, 120, 268.8),
#  (0.4, 120, 307.2),
#  (0.4, 120, 345.6),
#  (0.4, 120, 384.0),
#  (0.4, 140, 0.0),
#  (0.4, 140, 38.4),
#  (0.4, 140, 76.8),
#  (0.4, 140, 115.2),
#  (0.4, 140, 153.6),
#  (0.4, 140, 192.0),
#  (0.4, 140, 230.4),
#  (0.4, 140, 268.8),
#  (0.4, 140, 307.2),
#  (0.4, 140, 345.6),
#  (0.4, 140, 384.0),
#  (0.4, 160, 0.0),
#  (0.4, 160, 38.4),
#  (0.4, 160, 76.8),
#  (0.4, 160, 115.2),
#  (0.4, 160, 153.6),
#  (0.4, 160, 192.0),
#  (0.4, 160, 230.4),
#  (0.4, 160, 268.8),
#  (0.4, 160, 307.2),
#  (0.4, 160, 345.6),
#  (0.4, 160, 384.0),
#  (0.4, 180, 0.0),
#  (0.4, 180, 38.4),
#  (0.4, 180, 76.8),
#  (0.4, 180, 115.2),
#  (0.4, 180, 153.6),
#  (0.4, 180, 192.0),
#  (0.4, 180, 230.4),
#  (0.4, 180, 268.8),
#  (0.4, 180, 307.2),
#  (0.4, 180, 345.6),
#  (0.4, 180, 384.0),
#  (0.4, 200, 0.0),
#  (0.4, 200, 38.4),
#  (0.4, 200, 76.8),
#  (0.4, 200, 115.2),
#  (0.4, 200, 153.6),
#  (0.4, 200, 192.0),
#  (0.4, 200, 230.4),
#  (0.4, 200, 268.8),
#  (0.4, 200, 307.2),
#  (0.4, 200, 345.6),
#  (0.4, 200, 384.0),
#  (0.4, 220, 0.0),
#  (0.4, 220, 38.4),
#  (0.4, 220, 76.8),
#  (0.4, 220, 115.2),
#  (0.4, 220, 153.6),
#  (0.4, 220, 192.0),
#  (0.4, 220, 230.4),
#  (0.4, 220, 268.8),
#  (0.4, 220, 307.2),
#  (0.4, 220, 345.6),
#  (0.4, 220, 384.0),
#  (0.4, 240, 0.0),
#  (0.4, 240, 38.4),
#  (0.4, 240, 76.8),
#  (0.4, 240, 115.2),
#  (0.4, 240, 153.6),
#  (0.4, 240, 192.0),
#  (0.4, 240, 230.4),
#  (0.4, 240, 268.8),
#  (0.4, 240, 307.2),
#  (0.4, 240, 345.6),
#  (0.4, 240, 384.0),
#  (0.4, 260, 0.0),
#  (0.4, 260, 38.4),
#  (0.4, 260, 76.8),
#  (0.4, 260, 115.2),
#  (0.4, 260, 153.6),
#  (0.4, 260, 192.0),
#  (0.4, 260, 230.4),
#  (0.4, 260, 268.8),
#  (0.4, 260, 307.2),
#  (0.4, 260, 345.6),
#  (0.4, 260, 384.0),
#  (0.4, 280, 0.0),
#  (0.4, 280, 38.4),
#  (0.4, 280, 76.8),
#  (0.4, 280, 115.2),
#  (0.4, 280, 153.6),
#  (0.4, 280, 192.0),
#  (0.4, 280, 230.4),
#  (0.4, 280, 268.8),
#  (0.4, 280, 307.2),
#  (0.4, 280, 345.6),
#  (0.4, 280, 384.0),
#  (0.4, 300, 0.0),
#  (0.4, 300, 38.4),
#  (0.4, 300, 76.8),
#  (0.4, 300, 115.2),
#  (0.4, 300, 153.6),
#  (0.4, 300, 192.0),
#  (0.4, 300, 230.4),
#  (0.4, 300, 268.8),
#  (0.4, 300, 307.2),
#  (0.4, 300, 345.6),
#  (0.4, 300, 384.0),
#  (0.4, 320, 0.0),
#  (0.4, 320, 38.4),
#  (0.4, 320, 76.8),
#  (0.4, 320, 115.2),
#  (0.4, 320, 153.6),
#  (0.4, 320, 192.0),
#  (0.4, 320, 230.4),
#  (0.4, 320, 268.8),
#  (0.4, 320, 307.2),
#  (0.4, 320, 345.6),
#  (0.4, 320, 384.0),
#  (0.4, 340, 0.0),
#  (0.4, 340, 38.4),
#  (0.4, 340, 76.8),
#  (0.4, 340, 115.2),
#  (0.4, 340, 153.6),
#  (0.4, 340, 192.0),
#  (0.4, 340, 230.4),
#  (0.4, 340, 268.8),
#  (0.4, 340, 307.2),
#  (0.4, 340, 345.6),
#  (0.4, 340, 384.0),
#  (0.4, 360, 0.0),
#  (0.4, 360, 38.4),
#  (0.4, 360, 76.8),
#  (0.4, 360, 115.2),
#  (0.4, 360, 153.6),
#  (0.4, 360, 192.0),
#  (0.4, 360, 230.4),
#  (0.4, 360, 268.8),
#  (0.4, 360, 307.2),
#  (0.4, 360, 345.6),
#  (0.4, 360, 384.0),
#  (0.4, 380, 0.0),
#  (0.4, 380, 38.4),
#  (0.4, 380, 76.8),
#  (0.4, 380, 115.2),
#  (0.4, 380, 153.6),
#  (0.4, 380, 192.0),
#  (0.4, 380, 230.4),
#  (0.4, 380, 268.8),
#  (0.4, 380, 307.2),
#  (0.4, 380, 345.6),
#  (0.4, 380, 384.0),
#  (0.4, 400, 0.0),
#  (0.4, 400, 38.4),
#  (0.4, 400, 76.8),
#  (0.4, 400, 115.2),
#  (0.4, 400, 153.6),
#  (0.4, 400, 192.0),
#  (0.4, 400, 230.4),
#  (0.4, 400, 268.8),
#  (0.4, 400, 307.2),
#  (0.4, 400, 345.6),
#  (0.4, 400, 384.0),
#  (0.4, 420, 0.0),
#  (0.4, 420, 38.4),
#  (0.4, 420, 76.8),
#  (0.4, 420, 115.2),
#  (0.4, 420, 153.6),
#  (0.4, 420, 192.0),
#  (0.4, 420, 230.4),
#  (0.4, 420, 268.8),
#  (0.4, 420, 307.2),
#  (0.4, 420, 345.6),
#  (0.4, 420, 384.0),
#  (0.4, 440, 0.0),
#  (0.4, 440, 38.4),
#  (0.4, 440, 76.8),
#  (0.4, 440, 115.2),
#  (0.4, 440, 153.6),
#  (0.4, 440, 192.0),
#  (0.4, 440, 230.4),
#  (0.4, 440, 268.8),
#  (0.4, 440, 307.2),
#  (0.4, 440, 345.6),
#  (0.4, 440, 384.0),
#  (0.4, 460, 0.0),
#  (0.4, 460, 38.4),
#  (0.4, 460, 76.8),
#  (0.4, 460, 115.2),
#  (0.4, 460, 153.6),
#  (0.4, 460, 192.0),
#  (0.4, 460, 230.4),
#  (0.4, 460, 268.8),
#  (0.4, 460, 307.2),
#  (0.4, 460, 345.6),
#  (0.4, 460, 384.0),
#  (0.4, 480, 0.0),
#  (0.4, 480, 38.4),
#  (0.4, 480, 76.8),
#  (0.4, 480, 115.2),
#  (0.4, 480, 153.6),
#  (0.4, 480, 192.0),
#  (0.4, 480, 230.4),
#  (0.4, 480, 268.8),
#  (0.4, 480, 307.2),
#  (0.4, 480, 345.6),
#  (0.4, 480, 384.0),
#  (0.4, 500, 0.0),
#  (0.4, 500, 38.4),
#  (0.4, 500, 76.8),
#  (0.4, 500, 115.2),
#  (0.4, 500, 153.6),
#  (0.4, 500, 192.0),
#  (0.4, 500, 230.4),
#  (0.4, 500, 268.8),
#  (0.4, 500, 307.2),
#  (0.4, 500, 345.6),
#  (0.4, 500, 384.0),
#  (0.4, 520, 0.0),
#  (0.4, 520, 38.4),
#  (0.4, 520, 76.8),
#  (0.4, 520, 115.2),
#  (0.4, 520, 153.6),
#  (0.4, 520, 192.0),
#  (0.4, 520, 230.4),
#  (0.4, 520, 268.8),
#  (0.4, 520, 307.2),
#  (0.4, 520, 345.6),
#  (0.4, 520, 384.0),
#  (0.4, 540, 0.0),
#  (0.4, 540, 38.4),
#  (0.4, 540, 76.8),
#  (0.4, 540, 115.2),
#  (0.4, 540, 153.6),
#  (0.4, 540, 192.0),
#  (0.4, 540, 230.4),
#  (0.6, 340, 384.0),
#  (0.6, 360, 0.0),
#  (0.6, 360, 38.4),
#  (0.6, 360, 76.8),
#  (0.6, 360, 115.2),
#  (0.6, 360, 153.6),
#  (0.6, 360, 192.0),
#  (0.6, 360, 230.4),
#  (0.6, 360, 268.8),
#  (0.6, 360, 307.2),
#  (0.6, 360, 345.6),
#  ...]

# %% [markdown]
# # Policy iteration

# %%
def initialise_deterministic_policy(num_states = Number_of_discrete_states, num_actions = Number_of_possible_actions):
    '''Maps state with time to action ID
    returns a policy (dictionary) of this format:
    key (tuple) = (conc of x, conc of N, time). This describes the state and time at which the state is reached
    value (int) = a value from 0 to 14. basically refers to the specific action according to the action_ID_to_increase_in_N dict defined above
    
    For example, '0.2,260, 38.4': 4 means x = 0.2, N = 260 reached at time = 38.4 and take the 5th action which corresponds to increasing N by 2.0 units (according to the action_ID_to_increase_in_N dictionary)
    '''
    policy = {} # start off with empty map
    for x in range(1, Number_of_possible_x): #remove x = 0.0
        for N in range(Number_of_possible_N):
            for t in np.linspace(0,16*24/10*11,12): #add extra time step
                action_probs = np.random.rand((num_actions)) #randomly initialize
                action_probs /= sum(action_probs) #normalize probabilities
                policy[round(x*0.2,1),N*20, round(t,1)] = np.argmax(action_probs) # only line different to above - the function returns the action, rather than the dist over
    
    for state in policy.keys(): # this loop makes sure that when x conc is low, the action is NOT zero
        if (state[0] == 0.2) or (state[0] == 0.4) or (state[0] == 0.6): #check if x is low 
            policy[state] = random.randint(2,14) #reassign action to at least 3 and above to prevent x from falling further
            
    return policy

print('Number of entries in policy =', len(initialise_deterministic_policy(num_states = Number_of_discrete_states, num_actions = Number_of_possible_actions)))
policy = initialise_deterministic_policy(num_states = Number_of_discrete_states, num_actions = Number_of_possible_actions)
policy
# Out:
# Number of entries in policy = 4320
# {(0.2, 0, 0.0): 12,
#  (0.2, 0, 38.4): 2,
#  (0.2, 0, 76.8): 3,
#  (0.2, 0, 115.2): 9,
#  (0.2, 0, 153.6): 6,
#  (0.2, 0, 192.0): 4,
#  (0.2, 0, 230.4): 8,
#  (0.2, 0, 268.8): 14,
#  (0.2, 0, 307.2): 4,
#  (0.2, 0, 345.6): 8,
#  (0.2, 0, 384.0): 13,
#  (0.2, 0, 422.4): 12,
#  (0.2, 20, 0.0): 8,
#  (0.2, 20, 38.4): 6,
#  (0.2, 20, 76.8): 6,
#  (0.2, 20, 115.2): 10,
#  (0.2, 20, 153.6): 4,
#  (0.2, 20, 192.0): 3,
#  (0.2, 20, 230.4): 11,
#  (0.2, 20, 268.8): 4,
#  (0.2, 20, 307.2): 4,
#  (0.2, 20, 345.6): 9,
#  (0.2, 20, 384.0): 7,
#  (0.2, 20, 422.4): 14,
#  (0.2, 40, 0.0): 5,
#  (0.2, 40, 38.4): 13,
#  (0.2, 40, 76.8): 6,
#  (0.2, 40, 115.2): 12,
#  (0.2, 40, 153.6): 5,
#  (0.2, 40, 192.0): 4,
#  (0.2, 40, 230.4): 14,
#  (0.2, 40, 268.8): 8,
#  (0.2, 40, 307.2): 11,
#  (0.2, 40, 345.6): 9,
#  (0.2, 40, 384.0): 14,
#  (0.2, 40, 422.4): 3,
#  (0.2, 60, 0.0): 7,
#  (0.2, 60, 38.4): 3,
#  (0.2, 60, 76.8): 9,
#  (0.2, 60, 115.2): 12,
#  (0.2, 60, 153.6): 7,
#  (0.2, 60, 192.0): 4,
#  (0.2, 60, 230.4): 2,
#  (0.2, 60, 268.8): 4,
#  (0.2, 60, 307.2): 13,
#  (0.2, 60, 345.6): 10,
#  (0.2, 60, 384.0): 9,
#  (0.2, 60, 422.4): 3,
#  (0.2, 80, 0.0): 12,
#  (0.2, 80, 38.4): 9,
#  (0.2, 80, 76.8): 9,
#  (0.2, 80, 115.2): 12,
#  (0.2, 80, 153.6): 14,
#  (0.2, 80, 192.0): 7,
#  (0.2, 80, 230.4): 6,
#  (0.2, 80, 268.8): 14,
#  (0.2, 80, 307.2): 4,
#  (0.2, 80, 345.6): 11,
#  (0.2, 80, 384.0): 6,
#  (0.2, 80, 422.4): 11,
#  (0.2, 100, 0.0): 11,
#  (0.2, 100, 38.4): 14,
#  (0.2, 100, 76.8): 7,
#  (0.2, 100, 115.2): 2,
#  (0.2, 100, 153.6): 11,
#  (0.2, 100, 192.0): 14,
#  (0.2, 100, 230.4): 5,
#  (0.2, 100, 268.8): 12,
#  (0.2, 100, 307.2): 6,
#  (0.2, 100, 345.6): 13,
#  (0.2, 100, 384.0): 8,
#  (0.2, 100, 422.4): 8,
#  (0.2, 120, 0.0): 2,
#  (0.2, 120, 38.4): 6,
#  (0.2, 120, 76.8): 13,
#  (0.2, 120, 115.2): 7,
#  (0.2, 120, 153.6): 4,
#  (0.2, 120, 192.0): 2,
#  (0.2, 120, 230.4): 9,
#  (0.2, 120, 268.8): 4,
#  (0.2, 120, 307.2): 6,
#  (0.2, 120, 345.6): 2,
#  (0.2, 120, 384.0): 10,
#  (0.2, 120, 422.4): 6,
#  (0.2, 140, 0.0): 11,
#  (0.2, 140, 38.4): 11,
#  (0.2, 140, 76.8): 6,
#  (0.2, 140, 115.2): 4,
#  (0.2, 140, 153.6): 12,
#  (0.2, 140, 192.0): 5,
#  (0.2, 140, 230.4): 2,
#  (0.2, 140, 268.8): 6,
#  (0.2, 140, 307.2): 5,
#  (0.2, 140, 345.6): 12,
#  (0.2, 140, 384.0): 5,
#  (0.2, 140, 422.4): 7,
#  (0.2, 160, 0.0): 9,
#  (0.2, 160, 38.4): 4,
#  (0.2, 160, 76.8): 12,
#  (0.2, 160, 115.2): 3,
#  (0.2, 160, 153.6): 3,
#  (0.2, 160, 192.0): 11,
#  (0.2, 160, 230.4): 2,
#  (0.2, 160, 268.8): 11,
#  (0.2, 160, 307.2): 12,
#  (0.2, 160, 345.6): 10,
#  (0.2, 160, 384.0): 6,
#  (0.2, 160, 422.4): 6,
#  (0.2, 180, 0.0): 4,
#  (0.2, 180, 38.4): 7,
#  (0.2, 180, 76.8): 5,
#  (0.2, 180, 115.2): 5,
#  (0.2, 180, 153.6): 12,
#  (0.2, 180, 192.0): 8,
#  (0.2, 180, 230.4): 14,
#  (0.2, 180, 268.8): 8,
#  (0.2, 180, 307.2): 8,
#  (0.2, 180, 345.6): 12,
#  (0.2, 180, 384.0): 2,
#  (0.2, 180, 422.4): 2,
#  (0.2, 200, 0.0): 6,
#  (0.2, 200, 38.4): 12,
#  (0.2, 200, 76.8): 12,
#  (0.2, 200, 115.2): 11,
#  (0.2, 200, 153.6): 4,
#  (0.2, 200, 192.0): 4,
#  (0.2, 200, 230.4): 12,
#  (0.2, 200, 268.8): 13,
#  (0.2, 200, 307.2): 6,
#  (0.2, 200, 345.6): 5,
#  (0.2, 200, 384.0): 13,
#  (0.2, 200, 422.4): 12,
#  (0.2, 220, 0.0): 12,
#  (0.2, 220, 38.4): 3,
#  (0.2, 220, 76.8): 13,
#  (0.2, 220, 115.2): 7,
#  (0.2, 220, 153.6): 13,
#  (0.2, 220, 192.0): 5,
#  (0.2, 220, 230.4): 10,
#  (0.2, 220, 268.8): 2,
#  (0.2, 220, 307.2): 2,
#  (0.2, 220, 345.6): 4,
#  (0.2, 220, 384.0): 7,
#  (0.2, 220, 422.4): 5,
#  (0.2, 240, 0.0): 10,
#  (0.2, 240, 38.4): 14,
#  (0.2, 240, 76.8): 8,
#  (0.2, 240, 115.2): 6,
#  (0.2, 240, 153.6): 11,
#  (0.2, 240, 192.0): 3,
#  (0.2, 240, 230.4): 5,
#  (0.2, 240, 268.8): 6,
#  (0.2, 240, 307.2): 8,
#  (0.2, 240, 345.6): 13,
#  (0.2, 240, 384.0): 8,
#  (0.2, 240, 422.4): 8,
#  (0.2, 260, 0.0): 7,
#  (0.2, 260, 38.4): 2,
#  (0.2, 260, 76.8): 13,
#  (0.2, 260, 115.2): 3,
#  (0.2, 260, 153.6): 12,
#  (0.2, 260, 192.0): 9,
#  (0.2, 260, 230.4): 3,
#  (0.2, 260, 268.8): 13,
#  (0.2, 260, 307.2): 2,
#  (0.2, 260, 345.6): 14,
#  (0.2, 260, 384.0): 11,
#  (0.2, 260, 422.4): 9,
#  (0.2, 280, 0.0): 6,
#  (0.2, 280, 38.4): 9,
#  (0.2, 280, 76.8): 4,
#  (0.2, 280, 115.2): 4,
#  (0.2, 280, 153.6): 3,
#  (0.2, 280, 192.0): 10,
#  (0.2, 280, 230.4): 3,
#  (0.2, 280, 268.8): 7,
#  (0.2, 280, 307.2): 9,
#  (0.2, 280, 345.6): 8,
#  (0.2, 280, 384.0): 5,
#  (0.2, 280, 422.4): 4,
#  (0.2, 300, 0.0): 9,
#  (0.2, 300, 38.4): 3,
#  (0.2, 300, 76.8): 7,
#  (0.2, 300, 115.2): 14,
#  (0.2, 300, 153.6): 12,
#  (0.2, 300, 192.0): 11,
#  (0.2, 300, 230.4): 5,
#  (0.2, 300, 268.8): 7,
#  (0.2, 300, 307.2): 12,
#  (0.2, 300, 345.6): 13,
#  (0.2, 300, 384.0): 7,
#  (0.2, 300, 422.4): 14,
#  (0.2, 320, 0.0): 11,
#  (0.2, 320, 38.4): 2,
#  (0.2, 320, 76.8): 8,
#  (0.2, 320, 115.2): 7,
#  (0.2, 320, 153.6): 14,
#  (0.2, 320, 192.0): 6,
#  (0.2, 320, 230.4): 5,
#  (0.2, 320, 268.8): 13,
#  (0.2, 320, 307.2): 6,
#  (0.2, 320, 345.6): 10,
#  (0.2, 320, 384.0): 7,
#  (0.2, 320, 422.4): 4,
#  (0.2, 340, 0.0): 2,
#  (0.2, 340, 38.4): 10,
#  (0.2, 340, 76.8): 6,
#  (0.2, 340, 115.2): 7,
#  (0.2, 340, 153.6): 11,
#  (0.2, 340, 192.0): 12,
#  (0.2, 340, 230.4): 14,
#  (0.2, 340, 268.8): 6,
#  (0.2, 340, 307.2): 9,
#  (0.2, 340, 345.6): 10,
#  (0.2, 340, 384.0): 3,
#  (0.2, 340, 422.4): 12,
#  (0.2, 360, 0.0): 4,
#  (0.2, 360, 38.4): 8,
#  (0.2, 360, 76.8): 3,
#  (0.2, 360, 115.2): 5,
#  (0.2, 360, 153.6): 4,
#  (0.2, 360, 192.0): 5,
#  (0.2, 360, 230.4): 11,
#  (0.2, 360, 268.8): 2,
#  (0.2, 360, 307.2): 5,
#  (0.2, 360, 345.6): 9,
#  (0.2, 360, 384.0): 14,
#  (0.2, 360, 422.4): 5,
#  (0.2, 380, 0.0): 11,
#  (0.2, 380, 38.4): 8,
#  (0.2, 380, 76.8): 13,
#  (0.2, 380, 115.2): 6,
#  (0.2, 380, 153.6): 10,
#  (0.2, 380, 192.0): 8,
#  (0.2, 380, 230.4): 8,
#  (0.2, 380, 268.8): 3,
#  (0.2, 380, 307.2): 12,
#  (0.2, 380, 345.6): 3,
#  (0.2, 380, 384.0): 5,
#  (0.2, 380, 422.4): 4,
#  (0.2, 400, 0.0): 2,
#  (0.2, 400, 38.4): 10,
#  (0.2, 400, 76.8): 13,
#  (0.2, 400, 115.2): 9,
#  (0.2, 400, 153.6): 10,
#  (0.2, 400, 192.0): 4,
#  (0.2, 400, 230.4): 6,
#  (0.2, 400, 268.8): 12,
#  (0.2, 400, 307.2): 2,
#  (0.2, 400, 345.6): 14,
#  (0.2, 400, 384.0): 9,
#  (0.2, 400, 422.4): 11,
#  (0.2, 420, 0.0): 13,
#  (0.2, 420, 38.4): 8,
#  (0.2, 420, 76.8): 8,
#  (0.2, 420, 115.2): 6,
#  (0.2, 420, 153.6): 5,
#  (0.2, 420, 192.0): 2,
#  (0.2, 420, 230.4): 12,
#  (0.2, 420, 268.8): 7,
#  (0.2, 420, 307.2): 6,
#  (0.2, 420, 345.6): 14,
#  (0.2, 420, 384.0): 4,
#  (0.2, 420, 422.4): 12,
#  (0.2, 440, 0.0): 6,
#  (0.2, 440, 38.4): 2,
#  (0.2, 440, 76.8): 2,
#  (0.2, 440, 115.2): 2,
#  (0.2, 440, 153.6): 12,
#  (0.2, 440, 192.0): 9,
#  (0.2, 440, 230.4): 8,
#  (0.2, 440, 268.8): 5,
#  (0.2, 440, 307.2): 14,
#  (0.2, 440, 345.6): 5,
#  (0.2, 440, 384.0): 3,
#  (0.2, 440, 422.4): 10,
#  (0.2, 460, 0.0): 6,
#  (0.2, 460, 38.4): 12,
#  (0.2, 460, 76.8): 2,
#  (0.2, 460, 115.2): 10,
#  (0.2, 460, 153.6): 2,
#  (0.2, 460, 192.0): 5,
#  (0.2, 460, 230.4): 10,
#  (0.2, 460, 268.8): 12,
#  (0.2, 460, 307.2): 10,
#  (0.2, 460, 345.6): 7,
#  (0.2, 460, 384.0): 2,
#  (0.2, 460, 422.4): 5,
#  (0.2, 480, 0.0): 11,
#  (0.2, 480, 38.4): 13,
#  (0.2, 480, 76.8): 5,
#  (0.2, 480, 115.2): 3,
#  (0.2, 480, 153.6): 5,
#  (0.2, 480, 192.0): 8,
#  (0.2, 480, 230.4): 4,
#  (0.2, 480, 268.8): 6,
#  (0.2, 480, 307.2): 8,
#  (0.2, 480, 345.6): 11,
#  (0.2, 480, 384.0): 5,
#  (0.2, 480, 422.4): 5,
#  (0.2, 500, 0.0): 13,
#  (0.2, 500, 38.4): 13,
#  (0.2, 500, 76.8): 14,
#  (0.2, 500, 115.2): 9,
#  (0.2, 500, 153.6): 14,
#  (0.2, 500, 192.0): 8,
#  (0.2, 500, 230.4): 8,
#  (0.2, 500, 268.8): 5,
#  (0.2, 500, 307.2): 6,
#  (0.2, 500, 345.6): 5,
#  (0.2, 500, 384.0): 13,
#  (0.2, 500, 422.4): 13,
#  (0.2, 520, 0.0): 11,
#  (0.2, 520, 38.4): 9,
#  (0.2, 520, 76.8): 13,
#  (0.2, 520, 115.2): 10,
#  (0.2, 520, 153.6): 9,
#  (0.2, 520, 192.0): 8,
#  (0.2, 520, 230.4): 14,
#  (0.2, 520, 268.8): 8,
#  (0.2, 520, 307.2): 6,
#  (0.2, 520, 345.6): 3,
#  (0.2, 520, 384.0): 12,
#  (0.2, 520, 422.4): 7,
#  (0.2, 540, 0.0): 11,
#  (0.2, 540, 38.4): 3,
#  (0.2, 540, 76.8): 6,
#  (0.2, 540, 115.2): 3,
#  (0.2, 540, 153.6): 9,
#  (0.2, 540, 192.0): 9,
#  (0.2, 540, 230.4): 10,
#  (0.2, 540, 268.8): 4,
#  (0.2, 540, 307.2): 2,
#  (0.2, 540, 345.6): 7,
#  (0.2, 540, 384.0): 2,
#  (0.2, 540, 422.4): 6,
#  (0.2, 560, 0.0): 10,
#  (0.2, 560, 38.4): 11,
#  (0.2, 560, 76.8): 4,
#  (0.2, 560, 115.2): 13,
#  (0.2, 560, 153.6): 5,
#  (0.2, 560, 192.0): 3,
#  (0.2, 560, 230.4): 14,
#  (0.2, 560, 268.8): 11,
#  (0.2, 560, 307.2): 9,
#  (0.2, 560, 345.6): 14,
#  (0.2, 560, 384.0): 10,
#  (0.2, 560, 422.4): 12,
#  (0.2, 580, 0.0): 6,
#  (0.2, 580, 38.4): 3,
#  (0.2, 580, 76.8): 3,
#  (0.2, 580, 115.2): 2,
#  (0.2, 580, 153.6): 11,
#  (0.2, 580, 192.0): 7,
#  (0.2, 580, 230.4): 11,
#  (0.2, 580, 268.8): 6,
#  (0.2, 580, 307.2): 10,
#  (0.2, 580, 345.6): 11,
#  (0.2, 580, 384.0): 8,
#  (0.2, 580, 422.4): 5,
#  (0.2, 600, 0.0): 9,
#  (0.2, 600, 38.4): 11,
#  (0.2, 600, 76.8): 7,
#  (0.2, 600, 115.2): 9,
#  (0.2, 600, 153.6): 3,
#  (0.2, 600, 192.0): 14,
#  (0.2, 600, 230.4): 9,
#  (0.2, 600, 268.8): 8,
#  (0.2, 600, 307.2): 7,
#  (0.2, 600, 345.6): 2,
#  (0.2, 600, 384.0): 14,
#  (0.2, 600, 422.4): 4,
#  (0.2, 620, 0.0): 12,
#  (0.2, 620, 38.4): 12,
#  (0.2, 620, 76.8): 6,
#  (0.2, 620, 115.2): 13,
#  (0.2, 620, 153.6): 2,
#  (0.2, 620, 192.0): 10,
#  (0.2, 620, 230.4): 3,
#  (0.2, 620, 268.8): 9,
#  (0.2, 620, 307.2): 11,
#  (0.2, 620, 345.6): 13,
#  (0.2, 620, 384.0): 12,
#  (0.2, 620, 422.4): 4,
#  (0.2, 640, 0.0): 3,
#  (0.2, 640, 38.4): 12,
#  (0.2, 640, 76.8): 8,
#  (0.2, 640, 115.2): 12,
#  (0.2, 640, 153.6): 5,
#  (0.2, 640, 192.0): 7,
#  (0.2, 640, 230.4): 13,
#  (0.2, 640, 268.8): 12,
#  (0.2, 640, 307.2): 9,
#  (0.2, 640, 345.6): 10,
#  (0.2, 640, 384.0): 5,
#  (0.2, 640, 422.4): 8,
#  (0.2, 660, 0.0): 3,
#  (0.2, 660, 38.4): 6,
#  (0.2, 660, 76.8): 4,
#  (0.2, 660, 115.2): 12,
#  (0.2, 660, 153.6): 3,
#  (0.2, 660, 192.0): 13,
#  (0.2, 660, 230.4): 8,
#  (0.2, 660, 268.8): 8,
#  (0.2, 660, 307.2): 13,
#  (0.2, 660, 345.6): 9,
#  (0.2, 660, 384.0): 12,
#  (0.2, 660, 422.4): 10,
#  (0.2, 680, 0.0): 10,
#  (0.2, 680, 38.4): 10,
#  (0.2, 680, 76.8): 4,
#  (0.2, 680, 115.2): 6,
#  (0.2, 680, 153.6): 10,
#  (0.2, 680, 192.0): 4,
#  (0.2, 680, 230.4): 10,
#  (0.2, 680, 268.8): 13,
#  (0.2, 680, 307.2): 12,
#  (0.2, 680, 345.6): 9,
#  (0.2, 680, 384.0): 7,
#  (0.2, 680, 422.4): 8,
#  (0.2, 700, 0.0): 2,
#  (0.2, 700, 38.4): 11,
#  (0.2, 700, 76.8): 12,
#  (0.2, 700, 115.2): 9,
#  (0.2, 700, 153.6): 5,
#  (0.2, 700, 192.0): 6,
#  (0.2, 700, 230.4): 8,
#  (0.2, 700, 268.8): 7,
#  (0.2, 700, 307.2): 13,
#  (0.2, 700, 345.6): 2,
#  (0.2, 700, 384.0): 5,
#  (0.2, 700, 422.4): 2,
#  (0.4, 0, 0.0): 13,
#  (0.4, 0, 38.4): 7,
#  (0.4, 0, 76.8): 7,
#  (0.4, 0, 115.2): 7,
#  (0.4, 0, 153.6): 3,
#  (0.4, 0, 192.0): 8,
#  (0.4, 0, 230.4): 11,
#  (0.4, 0, 268.8): 13,
#  (0.4, 0, 307.2): 5,
#  (0.4, 0, 345.6): 2,
#  (0.4, 0, 384.0): 7,
#  (0.4, 0, 422.4): 10,
#  (0.4, 20, 0.0): 7,
#  (0.4, 20, 38.4): 10,
#  (0.4, 20, 76.8): 8,
#  (0.4, 20, 115.2): 7,
#  (0.4, 20, 153.6): 8,
#  (0.4, 20, 192.0): 6,
#  (0.4, 20, 230.4): 4,
#  (0.4, 20, 268.8): 6,
#  (0.4, 20, 307.2): 6,
#  (0.4, 20, 345.6): 5,
#  (0.4, 20, 384.0): 6,
#  (0.4, 20, 422.4): 8,
#  (0.4, 40, 0.0): 6,
#  (0.4, 40, 38.4): 7,
#  (0.4, 40, 76.8): 5,
#  (0.4, 40, 115.2): 7,
#  (0.4, 40, 153.6): 10,
#  (0.4, 40, 192.0): 8,
#  (0.4, 40, 230.4): 10,
#  (0.4, 40, 268.8): 12,
#  (0.4, 40, 307.2): 2,
#  (0.4, 40, 345.6): 8,
#  (0.4, 40, 384.0): 5,
#  (0.4, 40, 422.4): 7,
#  (0.4, 60, 0.0): 12,
#  (0.4, 60, 38.4): 3,
#  (0.4, 60, 76.8): 5,
#  (0.4, 60, 115.2): 3,
#  (0.4, 60, 153.6): 12,
#  (0.4, 60, 192.0): 5,
#  (0.4, 60, 230.4): 5,
#  (0.4, 60, 268.8): 8,
#  (0.4, 60, 307.2): 7,
#  (0.4, 60, 345.6): 12,
#  (0.4, 60, 384.0): 10,
#  (0.4, 60, 422.4): 5,
#  (0.4, 80, 0.0): 3,
#  (0.4, 80, 38.4): 13,
#  (0.4, 80, 76.8): 11,
#  (0.4, 80, 115.2): 2,
#  (0.4, 80, 153.6): 10,
#  (0.4, 80, 192.0): 11,
#  (0.4, 80, 230.4): 13,
#  (0.4, 80, 268.8): 4,
#  (0.4, 80, 307.2): 10,
#  (0.4, 80, 345.6): 13,
#  (0.4, 80, 384.0): 9,
#  (0.4, 80, 422.4): 12,
#  (0.4, 100, 0.0): 12,
#  (0.4, 100, 38.4): 4,
#  (0.4, 100, 76.8): 14,
#  (0.4, 100, 115.2): 14,
#  (0.4, 100, 153.6): 3,
#  (0.4, 100, 192.0): 2,
#  (0.4, 100, 230.4): 13,
#  (0.4, 100, 268.8): 13,
#  (0.4, 100, 307.2): 2,
#  (0.4, 100, 345.6): 8,
#  (0.4, 100, 384.0): 4,
#  (0.4, 100, 422.4): 10,
#  (0.4, 120, 0.0): 12,
#  (0.4, 120, 38.4): 3,
#  (0.4, 120, 76.8): 14,
#  (0.4, 120, 115.2): 5,
#  (0.4, 120, 153.6): 10,
#  (0.4, 120, 192.0): 12,
#  (0.4, 120, 230.4): 6,
#  (0.4, 120, 268.8): 10,
#  (0.4, 120, 307.2): 11,
#  (0.4, 120, 345.6): 12,
#  (0.4, 120, 384.0): 2,
#  (0.4, 120, 422.4): 4,
#  (0.4, 140, 0.0): 8,
#  (0.4, 140, 38.4): 6,
#  (0.4, 140, 76.8): 9,
#  (0.4, 140, 115.2): 8,
#  (0.4, 140, 153.6): 8,
#  (0.4, 140, 192.0): 4,
#  (0.4, 140, 230.4): 10,
#  (0.4, 140, 268.8): 8,
#  (0.4, 140, 307.2): 7,
#  (0.4, 140, 345.6): 8,
#  (0.4, 140, 384.0): 5,
#  (0.4, 140, 422.4): 5,
#  (0.4, 160, 0.0): 4,
#  (0.4, 160, 38.4): 4,
#  (0.4, 160, 76.8): 14,
#  (0.4, 160, 115.2): 4,
#  (0.4, 160, 153.6): 9,
#  (0.4, 160, 192.0): 13,
#  (0.4, 160, 230.4): 13,
#  (0.4, 160, 268.8): 6,
#  (0.4, 160, 307.2): 10,
#  (0.4, 160, 345.6): 6,
#  (0.4, 160, 384.0): 3,
#  (0.4, 160, 422.4): 12,
#  (0.4, 180, 0.0): 4,
#  (0.4, 180, 38.4): 3,
#  (0.4, 180, 76.8): 4,
#  (0.4, 180, 115.2): 6,
#  (0.4, 180, 153.6): 13,
#  (0.4, 180, 192.0): 11,
#  (0.4, 180, 230.4): 11,
#  (0.4, 180, 268.8): 2,
#  (0.4, 180, 307.2): 11,
#  (0.4, 180, 345.6): 6,
#  (0.4, 180, 384.0): 10,
#  (0.4, 180, 422.4): 12,
#  (0.4, 200, 0.0): 5,
#  (0.4, 200, 38.4): 10,
#  (0.4, 200, 76.8): 14,
#  (0.4, 200, 115.2): 11,
#  (0.4, 200, 153.6): 11,
#  (0.4, 200, 192.0): 8,
#  (0.4, 200, 230.4): 5,
#  (0.4, 200, 268.8): 12,
#  (0.4, 200, 307.2): 3,
#  (0.4, 200, 345.6): 2,
#  (0.4, 200, 384.0): 2,
#  (0.4, 200, 422.4): 10,
#  (0.4, 220, 0.0): 7,
#  (0.4, 220, 38.4): 14,
#  (0.4, 220, 76.8): 12,
#  (0.4, 220, 115.2): 8,
#  (0.4, 220, 153.6): 4,
#  (0.4, 220, 192.0): 13,
#  (0.4, 220, 230.4): 13,
#  (0.4, 220, 268.8): 5,
#  (0.4, 220, 307.2): 7,
#  (0.4, 220, 345.6): 2,
#  (0.4, 220, 384.0): 5,
#  (0.4, 220, 422.4): 2,
#  (0.4, 240, 0.0): 6,
#  (0.4, 240, 38.4): 3,
#  (0.4, 240, 76.8): 4,
#  (0.4, 240, 115.2): 11,
#  (0.4, 240, 153.6): 9,
#  (0.4, 240, 192.0): 10,
#  (0.4, 240, 230.4): 12,
#  (0.4, 240, 268.8): 2,
#  (0.4, 240, 307.2): 10,
#  (0.4, 240, 345.6): 11,
#  (0.4, 240, 384.0): 7,
#  (0.4, 240, 422.4): 14,
#  (0.4, 260, 0.0): 10,
#  (0.4, 260, 38.4): 9,
#  (0.4, 260, 76.8): 5,
#  (0.4, 260, 115.2): 6,
#  (0.4, 260, 153.6): 11,
#  (0.4, 260, 192.0): 5,
#  (0.4, 260, 230.4): 13,
#  (0.4, 260, 268.8): 4,
#  (0.4, 260, 307.2): 7,
#  (0.4, 260, 345.6): 9,
#  (0.4, 260, 384.0): 8,
#  (0.4, 260, 422.4): 2,
#  (0.4, 280, 0.0): 12,
#  (0.4, 280, 38.4): 14,
#  (0.4, 280, 76.8): 5,
#  (0.4, 280, 115.2): 5,
#  (0.4, 280, 153.6): 6,
#  (0.4, 280, 192.0): 14,
#  (0.4, 280, 230.4): 10,
#  (0.4, 280, 268.8): 6,
#  (0.4, 280, 307.2): 5,
#  (0.4, 280, 345.6): 14,
#  (0.4, 280, 384.0): 8,
#  (0.4, 280, 422.4): 14,
#  (0.4, 300, 0.0): 2,
#  (0.4, 300, 38.4): 6,
#  (0.4, 300, 76.8): 13,
#  (0.4, 300, 115.2): 11,
#  (0.4, 300, 153.6): 5,
#  (0.4, 300, 192.0): 12,
#  (0.4, 300, 230.4): 6,
#  (0.4, 300, 268.8): 7,
#  (0.4, 300, 307.2): 7,
#  (0.4, 300, 345.6): 6,
#  (0.4, 300, 384.0): 2,
#  (0.4, 300, 422.4): 8,
#  (0.4, 320, 0.0): 8,
#  (0.4, 320, 38.4): 4,
#  (0.4, 320, 76.8): 5,
#  (0.4, 320, 115.2): 11,
#  (0.4, 320, 153.6): 13,
#  (0.4, 320, 192.0): 12,
#  (0.4, 320, 230.4): 7,
#  (0.4, 320, 268.8): 3,
#  (0.4, 320, 307.2): 14,
#  (0.4, 320, 345.6): 12,
#  (0.4, 320, 384.0): 6,
#  (0.4, 320, 422.4): 12,
#  (0.4, 340, 0.0): 7,
#  (0.4, 340, 38.4): 2,
#  (0.4, 340, 76.8): 4,
#  (0.4, 340, 115.2): 11,
#  (0.4, 340, 153.6): 6,
#  (0.4, 340, 192.0): 6,
#  (0.4, 340, 230.4): 8,
#  (0.4, 340, 268.8): 14,
#  (0.4, 340, 307.2): 3,
#  (0.4, 340, 345.6): 5,
#  (0.4, 340, 384.0): 6,
#  (0.4, 340, 422.4): 6,
#  (0.4, 360, 0.0): 3,
#  (0.4, 360, 38.4): 12,
#  (0.4, 360, 76.8): 13,
#  (0.4, 360, 115.2): 3,
#  (0.4, 360, 153.6): 11,
#  (0.4, 360, 192.0): 5,
#  (0.4, 360, 230.4): 10,
#  (0.4, 360, 268.8): 7,
#  (0.4, 360, 307.2): 14,
#  (0.4, 360, 345.6): 5,
#  (0.4, 360, 384.0): 9,
#  (0.4, 360, 422.4): 14,
#  (0.4, 380, 0.0): 7,
#  (0.4, 380, 38.4): 2,
#  (0.4, 380, 76.8): 2,
#  (0.4, 380, 115.2): 9,
#  (0.4, 380, 153.6): 2,
#  (0.4, 380, 192.0): 14,
#  (0.4, 380, 230.4): 14,
#  (0.4, 380, 268.8): 3,
#  (0.4, 380, 307.2): 5,
#  (0.4, 380, 345.6): 14,
#  (0.4, 380, 384.0): 12,
#  (0.4, 380, 422.4): 13,
#  (0.4, 400, 0.0): 11,
#  (0.4, 400, 38.4): 2,
#  (0.4, 400, 76.8): 6,
#  (0.4, 400, 115.2): 13,
#  (0.4, 400, 153.6): 11,
#  (0.4, 400, 192.0): 9,
#  (0.4, 400, 230.4): 13,
#  (0.4, 400, 268.8): 2,
#  (0.4, 400, 307.2): 13,
#  (0.4, 400, 345.6): 10,
#  (0.4, 400, 384.0): 10,
#  (0.4, 400, 422.4): 5,
#  (0.4, 420, 0.0): 7,
#  (0.4, 420, 38.4): 13,
#  (0.4, 420, 76.8): 5,
#  (0.4, 420, 115.2): 9,
#  (0.4, 420, 153.6): 8,
#  (0.4, 420, 192.0): 5,
#  (0.4, 420, 230.4): 9,
#  (0.4, 420, 268.8): 8,
#  (0.4, 420, 307.2): 12,
#  (0.4, 420, 345.6): 5,
#  (0.4, 420, 384.0): 6,
#  (0.4, 420, 422.4): 13,
#  (0.4, 440, 0.0): 8,
#  (0.4, 440, 38.4): 5,
#  (0.4, 440, 76.8): 5,
#  (0.4, 440, 115.2): 5,
#  (0.4, 440, 153.6): 12,
#  (0.4, 440, 192.0): 6,
#  (0.4, 440, 230.4): 13,
#  (0.4, 440, 268.8): 10,
#  (0.4, 440, 307.2): 12,
#  (0.4, 440, 345.6): 3,
#  (0.4, 440, 384.0): 12,
#  (0.4, 440, 422.4): 8,
#  (0.4, 460, 0.0): 14,
#  (0.4, 460, 38.4): 7,
#  (0.4, 460, 76.8): 11,
#  (0.4, 460, 115.2): 5,
#  (0.4, 460, 153.6): 7,
#  (0.4, 460, 192.0): 2,
#  (0.4, 460, 230.4): 5,
#  (0.4, 460, 268.8): 12,
#  (0.4, 460, 307.2): 14,
#  (0.4, 460, 345.6): 8,
#  (0.4, 460, 384.0): 14,
#  (0.4, 460, 422.4): 10,
#  (0.4, 480, 0.0): 9,
#  (0.4, 480, 38.4): 12,
#  (0.4, 480, 76.8): 8,
#  (0.4, 480, 115.2): 2,
#  (0.4, 480, 153.6): 5,
#  (0.4, 480, 192.0): 9,
#  (0.4, 480, 230.4): 7,
#  (0.4, 480, 268.8): 5,
#  (0.4, 480, 307.2): 13,
#  (0.4, 480, 345.6): 12,
#  (0.4, 480, 384.0): 14,
#  (0.4, 480, 422.4): 8,
#  (0.4, 500, 0.0): 3,
#  (0.4, 500, 38.4): 3,
#  (0.4, 500, 76.8): 5,
#  (0.4, 500, 115.2): 8,
#  (0.4, 500, 153.6): 14,
#  (0.4, 500, 192.0): 7,
#  (0.4, 500, 230.4): 12,
#  (0.4, 500, 268.8): 11,
#  (0.4, 500, 307.2): 4,
#  (0.4, 500, 345.6): 11,
#  (0.4, 500, 384.0): 10,
#  (0.4, 500, 422.4): 5,
#  (0.4, 520, 0.0): 11,
#  (0.4, 520, 38.4): 7,
#  (0.4, 520, 76.8): 14,
#  (0.4, 520, 115.2): 12,
#  (0.4, 520, 153.6): 14,
#  (0.4, 520, 192.0): 6,
#  (0.4, 520, 230.4): 3,
#  (0.4, 520, 268.8): 3,
#  (0.4, 520, 307.2): 7,
#  (0.4, 520, 345.6): 4,
#  (0.4, 520, 384.0): 9,
#  (0.4, 520, 422.4): 8,
#  (0.4, 540, 0.0): 6,
#  (0.4, 540, 38.4): 14,
#  (0.4, 540, 76.8): 14,
#  (0.4, 540, 115.2): 8,
#  (0.4, 540, 153.6): 5,
#  (0.4, 540, 192.0): 5,
#  (0.4, 540, 230.4): 5,
#  (0.4, 540, 268.8): 10,
#  (0.4, 540, 307.2): 11,
#  (0.4, 540, 345.6): 4,
#  (0.4, 540, 384.0): 7,
#  (0.4, 540, 422.4): 6,
#  (0.4, 560, 0.0): 12,
#  (0.4, 560, 38.4): 6,
#  (0.4, 560, 76.8): 2,
#  (0.4, 560, 115.2): 13,
#  (0.4, 560, 153.6): 11,
#  (0.4, 560, 192.0): 3,
#  (0.4, 560, 230.4): 7,
#  (0.4, 560, 268.8): 7,
#  (0.4, 560, 307.2): 3,
#  (0.4, 560, 345.6): 3,
#  (0.4, 560, 384.0): 12,
#  (0.4, 560, 422.4): 14,
#  (0.4, 580, 0.0): 5,
#  (0.4, 580, 38.4): 6,
#  (0.4, 580, 76.8): 12,
#  (0.4, 580, 115.2): 6,
#  (0.4, 580, 153.6): 2,
#  (0.4, 580, 192.0): 5,
#  (0.4, 580, 230.4): 7,
#  (0.4, 580, 268.8): 13,
#  (0.4, 580, 307.2): 9,
#  (0.4, 580, 345.6): 3,
#  (0.4, 580, 384.0): 10,
#  (0.4, 580, 422.4): 7,
#  (0.4, 600, 0.0): 10,
#  (0.4, 600, 38.4): 13,
#  (0.4, 600, 76.8): 10,
#  (0.4, 600, 115.2): 13,
#  (0.4, 600, 153.6): 14,
#  (0.4, 600, 192.0): 11,
#  (0.4, 600, 230.4): 7,
#  (0.4, 600, 268.8): 4,
#  (0.4, 600, 307.2): 2,
#  (0.4, 600, 345.6): 13,
#  (0.4, 600, 384.0): 6,
#  (0.4, 600, 422.4): 11,
#  (0.4, 620, 0.0): 3,
#  (0.4, 620, 38.4): 5,
#  (0.4, 620, 76.8): 3,
#  (0.4, 620, 115.2): 12,
#  (0.4, 620, 153.6): 11,
#  (0.4, 620, 192.0): 4,
#  (0.4, 620, 230.4): 3,
#  (0.4, 620, 268.8): 3,
#  (0.4, 620, 307.2): 5,
#  (0.4, 620, 345.6): 14,
#  (0.4, 620, 384.0): 11,
#  (0.4, 620, 422.4): 3,
#  (0.4, 640, 0.0): 2,
#  (0.4, 640, 38.4): 9,
#  (0.4, 640, 76.8): 4,
#  (0.4, 640, 115.2): 2,
#  (0.4, 640, 153.6): 10,
#  (0.4, 640, 192.0): 11,
#  (0.4, 640, 230.4): 6,
#  (0.4, 640, 268.8): 7,
#  (0.4, 640, 307.2): 2,
#  (0.4, 640, 345.6): 2,
#  (0.4, 640, 384.0): 5,
#  (0.4, 640, 422.4): 9,
#  (0.4, 660, 0.0): 13,
#  (0.4, 660, 38.4): 3,
#  (0.4, 660, 76.8): 10,
#  (0.4, 660, 115.2): 3,
#  (0.4, 660, 153.6): 7,
#  (0.4, 660, 192.0): 14,
#  (0.4, 660, 230.4): 8,
#  (0.4, 660, 268.8): 13,
#  (0.4, 660, 307.2): 8,
#  (0.4, 660, 345.6): 10,
#  (0.4, 660, 384.0): 2,
#  (0.4, 660, 422.4): 14,
#  (0.4, 680, 0.0): 13,
#  (0.4, 680, 38.4): 7,
#  (0.4, 680, 76.8): 13,
#  (0.4, 680, 115.2): 12,
#  (0.4, 680, 153.6): 11,
#  (0.4, 680, 192.0): 14,
#  (0.4, 680, 230.4): 10,
#  (0.4, 680, 268.8): 3,
#  (0.4, 680, 307.2): 12,
#  (0.4, 680, 345.6): 4,
#  (0.4, 680, 384.0): 9,
#  (0.4, 680, 422.4): 9,
#  (0.4, 700, 0.0): 3,
#  (0.4, 700, 38.4): 10,
#  (0.4, 700, 76.8): 13,
#  (0.4, 700, 115.2): 2,
#  (0.4, 700, 153.6): 14,
#  (0.4, 700, 192.0): 3,
#  (0.4, 700, 230.4): 10,
#  (0.4, 700, 268.8): 14,
#  (0.4, 700, 307.2): 5,
#  (0.4, 700, 345.6): 10,
#  (0.4, 700, 384.0): 2,
#  (0.4, 700, 422.4): 9,
#  (0.6, 0, 0.0): 2,
#  (0.6, 0, 38.4): 10,
#  (0.6, 0, 76.8): 8,
#  (0.6, 0, 115.2): 3,
#  (0.6, 0, 153.6): 6,
#  (0.6, 0, 192.0): 9,
#  (0.6, 0, 230.4): 14,
#  (0.6, 0, 268.8): 12,
#  (0.6, 0, 307.2): 4,
#  (0.6, 0, 345.6): 12,
#  (0.6, 0, 384.0): 6,
#  (0.6, 0, 422.4): 4,
#  (0.6, 20, 0.0): 12,
#  (0.6, 20, 38.4): 13,
#  (0.6, 20, 76.8): 10,
#  (0.6, 20, 115.2): 10,
#  (0.6, 20, 153.6): 8,
#  (0.6, 20, 192.0): 6,
#  (0.6, 20, 230.4): 3,
#  (0.6, 20, 268.8): 5,
#  (0.6, 20, 307.2): 5,
#  (0.6, 20, 345.6): 2,
#  (0.6, 20, 384.0): 5,
#  (0.6, 20, 422.4): 12,
#  (0.6, 40, 0.0): 6,
#  (0.6, 40, 38.4): 12,
#  (0.6, 40, 76.8): 14,
#  (0.6, 40, 115.2): 14,
#  (0.6, 40, 153.6): 7,
#  (0.6, 40, 192.0): 6,
#  (0.6, 40, 230.4): 6,
#  (0.6, 40, 268.8): 14,
#  (0.6, 40, 307.2): 7,
#  (0.6, 40, 345.6): 8,
#  (0.6, 40, 384.0): 7,
#  (0.6, 40, 422.4): 12,
#  (0.6, 60, 0.0): 13,
#  (0.6, 60, 38.4): 2,
#  (0.6, 60, 76.8): 6,
#  (0.6, 60, 115.2): 12,
#  (0.6, 60, 153.6): 13,
#  (0.6, 60, 192.0): 8,
#  (0.6, 60, 230.4): 14,
#  (0.6, 60, 268.8): 10,
#  (0.6, 60, 307.2): 9,
#  (0.6, 60, 345.6): 4,
#  (0.6, 60, 384.0): 8,
#  (0.6, 60, 422.4): 13,
#  (0.6, 80, 0.0): 11,
#  (0.6, 80, 38.4): 4,
#  (0.6, 80, 76.8): 8,
#  (0.6, 80, 115.2): 12,
#  (0.6, 80, 153.6): 8,
#  (0.6, 80, 192.0): 9,
#  (0.6, 80, 230.4): 12,
#  (0.6, 80, 268.8): 2,
#  (0.6, 80, 307.2): 2,
#  (0.6, 80, 345.6): 11,
#  (0.6, 80, 384.0): 14,
#  (0.6, 80, 422.4): 9,
#  (0.6, 100, 0.0): 3,
#  (0.6, 100, 38.4): 12,
#  (0.6, 100, 76.8): 5,
#  (0.6, 100, 115.2): 3,
#  (0.6, 100, 153.6): 6,
#  (0.6, 100, 192.0): 8,
#  (0.6, 100, 230.4): 9,
#  (0.6, 100, 268.8): 6,
#  (0.6, 100, 307.2): 12,
#  (0.6, 100, 345.6): 13,
#  (0.6, 100, 384.0): 12,
#  (0.6, 100, 422.4): 2,
#  (0.6, 120, 0.0): 14,
#  (0.6, 120, 38.4): 6,
#  (0.6, 120, 76.8): 10,
#  (0.6, 120, 115.2): 7,
#  (0.6, 120, 153.6): 3,
#  (0.6, 120, 192.0): 2,
#  (0.6, 120, 230.4): 8,
#  (0.6, 120, 268.8): 12,
#  (0.6, 120, 307.2): 4,
#  (0.6, 120, 345.6): 4,
#  (0.6, 120, 384.0): 4,
#  (0.6, 120, 422.4): 8,
#  (0.6, 140, 0.0): 7,
#  (0.6, 140, 38.4): 10,
#  (0.6, 140, 76.8): 14,
#  (0.6, 140, 115.2): 9,
#  (0.6, 140, 153.6): 6,
#  (0.6, 140, 192.0): 4,
#  (0.6, 140, 230.4): 5,
#  (0.6, 140, 268.8): 13,
#  (0.6, 140, 307.2): 4,
#  (0.6, 140, 345.6): 5,
#  (0.6, 140, 384.0): 4,
#  (0.6, 140, 422.4): 6,
#  (0.6, 160, 0.0): 2,
#  (0.6, 160, 38.4): 13,
#  (0.6, 160, 76.8): 11,
#  (0.6, 160, 115.2): 4,
#  (0.6, 160, 153.6): 13,
#  (0.6, 160, 192.0): 12,
#  (0.6, 160, 230.4): 8,
#  (0.6, 160, 268.8): 11,
#  (0.6, 160, 307.2): 6,
#  (0.6, 160, 345.6): 7,
#  (0.6, 160, 384.0): 2,
#  (0.6, 160, 422.4): 7,
#  (0.6, 180, 0.0): 10,
#  (0.6, 180, 38.4): 2,
#  (0.6, 180, 76.8): 4,
#  (0.6, 180, 115.2): 11,
#  (0.6, 180, 153.6): 5,
#  (0.6, 180, 192.0): 4,
#  (0.6, 180, 230.4): 12,
#  (0.6, 180, 268.8): 14,
#  (0.6, 180, 307.2): 8,
#  (0.6, 180, 345.6): 4,
#  (0.6, 180, 384.0): 7,
#  (0.6, 180, 422.4): 12,
#  (0.6, 200, 0.0): 10,
#  (0.6, 200, 38.4): 12,
#  (0.6, 200, 76.8): 6,
#  (0.6, 200, 115.2): 13,
#  (0.6, 200, 153.6): 6,
#  (0.6, 200, 192.0): 14,
#  (0.6, 200, 230.4): 11,
#  (0.6, 200, 268.8): 8,
#  (0.6, 200, 307.2): 7,
#  (0.6, 200, 345.6): 5,
#  (0.6, 200, 384.0): 10,
#  (0.6, 200, 422.4): 8,
#  (0.6, 220, 0.0): 4,
#  (0.6, 220, 38.4): 6,
#  (0.6, 220, 76.8): 7,
#  (0.6, 220, 115.2): 4,
#  ...}

# %%
keys_to_be_iterated
# Out:
# [(0.2, 0, 0.0),
#  (0.2, 0, 38.4),
#  (0.2, 0, 76.8),
#  (0.2, 0, 115.2),
#  (0.2, 0, 153.6),
#  (0.2, 0, 192.0),
#  (0.2, 0, 230.4),
#  (0.2, 0, 268.8),
#  (0.2, 0, 307.2),
#  (0.2, 0, 345.6),
#  (0.2, 0, 384.0),
#  (0.2, 20, 0.0),
#  (0.2, 20, 38.4),
#  (0.2, 20, 76.8),
#  (0.2, 20, 115.2),
#  (0.2, 20, 153.6),
#  (0.2, 20, 192.0),
#  (0.2, 20, 230.4),
#  (0.2, 20, 268.8),
#  (0.2, 20, 307.2),
#  (0.2, 20, 345.6),
#  (0.2, 20, 384.0),
#  (0.2, 40, 0.0),
#  (0.2, 40, 38.4),
#  (0.2, 40, 76.8),
#  (0.2, 40, 115.2),
#  (0.2, 40, 153.6),
#  (0.2, 40, 192.0),
#  (0.2, 40, 230.4),
#  (0.2, 40, 268.8),
#  (0.2, 40, 307.2),
#  (0.2, 40, 345.6),
#  (0.2, 40, 384.0),
#  (0.2, 60, 0.0),
#  (0.2, 60, 38.4),
#  (0.2, 60, 76.8),
#  (0.2, 60, 115.2),
#  (0.2, 60, 153.6),
#  (0.2, 60, 192.0),
#  (0.2, 60, 230.4),
#  (0.2, 60, 268.8),
#  (0.2, 60, 307.2),
#  (0.2, 60, 345.6),
#  (0.2, 60, 384.0),
#  (0.2, 80, 0.0),
#  (0.2, 80, 38.4),
#  (0.2, 80, 76.8),
#  (0.2, 80, 115.2),
#  (0.2, 80, 153.6),
#  (0.2, 80, 192.0),
#  (0.2, 80, 230.4),
#  (0.2, 80, 268.8),
#  (0.2, 80, 307.2),
#  (0.2, 80, 345.6),
#  (0.2, 80, 384.0),
#  (0.2, 100, 0.0),
#  (0.2, 100, 38.4),
#  (0.2, 100, 76.8),
#  (0.2, 100, 115.2),
#  (0.2, 100, 153.6),
#  (0.2, 100, 192.0),
#  (0.2, 100, 230.4),
#  (0.2, 100, 268.8),
#  (0.2, 100, 307.2),
#  (0.2, 100, 345.6),
#  (0.2, 100, 384.0),
#  (0.2, 120, 0.0),
#  (0.2, 120, 38.4),
#  (0.2, 120, 76.8),
#  (0.2, 120, 115.2),
#  (0.2, 120, 153.6),
#  (0.2, 120, 192.0),
#  (0.2, 120, 230.4),
#  (0.2, 120, 268.8),
#  (0.2, 120, 307.2),
#  (0.2, 120, 345.6),
#  (0.2, 120, 384.0),
#  (0.2, 140, 0.0),
#  (0.2, 140, 38.4),
#  (0.2, 140, 76.8),
#  (0.2, 140, 115.2),
#  (0.2, 140, 153.6),
#  (0.2, 140, 192.0),
#  (0.2, 140, 230.4),
#  (0.2, 140, 268.8),
#  (0.2, 140, 307.2),
#  (0.2, 140, 345.6),
#  (0.2, 140, 384.0),
#  (0.2, 160, 0.0),
#  (0.2, 160, 38.4),
#  (0.2, 160, 76.8),
#  (0.2, 160, 115.2),
#  (0.2, 160, 153.6),
#  (0.2, 160, 192.0),
#  (0.2, 160, 230.4),
#  (0.2, 160, 268.8),
#  (0.2, 160, 307.2),
#  (0.2, 160, 345.6),
#  (0.2, 160, 384.0),
#  (0.2, 180, 0.0),
#  (0.2, 180, 38.4),
#  (0.2, 180, 76.8),
#  (0.2, 180, 115.2),
#  (0.2, 180, 153.6),
#  (0.2, 180, 192.0),
#  (0.2, 180, 230.4),
#  (0.2, 180, 268.8),
#  (0.2, 180, 307.2),
#  (0.2, 180, 345.6),
#  (0.2, 180, 384.0),
#  (0.2, 200, 0.0),
#  (0.2, 200, 38.4),
#  (0.2, 200, 76.8),
#  (0.2, 200, 115.2),
#  (0.2, 200, 153.6),
#  (0.2, 200, 192.0),
#  (0.2, 200, 230.4),
#  (0.2, 200, 268.8),
#  (0.2, 200, 307.2),
#  (0.2, 200, 345.6),
#  (0.2, 200, 384.0),
#  (0.2, 220, 0.0),
#  (0.2, 220, 38.4),
#  (0.2, 220, 76.8),
#  (0.2, 220, 115.2),
#  (0.2, 220, 153.6),
#  (0.2, 220, 192.0),
#  (0.2, 220, 230.4),
#  (0.2, 220, 268.8),
#  (0.2, 220, 307.2),
#  (0.2, 220, 345.6),
#  (0.2, 220, 384.0),
#  (0.2, 240, 0.0),
#  (0.2, 240, 38.4),
#  (0.2, 240, 76.8),
#  (0.2, 240, 115.2),
#  (0.2, 240, 153.6),
#  (0.2, 240, 192.0),
#  (0.2, 240, 230.4),
#  (0.2, 240, 268.8),
#  (0.2, 240, 307.2),
#  (0.2, 240, 345.6),
#  (0.2, 240, 384.0),
#  (0.2, 260, 0.0),
#  (0.2, 260, 38.4),
#  (0.2, 260, 76.8),
#  (0.2, 260, 115.2),
#  (0.2, 260, 153.6),
#  (0.2, 260, 192.0),
#  (0.2, 260, 230.4),
#  (0.2, 260, 268.8),
#  (0.2, 260, 307.2),
#  (0.2, 260, 345.6),
#  (0.2, 260, 384.0),
#  (0.2, 280, 0.0),
#  (0.2, 280, 38.4),
#  (0.2, 280, 76.8),
#  (0.2, 280, 115.2),
#  (0.2, 280, 153.6),
#  (0.2, 280, 192.0),
#  (0.2, 280, 230.4),
#  (0.2, 280, 268.8),
#  (0.2, 280, 307.2),
#  (0.2, 280, 345.6),
#  (0.2, 280, 384.0),
#  (0.2, 300, 0.0),
#  (0.2, 300, 38.4),
#  (0.2, 300, 76.8),
#  (0.2, 300, 115.2),
#  (0.2, 300, 153.6),
#  (0.2, 300, 192.0),
#  (0.2, 300, 230.4),
#  (0.2, 300, 268.8),
#  (0.2, 300, 307.2),
#  (0.2, 300, 345.6),
#  (0.2, 300, 384.0),
#  (0.2, 320, 0.0),
#  (0.2, 320, 38.4),
#  (0.2, 320, 76.8),
#  (0.2, 320, 115.2),
#  (0.2, 320, 153.6),
#  (0.2, 320, 192.0),
#  (0.2, 320, 230.4),
#  (0.2, 320, 268.8),
#  (0.2, 320, 307.2),
#  (0.2, 320, 345.6),
#  (0.2, 320, 384.0),
#  (0.2, 340, 0.0),
#  (0.2, 340, 38.4),
#  (0.2, 340, 76.8),
#  (0.2, 340, 115.2),
#  (0.2, 340, 153.6),
#  (0.2, 340, 192.0),
#  (0.2, 340, 230.4),
#  (0.2, 340, 268.8),
#  (0.2, 340, 307.2),
#  (0.2, 340, 345.6),
#  (0.2, 340, 384.0),
#  (0.2, 360, 0.0),
#  (0.2, 360, 38.4),
#  (0.2, 360, 76.8),
#  (0.2, 360, 115.2),
#  (0.2, 360, 153.6),
#  (0.2, 360, 192.0),
#  (0.2, 360, 230.4),
#  (0.2, 360, 268.8),
#  (0.2, 360, 307.2),
#  (0.2, 360, 345.6),
#  (0.2, 360, 384.0),
#  (0.2, 380, 0.0),
#  (0.2, 380, 38.4),
#  (0.2, 380, 76.8),
#  (0.2, 380, 115.2),
#  (0.2, 380, 153.6),
#  (0.2, 380, 192.0),
#  (0.2, 380, 230.4),
#  (0.2, 380, 268.8),
#  (0.2, 380, 307.2),
#  (0.2, 380, 345.6),
#  (0.2, 380, 384.0),
#  (0.2, 400, 0.0),
#  (0.2, 400, 38.4),
#  (0.2, 400, 76.8),
#  (0.2, 400, 115.2),
#  (0.2, 400, 153.6),
#  (0.2, 400, 192.0),
#  (0.2, 400, 230.4),
#  (0.2, 400, 268.8),
#  (0.2, 400, 307.2),
#  (0.2, 400, 345.6),
#  (0.2, 400, 384.0),
#  (0.2, 420, 0.0),
#  (0.2, 420, 38.4),
#  (0.2, 420, 76.8),
#  (0.2, 420, 115.2),
#  (0.2, 420, 153.6),
#  (0.2, 420, 192.0),
#  (0.2, 420, 230.4),
#  (0.2, 420, 268.8),
#  (0.2, 420, 307.2),
#  (0.2, 420, 345.6),
#  (0.2, 420, 384.0),
#  (0.2, 440, 0.0),
#  (0.2, 440, 38.4),
#  (0.2, 440, 76.8),
#  (0.2, 440, 115.2),
#  (0.2, 440, 153.6),
#  (0.2, 440, 192.0),
#  (0.2, 440, 230.4),
#  (0.2, 440, 268.8),
#  (0.2, 440, 307.2),
#  (0.2, 440, 345.6),
#  (0.2, 440, 384.0),
#  (0.2, 460, 0.0),
#  (0.2, 460, 38.4),
#  (0.2, 460, 76.8),
#  (0.2, 460, 115.2),
#  (0.2, 460, 153.6),
#  (0.2, 460, 192.0),
#  (0.2, 460, 230.4),
#  (0.2, 460, 268.8),
#  (0.2, 460, 307.2),
#  (0.2, 460, 345.6),
#  (0.2, 460, 384.0),
#  (0.2, 480, 0.0),
#  (0.2, 480, 38.4),
#  (0.2, 480, 76.8),
#  (0.2, 480, 115.2),
#  (0.2, 480, 153.6),
#  (0.2, 480, 192.0),
#  (0.2, 480, 230.4),
#  (0.2, 480, 268.8),
#  (0.2, 480, 307.2),
#  (0.2, 480, 345.6),
#  (0.2, 480, 384.0),
#  (0.2, 500, 0.0),
#  (0.2, 500, 38.4),
#  (0.2, 500, 76.8),
#  (0.2, 500, 115.2),
#  (0.2, 500, 153.6),
#  (0.2, 500, 192.0),
#  (0.2, 500, 230.4),
#  (0.2, 500, 268.8),
#  (0.2, 500, 307.2),
#  (0.2, 500, 345.6),
#  (0.2, 500, 384.0),
#  (0.2, 520, 0.0),
#  (0.2, 520, 38.4),
#  (0.2, 520, 76.8),
#  (0.2, 520, 115.2),
#  (0.2, 520, 153.6),
#  (0.2, 520, 192.0),
#  (0.2, 520, 230.4),
#  (0.2, 520, 268.8),
#  (0.2, 520, 307.2),
#  (0.2, 520, 345.6),
#  (0.2, 520, 384.0),
#  (0.2, 540, 0.0),
#  (0.2, 540, 38.4),
#  (0.2, 540, 76.8),
#  (0.2, 540, 115.2),
#  (0.2, 540, 153.6),
#  (0.2, 540, 192.0),
#  (0.2, 540, 230.4),
#  (0.2, 540, 268.8),
#  (0.2, 540, 307.2),
#  (0.2, 540, 345.6),
#  (0.2, 540, 384.0),
#  (0.2, 560, 0.0),
#  (0.2, 560, 38.4),
#  (0.2, 560, 76.8),
#  (0.2, 560, 115.2),
#  (0.2, 560, 153.6),
#  (0.2, 560, 192.0),
#  (0.2, 560, 230.4),
#  (0.2, 560, 268.8),
#  (0.2, 560, 307.2),
#  (0.2, 560, 345.6),
#  (0.2, 560, 384.0),
#  (0.2, 580, 0.0),
#  (0.2, 580, 38.4),
#  (0.2, 580, 76.8),
#  (0.2, 580, 115.2),
#  (0.2, 580, 153.6),
#  (0.2, 580, 192.0),
#  (0.2, 580, 230.4),
#  (0.2, 580, 268.8),
#  (0.2, 580, 307.2),
#  (0.2, 580, 345.6),
#  (0.2, 580, 384.0),
#  (0.2, 600, 0.0),
#  (0.2, 600, 38.4),
#  (0.2, 600, 76.8),
#  (0.2, 600, 115.2),
#  (0.2, 600, 153.6),
#  (0.2, 600, 192.0),
#  (0.2, 600, 230.4),
#  (0.2, 600, 268.8),
#  (0.2, 600, 307.2),
#  (0.2, 600, 345.6),
#  (0.2, 600, 384.0),
#  (0.2, 620, 0.0),
#  (0.2, 620, 38.4),
#  (0.2, 620, 76.8),
#  (0.2, 620, 115.2),
#  (0.2, 620, 153.6),
#  (0.2, 620, 192.0),
#  (0.2, 620, 230.4),
#  (0.2, 620, 268.8),
#  (0.2, 620, 307.2),
#  (0.2, 620, 345.6),
#  (0.2, 620, 384.0),
#  (0.2, 640, 0.0),
#  (0.2, 640, 38.4),
#  (0.2, 640, 76.8),
#  (0.2, 640, 115.2),
#  (0.2, 640, 153.6),
#  (0.2, 640, 192.0),
#  (0.2, 640, 230.4),
#  (0.2, 640, 268.8),
#  (0.2, 640, 307.2),
#  (0.2, 640, 345.6),
#  (0.2, 640, 384.0),
#  (0.2, 660, 0.0),
#  (0.2, 660, 38.4),
#  (0.2, 660, 76.8),
#  (0.2, 660, 115.2),
#  (0.2, 660, 153.6),
#  (0.2, 660, 192.0),
#  (0.2, 660, 230.4),
#  (0.2, 660, 268.8),
#  (0.2, 660, 307.2),
#  (0.2, 660, 345.6),
#  (0.2, 660, 384.0),
#  (0.2, 680, 0.0),
#  (0.2, 680, 38.4),
#  (0.2, 680, 76.8),
#  (0.2, 680, 115.2),
#  (0.2, 680, 153.6),
#  (0.2, 680, 192.0),
#  (0.2, 680, 230.4),
#  (0.2, 680, 268.8),
#  (0.2, 680, 307.2),
#  (0.2, 680, 345.6),
#  (0.2, 680, 384.0),
#  (0.2, 700, 0.0),
#  (0.2, 700, 38.4),
#  (0.2, 700, 76.8),
#  (0.2, 700, 115.2),
#  (0.2, 700, 153.6),
#  (0.2, 700, 192.0),
#  (0.2, 700, 230.4),
#  (0.2, 700, 268.8),
#  (0.2, 700, 307.2),
#  (0.2, 700, 345.6),
#  (0.2, 700, 384.0),
#  (0.4, 0, 0.0),
#  (0.4, 0, 38.4),
#  (0.4, 0, 76.8),
#  (0.4, 0, 115.2),
#  (0.4, 0, 153.6),
#  (0.4, 0, 192.0),
#  (0.4, 0, 230.4),
#  (0.4, 0, 268.8),
#  (0.4, 0, 307.2),
#  (0.4, 0, 345.6),
#  (0.4, 0, 384.0),
#  (0.4, 20, 0.0),
#  (0.4, 20, 38.4),
#  (0.4, 20, 76.8),
#  (0.4, 20, 115.2),
#  (0.4, 20, 153.6),
#  (0.4, 20, 192.0),
#  (0.4, 20, 230.4),
#  (0.4, 20, 268.8),
#  (0.4, 20, 307.2),
#  (0.4, 20, 345.6),
#  (0.4, 20, 384.0),
#  (0.4, 40, 0.0),
#  (0.4, 40, 38.4),
#  (0.4, 40, 76.8),
#  (0.4, 40, 115.2),
#  (0.4, 40, 153.6),
#  (0.4, 40, 192.0),
#  (0.4, 40, 230.4),
#  (0.4, 40, 268.8),
#  (0.4, 40, 307.2),
#  (0.4, 40, 345.6),
#  (0.4, 40, 384.0),
#  (0.4, 60, 0.0),
#  (0.4, 60, 38.4),
#  (0.4, 60, 76.8),
#  (0.4, 60, 115.2),
#  (0.4, 60, 153.6),
#  (0.4, 60, 192.0),
#  (0.4, 60, 230.4),
#  (0.4, 60, 268.8),
#  (0.4, 60, 307.2),
#  (0.4, 60, 345.6),
#  (0.4, 60, 384.0),
#  (0.4, 80, 0.0),
#  (0.4, 80, 38.4),
#  (0.4, 80, 76.8),
#  (0.4, 80, 115.2),
#  (0.4, 80, 153.6),
#  (0.4, 80, 192.0),
#  (0.4, 80, 230.4),
#  (0.4, 80, 268.8),
#  (0.4, 80, 307.2),
#  (0.4, 80, 345.6),
#  (0.4, 80, 384.0),
#  (0.4, 100, 0.0),
#  (0.4, 100, 38.4),
#  (0.4, 100, 76.8),
#  (0.4, 100, 115.2),
#  (0.4, 100, 153.6),
#  (0.4, 100, 192.0),
#  (0.4, 100, 230.4),
#  (0.4, 100, 268.8),
#  (0.4, 100, 307.2),
#  (0.4, 100, 345.6),
#  (0.4, 100, 384.0),
#  (0.4, 120, 0.0),
#  (0.4, 120, 38.4),
#  (0.4, 120, 76.8),
#  (0.4, 120, 115.2),
#  (0.4, 120, 153.6),
#  (0.4, 120, 192.0),
#  (0.4, 120, 230.4),
#  (0.4, 120, 268.8),
#  (0.4, 120, 307.2),
#  (0.4, 120, 345.6),
#  (0.4, 120, 384.0),
#  (0.4, 140, 0.0),
#  (0.4, 140, 38.4),
#  (0.4, 140, 76.8),
#  (0.4, 140, 115.2),
#  (0.4, 140, 153.6),
#  (0.4, 140, 192.0),
#  (0.4, 140, 230.4),
#  (0.4, 140, 268.8),
#  (0.4, 140, 307.2),
#  (0.4, 140, 345.6),
#  (0.4, 140, 384.0),
#  (0.4, 160, 0.0),
#  (0.4, 160, 38.4),
#  (0.4, 160, 76.8),
#  (0.4, 160, 115.2),
#  (0.4, 160, 153.6),
#  (0.4, 160, 192.0),
#  (0.4, 160, 230.4),
#  (0.4, 160, 268.8),
#  (0.4, 160, 307.2),
#  (0.4, 160, 345.6),
#  (0.4, 160, 384.0),
#  (0.4, 180, 0.0),
#  (0.4, 180, 38.4),
#  (0.4, 180, 76.8),
#  (0.4, 180, 115.2),
#  (0.4, 180, 153.6),
#  (0.4, 180, 192.0),
#  (0.4, 180, 230.4),
#  (0.4, 180, 268.8),
#  (0.4, 180, 307.2),
#  (0.4, 180, 345.6),
#  (0.4, 180, 384.0),
#  (0.4, 200, 0.0),
#  (0.4, 200, 38.4),
#  (0.4, 200, 76.8),
#  (0.4, 200, 115.2),
#  (0.4, 200, 153.6),
#  (0.4, 200, 192.0),
#  (0.4, 200, 230.4),
#  (0.4, 200, 268.8),
#  (0.4, 200, 307.2),
#  (0.4, 200, 345.6),
#  (0.4, 200, 384.0),
#  (0.4, 220, 0.0),
#  (0.4, 220, 38.4),
#  (0.4, 220, 76.8),
#  (0.4, 220, 115.2),
#  (0.4, 220, 153.6),
#  (0.4, 220, 192.0),
#  (0.4, 220, 230.4),
#  (0.4, 220, 268.8),
#  (0.4, 220, 307.2),
#  (0.4, 220, 345.6),
#  (0.4, 220, 384.0),
#  (0.4, 240, 0.0),
#  (0.4, 240, 38.4),
#  (0.4, 240, 76.8),
#  (0.4, 240, 115.2),
#  (0.4, 240, 153.6),
#  (0.4, 240, 192.0),
#  (0.4, 240, 230.4),
#  (0.4, 240, 268.8),
#  (0.4, 240, 307.2),
#  (0.4, 240, 345.6),
#  (0.4, 240, 384.0),
#  (0.4, 260, 0.0),
#  (0.4, 260, 38.4),
#  (0.4, 260, 76.8),
#  (0.4, 260, 115.2),
#  (0.4, 260, 153.6),
#  (0.4, 260, 192.0),
#  (0.4, 260, 230.4),
#  (0.4, 260, 268.8),
#  (0.4, 260, 307.2),
#  (0.4, 260, 345.6),
#  (0.4, 260, 384.0),
#  (0.4, 280, 0.0),
#  (0.4, 280, 38.4),
#  (0.4, 280, 76.8),
#  (0.4, 280, 115.2),
#  (0.4, 280, 153.6),
#  (0.4, 280, 192.0),
#  (0.4, 280, 230.4),
#  (0.4, 280, 268.8),
#  (0.4, 280, 307.2),
#  (0.4, 280, 345.6),
#  (0.4, 280, 384.0),
#  (0.4, 300, 0.0),
#  (0.4, 300, 38.4),
#  (0.4, 300, 76.8),
#  (0.4, 300, 115.2),
#  (0.4, 300, 153.6),
#  (0.4, 300, 192.0),
#  (0.4, 300, 230.4),
#  (0.4, 300, 268.8),
#  (0.4, 300, 307.2),
#  (0.4, 300, 345.6),
#  (0.4, 300, 384.0),
#  (0.4, 320, 0.0),
#  (0.4, 320, 38.4),
#  (0.4, 320, 76.8),
#  (0.4, 320, 115.2),
#  (0.4, 320, 153.6),
#  (0.4, 320, 192.0),
#  (0.4, 320, 230.4),
#  (0.4, 320, 268.8),
#  (0.4, 320, 307.2),
#  (0.4, 320, 345.6),
#  (0.4, 320, 384.0),
#  (0.4, 340, 0.0),
#  (0.4, 340, 38.4),
#  (0.4, 340, 76.8),
#  (0.4, 340, 115.2),
#  (0.4, 340, 153.6),
#  (0.4, 340, 192.0),
#  (0.4, 340, 230.4),
#  (0.4, 340, 268.8),
#  (0.4, 340, 307.2),
#  (0.4, 340, 345.6),
#  (0.4, 340, 384.0),
#  (0.4, 360, 0.0),
#  (0.4, 360, 38.4),
#  (0.4, 360, 76.8),
#  (0.4, 360, 115.2),
#  (0.4, 360, 153.6),
#  (0.4, 360, 192.0),
#  (0.4, 360, 230.4),
#  (0.4, 360, 268.8),
#  (0.4, 360, 307.2),
#  (0.4, 360, 345.6),
#  (0.4, 360, 384.0),
#  (0.4, 380, 0.0),
#  (0.4, 380, 38.4),
#  (0.4, 380, 76.8),
#  (0.4, 380, 115.2),
#  (0.4, 380, 153.6),
#  (0.4, 380, 192.0),
#  (0.4, 380, 230.4),
#  (0.4, 380, 268.8),
#  (0.4, 380, 307.2),
#  (0.4, 380, 345.6),
#  (0.4, 380, 384.0),
#  (0.4, 400, 0.0),
#  (0.4, 400, 38.4),
#  (0.4, 400, 76.8),
#  (0.4, 400, 115.2),
#  (0.4, 400, 153.6),
#  (0.4, 400, 192.0),
#  (0.4, 400, 230.4),
#  (0.4, 400, 268.8),
#  (0.4, 400, 307.2),
#  (0.4, 400, 345.6),
#  (0.4, 400, 384.0),
#  (0.4, 420, 0.0),
#  (0.4, 420, 38.4),
#  (0.4, 420, 76.8),
#  (0.4, 420, 115.2),
#  (0.4, 420, 153.6),
#  (0.4, 420, 192.0),
#  (0.4, 420, 230.4),
#  (0.4, 420, 268.8),
#  (0.4, 420, 307.2),
#  (0.4, 420, 345.6),
#  (0.4, 420, 384.0),
#  (0.4, 440, 0.0),
#  (0.4, 440, 38.4),
#  (0.4, 440, 76.8),
#  (0.4, 440, 115.2),
#  (0.4, 440, 153.6),
#  (0.4, 440, 192.0),
#  (0.4, 440, 230.4),
#  (0.4, 440, 268.8),
#  (0.4, 440, 307.2),
#  (0.4, 440, 345.6),
#  (0.4, 440, 384.0),
#  (0.4, 460, 0.0),
#  (0.4, 460, 38.4),
#  (0.4, 460, 76.8),
#  (0.4, 460, 115.2),
#  (0.4, 460, 153.6),
#  (0.4, 460, 192.0),
#  (0.4, 460, 230.4),
#  (0.4, 460, 268.8),
#  (0.4, 460, 307.2),
#  (0.4, 460, 345.6),
#  (0.4, 460, 384.0),
#  (0.4, 480, 0.0),
#  (0.4, 480, 38.4),
#  (0.4, 480, 76.8),
#  (0.4, 480, 115.2),
#  (0.4, 480, 153.6),
#  (0.4, 480, 192.0),
#  (0.4, 480, 230.4),
#  (0.4, 480, 268.8),
#  (0.4, 480, 307.2),
#  (0.4, 480, 345.6),
#  (0.4, 480, 384.0),
#  (0.4, 500, 0.0),
#  (0.4, 500, 38.4),
#  (0.4, 500, 76.8),
#  (0.4, 500, 115.2),
#  (0.4, 500, 153.6),
#  (0.4, 500, 192.0),
#  (0.4, 500, 230.4),
#  (0.4, 500, 268.8),
#  (0.4, 500, 307.2),
#  (0.4, 500, 345.6),
#  (0.4, 500, 384.0),
#  (0.4, 680, 307.2),
#  (0.4, 680, 345.6),
#  (0.4, 680, 384.0),
#  (0.4, 700, 0.0),
#  (0.4, 700, 38.4),
#  (0.4, 700, 76.8),
#  (0.4, 700, 115.2),
#  (0.4, 700, 153.6),
#  (0.4, 700, 192.0),
#  (0.4, 700, 230.4),
#  (0.4, 700, 268.8),
#  (0.4, 700, 307.2),
#  (0.4, 700, 345.6),
#  (0.4, 700, 384.0),
#  (0.6, 0, 0.0),
#  (0.6, 0, 38.4),
#  (0.6, 0, 76.8),
#  (0.6, 0, 115.2),
#  (0.6, 0, 153.6),
#  (0.6, 0, 192.0),
#  (0.6, 0, 230.4),
#  (0.6, 0, 268.8),
#  (0.6, 0, 307.2),
#  (0.6, 0, 345.6),
#  (0.6, 0, 384.0),
#  (0.6, 20, 0.0),
#  (0.6, 20, 38.4),
#  (0.6, 20, 76.8),
#  (0.6, 20, 115.2),
#  (0.6, 20, 153.6),
#  (0.6, 20, 192.0),
#  (0.6, 20, 230.4),
#  (0.6, 20, 268.8),
#  (0.6, 20, 307.2),
#  (0.6, 20, 345.6),
#  (0.6, 20, 384.0),
#  (0.6, 40, 0.0),
#  (0.6, 40, 38.4),
#  (0.6, 40, 76.8),
#  (0.6, 40, 115.2),
#  (0.6, 40, 153.6),
#  (0.6, 40, 192.0),
#  (0.6, 40, 230.4),
#  (0.6, 40, 268.8),
#  (0.6, 40, 307.2),
#  (0.6, 40, 345.6),
#  (0.6, 40, 384.0),
#  (0.6, 60, 0.0),
#  (0.6, 60, 38.4),
#  (0.6, 60, 76.8),
#  (0.6, 60, 115.2),
#  (0.6, 60, 153.6),
#  (0.6, 60, 192.0),
#  (0.6, 60, 230.4),
#  (0.6, 60, 268.8),
#  (0.6, 60, 307.2),
#  (0.6, 60, 345.6),
#  (0.6, 60, 384.0),
#  (0.6, 80, 0.0),
#  (0.6, 80, 38.4),
#  (0.6, 80, 76.8),
#  (0.6, 80, 115.2),
#  (0.6, 80, 153.6),
#  (0.6, 80, 192.0),
#  (0.6, 80, 230.4),
#  (0.6, 80, 268.8),
#  (0.6, 80, 307.2),
#  (0.6, 80, 345.6),
#  (0.6, 80, 384.0),
#  (0.6, 100, 0.0),
#  (0.6, 100, 38.4),
#  (0.6, 100, 76.8),
#  (0.6, 100, 115.2),
#  (0.6, 100, 153.6),
#  (0.6, 100, 192.0),
#  (0.6, 100, 230.4),
#  (0.6, 100, 268.8),
#  (0.6, 100, 307.2),
#  (0.6, 100, 345.6),
#  (0.6, 100, 384.0),
#  (0.6, 120, 0.0),
#  (0.6, 120, 38.4),
#  (0.6, 120, 76.8),
#  (0.6, 120, 115.2),
#  (0.6, 120, 153.6),
#  (0.6, 120, 192.0),
#  (0.6, 120, 230.4),
#  (0.6, 120, 268.8),
#  (0.6, 120, 307.2),
#  (0.6, 120, 345.6),
#  (0.6, 120, 384.0),
#  (0.6, 140, 0.0),
#  (0.6, 140, 38.4),
#  (0.6, 140, 76.8),
#  (0.6, 140, 115.2),
#  (0.6, 140, 153.6),
#  (0.6, 140, 192.0),
#  (0.6, 320, 115.2),
#  (0.6, 320, 153.6),
#  (0.6, 320, 192.0),
#  (0.6, 320, 230.4),
#  (0.6, 320, 268.8),
#  (0.6, 320, 307.2),
#  (0.6, 320, 345.6),
#  (0.6, 320, 384.0),
#  (0.6, 340, 0.0),
#  (0.6, 340, 38.4),
#  (0.6, 340, 76.8),
#  (0.6, 340, 115.2),
#  (0.6, 340, 153.6),
#  (0.6, 340, 192.0),
#  (0.6, 340, 230.4),
#  (0.6, 340, 268.8),
#  (0.6, 340, 307.2),
#  (0.6, 340, 345.6),
#  (0.6, 340, 384.0),
#  (0.6, 360, 0.0),
#  (0.6, 360, 38.4),
#  (0.6, 360, 76.8),
#  (0.6, 360, 115.2),
#  (0.6, 360, 153.6),
#  (0.6, 360, 192.0),
#  (0.6, 360, 230.4),
#  (0.6, 360, 268.8),
#  (0.6, 360, 307.2),
#  (0.6, 360, 345.6),
#  ...]

# %%
# COMPUTING VALUE FUNCTION USING DYNAMIC PROGRAMMING
def policy_evaluation(policy, value_table, discount_factor, error_threshold=0.01, num_states=Number_of_discrete_states):
    print()
    new_value_table = value_table # init new value table to be filled in and returned
    converged = False # initially we have not found a converged value function for this policy
    k = 0 # sweep index
    while not converged: # until the value function converges
        print('sweep ', k)
        k += 1 # increment sweep counter
        worst_delta = 0 # difference between previous values and iterated values
        for state in keys_to_be_iterated: # loop over each state
            action = policy[state] # get the action according to current policy
            new_state, reward = transition(state, action) # use model to simulate next state and reward
         #check for errors if the state entry has not been created in value table
            new_val = reward + discount_factor * value_table[new_state] # compute new value
#             except:
#                 new_value_table[new_state] = 0 #when the above fails, new state is TERMINAL state, hence has value of 0
#                 new_val = reward #if error occurs, the new value will take just reward, with value of unexplored state being zero
#             print(new_val)
#             print(value_table[state])
            new_value_table[state] = new_val # update value table
            delta = abs(new_val - value_table[state]) # find the absolute diff between new val and old val for this state
#             print('delta:', delta)
            if delta > worst_delta: # is this state the one for which our value table is most wrong?
                worst_delta = delta # update worst error for this sweep
                print('worst_delta:', worst_delta)
        if worst_delta < error_threshold: # once the values stop changing
            converged = True # we have found the value function
            print('Converged on value function')
        value_table = new_value_table # update value table (took me ages to realise i was missing this line and debug )
    return value_table # return converged value table evaluated for this policy

# %%
# discount_factor = 0.9
# new_value_table = policy_evaluation(policy, value_table, discount_factor, error_threshold=0.01, num_states=Number_of_discrete_states)
# new_value_table

# %%
def policy_improvement(value_table, discount_factor): # set a greedy policy which will always be better than the previous
    new_policy = {} # initialise empty new policy to be filled and returned
    action_space = range(15) #  
    for state in keys_to_be_iterated: # loop over each state
        best_value = -float('inf') # initialise best value as negative infinity
        best_action = None # no best action found yet
        if (state[0] == 0.2) or (state[0] == 0.4):
            for action in range(2,15): # don't consider small additions of N
                try:
                    new_state, reward = transition(state, action) # use model to simulate next state and reward
                    value = reward + discount_factor * value_table[new_state] # update value of state
                except:
                    value = 0 #assign zero value to new states
                if value > best_value: # checking all actions, which gives this state the best value?
                    best_value = value # update best value
                    best_action = action # update best action found so far
        else:
            for action in action_space: # set the policy as greedy with respect to the value function
                try:
                    new_state, reward = transition(state, action) # use model to simulate next state and reward
                    value = reward + discount_factor * value_table[new_state] # update value of state
                except:
                    value = 0 #assign zero value to new states
                if value > best_value: # checking all actions, which gives this state the best value?
                    best_value = value # update best value
                    best_action = action # update best action found so far
        new_policy[state] = best_action # update new policy to take best action found when it sees this state
    return new_policy

# %%
def check_stable_policy(old_policy, new_policy):
    stable = True
    for state in keys_to_be_iterated:
        old_action = old_policy[state]
        new_action = new_policy[state]
        if new_action != old_action:
            stable = False
    return stable

# %%
# POLICY ITERATION ALGORITHM
def policy_iteration(discount_factor=0.9):
    value_table = initialise_value_table()
#     policy = initialise_policy()
    policy = initialise_deterministic_policy()
    policy_stable = False
    policy_idx = 0
    policy_library = []
    while not policy_stable: # until convergence
        
        # POLICY ITERATION
        print('Evaluating policy ', policy_idx)
        value_table = policy_evaluation(policy, value_table, discount_factor) # converge on value function
        
        # POLICY IMPROVEMENT
        print('Iterating policy ', policy_idx)
        new_policy = policy_improvement(value_table, discount_factor) # get greedy policy using converged value function
        
        # CHECK CONVERGENCE
        if check_stable_policy(policy, new_policy): # compare policies
            policy_stable = True # when they have the same greedy action for each state in the state space
            print('Policy now stable - optimal policy found')
            
        policy = new_policy # update policy
        
        policy_idx += 1
        
        policy_library += [policy]
        
        if policy_idx >= 100:
            break
    print('Optimal policy:', policy)
    return policy, policy_library
        
optimal_policy, policy_library = policy_iteration()
# Out:
# Evaluating policy  0
#
# sweep  0
# Converged on value function
# Iterating policy  0

# %%
value_table
# Out:
# {(0.2, 0, 0.0): 0.33738228055571795,
#  (0.2, 0, 38.4): 0.4996232276960296,
#  (0.2, 0, 76.8): 0.8092978048006854,
#  (0.2, 0, 115.2): 0.5583753801111581,
#  (0.2, 0, 153.6): 0.744696035844577,
#  (0.2, 0, 192.0): 0.4812048250845252,
#  (0.2, 0, 230.4): 0.7031419309991923,
#  (0.2, 0, 268.8): 0.040826955356750294,
#  (0.2, 0, 307.2): 0.6329508154762163,
#  (0.2, 0, 345.6): 0.1681745237670934,
#  (0.2, 0, 384.0): 0.6137670635245707,
#  (0.2, 0, 422.4): 0,
#  (0.2, 20, 0.0): 0.010942125930392343,
#  (0.2, 20, 38.4): 0.8252368981514783,
#  (0.2, 20, 76.8): 0.4313375074675715,
#  (0.2, 20, 115.2): 0.19176481189017747,
#  (0.2, 20, 153.6): 0.5803296683254452,
#  (0.2, 20, 192.0): 0.20321329538129862,
#  (0.2, 20, 230.4): 0.7875151060720407,
#  (0.2, 20, 268.8): 0.12739772435367014,
#  (0.2, 20, 307.2): 0.2018966919097248,
#  (0.2, 20, 345.6): 0.07890169941448955,
#  (0.2, 20, 384.0): 0.9284689726569554,
#  (0.2, 20, 422.4): 0,
#  (0.2, 40, 0.0): 0.8848004609835811,
#  (0.2, 40, 38.4): 0.9711801222398828,
#  (0.2, 40, 76.8): 0.36725581047392575,
#  (0.2, 40, 115.2): 0.02752371043214974,
#  (0.2, 40, 153.6): 0.779814094588219,
#  (0.2, 40, 192.0): 0.3907038800748823,
# f.close()

# %%
first_entry_in_library = policy_library[0]
for i in range(len(policy_library)):
    number_of_same_action = 0
    for state in keys_to_be_iterated:
        if policy_library[i][state] ==  first_entry_in_library[state]:
            number_of_same_action += 1
    print(i,'th policy','% same as final entry:', number_of_same_action/len(first_entry_in_library))
# Out:
# 0 th policy % same as final entry: 1.0
# 1 th policy % same as final entry: 0.2361111111111111
# 2 th policy % same as final entry: 0.24179292929292928
# 3 th policy % same as final entry: 0.2345328282828283
# 4 th policy % same as final entry: 0.2528409090909091
# 5 th policy % same as final entry: 0.24494949494949494
# 6 th policy % same as final entry: 0.25
# 7 th policy % same as final entry: 0.2730429292929293
# 8 th policy % same as final entry: 0.2471590909090909
# 9 th policy % same as final entry: 0.24210858585858586
# 10 th policy % same as final entry: 0.2380050505050505
# 11 th policy % same as final entry: 0.24526515151515152
# 12 th policy % same as final entry: 0.25315656565656564
# 13 th policy % same as final entry: 0.25063131313131315
# 14 th policy % same as final entry: 0.2563131313131313
# 15 th policy % same as final entry: 0.24431818181818182
# 16 th policy % same as final entry: 0.25978535353535354
# 17 th policy % same as final entry: 0.23958333333333334
# 18 th policy % same as final entry: 0.2465277777777778
# 19 th policy % same as final entry: 0.24337121212121213
# 20 th policy % same as final entry: 0.2730429292929293
# 21 th policy % same as final entry: 0.25757575757575757
# 22 th policy % same as final entry: 0.2588383838383838
# 23 th policy % same as final entry: 0.25946969696969696
# 24 th policy % same as final entry: 0.24936868686868688
# 25 th policy % same as final entry: 0.2503156565656566
# 26 th policy % same as final entry: 0.2534722222222222
# 27 th policy % same as final entry: 0.2455808080808081
# 28 th policy % same as final entry: 0.26073232323232326
# 29 th policy % same as final entry: 0.2316919191919192
# 30 th policy % same as final entry: 0.24842171717171718
# 31 th policy % same as final entry: 0.26704545454545453
# 32 th policy % same as final entry: 0.2601010101010101
# 33 th policy % same as final entry: 0.2515782828282828
# 34 th policy % same as final entry: 0.23011363636363635
# 35 th policy % same as final entry: 0.24368686868686867
# 36 th policy % same as final entry: 0.25946969696969696
# 37 th policy % same as final entry: 0.24431818181818182
# 38 th policy % same as final entry: 0.24589646464646464
# 39 th policy % same as final entry: 0.25978535353535354
# 40 th policy % same as final entry: 0.25
# 41 th policy % same as final entry: 0.24368686868686867
# 42 th policy % same as final entry: 0.25789141414141414
# 43 th policy % same as final entry: 0.24494949494949494
# 44 th policy % same as final entry: 0.2316919191919192
# 45 th policy % same as final entry: 0.24210858585858586
# 46 th policy % same as final entry: 0.2563131313131313
# 47 th policy % same as final entry: 0.26262626262626265
# 48 th policy % same as final entry: 0.2569444444444444
# 49 th policy % same as final entry: 0.23547979797979798
# 50 th policy % same as final entry: 0.2490530303030303
# 51 th policy % same as final entry: 0.25441919191919193
# 52 th policy % same as final entry: 0.25789141414141414
# 53 th policy % same as final entry: 0.24684343434343434
# 54 th policy % same as final entry: 0.2563131313131313
# 55 th policy % same as final entry: 0.257260101010101
# 56 th policy % same as final entry: 0.25410353535353536
# 57 th policy % same as final entry: 0.23106060606060605
# 58 th policy % same as final entry: 0.2537878787878788
# 59 th policy % same as final entry: 0.25126262626262624
# 60 th policy % same as final entry: 0.2623106060606061
# 61 th policy % same as final entry: 0.2518939393939394
# 62 th policy % same as final entry: 0.24526515151515152
# 63 th policy % same as final entry: 0.23863636363636365
# 64 th policy % same as final entry: 0.2689393939393939
# 65 th policy % same as final entry: 0.2481060606060606
# 66 th policy % same as final entry: 0.26136363636363635
# 67 th policy % same as final entry: 0.24873737373737373
# 68 th policy % same as final entry: 0.2528409090909091
# 69 th policy % same as final entry: 0.2591540404040404
# 70 th policy % same as final entry: 0.24621212121212122
# 71 th policy % same as final entry: 0.23327020202020202
# 72 th policy % same as final entry: 0.24526515151515152
# 73 th policy % same as final entry: 0.2465277777777778
# 74 th policy % same as final entry: 0.25252525252525254
# 75 th policy % same as final entry: 0.24368686868686867
# 76 th policy % same as final entry: 0.24053030303030304
# 77 th policy % same as final entry: 0.2503156565656566
# 78 th policy % same as final entry: 0.2588383838383838
# 79 th policy % same as final entry: 0.24779040404040403
# 80 th policy % same as final entry: 0.2528409090909091
# 81 th policy % same as final entry: 0.255050505050505
# 82 th policy % same as final entry: 0.25220959595959597
# 83 th policy % same as final entry: 0.2537878787878788
# 84 th policy % same as final entry: 0.2326388888888889
# 85 th policy % same as final entry: 0.24147727272727273
# 86 th policy % same as final entry: 0.2481060606060606
# 87 th policy % same as final entry: 0.24242424242424243
# 88 th policy % same as final entry: 0.24779040404040403
# 89 th policy % same as final entry: 0.24305555555555555
# 90 th policy % same as final entry: 0.24084595959595959
# 91 th policy % same as final entry: 0.2342171717171717
# 92 th policy % same as final entry: 0.26672979797979796
# 93 th policy % same as final entry: 0.2619949494949495
# 94 th policy % same as final entry: 0.24526515151515152
# 95 th policy % same as final entry: 0.2619949494949495
# 96 th policy % same as final entry: 0.2509469696969697
# 97 th policy % same as final entry: 0.25126262626262624
# 98 th policy % same as final entry: 0.2490530303030303
# 99 th policy % same as final entry: 0.24684343434343434
# 100 th policy % same as final entry: 0.2518939393939394
# 101 th policy % same as final entry: 0.23579545454545456
# 102 th policy % same as final entry: 0.23958333333333334
# 103 th policy % same as final entry: 0.24526515151515152
# 104 th policy % same as final entry: 0.2481060606060606
# 105 th policy % same as final entry: 0.2503156565656566
# 106 th policy % same as final entry: 0.2537878787878788
# 107 th policy % same as final entry: 0.255050505050505
# 108 th policy % same as final entry: 0.22506313131313133
# 109 th policy % same as final entry: 0.23327020202020202
# 110 th policy % same as final entry: 0.25599747474747475
# 111 th policy % same as final entry: 0.24431818181818182
# 112 th policy % same as final entry: 0.2588383838383838
# 113 th policy % same as final entry: 0.26294191919191917
# 114 th policy % same as final entry: 0.2528409090909091
# 115 th policy % same as final entry: 0.2582070707070707
# 116 th policy % same as final entry: 0.2556818181818182
# 117 th policy % same as final entry: 0.25441919191919193
# 118 th policy % same as final entry: 0.2481060606060606
# 119 th policy % same as final entry: 0.21843434343434343
# 120 th policy % same as final entry: 0.25978535353535354
# 121 th policy % same as final entry: 0.24873737373737373
# 122 th policy % same as final entry: 0.257260101010101
# 123 th policy % same as final entry: 0.2569444444444444
# 124 th policy % same as final entry: 0.24526515151515152
# 125 th policy % same as final entry: 0.26325757575757575
# 126 th policy % same as final entry: 0.255050505050505
# 127 th policy % same as final entry: 0.2518939393939394
# 128 th policy % same as final entry: 0.25410353535353536
# 129 th policy % same as final entry: 0.25757575757575757
# 130 th policy % same as final entry: 0.24621212121212122
# 131 th policy % same as final entry: 0.2515782828282828
# 132 th policy % same as final entry: 0.2623106060606061
# 133 th policy % same as final entry: 0.24116161616161616
# 134 th policy % same as final entry: 0.257260101010101
# 135 th policy % same as final entry: 0.2588383838383838
# 136 th policy % same as final entry: 0.2673611111111111
# 137 th policy % same as final entry: 0.2569444444444444
# 138 th policy % same as final entry: 0.23958333333333334
# 139 th policy % same as final entry: 0.2471590909090909
# 140 th policy % same as final entry: 0.24337121212121213
# 141 th policy % same as final entry: 0.25410353535353536
# 142 th policy % same as final entry: 0.22758838383838384
# 143 th policy % same as final entry: 0.2556818181818182
# 144 th policy % same as final entry: 0.23863636363636365
# 145 th policy % same as final entry: 0.24621212121212122
# 146 th policy % same as final entry: 0.24053030303030304
# 147 th policy % same as final entry: 0.25441919191919193
# 148 th policy % same as final entry: 0.24210858585858586
# 149 th policy % same as final entry: 0.255050505050505
# 150 th policy % same as final entry: 0.24242424242424243
# 151 th policy % same as final entry: 0.25
# 152 th policy % same as final entry: 0.2588383838383838
# 153 th policy % same as final entry: 0.2503156565656566
# 154 th policy % same as final entry: 0.2604166666666667
# 155 th policy % same as final entry: 0.2547348484848485
# 156 th policy % same as final entry: 0.25978535353535354
# 157 th policy % same as final entry: 0.24621212121212122
# 158 th policy % same as final entry: 0.24936868686868688
# 159 th policy % same as final entry: 0.24589646464646464
# 160 th policy % same as final entry: 0.2455808080808081
# 161 th policy % same as final entry: 0.24116161616161616
# 162 th policy % same as final entry: 0.24210858585858586
# 163 th policy % same as final entry: 0.26452020202020204
# 164 th policy % same as final entry: 0.24873737373737373
# 165 th policy % same as final entry: 0.24147727272727273
# 166 th policy % same as final entry: 0.2481060606060606
# 167 th policy % same as final entry: 0.2316919191919192
# 168 th policy % same as final entry: 0.25315656565656564
# 169 th policy % same as final entry: 0.2569444444444444
# 170 th policy % same as final entry: 0.24968434343434343
# 171 th policy % same as final entry: 0.26483585858585856
# 172 th policy % same as final entry: 0.2563131313131313
# 173 th policy % same as final entry: 0.26167929292929293
# 174 th policy % same as final entry: 0.24684343434343434
# 175 th policy % same as final entry: 0.2588383838383838
# 176 th policy % same as final entry: 0.2553661616161616
# 177 th policy % same as final entry: 0.26262626262626265
# 178 th policy % same as final entry: 0.2563131313131313
# 179 th policy % same as final entry: 0.25599747474747475
# 180 th policy % same as final entry: 0.24305555555555555
# 181 th policy % same as final entry: 0.24368686868686867
# 182 th policy % same as final entry: 0.25
# 183 th policy % same as final entry: 0.22758838383838384
# 184 th policy % same as final entry: 0.24305555555555555
# 185 th policy % same as final entry: 0.24400252525252525
# 186 th policy % same as final entry: 0.255050505050505
# 187 th policy % same as final entry: 0.26167929292929293
# 188 th policy % same as final entry: 0.2465277777777778
# 189 th policy % same as final entry: 0.24305555555555555
# 190 th policy % same as final entry: 0.24242424242424243
# 191 th policy % same as final entry: 0.24431818181818182
# 192 th policy % same as final entry: 0.2619949494949495
# 193 th policy % same as final entry: 0.2398989898989899
# 194 th policy % same as final entry: 0.24368686868686867
# 195 th policy % same as final entry: 0.2591540404040404
# 196 th policy % same as final entry: 0.24621212121212122
# 197 th policy % same as final entry: 0.2547348484848485
# 198 th policy % same as final entry: 0.27051767676767674
# 199 th policy % same as final entry: 0.26136363636363635

# %% [markdown]
# # Evaluation

# %%
#Score every policy in the library
scores_of_policy_library = []
ith_iteration = []

for j in range(len(policy_library)):
    policy_entry = policy_library[j]
    my_policy += [action]
    x_data += [state[0]]
    N_data += [state[1]]
    t_data += [state[2]]
    sum_score = 0 #reset counter
    score = 0
    
    for episode in range(1000): #run 1000 episodes and take average score
        state = (0.2,160,0) #set initial state
        
        for step in range(10): #take ten steps in each episode
            action = policy_entry[state] #get action from policy
            state = transition(state, action)[0] #evolve current state and get new state
            my_policy += [action]
            x_data += [state[0]]
            N_data += [state[1]]
            t_data += [state[2]]
            
        score = 100*x_data[-1] - N_data[-1] #calculate score from final state
        sum_score += score #add score to sum
    score = sum_score/1000 #take average
    
    scores_of_policy_library += [score] #store score
    ith_iteration += [j+1] #store jth iteration
    print(j+1,'th policy in library:', score)
# Out:
# 1 th policy in library: 64.86
# 2 th policy in library: 57.04
# 3 th policy in library: 48.9
# 4 th policy in library: 47.18
# 5 th policy in library: 61.02
# 6 th policy in library: 50.04
# 7 th policy in library: 54.4
# 8 th policy in library: 43.14
# 9 th policy in library: 39.32
# 10 th policy in library: 54.92
# 11 th policy in library: 47.94
# 12 th policy in library: 35.12
# 13 th policy in library: 55.26
# 14 th policy in library: 66.82
# 15 th policy in library: 43.6
# 16 th policy in library: 36.78
# 17 th policy in library: 55.96
# 18 th policy in library: 37.28
# 19 th policy in library: 58.1
# 20 th policy in library: 47.88
# 21 th policy in library: 40.36
# 22 th policy in library: 50.72
# 23 th policy in library: 52.44
# 24 th policy in library: 48.86
# 25 th policy in library: 33.44
# 26 th policy in library: 68.36
# 27 th policy in library: 56.52
# 28 th policy in library: 54.68
# 29 th policy in library: 47.24
# 30 th policy in library: 38.78
# 31 th policy in library: 49.34
# 32 th policy in library: 45.38
# 33 th policy in library: 45.74
# 34 th policy in library: 54.08
# 35 th policy in library: 48.7
# 36 th policy in library: 65.4
# 37 th policy in library: 34.52
# 38 th policy in library: 59.66
# 39 th policy in library: 30.24
# 40 th policy in library: 63.34
# 41 th policy in library: 62.36
# 42 th policy in library: 58.22
# 43 th policy in library: 66.72
# 44 th policy in library: 54.02
# 45 th policy in library: 42.58
# 46 th policy in library: 57.34
# 47 th policy in library: 59.16
# 48 th policy in library: 60.06
# 49 th policy in library: 49.96
# 50 th policy in library: 45.48
# 51 th policy in library: 56.24
# 52 th policy in library: 31.42
# 53 th policy in library: 53.6
# 54 th policy in library: 59.46
# 55 th policy in library: 55.46
# 56 th policy in library: 37.82
# 57 th policy in library: 51.1
# 58 th policy in library: 44.92
# 59 th policy in library: 41.76
# 60 th policy in library: 63.42
# 61 th policy in library: 53.92
# 62 th policy in library: 46.02
# 63 th policy in library: 45.0
# 64 th policy in library: 55.84
# 65 th policy in library: 32.9
# 66 th policy in library: 58.02
# 67 th policy in library: 46.34
# 68 th policy in library: 50.92
# 69 th policy in library: 37.38
# 70 th policy in library: 54.08
# 71 th policy in library: 60.84
# 72 th policy in library: 55.38
# 73 th policy in library: 51.48
# 74 th policy in library: 42.46
# 75 th policy in library: 51.88
# 76 th policy in library: 50.22
# 77 th policy in library: 37.38
# 78 th policy in library: 49.04
# 79 th policy in library: 54.92
# 80 th policy in library: 48.22
# 81 th policy in library: 51.66
# 82 th policy in library: 58.48
# 83 th policy in library: 41.88
# 84 th policy in library: 42.94
# 85 th policy in library: 44.24
# 86 th policy in library: 52.02
# 87 th policy in library: 55.34
# 88 th policy in library: 51.96
# 89 th policy in library: 57.6
# 90 th policy in library: 51.06
# 91 th policy in library: 55.8
# 92 th policy in library: 50.6
# 93 th policy in library: 53.48
# 94 th policy in library: 53.84
# 95 th policy in library: 50.78
# 96 th policy in library: 32.84
# 97 th policy in library: 54.84
# 98 th policy in library: 53.12
# 99 th policy in library: 36.48
# 100 th policy in library: 58.0
# 101 th policy in library: 54.12
# 102 th policy in library: 40.26
# 103 th policy in library: 42.2
# 104 th policy in library: 45.84
# 105 th policy in library: 45.82
# 106 th policy in library: 55.72
# 107 th policy in library: 59.84
# 108 th policy in library: 36.26
# 109 th policy in library: 63.92
# 110 th policy in library: 57.36
# 111 th policy in library: 50.22
# 112 th policy in library: 38.38
# 113 th policy in library: 53.3
# 114 th policy in library: 57.84
# 115 th policy in library: 50.22
# 116 th policy in library: 41.68
# 117 th policy in library: 46.86
# 118 th policy in library: 53.12
# 119 th policy in library: 47.58
# 120 th policy in library: 53.88
# 121 th policy in library: 60.42
# 122 th policy in library: 38.92
# 123 th policy in library: 57.32
# 124 th policy in library: 47.62
# 125 th policy in library: 44.52
# 126 th policy in library: 56.32
# 127 th policy in library: 40.42
# 128 th policy in library: 49.56
# 129 th policy in library: 61.78
# 130 th policy in library: 36.02
# 131 th policy in library: 58.0
# 132 th policy in library: 62.28
# 133 th policy in library: 56.32
# 134 th policy in library: 58.7
# 135 th policy in library: 50.1
# 136 th policy in library: 53.98
# 137 th policy in library: 50.16
# 138 th policy in library: 54.86
# 139 th policy in library: 51.1
# 140 th policy in library: 39.34
# 141 th policy in library: 57.5
# 142 th policy in library: 49.2
# 143 th policy in library: 51.06
# 144 th policy in library: 63.1
# 145 th policy in library: 46.0
# 146 th policy in library: 63.1
# 147 th policy in library: 52.28
# 148 th policy in library: 49.44
# 149 th policy in library: 42.3
# 150 th policy in library: 56.24
# 151 th policy in library: 64.8
# 152 th policy in library: 65.34
# 153 th policy in library: 51.72
# 154 th policy in library: 40.28
# 155 th policy in library: 53.24
# 156 th policy in library: 51.26
# 157 th policy in library: 51.42
# 158 th policy in library: 54.1
# 159 th policy in library: 35.5
# 160 th policy in library: 37.14
# 161 th policy in library: 53.34
# 162 th policy in library: 43.34
# 163 th policy in library: 46.46
# 164 th policy in library: 41.0
# 165 th policy in library: 39.72
# 166 th policy in library: 52.7
# 167 th policy in library: 51.6
# 168 th policy in library: 55.28
# 169 th policy in library: 57.9
# 170 th policy in library: 68.98
# 171 th policy in library: 49.8
# 172 th policy in library: 41.82
# 173 th policy in library: 58.3
# 174 th policy in library: 57.44
# 175 th policy in library: 51.42
# 176 th policy in library: 52.56
# 177 th policy in library: 27.58
# 178 th policy in library: 61.22
# 179 th policy in library: 49.88
# 180 th policy in library: 48.72
# 181 th policy in library: 38.1
# 182 th policy in library: 65.52
# 183 th policy in library: 41.14
# 184 th policy in library: 54.9
# 185 th policy in library: 47.74
# 186 th policy in library: 68.18
# 187 th policy in library: 50.88
# 188 th policy in library: 42.12
# 189 th policy in library: 56.96
# 190 th policy in library: 57.98
# 191 th policy in library: 44.96
# 192 th policy in library: 48.56
# 193 th policy in library: 66.74
# 194 th policy in library: 46.02
# 195 th policy in library: 46.86
# 196 th policy in library: 45.82
# 197 th policy in library: 37.8
# 198 th policy in library: 59.62
# 199 th policy in library: 42.8
# 200 th policy in library: 52.08

# %%
#plot score of policy library 
plt.plot(ith_iteration,scores_of_policy_library)
print('Index of best policy in library:', argmax(scores_of_policy_library))
# Out:
# Index of best policy in library: 169

# %%
# evaluate random policy
random_policy = initialise_deterministic_policy()
sum_score = 0
score = 0
for episode in range(1000): #run 1000 episodes and take average score
    state = (0.2,160,0) #set initial state
        
    for step in range(10): #take ten steps in each episode
        action = random_policy[state] #get action from policy
        state = transition(state, action)[0] #evolve current state and get new state
        my_policy += [action]
        x_data += [state[0]]
        N_data += [state[1]]
        t_data += [state[2]]
            
    score = 100*x_data[-1] - N_data[-1] #calculate score from final state
    sum_score += score #add score to sum
score = sum_score/1000 #take average
    
print('Random policy:', score)
# Out:
# Random policy: -0.98

# %%
policy_to_be_plotted = policy_library[169] #choose a particular policy from library
state = (0.2,160,0) #initial state
x_data = [state[0]] #store initial data
N_data = [state[1]]
t_data = [state[2]]
my_policy = []
for i in range(10): #take ten steps
        action = policy_to_be_plotted[state]
        state = transition(state, action)[0]
        my_policy += [action]
        x_data += [state[0]]
        N_data += [state[1]]
        t_data += [state[2]]
print('Current policy:', my_policy)
print('Concentration of x:', x_data)
print('Concentration of N:', N_data)
print('')
score = 100*x_data[-1] - N_data[-1]
print('Score:', score)
def plot(t_data, x_data, N_data):
    plt.figure()
    plt.plot(t_data, x_data, label = 'x')
    plt.legend()
    plt.figure()
    plt.plot(t_data, N_data, label = 'N')
    plt.legend()
    score = 100*x_data[-1] - N_data[-1]
plot(t_data, x_data, N_data)
# Out:
# Current policy: [8, 2, 0, 0, 1, 9, 4, 13, 5, 0]
# Concentration of x: [0.2, 0.4, 0.6, 0.6, 0.6, 0.4, 0.4, 0.4, 0.6, 0.8, 0.8]
# Concentration of N: [160, 220.0, 100.0, 40.0, 20.0, 20.0, 100.0, 100.0, 200.0, 100.0, 0.0]
#
# Score: 80.0
